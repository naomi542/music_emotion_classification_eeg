# %% [markdown]
# The following code blocks have been sourced or adapted from
#
# [10] T. M. Ngo, “tuengominh/deap-eeg-classification.” Apr. 12, 2023. Accessed: Apr. 16, 2023. [Online]. Available: https://github.com/tuengominh/deap-eeg-classification/blob/b7c720e9ea1c37241b2b336d33d1d9830c17a8bf/eeg_based_emotion_classification.ipynb

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import os
import time
import pickle
import pandas as pd
import numpy as np

from scipy import signal
from scipy.signal import welch
from scipy.integrate import simps
from scipy.stats import f_oneway

#!pip install scikit-learn==0.20.3
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn import model_selection
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import itertools
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_auc_score

# !pip install mne==0.22.0
import mne
from mne.preprocessing import (ICA, create_eog_epochs, create_ecg_epochs, corrmap)
from mne.time_frequency import psd_welch
from mne.decoding import cross_val_multiscore

# !pip install fooof
from fooof import FOOOFGroup
from fooof.bands import Bands
from fooof.analysis import get_band_peak_fg
from fooof.plts.spectra import plot_spectrum

import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
# %matplotlib inline
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: mne==0.22.0 in /usr/local/lib/python3.9/dist-packages (0.22.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.9/dist-packages (from mne==0.22.0) (1.22.4)
# Requirement already satisfied: scipy>=0.17.1 in /usr/local/lib/python3.9/dist-packages (from mne==0.22.0) (1.10.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fooof in /usr/local/lib/python3.9/dist-packages (1.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from fooof) (1.22.4)
# Requirement already satisfied: scipy>=0.19.0 in /usr/local/lib/python3.9/dist-packages (from fooof) (1.10.1)

# %% [markdown]
# ## Load Dataset

# %%
sohas_base_path = '/content/gdrive/MyDrive/BME 4B/SYDE 544/SYDE544 - Project/DEAP Dataset/'
aarzoos_base_path = '/content/gdrive/MyDrive/4B/SYDE544/SYDE544 - Project (1)/DEAP Dataset/'
elizabeths_base_path = '/content/gdrive/MyDrive/SYDE 544/SYDE544- Project/DEAP Dataset/'
# base_path = sohas_base_path
# base_path = aarzoos_base_path
base_path = elizabeths_base_path
dat_files_path = os.path.join(base_path, 'data_preprocessed_python')
print(dat_files_path)
# Out:
# /content/gdrive/MyDrive/SYDE 544/SYDE544- Project/DEAP Dataset/data_preprocessed_python

# %%
# Function to load data from each participant file
def read_eeg_signal_from_file(filename):
    x = pickle._Unpickler(open(filename, 'rb'))
    x.encoding = 'latin1'
    p = x.load()
    return p

# %%
# 32x40 = 1280 trials for 32 participants
# 128 Hz x 63 seconds (60s stimulus + 3s baseline?) = 8064 samples
labels = []
data = []

for sub_dat_file in os.listdir(dat_files_path):
  # print(sub_dat_file)
  filename = os.path.join(dat_files_path, sub_dat_file)
  trial = read_eeg_signal_from_file(filename)
  labels.append(trial['labels'])
  data.append(trial['data'])

# Re-shape arrays into desired shapes
# Order is in order of video ID (not in which way they were presented to the participant)
labels = np.array(labels)
labels = labels.flatten()
labels = labels.reshape(1280, 4)

data = np.array(data)
data = data.flatten()
data = data.reshape(1280, 40, 8064)

# %%
# Double-check the new arrays
print("Labels: ", labels.shape) # trial x label
print("Data: ", data.shape) # trial x channel x data
# Out:
# Labels:  (1280, 4)
# Data:  (1280, 40, 8064)

# %%
# Only extract Liking ratings
df_label_ratings = pd.DataFrame({'Valence': labels[:,0]})
# print(df_label_ratings.head())
# print(df_label_ratings.describe())

# %%
# Function to check if each trial has positive or negative valence
def positive_valence(trial):
    return 1 if labels[trial,0] >= np.median(labels[:,0]) else 0 

# Convert valence to binary 0 (low), 1 (high)
valence_labels_encoded = []
for i in range (len(labels)):
  valence_labels_encoded.append(positive_valence(i))
valence_labels_encoded = np.reshape(valence_labels_encoded, (1280))

# %% [markdown]
# ## EEG Data
#
# https://www.researchgate.net/figure/Comparison-of-electrode-placement-between-MUSE-and-the-international-10-20-system-a_fig2_352019337
# We'll use
# * AF7 --> AF3 (channel 2)
# * AF8 --> AF4 (channel 18)
# * TP9 --> T7 (channel 8)
# * TP10 --> T8 (channel 26)

# %%
eeg_channels = np.array(["Fp1", "AF3", "F3", "F7", "FC5", "FC1", "C3", "T7", "CP5", "CP1", "P3", "P7", "PO3", "O1", "Oz", "Pz", "Fp2", "AF4", "Fz", "F4", "F8", "FC6", "FC2", "Cz", "C4", "T8", "CP6", "CP2", "P4", "P8", "PO4", "O2"])
peripheral_channels = np.array(["hEOG", "vEOG", "zEMG", "tEMG", "GSR", "Respiration belt", "Plethysmograph", "Temperature"])

# %%
# params
fs = 128
num_desired_channels = 4
# num_desired_channels = len(eeg_channels)
n_samples = fs * 30

# Extract our desired channels
# Also segment the middle 30s
# Taking t_start = 3s + 15s to t_end  = t_start + 30s 
eeg_data = []

# for middle 30 s
# t_start_seg = (fs * (3 + 15)) - 1
# t_end_seg = t_start_seg + (fs * 30)

# for full 60s
t_start_seg = (fs * 3) - 1
t_end_seg = t_start_seg + (fs * 60)


for i in range (len(data)):
  # AF3 (channel 2)
  eeg_data.append(data[i,1,t_start_seg:t_end_seg])

  # T7 (channel 8)
  eeg_data.append(data[i,7,t_start_seg:t_end_seg])

  # AF4 (channel 18)
  eeg_data.append(data[i,17,t_start_seg:t_end_seg])

  # T8 (channel 26)
  eeg_data.append(data[i,25,t_start_seg:t_end_seg])

# # Testing with using all EEG channels to see baseline accuracy 
# for i in range (len(data)):
#   for j in range (len(eeg_channels)):
#     eeg_data.append(data[i, j, t_start_seg:t_end_seg])

eeg_data = np.reshape(eeg_data, (len(data), num_desired_channels, n_samples))
print(eeg_data.shape)
# Out:
# (1280, 32, 3840)

# %% [markdown]
# ## Test, train split

# %%
# Split the data into training/testing sets
def split_train_test(x, y):
  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=42)
  return x_train, x_test, y_train, y_test

# %%
x_train, x_test, y_train, y_test = split_train_test(eeg_data, valence_labels_encoded)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (896, 32, 3840)
# (384, 32, 3840)
# (896,)
# (384,)

# %% [markdown]
# # Open Source EEG Model Implementations
#
# The following code block implements the opensource code provided by Lawhern, et al. [11, 12, 13]. Code source: https://github.com/vlawhern/arl-eegmodels. Please see the attached License.txt file that was submitted in the Learn DropBox.
#
# [11] V. J. Lawhern, A. J. Solon, N. R. Waytowich, S. M. Gordon, C. P. Hung, and B. J. Lance, “EEGNet: a compact convolutional neural network for EEG-based brain–computer interfaces,” J. Neural Eng., vol. 15, no. 5, p. 056013, Oct. 2018, doi: 10.1088/1741-2552/aace8c.
#
# [12] vlawhern, “arl-eegmodels.” Apr. 04, 2023. Accessed: Apr. 05, 2023. [Online]. Available: https://github.com/vlawhern/arl-eegmodels
#
# [13] R. T. Schirrmeister et al., “Deep learning with convolutional neural networks for EEG decoding and visualization,” Human Brain Mapping, vol. 38, no. 11, pp. 5391–5420, 2017, doi: 10.1002/hbm.23730.

# %%
"""
 ARL_EEGModels - A collection of Convolutional Neural Network models for EEG
 Signal Processing and Classification, using Keras and Tensorflow

 Requirements:
    (1) tensorflow == 2.X (as of this writing, 2.0 - 2.3 have been verified
        as working)
 
 To run the EEG/MEG ERP classification sample script, you will also need

    (4) mne >= 0.17.1
    (5) PyRiemann >= 0.2.5
    (6) scikit-learn >= 0.20.1
    (7) matplotlib >= 2.2.3
    
 To use:
    
    (1) Place this file in the PYTHONPATH variable in your IDE (i.e.: Spyder)
    (2) Import the model as
        
        from EEGModels import EEGNet    
        
        model = EEGNet(nb_classes = ..., Chans = ..., Samples = ...)
        
    (3) Then compile and fit the model
    
        model.compile(loss = ..., optimizer = ..., metrics = ...)
        fitted    = model.fit(...)
        predicted = model.predict(...)

 Portions of this project are works of the United States Government and are not
 subject to domestic copyright protection under 17 USC Sec. 105.  Those 
 portions are released world-wide under the terms of the Creative Commons Zero 
 1.0 (CC0) license.  
 
 Other portions of this project are subject to domestic copyright protection 
 under 17 USC Sec. 105.  Those portions are licensed under the Apache 2.0 
 license.  The complete text of the license governing this material is in 
 the file labeled LICENSE.TXT that is a part of this project's official 
 distribution. 
"""

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.constraints import max_norm
from tensorflow.keras import backend as K


def EEGNet(nb_classes, Chans = 64, Samples = 128, 
             dropoutRate = 0.5, kernLength = 64, F1 = 8, 
             D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout'):
    """ Keras Implementation of EEGNet
    http://iopscience.iop.org/article/10.1088/1741-2552/aace8c/meta

    Note that this implements the newest version of EEGNet and NOT the earlier
    version (version v1 and v2 on arxiv). We strongly recommend using this
    architecture as it performs much better and has nicer properties than
    our earlier version. For example:
        
        1. Depthwise Convolutions to learn spatial filters within a 
        temporal convolution. The use of the depth_multiplier option maps 
        exactly to the number of spatial filters learned within a temporal
        filter. This matches the setup of algorithms like FBCSP which learn 
        spatial filters within each filter in a filter-bank. This also limits 
        the number of free parameters to fit when compared to a fully-connected
        convolution. 
        
        2. Separable Convolutions to learn how to optimally combine spatial
        filters across temporal bands. Separable Convolutions are Depthwise
        Convolutions followed by (1x1) Pointwise Convolutions. 
        
    
    While the original paper used Dropout, we found that SpatialDropout2D 
    sometimes produced slightly better results for classification of ERP 
    signals. However, SpatialDropout2D significantly reduced performance 
    on the Oscillatory dataset (SMR, BCI-IV Dataset 2A). We recommend using
    the default Dropout in most cases.
        
    Assumes the input signal is sampled at 128Hz. If you want to use this model
    for any other sampling rate you will need to modify the lengths of temporal
    kernels and average pooling size in blocks 1 and 2 as needed (double the 
    kernel lengths for double the sampling rate, etc). Note that we haven't 
    tested the model performance with this rule so this may not work well. 
    
    The model with default parameters gives the EEGNet-8,2 model as discussed
    in the paper. This model should do pretty well in general, although it is
	advised to do some model searching to get optimal performance on your
	particular dataset.

    We set F2 = F1 * D (number of input filters = number of output filters) for
    the SeparableConv2D layer. We haven't extensively tested other values of this
    parameter (say, F2 < F1 * D for compressed learning, and F2 > F1 * D for
    overcomplete). We believe the main parameters to focus on are F1 and D. 

    Inputs:
        
      nb_classes      : int, number of classes to classify
      Chans, Samples  : number of channels and time points in the EEG data
      dropoutRate     : dropout fraction
      kernLength      : length of temporal convolution in first layer. We found
                        that setting this to be half the sampling rate worked
                        well in practice. For the SMR dataset in particular
                        since the data was high-passed at 4Hz we used a kernel
                        length of 32.     
      F1, F2          : number of temporal filters (F1) and number of pointwise
                        filters (F2) to learn. Default: F1 = 8, F2 = F1 * D. 
      D               : number of spatial filters to learn within each temporal
                        convolution. Default: D = 2
      dropoutType     : Either SpatialDropout2D or Dropout, passed as a string.

    """
    
    if dropoutType == 'SpatialDropout2D':
        dropoutType = SpatialDropout2D
    elif dropoutType == 'Dropout':
        dropoutType = Dropout
    else:
        raise ValueError('dropoutType must be one of SpatialDropout2D '
                         'or Dropout, passed as a string.')
    
    input1   = Input(shape = (Chans, Samples, 1))

    ##################################################################
    block1       = Conv2D(F1, (1, kernLength), padding = 'same',
                                   input_shape = (Chans, Samples, 1),
                                   use_bias = False)(input1)
    block1       = BatchNormalization()(block1)
    block1       = DepthwiseConv2D((Chans, 1), use_bias = False, 
                                   depth_multiplier = D,
                                   depthwise_constraint = max_norm(1.))(block1)
    block1       = BatchNormalization()(block1)
    block1       = Activation('elu')(block1)
    block1       = AveragePooling2D((1, 4))(block1)
    block1       = dropoutType(dropoutRate)(block1)
    
    block2       = SeparableConv2D(F2, (1, 16),
                                   use_bias = False, padding = 'same')(block1)
    block2       = BatchNormalization()(block2)
    block2       = Activation('elu')(block2)
    block2       = AveragePooling2D((1, 8))(block2)
    block2       = dropoutType(dropoutRate)(block2)
        
    flatten      = Flatten(name = 'flatten')(block2)
    
    dense        = Dense(nb_classes, name = 'dense', 
                         kernel_constraint = max_norm(norm_rate))(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)
    
    return Model(inputs=input1, outputs=softmax)




def EEGNet_SSVEP(nb_classes = 12, Chans = 8, Samples = 256, 
             dropoutRate = 0.5, kernLength = 256, F1 = 96, 
             D = 1, F2 = 96, dropoutType = 'Dropout'):
    """ SSVEP Variant of EEGNet, as used in [1]. 

    Inputs:
        
      nb_classes      : int, number of classes to classify
      Chans, Samples  : number of channels and time points in the EEG data
      dropoutRate     : dropout fraction
      kernLength      : length of temporal convolution in first layer
      F1, F2          : number of temporal filters (F1) and number of pointwise
                        filters (F2) to learn. 
      D               : number of spatial filters to learn within each temporal
                        convolution.
      dropoutType     : Either SpatialDropout2D or Dropout, passed as a string.
      
      
    [1]. Waytowich, N. et. al. (2018). Compact Convolutional Neural Networks
    for Classification of Asynchronous Steady-State Visual Evoked Potentials.
    Journal of Neural Engineering vol. 15(6). 
    http://iopscience.iop.org/article/10.1088/1741-2552/aae5d8

    """
    
    if dropoutType == 'SpatialDropout2D':
        dropoutType = SpatialDropout2D
    elif dropoutType == 'Dropout':
        dropoutType = Dropout
    else:
        raise ValueError('dropoutType must be one of SpatialDropout2D '
                         'or Dropout, passed as a string.')
    
    input1   = Input(shape = (Chans, Samples, 1))

    ##################################################################
    block1       = Conv2D(F1, (1, kernLength), padding = 'same',
                                   input_shape = (Chans, Samples, 1),
                                   use_bias = False)(input1)
    block1       = BatchNormalization()(block1)
    block1       = DepthwiseConv2D((Chans, 1), use_bias = False, 
                                   depth_multiplier = D,
                                   depthwise_constraint = max_norm(1.))(block1)
    block1       = BatchNormalization()(block1)
    block1       = Activation('elu')(block1)
    block1       = AveragePooling2D((1, 4))(block1)
    block1       = dropoutType(dropoutRate)(block1)
    
    block2       = SeparableConv2D(F2, (1, 16),
                                   use_bias = False, padding = 'same')(block1)
    block2       = BatchNormalization()(block2)
    block2       = Activation('elu')(block2)
    block2       = AveragePooling2D((1, 8))(block2)
    block2       = dropoutType(dropoutRate)(block2)
        
    flatten      = Flatten(name = 'flatten')(block2)
    
    dense        = Dense(nb_classes, name = 'dense')(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)
    
    return Model(inputs=input1, outputs=softmax)



def EEGNet_old(nb_classes, Chans = 64, Samples = 128, regRate = 0.0001,
           dropoutRate = 0.25, kernels = [(2, 32), (8, 4)], strides = (2, 4)):
    """ Keras Implementation of EEGNet_v1 (https://arxiv.org/abs/1611.08024v2)

    This model is the original EEGNet model proposed on arxiv
            https://arxiv.org/abs/1611.08024v2
    
    with a few modifications: we use striding instead of max-pooling as this 
    helped slightly in classification performance while also providing a 
    computational speed-up. 
    
    Note that we no longer recommend the use of this architecture, as the new
    version of EEGNet performs much better overall and has nicer properties.
    
    Inputs:
        
        nb_classes     : total number of final categories
        Chans, Samples : number of EEG channels and samples, respectively
        regRate        : regularization rate for L1 and L2 regularizations
        dropoutRate    : dropout fraction
        kernels        : the 2nd and 3rd layer kernel dimensions (default is 
                         the [2, 32] x [8, 4] configuration)
        strides        : the stride size (note that this replaces the max-pool
                         used in the original paper)
    
    """

    # start the model
    input_main   = Input((Chans, Samples))
    layer1       = Conv2D(16, (Chans, 1), input_shape=(Chans, Samples, 1),
                                 kernel_regularizer = l1_l2(l1=regRate, l2=regRate))(input_main)
    layer1       = BatchNormalization()(layer1)
    layer1       = Activation('elu')(layer1)
    layer1       = Dropout(dropoutRate)(layer1)
    
    permute_dims = 2, 1, 3
    permute1     = Permute(permute_dims)(layer1)
    
    layer2       = Conv2D(4, kernels[0], padding = 'same', 
                            kernel_regularizer=l1_l2(l1=0.0, l2=regRate),
                            strides = strides)(permute1)
    layer2       = BatchNormalization()(layer2)
    layer2       = Activation('elu')(layer2)
    layer2       = Dropout(dropoutRate)(layer2)
    
    layer3       = Conv2D(4, kernels[1], padding = 'same',
                            kernel_regularizer=l1_l2(l1=0.0, l2=regRate),
                            strides = strides)(layer2)
    layer3       = BatchNormalization()(layer3)
    layer3       = Activation('elu')(layer3)
    layer3       = Dropout(dropoutRate)(layer3)
    
    flatten      = Flatten(name = 'flatten')(layer3)
    
    dense        = Dense(nb_classes, name = 'dense')(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)
    
    return Model(inputs=input_main, outputs=softmax)



def DeepConvNet(nb_classes, Chans = 64, Samples = 256,
                dropoutRate = 0.5):
    """ Keras implementation of the Deep Convolutional Network as described in
    Schirrmeister et. al. (2017), Human Brain Mapping.
    
    This implementation assumes the input is a 2-second EEG signal sampled at 
    128Hz, as opposed to signals sampled at 250Hz as described in the original
    paper. We also perform temporal convolutions of length (1, 5) as opposed
    to (1, 10) due to this sampling rate difference. 
    
    Note that we use the max_norm constraint on all convolutional layers, as 
    well as the classification layer. We also change the defaults for the
    BatchNormalization layer. We used this based on a personal communication 
    with the original authors.
    
                      ours        original paper
    pool_size        1, 2        1, 3
    strides          1, 2        1, 3
    conv filters     1, 5        1, 10
    
    Note that this implementation has not been verified by the original 
    authors. 
    
    """

    # start the model
    input_main   = Input((Chans, Samples, 1))
    block1       = Conv2D(25, (1, 5), 
                                 input_shape=(Chans, Samples, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(input_main)
    block1       = Conv2D(25, (Chans, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block1       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block1)
    block1       = Activation('elu')(block1)
    block1       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block1)
    block1       = Dropout(dropoutRate)(block1)
  
    block2       = Conv2D(50, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block2       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block2)
    block2       = Activation('elu')(block2)
    block2       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block2)
    block2       = Dropout(dropoutRate)(block2)
    
    block3       = Conv2D(100, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block2)
    block3       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block3)
    block3       = Activation('elu')(block3)
    block3       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block3)
    block3       = Dropout(dropoutRate)(block3)
    
    block4       = Conv2D(200, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block3)
    block4       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block4)
    block4       = Activation('elu')(block4)
    block4       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block4)
    block4       = Dropout(dropoutRate)(block4)
    
    flatten      = Flatten()(block4)
    
    dense        = Dense(nb_classes, kernel_constraint = max_norm(0.5))(flatten)
    softmax      = Activation('softmax')(dense)
    
    return Model(inputs=input_main, outputs=softmax)


# need these for ShallowConvNet
def square(x):
    return K.square(x)

def log(x):
    return K.log(K.clip(x, min_value = 1e-7, max_value = 10000))   


def ShallowConvNet(nb_classes, Chans = 64, Samples = 128, dropoutRate = 0.5):
    """ Keras implementation of the Shallow Convolutional Network as described
    in Schirrmeister et. al. (2017), Human Brain Mapping.
    
    Assumes the input is a 2-second EEG signal sampled at 128Hz. Note that in 
    the original paper, they do temporal convolutions of length 25 for EEG
    data sampled at 250Hz. We instead use length 13 since the sampling rate is 
    roughly half of the 250Hz which the paper used. The pool_size and stride
    in later layers is also approximately half of what is used in the paper.
    
    Note that we use the max_norm constraint on all convolutional layers, as 
    well as the classification layer. We also change the defaults for the
    BatchNormalization layer. We used this based on a personal communication 
    with the original authors.
    
                     ours        original paper
    pool_size        1, 35       1, 75
    strides          1, 7        1, 15
    conv filters     1, 13       1, 25    
    
    Note that this implementation has not been verified by the original 
    authors. We do note that this implementation reproduces the results in the
    original paper with minor deviations. 
    """

    # start the model
    input_main   = Input((Chans, Samples, 1))
    block1       = Conv2D(40, (1, 13), 
                                 input_shape=(Chans, Samples, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(input_main)
    block1       = Conv2D(40, (Chans, 1), use_bias=False, 
                          kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block1       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block1)
    block1       = Activation(square)(block1)
    block1       = AveragePooling2D(pool_size=(1, 35), strides=(1, 7))(block1)
    block1       = Activation(log)(block1)
    block1       = Dropout(dropoutRate)(block1)
    flatten      = Flatten()(block1)
    dense        = Dense(nb_classes, kernel_constraint = max_norm(0.5))(flatten)
    softmax      = Activation('softmax')(dense)
    
    return Model(inputs=input_main, outputs=softmax)

# %% [markdown]
# # Train Classifier
#
# The code in the following code block was written by our team to train and evaluate the opensource EEGNet, ShallowConvNet, and DeepConvNet models which are implemented above.

# %%
import tensorflow as tf
# from arl_eegmodels.EEGModels import EEGNet, DeepConvNet, ShallowConvNet
from tensorflow.keras.callbacks import ModelCheckpoint

# To be used for training the model on the opensource dataset

# Train data - 70% of opensource dataset
# Validation data - 30% of opensource dataset
# Test data - data collected from EEG


# Define initial model parameters
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy()
optimizer = 'adam'
metrics = ['accuracy']
epochs = 80
channels = num_desired_channels
classes = 2
dropout = 0.25
F1 = 8
F2 = 16

# EEGNet Implementation
samples = n_samples 
model = EEGNet(nb_classes=classes, Chans=num_desired_channels, Samples=samples, dropoutRate=dropout, F1=F1, F2=F2)
model.compile(loss=loss_fn, optimizer=optimizer, metrics=metrics)
# eeg_net_checkpoint = ModelCheckpoint(filepath='/trained_models/eeg_net_checkpoint.h5', verbose=1, save_best_only=True)

# Fit and train the model
eegnet_history = model.fit(
    x_train, y_train, batch_size=16, epochs=epochs, verbose=2, validation_data=(x_test, y_test)
)

# Evaluate accuracy on test data
probabilities = model.predict(x_test)
predictions = probabilities.argmax(axis=-1)

accuracy = accuracy_score(y_test, predictions)
conf_matrix = confusion_matrix(y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)
f1 = f1_score(y_test, predictions)
# roc_auc = roc_auc_score(y_test, probabilities)


print('EEGNet Accuracy Metrics')
print(f'Accuracy: {accuracy}')
print(f'F1 Score: {f1}')
# print(confusion_matrix)
disp.plot()
plt.show()
# print(f'AUC Score: {roc_auc}')

# EEGNet Accuracy Plot
plt.plot(eegnet_history.history['accuracy'])
plt.plot(eegnet_history.history['val_accuracy'])
plt.title('EEGNet Accuracy During Training')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()

# EEGNet Loss Plot
plt.plot(eegnet_history.history['loss'])
plt.plot(eegnet_history.history['val_loss'])
plt.title('EEGNet Loss During Training')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()


# DeepConvNet Implementation
deep_conv_net_model = DeepConvNet(nb_classes=classes, Chans=num_desired_channels, Samples=samples, dropoutRate=dropout)
deep_conv_net_model.compile(loss=loss_fn, optimizer=optimizer, metrics=metrics)
# deep_conv_net_checkpoint = ModelCheckpoint(
#     filepath='/trained_models/deep_conv_net_checkpoint.h5', verbose=1, save_best_only=True
# )

# Fit and train the model
deepconvnet_history = deep_conv_net_model.fit(
    x_train, y_train, batch_size=16, epochs=epochs, verbose=2, validation_data=(x_test, y_test)
)

# Evaluate accuracy on test data
probabilities = deep_conv_net_model.predict(x_test)
predictions = probabilities.argmax(axis=-1)

accuracy = accuracy_score(y_test, predictions)
conf_matrix = confusion_matrix(y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)
f1 = f1_score(y_test, predictions)
# roc_auc = roc_auc_score(y_test, probabilities)


print('Deep Conv Net Accuracy Metrics')
print(f'Accuracy: {accuracy}')
print(f'F1 Score: {f1}')
# print(confusion_matrix)
disp.plot()
plt.show()
# print(f'AUC Score: {roc_auc}')

# DeepConvNet Accuracy Plot
plt.plot(deepconvnet_history.history['accuracy'])
plt.plot(deepconvnet_history.history['val_accuracy'])
plt.title('DeepConvNet Accuracy During Training')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()

# DeepConvNet Loss Plot
plt.plot(deepconvnet_history.history['loss'])
plt.plot(deepconvnet_history.history['val_loss'])
plt.title('DeepConvNet Loss During Training')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()


# ShallowConvNet Implementation
shallow_conv_net_model = ShallowConvNet(nb_classes=classes, Chans=num_desired_channels, Samples=samples, dropoutRate=dropout)
shallow_conv_net_model.compile(loss=loss_fn, optimizer=optimizer, metrics=metrics)
# shallow_conv_net_checkpoint = ModelCheckpoint(
#     filepath='/trained_models/shallow_conv_net_checkpoint.h5', verbose=1, save_best_only=True
# )

# Fit and train the model
shallowconvnet_history = shallow_conv_net_model.fit(
    x_train, y_train, batch_size=16, epochs=epochs, verbose=2, validation_data=(x_test, y_test)
)

# Evaluate accuracy on test data
probabilities = shallow_conv_net_model.predict(x_test)
predictions = probabilities.argmax(axis=-1)

accuracy = accuracy_score(y_test, predictions)
conf_matrix = confusion_matrix(y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)
f1 = f1_score(y_test, predictions)
# roc_auc = roc_auc_score(y_test, probabilities)


print('Shallow Conv Net Accuracy Metrics')
print(f'Accuracy: {accuracy}')
print(f'F1 Score: {f1}')
# print(confusion_matrix)
disp.plot()
plt.show()
# print(f'AUC Score: {roc_auc}')

# ShallowConvNet Accuracy Plot
plt.plot(shallowconvnet_history.history['accuracy'])
plt.plot(shallowconvnet_history.history['val_accuracy'])
plt.title('ShallowConvNet Accuracy During Training')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()

# ShallowConvNet Loss Plot
plt.plot(shallowconvnet_history.history['loss'])
plt.plot(shallowconvnet_history.history['val_loss'])
plt.title('ShallowConvNet Loss During Training')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()
# Out:
# Epoch 1/80
# 56/56 - 10s - loss: 0.7138 - accuracy: 0.5179 - val_loss: 0.6985 - val_accuracy: 0.4766 - 10s/epoch - 175ms/step
# Epoch 2/80
# 56/56 - 3s - loss: 0.6872 - accuracy: 0.5513 - val_loss: 0.6960 - val_accuracy: 0.4714 - 3s/epoch - 49ms/step
# Epoch 3/80
# 56/56 - 2s - loss: 0.6604 - accuracy: 0.6004 - val_loss: 0.6974 - val_accuracy: 0.5312 - 2s/epoch - 35ms/step
# Epoch 4/80
# 56/56 - 2s - loss: 0.6595 - accuracy: 0.6161 - val_loss: 0.7038 - val_accuracy: 0.5156 - 2s/epoch - 38ms/step
# Epoch 5/80
# 56/56 - 2s - loss: 0.6542 - accuracy: 0.6228 - val_loss: 0.7079 - val_accuracy: 0.5260 - 2s/epoch - 37ms/step
# Epoch 6/80
# 56/56 - 2s - loss: 0.6350 - accuracy: 0.6417 - val_loss: 0.7176 - val_accuracy: 0.5312 - 2s/epoch - 40ms/step
# Epoch 7/80
# 56/56 - 3s - loss: 0.6499 - accuracy: 0.6272 - val_loss: 0.7291 - val_accuracy: 0.5312 - 3s/epoch - 49ms/step
# Epoch 8/80
# 56/56 - 2s - loss: 0.6414 - accuracy: 0.6295 - val_loss: 0.7380 - val_accuracy: 0.5182 - 2s/epoch - 42ms/step
# Epoch 9/80
# 56/56 - 2s - loss: 0.6416 - accuracy: 0.6228 - val_loss: 0.7079 - val_accuracy: 0.5599 - 2s/epoch - 37ms/step
# Epoch 10/80
# 56/56 - 2s - loss: 0.6356 - accuracy: 0.6451 - val_loss: 0.7325 - val_accuracy: 0.5286 - 2s/epoch - 34ms/step
# Epoch 11/80
# 56/56 - 2s - loss: 0.6307 - accuracy: 0.6574 - val_loss: 0.7048 - val_accuracy: 0.5495 - 2s/epoch - 34ms/step
# Epoch 12/80
# 56/56 - 2s - loss: 0.6296 - accuracy: 0.6283 - val_loss: 0.6995 - val_accuracy: 0.5599 - 2s/epoch - 32ms/step
# Epoch 13/80
# 56/56 - 2s - loss: 0.6240 - accuracy: 0.6663 - val_loss: 0.7077 - val_accuracy: 0.5781 - 2s/epoch - 32ms/step
# Epoch 14/80
# 56/56 - 2s - loss: 0.6150 - accuracy: 0.6618 - val_loss: 0.7240 - val_accuracy: 0.5260 - 2s/epoch - 35ms/step
# Epoch 15/80
# 56/56 - 2s - loss: 0.6278 - accuracy: 0.6317 - val_loss: 0.7171 - val_accuracy: 0.5417 - 2s/epoch - 35ms/step
# Epoch 16/80
# 56/56 - 2s - loss: 0.6245 - accuracy: 0.6484 - val_loss: 0.7285 - val_accuracy: 0.5365 - 2s/epoch - 35ms/step
# Epoch 17/80
# 56/56 - 2s - loss: 0.6106 - accuracy: 0.6663 - val_loss: 0.7268 - val_accuracy: 0.5391 - 2s/epoch - 32ms/step
# Epoch 18/80
# 56/56 - 2s - loss: 0.6039 - accuracy: 0.6618 - val_loss: 0.7205 - val_accuracy: 0.5521 - 2s/epoch - 32ms/step
# Epoch 19/80
# 56/56 - 2s - loss: 0.6135 - accuracy: 0.6842 - val_loss: 0.7199 - val_accuracy: 0.5260 - 2s/epoch - 32ms/step
# Epoch 20/80
# 56/56 - 2s - loss: 0.6132 - accuracy: 0.6730 - val_loss: 0.7419 - val_accuracy: 0.5156 - 2s/epoch - 35ms/step
# Epoch 21/80
# 56/56 - 2s - loss: 0.5944 - accuracy: 0.6987 - val_loss: 0.7462 - val_accuracy: 0.5339 - 2s/epoch - 33ms/step
# Epoch 22/80
# 56/56 - 2s - loss: 0.5905 - accuracy: 0.6786 - val_loss: 0.7383 - val_accuracy: 0.5495 - 2s/epoch - 33ms/step
# Epoch 23/80
# 56/56 - 2s - loss: 0.5953 - accuracy: 0.6730 - val_loss: 0.7218 - val_accuracy: 0.5312 - 2s/epoch - 35ms/step
# Epoch 24/80
# 56/56 - 2s - loss: 0.6045 - accuracy: 0.6786 - val_loss: 0.7130 - val_accuracy: 0.5391 - 2s/epoch - 32ms/step
# Epoch 25/80
# 56/56 - 2s - loss: 0.6156 - accuracy: 0.6518 - val_loss: 0.7448 - val_accuracy: 0.5156 - 2s/epoch - 32ms/step
# Epoch 26/80
# 56/56 - 2s - loss: 0.5868 - accuracy: 0.6920 - val_loss: 0.7460 - val_accuracy: 0.5339 - 2s/epoch - 34ms/step
# Epoch 27/80
# 56/56 - 2s - loss: 0.5957 - accuracy: 0.6842 - val_loss: 0.7167 - val_accuracy: 0.5495 - 2s/epoch - 34ms/step
# Epoch 28/80
# 56/56 - 2s - loss: 0.6040 - accuracy: 0.6629 - val_loss: 0.7283 - val_accuracy: 0.5286 - 2s/epoch - 34ms/step
# Epoch 29/80
# 56/56 - 2s - loss: 0.5938 - accuracy: 0.6964 - val_loss: 0.7011 - val_accuracy: 0.5573 - 2s/epoch - 33ms/step
# Epoch 30/80
# 56/56 - 2s - loss: 0.5854 - accuracy: 0.7009 - val_loss: 0.7226 - val_accuracy: 0.5339 - 2s/epoch - 35ms/step
# Epoch 31/80
# 56/56 - 2s - loss: 0.5685 - accuracy: 0.7031 - val_loss: 0.7592 - val_accuracy: 0.5521 - 2s/epoch - 32ms/step
# Epoch 32/80
# 56/56 - 2s - loss: 0.5851 - accuracy: 0.6819 - val_loss: 0.7404 - val_accuracy: 0.5521 - 2s/epoch - 32ms/step
# Epoch 33/80
# 56/56 - 2s - loss: 0.5667 - accuracy: 0.7076 - val_loss: 0.7528 - val_accuracy: 0.5286 - 2s/epoch - 32ms/step
# Epoch 34/80
# 56/56 - 2s - loss: 0.5758 - accuracy: 0.7020 - val_loss: 0.7718 - val_accuracy: 0.5443 - 2s/epoch - 34ms/step
# Epoch 35/80
# 56/56 - 2s - loss: 0.5674 - accuracy: 0.7121 - val_loss: 0.7210 - val_accuracy: 0.5651 - 2s/epoch - 32ms/step
# Epoch 36/80
# 56/56 - 2s - loss: 0.5773 - accuracy: 0.7031 - val_loss: 0.7430 - val_accuracy: 0.5781 - 2s/epoch - 34ms/step
# Epoch 37/80
# 56/56 - 2s - loss: 0.5695 - accuracy: 0.6864 - val_loss: 0.7480 - val_accuracy: 0.5521 - 2s/epoch - 34ms/step
# Epoch 38/80
# 56/56 - 2s - loss: 0.5698 - accuracy: 0.6908 - val_loss: 0.7393 - val_accuracy: 0.5078 - 2s/epoch - 35ms/step
# Epoch 39/80
# 56/56 - 2s - loss: 0.5644 - accuracy: 0.7132 - val_loss: 0.7749 - val_accuracy: 0.5391 - 2s/epoch - 34ms/step
# Epoch 40/80
# 56/56 - 2s - loss: 0.5591 - accuracy: 0.7098 - val_loss: 0.7482 - val_accuracy: 0.5417 - 2s/epoch - 34ms/step
# Epoch 41/80
# 56/56 - 2s - loss: 0.5541 - accuracy: 0.7109 - val_loss: 0.7228 - val_accuracy: 0.5677 - 2s/epoch - 32ms/step
# Epoch 42/80
# 56/56 - 2s - loss: 0.5545 - accuracy: 0.6842 - val_loss: 0.7010 - val_accuracy: 0.5677 - 2s/epoch - 32ms/step
# Epoch 43/80
# 56/56 - 2s - loss: 0.5550 - accuracy: 0.7098 - val_loss: 0.7428 - val_accuracy: 0.5365 - 2s/epoch - 32ms/step
# Epoch 44/80
# 56/56 - 2s - loss: 0.5522 - accuracy: 0.7210 - val_loss: 0.7380 - val_accuracy: 0.5443 - 2s/epoch - 34ms/step
# Epoch 45/80
# 56/56 - 2s - loss: 0.5600 - accuracy: 0.7109 - val_loss: 0.7328 - val_accuracy: 0.5495 - 2s/epoch - 34ms/step
# Epoch 46/80
# 56/56 - 2s - loss: 0.5464 - accuracy: 0.7121 - val_loss: 0.7206 - val_accuracy: 0.5651 - 2s/epoch - 33ms/step
# Epoch 47/80
# 56/56 - 2s - loss: 0.5634 - accuracy: 0.6875 - val_loss: 0.7547 - val_accuracy: 0.5651 - 2s/epoch - 32ms/step
# Epoch 48/80
# 56/56 - 2s - loss: 0.5420 - accuracy: 0.7299 - val_loss: 0.7406 - val_accuracy: 0.5417 - 2s/epoch - 32ms/step
# Epoch 49/80
# 56/56 - 2s - loss: 0.5411 - accuracy: 0.7433 - val_loss: 0.7388 - val_accuracy: 0.5365 - 2s/epoch - 32ms/step
# Epoch 50/80
# 56/56 - 2s - loss: 0.5395 - accuracy: 0.7165 - val_loss: 0.7588 - val_accuracy: 0.5312 - 2s/epoch - 34ms/step
# Epoch 51/80
# 56/56 - 2s - loss: 0.5426 - accuracy: 0.7199 - val_loss: 0.7325 - val_accuracy: 0.5651 - 2s/epoch - 32ms/step
# Epoch 52/80
# 56/56 - 2s - loss: 0.5291 - accuracy: 0.7321 - val_loss: 0.7874 - val_accuracy: 0.5521 - 2s/epoch - 35ms/step
# Epoch 53/80
# 56/56 - 2s - loss: 0.5288 - accuracy: 0.7310 - val_loss: 0.7261 - val_accuracy: 0.5990 - 2s/epoch - 43ms/step
# Epoch 54/80
# 56/56 - 2s - loss: 0.5325 - accuracy: 0.7299 - val_loss: 0.7427 - val_accuracy: 0.5469 - 2s/epoch - 38ms/step
# Epoch 55/80
# 56/56 - 2s - loss: 0.5438 - accuracy: 0.7199 - val_loss: 0.7724 - val_accuracy: 0.5365 - 2s/epoch - 34ms/step
# Epoch 56/80
# 56/56 - 2s - loss: 0.5589 - accuracy: 0.6998 - val_loss: 0.7496 - val_accuracy: 0.5443 - 2s/epoch - 34ms/step
# Epoch 57/80
# 56/56 - 2s - loss: 0.5361 - accuracy: 0.7288 - val_loss: 0.7310 - val_accuracy: 0.5234 - 2s/epoch - 34ms/step
# Epoch 58/80
# 56/56 - 2s - loss: 0.5445 - accuracy: 0.7042 - val_loss: 0.7915 - val_accuracy: 0.5078 - 2s/epoch - 32ms/step
# Epoch 59/80
# 56/56 - 2s - loss: 0.5277 - accuracy: 0.7310 - val_loss: 0.7717 - val_accuracy: 0.5182 - 2s/epoch - 34ms/step
# Epoch 60/80
# 56/56 - 2s - loss: 0.5409 - accuracy: 0.7210 - val_loss: 0.7955 - val_accuracy: 0.5234 - 2s/epoch - 35ms/step
# Epoch 61/80
# 56/56 - 2s - loss: 0.5119 - accuracy: 0.7388 - val_loss: 0.7432 - val_accuracy: 0.5469 - 2s/epoch - 32ms/step
# Epoch 62/80
# 56/56 - 2s - loss: 0.5268 - accuracy: 0.7277 - val_loss: 0.7444 - val_accuracy: 0.5312 - 2s/epoch - 32ms/step
# Epoch 63/80
# 56/56 - 2s - loss: 0.5218 - accuracy: 0.7433 - val_loss: 0.7263 - val_accuracy: 0.5391 - 2s/epoch - 32ms/step
# Epoch 64/80
# 56/56 - 2s - loss: 0.5254 - accuracy: 0.7232 - val_loss: 0.7337 - val_accuracy: 0.5547 - 2s/epoch - 34ms/step
# Epoch 65/80
# 56/56 - 2s - loss: 0.5455 - accuracy: 0.7154 - val_loss: 0.7882 - val_accuracy: 0.5234 - 2s/epoch - 34ms/step
# Epoch 66/80
# 56/56 - 2s - loss: 0.5236 - accuracy: 0.7310 - val_loss: 0.7788 - val_accuracy: 0.5260 - 2s/epoch - 35ms/step
# Epoch 67/80
# 56/56 - 2s - loss: 0.5131 - accuracy: 0.7522 - val_loss: 0.7796 - val_accuracy: 0.5182 - 2s/epoch - 35ms/step
# Epoch 68/80
# 56/56 - 2s - loss: 0.5186 - accuracy: 0.7377 - val_loss: 0.7861 - val_accuracy: 0.5443 - 2s/epoch - 34ms/step
# Epoch 69/80
# 56/56 - 2s - loss: 0.5039 - accuracy: 0.7511 - val_loss: 0.7875 - val_accuracy: 0.5469 - 2s/epoch - 32ms/step
# Epoch 70/80
# 56/56 - 2s - loss: 0.5294 - accuracy: 0.7467 - val_loss: 0.7134 - val_accuracy: 0.5781 - 2s/epoch - 34ms/step
# Epoch 71/80
# 56/56 - 2s - loss: 0.5127 - accuracy: 0.7433 - val_loss: 0.7701 - val_accuracy: 0.5234 - 2s/epoch - 32ms/step
# Epoch 72/80
# 56/56 - 2s - loss: 0.5236 - accuracy: 0.7388 - val_loss: 0.8346 - val_accuracy: 0.5026 - 2s/epoch - 32ms/step
# Epoch 73/80
# 56/56 - 2s - loss: 0.5134 - accuracy: 0.7366 - val_loss: 0.7935 - val_accuracy: 0.5260 - 2s/epoch - 33ms/step
# Epoch 74/80
# 56/56 - 2s - loss: 0.5218 - accuracy: 0.7533 - val_loss: 0.7768 - val_accuracy: 0.5260 - 2s/epoch - 35ms/step
# Epoch 75/80
# 56/56 - 2s - loss: 0.5305 - accuracy: 0.7299 - val_loss: 0.7787 - val_accuracy: 0.5286 - 2s/epoch - 33ms/step
# Epoch 76/80
# 56/56 - 2s - loss: 0.5037 - accuracy: 0.7455 - val_loss: 0.8027 - val_accuracy: 0.5208 - 2s/epoch - 34ms/step
# Epoch 77/80
# 56/56 - 2s - loss: 0.5176 - accuracy: 0.7299 - val_loss: 0.7622 - val_accuracy: 0.5495 - 2s/epoch - 32ms/step
# Epoch 78/80
# 56/56 - 2s - loss: 0.5184 - accuracy: 0.7321 - val_loss: 0.7435 - val_accuracy: 0.5495 - 2s/epoch - 32ms/step
# Epoch 79/80
# 56/56 - 2s - loss: 0.4975 - accuracy: 0.7600 - val_loss: 0.8112 - val_accuracy: 0.5521 - 2s/epoch - 32ms/step
# Epoch 80/80
# 56/56 - 2s - loss: 0.4901 - accuracy: 0.7634 - val_loss: 0.7981 - val_accuracy: 0.5469 - 2s/epoch - 32ms/step
# 12/12 [==============================] - 0s 17ms/step
# EEGNet Accuracy Metrics
# Accuracy: 0.546875
# F1 Score: 0.5693069306930693
# Epoch 1/80
# 56/56 - 8s - loss: 1.4929 - accuracy: 0.5246 - val_loss: 1.0510 - val_accuracy: 0.4688 - 8s/epoch - 145ms/step
# Epoch 2/80
# 56/56 - 2s - loss: 1.0478 - accuracy: 0.5167 - val_loss: 1.1741 - val_accuracy: 0.5365 - 2s/epoch - 40ms/step
# Epoch 3/80
# 56/56 - 2s - loss: 0.9367 - accuracy: 0.5558 - val_loss: 1.2537 - val_accuracy: 0.5495 - 2s/epoch - 42ms/step
# Epoch 4/80
# 56/56 - 2s - loss: 0.9524 - accuracy: 0.5692 - val_loss: 0.8393 - val_accuracy: 0.4870 - 2s/epoch - 42ms/step
# Epoch 5/80
# 56/56 - 2s - loss: 0.8950 - accuracy: 0.5826 - val_loss: 0.9629 - val_accuracy: 0.5182 - 2s/epoch - 41ms/step
# Epoch 6/80
# 56/56 - 2s - loss: 0.9635 - accuracy: 0.5904 - val_loss: 0.9343 - val_accuracy: 0.5260 - 2s/epoch - 40ms/step
# Epoch 7/80
# 56/56 - 2s - loss: 0.8432 - accuracy: 0.6049 - val_loss: 0.7929 - val_accuracy: 0.5547 - 2s/epoch - 40ms/step
# Epoch 8/80
# 56/56 - 2s - loss: 0.6216 - accuracy: 0.6496 - val_loss: 0.8377 - val_accuracy: 0.4766 - 2s/epoch - 41ms/step
# Epoch 9/80
# 56/56 - 2s - loss: 0.6262 - accuracy: 0.6652 - val_loss: 1.1439 - val_accuracy: 0.5339 - 2s/epoch - 42ms/step
# Epoch 10/80
# 56/56 - 2s - loss: 0.5895 - accuracy: 0.6741 - val_loss: 0.7912 - val_accuracy: 0.4792 - 2s/epoch - 43ms/step
# Epoch 11/80
# 56/56 - 2s - loss: 0.6126 - accuracy: 0.6975 - val_loss: 0.8372 - val_accuracy: 0.4922 - 2s/epoch - 42ms/step
# Epoch 12/80
# 56/56 - 2s - loss: 0.5682 - accuracy: 0.7199 - val_loss: 0.8182 - val_accuracy: 0.5130 - 2s/epoch - 42ms/step
# Epoch 13/80
# 56/56 - 2s - loss: 0.5556 - accuracy: 0.7232 - val_loss: 0.8927 - val_accuracy: 0.5391 - 2s/epoch - 40ms/step
# Epoch 14/80
# 56/56 - 2s - loss: 0.5956 - accuracy: 0.6931 - val_loss: 0.7499 - val_accuracy: 0.5443 - 2s/epoch - 41ms/step
# Epoch 15/80
# 56/56 - 2s - loss: 0.5364 - accuracy: 0.7333 - val_loss: 0.8868 - val_accuracy: 0.5417 - 2s/epoch - 42ms/step
# Epoch 16/80
# 56/56 - 2s - loss: 0.6344 - accuracy: 0.6864 - val_loss: 0.9489 - val_accuracy: 0.4922 - 2s/epoch - 42ms/step
# Epoch 17/80
# 56/56 - 2s - loss: 0.6362 - accuracy: 0.6596 - val_loss: 0.8739 - val_accuracy: 0.5469 - 2s/epoch - 40ms/step
# Epoch 18/80
# 56/56 - 2s - loss: 0.5556 - accuracy: 0.6998 - val_loss: 0.8867 - val_accuracy: 0.4922 - 2s/epoch - 41ms/step
# Epoch 19/80
# 56/56 - 2s - loss: 0.5644 - accuracy: 0.7132 - val_loss: 0.8925 - val_accuracy: 0.4818 - 2s/epoch - 41ms/step
# Epoch 20/80
# 56/56 - 2s - loss: 0.5612 - accuracy: 0.7321 - val_loss: 0.9698 - val_accuracy: 0.5026 - 2s/epoch - 40ms/step
# Epoch 21/80
# 56/56 - 2s - loss: 0.5786 - accuracy: 0.7221 - val_loss: 0.9014 - val_accuracy: 0.5130 - 2s/epoch - 42ms/step
# Epoch 22/80
# 56/56 - 2s - loss: 0.5222 - accuracy: 0.7589 - val_loss: 0.9766 - val_accuracy: 0.5208 - 2s/epoch - 42ms/step
# Epoch 23/80
# 56/56 - 2s - loss: 0.5979 - accuracy: 0.7165 - val_loss: 0.8455 - val_accuracy: 0.5130 - 2s/epoch - 40ms/step
# Epoch 24/80
# 56/56 - 2s - loss: 0.5934 - accuracy: 0.7098 - val_loss: 0.9194 - val_accuracy: 0.5156 - 2s/epoch - 40ms/step
# Epoch 25/80
# 56/56 - 2s - loss: 0.5122 - accuracy: 0.7600 - val_loss: 0.8634 - val_accuracy: 0.5417 - 2s/epoch - 40ms/step
# Epoch 26/80
# 56/56 - 2s - loss: 0.4723 - accuracy: 0.7746 - val_loss: 1.0763 - val_accuracy: 0.5391 - 2s/epoch - 41ms/step
# Epoch 27/80
# 56/56 - 2s - loss: 0.4800 - accuracy: 0.7824 - val_loss: 0.9730 - val_accuracy: 0.5286 - 2s/epoch - 41ms/step
# Epoch 28/80
# 56/56 - 2s - loss: 0.5047 - accuracy: 0.7612 - val_loss: 0.8573 - val_accuracy: 0.5443 - 2s/epoch - 41ms/step
# Epoch 29/80
# 56/56 - 2s - loss: 0.4997 - accuracy: 0.7500 - val_loss: 1.2113 - val_accuracy: 0.5651 - 2s/epoch - 40ms/step
# Epoch 30/80
# 56/56 - 2s - loss: 0.4885 - accuracy: 0.7600 - val_loss: 0.9492 - val_accuracy: 0.4870 - 2s/epoch - 40ms/step
# Epoch 31/80
# 56/56 - 2s - loss: 0.4776 - accuracy: 0.7768 - val_loss: 1.2990 - val_accuracy: 0.5391 - 2s/epoch - 41ms/step
# Epoch 32/80
# 56/56 - 2s - loss: 0.4859 - accuracy: 0.7567 - val_loss: 0.9565 - val_accuracy: 0.4896 - 2s/epoch - 41ms/step
# Epoch 33/80
# 56/56 - 2s - loss: 0.4509 - accuracy: 0.8058 - val_loss: 1.2120 - val_accuracy: 0.5365 - 2s/epoch - 42ms/step
# Epoch 34/80
# 56/56 - 2s - loss: 0.4475 - accuracy: 0.8013 - val_loss: 0.9507 - val_accuracy: 0.5391 - 2s/epoch - 41ms/step
# Epoch 35/80
# 56/56 - 2s - loss: 0.4554 - accuracy: 0.7913 - val_loss: 0.9180 - val_accuracy: 0.5339 - 2s/epoch - 40ms/step
# Epoch 36/80
# 56/56 - 2s - loss: 0.4465 - accuracy: 0.8002 - val_loss: 1.3010 - val_accuracy: 0.5000 - 2s/epoch - 40ms/step
# Epoch 37/80
# 56/56 - 2s - loss: 0.4739 - accuracy: 0.7679 - val_loss: 0.9115 - val_accuracy: 0.5469 - 2s/epoch - 40ms/step
# Epoch 38/80
# 56/56 - 2s - loss: 0.4162 - accuracy: 0.8170 - val_loss: 0.9875 - val_accuracy: 0.5208 - 2s/epoch - 41ms/step
# Epoch 39/80
# 56/56 - 2s - loss: 0.4276 - accuracy: 0.8080 - val_loss: 0.8995 - val_accuracy: 0.5026 - 2s/epoch - 41ms/step
# Epoch 40/80
# 56/56 - 2s - loss: 0.3984 - accuracy: 0.8315 - val_loss: 0.9587 - val_accuracy: 0.5130 - 2s/epoch - 41ms/step
# Epoch 41/80
# 56/56 - 2s - loss: 0.4082 - accuracy: 0.8047 - val_loss: 1.1734 - val_accuracy: 0.4844 - 2s/epoch - 42ms/step
# Epoch 42/80
# 56/56 - 2s - loss: 0.4238 - accuracy: 0.8002 - val_loss: 1.0268 - val_accuracy: 0.5208 - 2s/epoch - 41ms/step
# Epoch 43/80
# 56/56 - 2s - loss: 0.3876 - accuracy: 0.8270 - val_loss: 1.0203 - val_accuracy: 0.5026 - 2s/epoch - 41ms/step
# Epoch 44/80
# 56/56 - 2s - loss: 0.4124 - accuracy: 0.8225 - val_loss: 0.9963 - val_accuracy: 0.5000 - 2s/epoch - 40ms/step
# Epoch 45/80
# 56/56 - 2s - loss: 0.3788 - accuracy: 0.8393 - val_loss: 1.0339 - val_accuracy: 0.4870 - 2s/epoch - 42ms/step
# Epoch 46/80
# 56/56 - 2s - loss: 0.3465 - accuracy: 0.8460 - val_loss: 1.0299 - val_accuracy: 0.5469 - 2s/epoch - 42ms/step
# Epoch 47/80
# 56/56 - 2s - loss: 0.3373 - accuracy: 0.8460 - val_loss: 1.2664 - val_accuracy: 0.5156 - 2s/epoch - 40ms/step
# Epoch 48/80
# 56/56 - 2s - loss: 0.4102 - accuracy: 0.8125 - val_loss: 1.0393 - val_accuracy: 0.5156 - 2s/epoch - 40ms/step
# Epoch 49/80
# 56/56 - 2s - loss: 0.3643 - accuracy: 0.8471 - val_loss: 1.1473 - val_accuracy: 0.5339 - 2s/epoch - 41ms/step
# Epoch 50/80
# 56/56 - 2s - loss: 0.3329 - accuracy: 0.8605 - val_loss: 1.0000 - val_accuracy: 0.5365 - 2s/epoch - 40ms/step
# Epoch 51/80
# 56/56 - 2s - loss: 0.3237 - accuracy: 0.8627 - val_loss: 1.0311 - val_accuracy: 0.5547 - 2s/epoch - 42ms/step
# Epoch 52/80
# 56/56 - 2s - loss: 0.3369 - accuracy: 0.8471 - val_loss: 1.1965 - val_accuracy: 0.5417 - 2s/epoch - 42ms/step
# Epoch 53/80
# 56/56 - 2s - loss: 0.3055 - accuracy: 0.8728 - val_loss: 1.1372 - val_accuracy: 0.5495 - 2s/epoch - 42ms/step
# Epoch 54/80
# 56/56 - 2s - loss: 0.3783 - accuracy: 0.8371 - val_loss: 0.9831 - val_accuracy: 0.5182 - 2s/epoch - 41ms/step
# Epoch 55/80
# 56/56 - 2s - loss: 0.3321 - accuracy: 0.8616 - val_loss: 1.0940 - val_accuracy: 0.5495 - 2s/epoch - 41ms/step
# Epoch 56/80
# 56/56 - 2s - loss: 0.3142 - accuracy: 0.8672 - val_loss: 1.0504 - val_accuracy: 0.5312 - 2s/epoch - 40ms/step
# Epoch 57/80
# 56/56 - 2s - loss: 0.3197 - accuracy: 0.8650 - val_loss: 1.3875 - val_accuracy: 0.5339 - 2s/epoch - 41ms/step
# Epoch 58/80
# 56/56 - 2s - loss: 0.3293 - accuracy: 0.8538 - val_loss: 1.0993 - val_accuracy: 0.5208 - 2s/epoch - 42ms/step
# Epoch 59/80
# 56/56 - 2s - loss: 0.3026 - accuracy: 0.8783 - val_loss: 1.1022 - val_accuracy: 0.5052 - 2s/epoch - 42ms/step
# Epoch 60/80
# 56/56 - 2s - loss: 0.3461 - accuracy: 0.8404 - val_loss: 1.1236 - val_accuracy: 0.5286 - 2s/epoch - 40ms/step
# Epoch 61/80
# 56/56 - 2s - loss: 0.3504 - accuracy: 0.8594 - val_loss: 1.0975 - val_accuracy: 0.5234 - 2s/epoch - 41ms/step
# Epoch 62/80
# 56/56 - 2s - loss: 0.3165 - accuracy: 0.8705 - val_loss: 1.0973 - val_accuracy: 0.5182 - 2s/epoch - 41ms/step
# Epoch 63/80
# 56/56 - 2s - loss: 0.2405 - accuracy: 0.9118 - val_loss: 1.0658 - val_accuracy: 0.5312 - 2s/epoch - 41ms/step
# Epoch 64/80
# 56/56 - 2s - loss: 0.3029 - accuracy: 0.8783 - val_loss: 1.0130 - val_accuracy: 0.5521 - 2s/epoch - 42ms/step
# Epoch 65/80
# 56/56 - 2s - loss: 0.3060 - accuracy: 0.8739 - val_loss: 0.9607 - val_accuracy: 0.5469 - 2s/epoch - 40ms/step
# Epoch 66/80
# 56/56 - 2s - loss: 0.2615 - accuracy: 0.9040 - val_loss: 1.0042 - val_accuracy: 0.5443 - 2s/epoch - 40ms/step
# Epoch 67/80
# 56/56 - 2s - loss: 0.2493 - accuracy: 0.9051 - val_loss: 1.2722 - val_accuracy: 0.5703 - 2s/epoch - 40ms/step
# Epoch 68/80
# 56/56 - 2s - loss: 0.2934 - accuracy: 0.8795 - val_loss: 1.0165 - val_accuracy: 0.4922 - 2s/epoch - 40ms/step
# Epoch 69/80
# 56/56 - 2s - loss: 0.2510 - accuracy: 0.9018 - val_loss: 1.0073 - val_accuracy: 0.5729 - 2s/epoch - 40ms/step
# Epoch 70/80
# 56/56 - 2s - loss: 0.2937 - accuracy: 0.8761 - val_loss: 1.0164 - val_accuracy: 0.5339 - 2s/epoch - 41ms/step
# Epoch 71/80
# 56/56 - 2s - loss: 0.2215 - accuracy: 0.9219 - val_loss: 0.9443 - val_accuracy: 0.5182 - 2s/epoch - 41ms/step
# Epoch 72/80
# 56/56 - 2s - loss: 0.2586 - accuracy: 0.8962 - val_loss: 1.3010 - val_accuracy: 0.5651 - 2s/epoch - 41ms/step
# Epoch 73/80
# 56/56 - 2s - loss: 0.2563 - accuracy: 0.8828 - val_loss: 1.2741 - val_accuracy: 0.5573 - 2s/epoch - 40ms/step
# Epoch 74/80
# 56/56 - 2s - loss: 0.2496 - accuracy: 0.8984 - val_loss: 1.0288 - val_accuracy: 0.5443 - 2s/epoch - 41ms/step
# Epoch 75/80
# 56/56 - 2s - loss: 0.2217 - accuracy: 0.9107 - val_loss: 1.5037 - val_accuracy: 0.5286 - 2s/epoch - 41ms/step
# Epoch 76/80
# 56/56 - 2s - loss: 0.2315 - accuracy: 0.9051 - val_loss: 1.1224 - val_accuracy: 0.5703 - 2s/epoch - 42ms/step
# Epoch 77/80
# 56/56 - 2s - loss: 0.2472 - accuracy: 0.9085 - val_loss: 1.1562 - val_accuracy: 0.5104 - 2s/epoch - 42ms/step
# Epoch 78/80
# 56/56 - 2s - loss: 0.2642 - accuracy: 0.9007 - val_loss: 1.1062 - val_accuracy: 0.5052 - 2s/epoch - 41ms/step
# Epoch 79/80
# 56/56 - 2s - loss: 0.2375 - accuracy: 0.9152 - val_loss: 1.0884 - val_accuracy: 0.5312 - 2s/epoch - 41ms/step
# Epoch 80/80
# 56/56 - 2s - loss: 0.2246 - accuracy: 0.9062 - val_loss: 1.1422 - val_accuracy: 0.5365 - 2s/epoch - 40ms/step
# 12/12 [==============================] - 1s 21ms/step
# Deep Conv Net Accuracy Metrics
# Accuracy: 0.5364583333333334
# F1 Score: 0.5821596244131456
# Epoch 1/80
# 56/56 - 7s - loss: 4.6679 - accuracy: 0.4900 - val_loss: 1.0384 - val_accuracy: 0.5964 - 7s/epoch - 117ms/step
# Epoch 2/80
# 56/56 - 3s - loss: 1.4211 - accuracy: 0.5893 - val_loss: 2.2060 - val_accuracy: 0.5104 - 3s/epoch - 55ms/step
# Epoch 3/80
# 56/56 - 3s - loss: 0.9817 - accuracy: 0.6406 - val_loss: 1.3743 - val_accuracy: 0.5286 - 3s/epoch - 61ms/step
# Epoch 4/80
# 56/56 - 3s - loss: 0.6217 - accuracy: 0.7199 - val_loss: 1.0082 - val_accuracy: 0.5729 - 3s/epoch - 56ms/step
# Epoch 5/80
# 56/56 - 3s - loss: 0.7637 - accuracy: 0.7031 - val_loss: 1.0360 - val_accuracy: 0.5703 - 3s/epoch - 55ms/step
# Epoch 6/80
# 56/56 - 3s - loss: 0.5218 - accuracy: 0.7723 - val_loss: 1.2116 - val_accuracy: 0.5208 - 3s/epoch - 55ms/step
# Epoch 7/80
# 56/56 - 3s - loss: 1.0904 - accuracy: 0.6908 - val_loss: 1.3865 - val_accuracy: 0.5026 - 3s/epoch - 55ms/step
# Epoch 8/80
# 56/56 - 3s - loss: 0.9392 - accuracy: 0.6897 - val_loss: 1.2765 - val_accuracy: 0.5521 - 3s/epoch - 58ms/step
# Epoch 9/80
# 56/56 - 3s - loss: 0.8732 - accuracy: 0.7310 - val_loss: 1.1669 - val_accuracy: 0.5703 - 3s/epoch - 56ms/step
# Epoch 10/80
# 56/56 - 3s - loss: 1.0033 - accuracy: 0.7054 - val_loss: 1.2546 - val_accuracy: 0.5729 - 3s/epoch - 55ms/step
# Epoch 11/80
# 56/56 - 3s - loss: 0.5541 - accuracy: 0.7656 - val_loss: 1.1399 - val_accuracy: 0.5026 - 3s/epoch - 55ms/step
# Epoch 12/80
# 56/56 - 3s - loss: 0.3987 - accuracy: 0.8393 - val_loss: 1.1046 - val_accuracy: 0.5339 - 3s/epoch - 57ms/step
# Epoch 13/80
# 56/56 - 3s - loss: 0.4284 - accuracy: 0.8382 - val_loss: 2.2493 - val_accuracy: 0.4870 - 3s/epoch - 56ms/step
# Epoch 14/80
# 56/56 - 3s - loss: 0.5752 - accuracy: 0.7712 - val_loss: 1.2494 - val_accuracy: 0.5365 - 3s/epoch - 55ms/step
# Epoch 15/80
# 56/56 - 3s - loss: 0.3424 - accuracy: 0.8549 - val_loss: 0.9945 - val_accuracy: 0.5651 - 3s/epoch - 55ms/step
# Epoch 16/80
# 56/56 - 3s - loss: 0.3178 - accuracy: 0.8683 - val_loss: 1.1776 - val_accuracy: 0.5234 - 3s/epoch - 61ms/step
# Epoch 17/80
# 56/56 - 3s - loss: 0.6511 - accuracy: 0.7969 - val_loss: 1.2056 - val_accuracy: 0.5781 - 3s/epoch - 56ms/step
# Epoch 18/80
# 56/56 - 3s - loss: 0.9298 - accuracy: 0.7321 - val_loss: 1.1082 - val_accuracy: 0.5651 - 3s/epoch - 55ms/step
# Epoch 19/80
# 56/56 - 3s - loss: 0.5326 - accuracy: 0.8114 - val_loss: 1.0523 - val_accuracy: 0.5807 - 3s/epoch - 55ms/step
# Epoch 20/80
# 56/56 - 3s - loss: 0.5626 - accuracy: 0.7801 - val_loss: 1.3147 - val_accuracy: 0.5052 - 3s/epoch - 55ms/step
# Epoch 21/80
# 56/56 - 3s - loss: 0.4602 - accuracy: 0.8259 - val_loss: 1.0891 - val_accuracy: 0.5755 - 3s/epoch - 55ms/step
# Epoch 22/80
# 56/56 - 3s - loss: 0.5099 - accuracy: 0.8147 - val_loss: 1.0977 - val_accuracy: 0.5234 - 3s/epoch - 55ms/step
# Epoch 23/80
# 56/56 - 3s - loss: 0.5573 - accuracy: 0.8080 - val_loss: 1.2028 - val_accuracy: 0.5573 - 3s/epoch - 55ms/step
# Epoch 24/80
# 56/56 - 3s - loss: 0.5729 - accuracy: 0.7779 - val_loss: 1.3022 - val_accuracy: 0.5938 - 3s/epoch - 55ms/step
# Epoch 25/80
# 56/56 - 3s - loss: 0.4503 - accuracy: 0.8170 - val_loss: 1.0898 - val_accuracy: 0.5260 - 3s/epoch - 61ms/step
# Epoch 26/80
# 56/56 - 3s - loss: 0.3494 - accuracy: 0.8504 - val_loss: 1.2109 - val_accuracy: 0.5651 - 3s/epoch - 55ms/step
# Epoch 27/80
# 56/56 - 3s - loss: 0.4205 - accuracy: 0.8237 - val_loss: 1.1721 - val_accuracy: 0.5391 - 3s/epoch - 55ms/step
# Epoch 28/80
# 56/56 - 3s - loss: 0.3951 - accuracy: 0.8504 - val_loss: 1.1746 - val_accuracy: 0.5703 - 3s/epoch - 55ms/step
# Epoch 29/80
# 56/56 - 3s - loss: 0.5374 - accuracy: 0.7879 - val_loss: 1.3961 - val_accuracy: 0.5208 - 3s/epoch - 61ms/step
# Epoch 30/80
# 56/56 - 3s - loss: 0.5043 - accuracy: 0.8170 - val_loss: 1.3401 - val_accuracy: 0.5339 - 3s/epoch - 57ms/step
# Epoch 31/80
# 56/56 - 3s - loss: 0.6880 - accuracy: 0.7522 - val_loss: 1.3410 - val_accuracy: 0.5391 - 3s/epoch - 55ms/step
# Epoch 32/80
# 56/56 - 3s - loss: 0.8733 - accuracy: 0.7400 - val_loss: 2.0331 - val_accuracy: 0.5052 - 3s/epoch - 55ms/step
# Epoch 33/80
# 56/56 - 3s - loss: 0.5458 - accuracy: 0.7812 - val_loss: 1.2114 - val_accuracy: 0.5391 - 3s/epoch - 55ms/step
# Epoch 34/80
# 56/56 - 3s - loss: 0.4250 - accuracy: 0.8259 - val_loss: 1.0218 - val_accuracy: 0.5807 - 3s/epoch - 57ms/step
# Epoch 35/80
# 56/56 - 3s - loss: 0.3348 - accuracy: 0.8616 - val_loss: 1.5206 - val_accuracy: 0.5729 - 3s/epoch - 55ms/step
# Epoch 36/80
# 56/56 - 3s - loss: 0.4560 - accuracy: 0.8181 - val_loss: 1.4848 - val_accuracy: 0.5339 - 3s/epoch - 55ms/step
# Epoch 37/80
# 56/56 - 3s - loss: 0.4640 - accuracy: 0.8259 - val_loss: 1.3608 - val_accuracy: 0.5026 - 3s/epoch - 56ms/step
# Epoch 38/80
# 56/56 - 3s - loss: 0.3357 - accuracy: 0.8560 - val_loss: 1.1476 - val_accuracy: 0.5208 - 3s/epoch - 56ms/step
# Epoch 39/80
# 56/56 - 3s - loss: 0.3930 - accuracy: 0.8426 - val_loss: 1.4925 - val_accuracy: 0.5625 - 3s/epoch - 57ms/step
# Epoch 40/80
# 56/56 - 3s - loss: 0.6078 - accuracy: 0.7634 - val_loss: 1.1308 - val_accuracy: 0.5755 - 3s/epoch - 55ms/step
# Epoch 41/80
# 56/56 - 3s - loss: 0.3199 - accuracy: 0.8750 - val_loss: 1.1750 - val_accuracy: 0.5807 - 3s/epoch - 56ms/step
# Epoch 42/80
# 56/56 - 3s - loss: 0.3113 - accuracy: 0.8672 - val_loss: 1.0721 - val_accuracy: 0.5703 - 3s/epoch - 55ms/step
# Epoch 43/80
# 56/56 - 3s - loss: 0.3833 - accuracy: 0.8449 - val_loss: 1.1129 - val_accuracy: 0.5938 - 3s/epoch - 57ms/step
# Epoch 44/80
# 56/56 - 3s - loss: 0.4641 - accuracy: 0.8158 - val_loss: 1.6655 - val_accuracy: 0.5547 - 3s/epoch - 55ms/step
# Epoch 45/80
# 56/56 - 3s - loss: 0.5204 - accuracy: 0.7902 - val_loss: 1.2584 - val_accuracy: 0.5469 - 3s/epoch - 55ms/step
# Epoch 46/80
# 56/56 - 3s - loss: 0.8597 - accuracy: 0.7333 - val_loss: 1.8396 - val_accuracy: 0.4948 - 3s/epoch - 56ms/step
# Epoch 47/80
# 56/56 - 3s - loss: 0.6660 - accuracy: 0.7712 - val_loss: 1.2641 - val_accuracy: 0.5781 - 3s/epoch - 62ms/step
# Epoch 48/80
# 56/56 - 3s - loss: 0.5182 - accuracy: 0.7879 - val_loss: 1.4745 - val_accuracy: 0.5104 - 3s/epoch - 56ms/step
# Epoch 49/80
# 56/56 - 3s - loss: 0.6088 - accuracy: 0.7634 - val_loss: 1.2509 - val_accuracy: 0.5521 - 3s/epoch - 55ms/step
# Epoch 50/80
# 56/56 - 3s - loss: 0.5886 - accuracy: 0.7645 - val_loss: 1.5081 - val_accuracy: 0.5625 - 3s/epoch - 55ms/step
# Epoch 51/80
# 56/56 - 3s - loss: 0.5011 - accuracy: 0.7969 - val_loss: 1.2222 - val_accuracy: 0.5286 - 3s/epoch - 61ms/step
# Epoch 52/80
# 56/56 - 3s - loss: 0.5591 - accuracy: 0.7958 - val_loss: 1.6848 - val_accuracy: 0.4948 - 3s/epoch - 56ms/step
# Epoch 53/80
# 56/56 - 3s - loss: 0.3919 - accuracy: 0.8270 - val_loss: 1.0695 - val_accuracy: 0.5781 - 3s/epoch - 55ms/step
# Epoch 54/80
# 56/56 - 3s - loss: 0.3923 - accuracy: 0.8426 - val_loss: 1.0391 - val_accuracy: 0.5495 - 3s/epoch - 55ms/step
# Epoch 55/80
# 56/56 - 3s - loss: 0.5112 - accuracy: 0.8147 - val_loss: 1.2477 - val_accuracy: 0.5104 - 3s/epoch - 55ms/step
# Epoch 56/80
# 56/56 - 3s - loss: 0.5533 - accuracy: 0.7891 - val_loss: 1.2625 - val_accuracy: 0.5573 - 3s/epoch - 57ms/step
# Epoch 57/80
# 56/56 - 3s - loss: 0.5737 - accuracy: 0.7690 - val_loss: 1.1795 - val_accuracy: 0.5365 - 3s/epoch - 55ms/step
# Epoch 58/80
# 56/56 - 3s - loss: 0.4231 - accuracy: 0.8114 - val_loss: 1.5414 - val_accuracy: 0.5651 - 3s/epoch - 55ms/step
# Epoch 59/80
# 56/56 - 3s - loss: 0.4439 - accuracy: 0.8158 - val_loss: 1.1284 - val_accuracy: 0.5208 - 3s/epoch - 55ms/step
# Epoch 60/80
# 56/56 - 3s - loss: 0.4055 - accuracy: 0.8326 - val_loss: 1.5909 - val_accuracy: 0.4688 - 3s/epoch - 56ms/step
# Epoch 61/80
# 56/56 - 3s - loss: 0.8111 - accuracy: 0.7478 - val_loss: 1.4744 - val_accuracy: 0.5312 - 3s/epoch - 56ms/step
# Epoch 62/80
# 56/56 - 3s - loss: 0.9862 - accuracy: 0.7221 - val_loss: 1.7814 - val_accuracy: 0.5547 - 3s/epoch - 55ms/step
# Epoch 63/80
# 56/56 - 3s - loss: 0.6635 - accuracy: 0.7623 - val_loss: 1.2674 - val_accuracy: 0.5833 - 3s/epoch - 55ms/step
# Epoch 64/80
# 56/56 - 3s - loss: 0.5192 - accuracy: 0.7790 - val_loss: 1.2843 - val_accuracy: 0.5182 - 3s/epoch - 55ms/step
# Epoch 65/80
# 56/56 - 3s - loss: 0.8427 - accuracy: 0.7277 - val_loss: 1.1475 - val_accuracy: 0.5599 - 3s/epoch - 62ms/step
# Epoch 66/80
# 56/56 - 3s - loss: 0.6618 - accuracy: 0.7690 - val_loss: 1.2113 - val_accuracy: 0.5781 - 3s/epoch - 55ms/step
# Epoch 67/80
# 56/56 - 3s - loss: 0.4783 - accuracy: 0.7935 - val_loss: 1.0895 - val_accuracy: 0.5964 - 3s/epoch - 55ms/step
# Epoch 68/80
# 56/56 - 3s - loss: 0.4302 - accuracy: 0.8270 - val_loss: 1.4310 - val_accuracy: 0.5104 - 3s/epoch - 55ms/step
# Epoch 69/80
# 56/56 - 3s - loss: 0.5219 - accuracy: 0.7958 - val_loss: 1.1232 - val_accuracy: 0.5964 - 3s/epoch - 62ms/step
# Epoch 70/80
# 56/56 - 3s - loss: 0.4281 - accuracy: 0.8225 - val_loss: 1.1059 - val_accuracy: 0.5755 - 3s/epoch - 55ms/step
# Epoch 71/80
# 56/56 - 3s - loss: 0.3172 - accuracy: 0.8605 - val_loss: 1.0801 - val_accuracy: 0.5469 - 3s/epoch - 55ms/step
# Epoch 72/80
# 56/56 - 3s - loss: 0.3109 - accuracy: 0.8605 - val_loss: 1.1865 - val_accuracy: 0.5521 - 3s/epoch - 55ms/step
# Epoch 73/80
# 56/56 - 3s - loss: 0.2397 - accuracy: 0.9085 - val_loss: 1.2258 - val_accuracy: 0.5443 - 3s/epoch - 56ms/step
# Epoch 74/80
# 56/56 - 3s - loss: 0.3898 - accuracy: 0.8382 - val_loss: 1.1304 - val_accuracy: 0.5521 - 3s/epoch - 56ms/step
# Epoch 75/80
# 56/56 - 3s - loss: 0.3398 - accuracy: 0.8549 - val_loss: 1.1450 - val_accuracy: 0.5573 - 3s/epoch - 55ms/step
# Epoch 76/80
# 56/56 - 3s - loss: 0.3627 - accuracy: 0.8627 - val_loss: 1.0906 - val_accuracy: 0.5807 - 3s/epoch - 55ms/step
# Epoch 77/80
# 56/56 - 3s - loss: 0.3511 - accuracy: 0.8538 - val_loss: 1.2745 - val_accuracy: 0.5573 - 3s/epoch - 55ms/step
# Epoch 78/80
# 56/56 - 3s - loss: 0.4165 - accuracy: 0.8426 - val_loss: 1.3358 - val_accuracy: 0.5807 - 3s/epoch - 62ms/step
# Epoch 79/80
# 56/56 - 3s - loss: 0.4015 - accuracy: 0.8304 - val_loss: 1.3195 - val_accuracy: 0.5599 - 3s/epoch - 55ms/step
# Epoch 80/80
# 56/56 - 3s - loss: 0.5586 - accuracy: 0.7913 - val_loss: 1.0785 - val_accuracy: 0.5417 - 3s/epoch - 56ms/step
# 12/12 [==============================] - 1s 22ms/step
# Shallow Conv Net Accuracy Metrics
# Accuracy: 0.5416666666666666
# F1 Score: 0.5532994923857869
