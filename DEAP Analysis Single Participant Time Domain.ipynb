# %% [markdown]
# The following code blocks have been sourced or adapted from
#
# [10] T. M. Ngo, “tuengominh/deap-eeg-classification.” Apr. 12, 2023. Accessed: Apr. 16, 2023. [Online]. Available: https://github.com/tuengominh/deap-eeg-classification/blob/b7c720e9ea1c37241b2b336d33d1d9830c17a8bf/eeg_based_emotion_classification.ipynb

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import os
import time
import pickle
import pandas as pd
import numpy as np

from scipy import signal
from scipy.signal import welch
from scipy.integrate import simps
from scipy.stats import f_oneway

#!pip install scikit-learn==0.20.3
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn import model_selection
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import itertools
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_recall_curve

# !pip install mne==0.22.0
import mne
from mne.preprocessing import (ICA, create_eog_epochs, create_ecg_epochs, corrmap)
from mne.time_frequency import psd_welch
from mne.decoding import cross_val_multiscore

# !pip install fooof
from fooof import FOOOFGroup
from fooof.bands import Bands
from fooof.analysis import get_band_peak_fg
from fooof.plts.spectra import plot_spectrum

import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
# %matplotlib inline
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mne==0.22.0
#   Downloading mne-0.22.0-py3-none-any.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 65.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.9/dist-packages (from mne==0.22.0) (1.22.4)
# Requirement already satisfied: scipy>=0.17.1 in /usr/local/lib/python3.9/dist-packages (from mne==0.22.0) (1.10.1)
# Installing collected packages: mne
# Successfully installed mne-0.22.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting fooof
#   Downloading fooof-1.0.0-py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from fooof) (1.22.4)
# Requirement already satisfied: scipy>=0.19.0 in /usr/local/lib/python3.9/dist-packages (from fooof) (1.10.1)
# Installing collected packages: fooof
# Successfully installed fooof-1.0.0

# %% [markdown]
# ## Load Dataset

# %%
sohas_base_path = '/content/gdrive/MyDrive/BME 4B/SYDE 544/SYDE544 - Project/DEAP Dataset/'
aarzoos_base_path = '/content/gdrive/MyDrive/4B/SYDE544/SYDE544 - Project (1)/DEAP Dataset/'
elizabeths_base_path = '/content/gdrive/MyDrive/SYDE 544/SYDE544- Project/DEAP Dataset/'
# sonalis_base_path = '/content/gdrive/MyDrive/Waterloo/Waterloo 4B Term/SYDE544 - Project/DEAP Dataset/'

# base_path = sohas_base_path
# base_path = aarzoos_base_path
# base_path = sonalis_base_path
base_path = elizabeths_base_path
dat_files_path = os.path.join(base_path, 'data_preprocessed_python')
print(dat_files_path)
# Out:
# /content/gdrive/MyDrive/SYDE 544/SYDE544- Project/DEAP Dataset/data_preprocessed_python

# %%
# Function to load data from each participant file
def read_eeg_signal_from_file(filename):
    x = pickle._Unpickler(open(filename, 'rb'))
    x.encoding = 'latin1'
    p = x.load()
    return p

# %%
# 32x40 = 1280 trials for 32 participants
# 128 Hz x 63 seconds (60s stimulus + 3s baseline?) = 8064 samples
labels = []
data = []

sub_dat_file = os.listdir(dat_files_path)[0]
filename = os.path.join(dat_files_path, sub_dat_file)
trial = read_eeg_signal_from_file(filename)
labels.append(trial['labels'])
data.append(trial['data'])

# Re-shape arrays into desired shapes
# Order is in order of video ID (not in which way they were presented to the participant)
labels = np.array(labels)
labels = labels.flatten()
labels = labels.reshape(40, 4)

data = np.array(data)
data = data.flatten()
data = data.reshape(40, 40, 8064)

# %%
# Double-check the new arrays
print("Labels: ", labels.shape) # trial x label
print("Data: ", data.shape) # trial x channel x data
# Out:
# Labels:  (40, 4)
# Data:  (40, 40, 8064)

# %%
# Only extract Liking ratings
df_label_ratings = pd.DataFrame({'Valence': labels[:,0]})
# print(df_label_ratings.head())
# print(df_label_ratings.describe())

# %%
# Function to check if each trial has positive or negative valence
def positive_valence(trial):
    return 1 if labels[trial,0] >= np.median(labels[:,0]) else 0 

# Convert valence to binary 0 (low), 1 (high)
valence_labels_encoded = []
for i in range (len(labels)):
  valence_labels_encoded.append(positive_valence(i))
valence_labels_encoded = np.reshape(valence_labels_encoded, (40))

# %% [markdown]
# ## EEG Data
#
# https://www.researchgate.net/figure/Comparison-of-electrode-placement-between-MUSE-and-the-international-10-20-system-a_fig2_352019337
# We'll use
# * AF7 --> AF3 (channel 2)
# * AF8 --> AF4 (channel 18)
# * TP9 --> T7 (channel 8)
# * TP10 --> T8 (channel 26)

# %%
eeg_channels = np.array(["Fp1", "AF3", "F3", "F7", "FC5", "FC1", "C3", "T7", "CP5", "CP1", "P3", "P7", "PO3", "O1", "Oz", "Pz", "Fp2", "AF4", "Fz", "F4", "F8", "FC6", "FC2", "Cz", "C4", "T8", "CP6", "CP2", "P4", "P8", "PO4", "O2"])
peripheral_channels = np.array(["hEOG", "vEOG", "zEMG", "tEMG", "GSR", "Respiration belt", "Plethysmograph", "Temperature"])

# %%
# params
fs = 128
num_desired_channels = 4
# num_desired_channels = len(eeg_channels)
n_samples = fs * 60

# Extract our desired channels
# Also segment the middle 30s
# Taking t_start = 3s + 15s to t_end  = t_start + 30s 
eeg_data = []

# for middle 30 s
# t_start_seg = (fs * (3 + 15)) - 1
# t_end_seg = t_start_seg + (fs * 30)

# for full 60s
t_start_seg = (fs * 3) - 1
t_end_seg = t_start_seg + (fs * 60)


for i in range (len(data)):
  # AF3 (channel 2)
  eeg_data.append(data[i,1,t_start_seg:t_end_seg])

  # T7 (channel 8)
  eeg_data.append(data[i,7,t_start_seg:t_end_seg])

  # AF4 (channel 18)
  eeg_data.append(data[i,17,t_start_seg:t_end_seg])

  # T8 (channel 26)
  eeg_data.append(data[i,25,t_start_seg:t_end_seg])

# # Testing with using all EEG channels to see baseline accuracy 
# for i in range (len(data)):
#   for j in range (len(eeg_channels)):
#     eeg_data.append(data[i, j, t_start_seg:t_end_seg])

eeg_data = np.reshape(eeg_data, (len(data), num_desired_channels, n_samples))
print(eeg_data.shape)
# Out:
# (40, 4, 7680)

# %%
sns.set(font_scale=1.2)

# Define sampling frequency and time vector
sf = 128.
time = np.arange(eeg_data.size) / sf

# Plot the signal of first trial, first channel 
fig, ax = plt.subplots(1, 1, figsize=(16, 4))
#signal of first trail, last channel
plt.plot(eeg_data[0,0], lw=1.5, color='k') 
plt.xlabel('Time')
plt.ylabel('Voltage')
sns.despine()

# %%
print(num_desired_channels)

sf = 128
#defined window of 1 second
win = 1*sf
times = list(range(0, 61))
times_sf = [i * 128 for i in times]
freqs, psd = signal.welch(eeg_data[0,0, times_sf[29]:times_sf[30]], sf, nperseg=win)

# Plot the power spectrum
sns.set(font_scale=1.2, style='white')
plt.figure(figsize=(8, 4))
plt.plot(freqs, psd, color='k', lw=2)
plt.xlabel('Frequency (Hz)')
plt.ylabel('Power spectral density (V^2 / Hz)')
plt.ylim([0, psd.max() * 1.1])
plt.title("Welch's periodogram")
plt.xlim([0, freqs.max()])
sns.despine()
# Out:
# 4

# %%
# Define delta lower and upper limits
low, high = 0.5, 4

# Find intersecting values in frequency vector
idx_delta = np.logical_and(freqs >= low, freqs <= high)

# Frequency resolution
freq_res = freqs[1] - freqs[0]  # = 1 / 4 = 0.25

# Compute the absolute power by approximating the area under the curve
delta_power = simps(psd[idx_delta], dx=freq_res)
print('Absolute delta power: %.3f uV^2' % delta_power)
# Out:
# Absolute delta power: 1.982 uV^2

# %%
def get_all_powers(freqs, psd):

  # Define delta lower and upper limits
  delta_l, delta_h = 0.5, 4
  theta_l, theta_h = 4, 8
  alpha_l, alpha_h = 8, 12
  beta_l, beta_h = 12, 30

  # Find intersecting values in frequency vector
  idx_delta = np.logical_and(freqs >= delta_l, freqs <= delta_h)
  idx_theta = np.logical_and(freqs >= theta_l, freqs <= theta_h)
  idx_alpha = np.logical_and(freqs >= alpha_l, freqs <= alpha_h)
  idx_beta = np.logical_and(freqs >= beta_l, freqs <= beta_h)
  # Frequency resolution
  freq_res = freqs[1] - freqs[0]  # = 1 / 4 = 0.25

  # Compute the absolute power by approximating the area under the curve
  # multiplied by 100000 for microVolts
  delta_power = simps(psd[idx_delta], dx=freq_res) * 100000
  theta_power = simps(psd[idx_theta], dx=freq_res) * 100000
  alpha_power = simps(psd[idx_alpha], dx=freq_res) * 100000
  beta_power = simps(psd[idx_beta], dx=freq_res) * 100000

  return delta_power, theta_power, alpha_power, beta_power

# %%
# preprocessing for bandpower per fequecy 
delta = np.empty((40, 4, 60))
theta = np.empty((40, 4, 60))
alpha = np.empty((40, 4, 60))
beta = np.empty((40, 4, 60))

# times = list(range(0, 31))
# times_sf = [i * 128 for i in times]

sf = 128
#defined window of 1 second
win = 1*sf

for trial in range(eeg_data.shape[0]):
  #print("trial: ", trial, " channel: ", channel, " second: ", second)
  for channel in range(eeg_data.shape[1]):
    for second in range(len(times_sf)-1):
      
      first = times_sf[second]
      last = times_sf[second+1]
      #print("first: ", first, " last: ", last)
      freqs, psd = signal.welch(eeg_data[trial, channel, first:last], sf, nperseg=win)

      d_power, t_power, a_power, b_power = get_all_powers(freqs, psd)
      #d_power, t_power = get_all_powers(freqs, psd)
      delta[trial, channel, second] = d_power
      theta[trial, channel, second] = t_power
      alpha[trial, channel, second] = a_power
      beta[trial, channel, second] = b_power

# %%
print(alpha.shape)
# Out:
# (40, 4, 60)

# %% [markdown]
# ## Test, train split

# %%
# Split the data into training/testing sets
def split_train_test(x, y):
  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=42)
  return x_train, x_test, y_train, y_test

# %%
x_train, x_test, y_train, y_test = split_train_test(eeg_data, valence_labels_encoded)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (28, 4, 7680)
# (12, 4, 7680)
# (28,)
# (12,)

# %%
delta_x_train, delta_x_test, delta_y_train, delta_y_test = split_train_test(delta, valence_labels_encoded)

print(delta_x_train.shape)
print(delta_x_test.shape)
print(delta_y_train.shape)
print(delta_y_test.shape)
# Out:
# (28, 4, 60)
# (12, 4, 60)
# (28,)
# (12,)

# %%
theta_x_train, theta_x_test, theta_y_train, theta_y_test = split_train_test(theta, valence_labels_encoded)

print(theta_x_train.shape)
print(theta_x_test.shape)
print(theta_y_train.shape)
print(theta_y_test.shape)
# Out:
# (28, 4, 60)
# (12, 4, 60)
# (28,)
# (12,)

# %%
alpha_x_train, alpha_x_test, alpha_y_train, alpha_y_test = split_train_test(alpha, valence_labels_encoded)

print(alpha_x_train.shape)
print(alpha_x_test.shape)
print(alpha_y_train.shape)
print(alpha_y_test.shape)
# Out:
# (28, 4, 60)
# (12, 4, 60)
# (28,)
# (12,)

# %%
beta_x_train, beta_x_test, beta_y_train, beta_y_test = split_train_test(beta, valence_labels_encoded)

print(beta_x_train.shape)
print(beta_x_test.shape)
print(beta_y_train.shape)
print(beta_y_test.shape)
# Out:
# (28, 4, 60)
# (12, 4, 60)
# (28,)
# (12,)

# %% [markdown]
# # Open Source EEG Model Implementations
#
# The following code block implements the opensource code provided by Lawhern, et al. [11, 12, 13]. Code source: https://github.com/vlawhern/arl-eegmodels. Please see the attached License.txt file that was submitted in the Learn DropBox.
#
# [11] V. J. Lawhern, A. J. Solon, N. R. Waytowich, S. M. Gordon, C. P. Hung, and B. J. Lance, “EEGNet: a compact convolutional neural network for EEG-based brain–computer interfaces,” J. Neural Eng., vol. 15, no. 5, p. 056013, Oct. 2018, doi: 10.1088/1741-2552/aace8c.
#
# [12] vlawhern, “arl-eegmodels.” Apr. 04, 2023. Accessed: Apr. 05, 2023. [Online]. Available: https://github.com/vlawhern/arl-eegmodels
#
# [13] R. T. Schirrmeister et al., “Deep learning with convolutional neural networks for EEG decoding and visualization,” Human Brain Mapping, vol. 38, no. 11, pp. 5391–5420, 2017, doi: 10.1002/hbm.23730.

# %%
"""
 ARL_EEGModels - A collection of Convolutional Neural Network models for EEG
 Signal Processing and Classification, using Keras and Tensorflow

 Requirements:
    (1) tensorflow == 2.X (as of this writing, 2.0 - 2.3 have been verified
        as working)
 
 To run the EEG/MEG ERP classification sample script, you will also need

    (4) mne >= 0.17.1
    (5) PyRiemann >= 0.2.5
    (6) scikit-learn >= 0.20.1
    (7) matplotlib >= 2.2.3
    
 To use:
    
    (1) Place this file in the PYTHONPATH variable in your IDE (i.e.: Spyder)
    (2) Import the model as
        
        from EEGModels import EEGNet    
        
        model = EEGNet(nb_classes = ..., Chans = ..., Samples = ...)
        
    (3) Then compile and fit the model
    
        model.compile(loss = ..., optimizer = ..., metrics = ...)
        fitted    = model.fit(...)
        predicted = model.predict(...)

 Portions of this project are works of the United States Government and are not
 subject to domestic copyright protection under 17 USC Sec. 105.  Those 
 portions are released world-wide under the terms of the Creative Commons Zero 
 1.0 (CC0) license.  
 
 Other portions of this project are subject to domestic copyright protection 
 under 17 USC Sec. 105.  Those portions are licensed under the Apache 2.0 
 license.  The complete text of the license governing this material is in 
 the file labeled LICENSE.TXT that is a part of this project's official 
 distribution. 
"""

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.constraints import max_norm
from tensorflow.keras import backend as K


def EEGNet(nb_classes, Chans = 64, Samples = 128, 
             dropoutRate = 0.5, kernLength = 64, F1 = 8, 
             D = 2, F2 = 16, norm_rate = 0.25, dropoutType = 'Dropout'):
    """ Keras Implementation of EEGNet
    http://iopscience.iop.org/article/10.1088/1741-2552/aace8c/meta

    Note that this implements the newest version of EEGNet and NOT the earlier
    version (version v1 and v2 on arxiv). We strongly recommend using this
    architecture as it performs much better and has nicer properties than
    our earlier version. For example:
        
        1. Depthwise Convolutions to learn spatial filters within a 
        temporal convolution. The use of the depth_multiplier option maps 
        exactly to the number of spatial filters learned within a temporal
        filter. This matches the setup of algorithms like FBCSP which learn 
        spatial filters within each filter in a filter-bank. This also limits 
        the number of free parameters to fit when compared to a fully-connected
        convolution. 
        
        2. Separable Convolutions to learn how to optimally combine spatial
        filters across temporal bands. Separable Convolutions are Depthwise
        Convolutions followed by (1x1) Pointwise Convolutions. 
        
    
    While the original paper used Dropout, we found that SpatialDropout2D 
    sometimes produced slightly better results for classification of ERP 
    signals. However, SpatialDropout2D significantly reduced performance 
    on the Oscillatory dataset (SMR, BCI-IV Dataset 2A). We recommend using
    the default Dropout in most cases.
        
    Assumes the input signal is sampled at 128Hz. If you want to use this model
    for any other sampling rate you will need to modify the lengths of temporal
    kernels and average pooling size in blocks 1 and 2 as needed (double the 
    kernel lengths for double the sampling rate, etc). Note that we haven't 
    tested the model performance with this rule so this may not work well. 
    
    The model with default parameters gives the EEGNet-8,2 model as discussed
    in the paper. This model should do pretty well in general, although it is
	advised to do some model searching to get optimal performance on your
	particular dataset.

    We set F2 = F1 * D (number of input filters = number of output filters) for
    the SeparableConv2D layer. We haven't extensively tested other values of this
    parameter (say, F2 < F1 * D for compressed learning, and F2 > F1 * D for
    overcomplete). We believe the main parameters to focus on are F1 and D. 

    Inputs:
        
      nb_classes      : int, number of classes to classify
      Chans, Samples  : number of channels and time points in the EEG data
      dropoutRate     : dropout fraction
      kernLength      : length of temporal convolution in first layer. We found
                        that setting this to be half the sampling rate worked
                        well in practice. For the SMR dataset in particular
                        since the data was high-passed at 4Hz we used a kernel
                        length of 32.     
      F1, F2          : number of temporal filters (F1) and number of pointwise
                        filters (F2) to learn. Default: F1 = 8, F2 = F1 * D. 
      D               : number of spatial filters to learn within each temporal
                        convolution. Default: D = 2
      dropoutType     : Either SpatialDropout2D or Dropout, passed as a string.

    """
    
    if dropoutType == 'SpatialDropout2D':
        dropoutType = SpatialDropout2D
    elif dropoutType == 'Dropout':
        dropoutType = Dropout
    else:
        raise ValueError('dropoutType must be one of SpatialDropout2D '
                         'or Dropout, passed as a string.')
    
    input1   = Input(shape = (Chans, Samples, 1))

    ##################################################################
    block1       = Conv2D(F1, (1, kernLength), padding = 'same',
                                   input_shape = (Chans, Samples, 1),
                                   use_bias = False)(input1)
    block1       = BatchNormalization()(block1)
    block1       = DepthwiseConv2D((Chans, 1), use_bias = False, 
                                   depth_multiplier = D,
                                   depthwise_constraint = max_norm(1.))(block1)
    block1       = BatchNormalization()(block1)
    block1       = Activation('elu')(block1)
    block1       = AveragePooling2D((1, 4))(block1)
    block1       = dropoutType(dropoutRate)(block1)
    
    block2       = SeparableConv2D(F2, (1, 16),
                                   use_bias = False, padding = 'same')(block1)
    block2       = BatchNormalization()(block2)
    block2       = Activation('elu')(block2)
    block2       = AveragePooling2D((1, 8))(block2)
    block2       = dropoutType(dropoutRate)(block2)
        
    flatten      = Flatten(name = 'flatten')(block2)
    
    dense        = Dense(nb_classes, name = 'dense', 
                         kernel_constraint = max_norm(norm_rate))(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)
    
    return Model(inputs=input1, outputs=softmax)




def EEGNet_SSVEP(nb_classes = 12, Chans = 8, Samples = 256, 
             dropoutRate = 0.5, kernLength = 256, F1 = 96, 
             D = 1, F2 = 96, dropoutType = 'Dropout'):
    """ SSVEP Variant of EEGNet, as used in [1]. 

    Inputs:
        
      nb_classes      : int, number of classes to classify
      Chans, Samples  : number of channels and time points in the EEG data
      dropoutRate     : dropout fraction
      kernLength      : length of temporal convolution in first layer
      F1, F2          : number of temporal filters (F1) and number of pointwise
                        filters (F2) to learn. 
      D               : number of spatial filters to learn within each temporal
                        convolution.
      dropoutType     : Either SpatialDropout2D or Dropout, passed as a string.
      
      
    [1]. Waytowich, N. et. al. (2018). Compact Convolutional Neural Networks
    for Classification of Asynchronous Steady-State Visual Evoked Potentials.
    Journal of Neural Engineering vol. 15(6). 
    http://iopscience.iop.org/article/10.1088/1741-2552/aae5d8

    """
    
    if dropoutType == 'SpatialDropout2D':
        dropoutType = SpatialDropout2D
    elif dropoutType == 'Dropout':
        dropoutType = Dropout
    else:
        raise ValueError('dropoutType must be one of SpatialDropout2D '
                         'or Dropout, passed as a string.')
    
    input1   = Input(shape = (Chans, Samples, 1))

    ##################################################################
    block1       = Conv2D(F1, (1, kernLength), padding = 'same',
                                   input_shape = (Chans, Samples, 1),
                                   use_bias = False)(input1)
    block1       = BatchNormalization()(block1)
    block1       = DepthwiseConv2D((Chans, 1), use_bias = False, 
                                   depth_multiplier = D,
                                   depthwise_constraint = max_norm(1.))(block1)
    block1       = BatchNormalization()(block1)
    block1       = Activation('elu')(block1)
    block1       = AveragePooling2D((1, 4))(block1)
    block1       = dropoutType(dropoutRate)(block1)
    
    block2       = SeparableConv2D(F2, (1, 16),
                                   use_bias = False, padding = 'same')(block1)
    block2       = BatchNormalization()(block2)
    block2       = Activation('elu')(block2)
    block2       = AveragePooling2D((1, 8))(block2)
    block2       = dropoutType(dropoutRate)(block2)
        
    flatten      = Flatten(name = 'flatten')(block2)
    
    dense        = Dense(nb_classes, name = 'dense')(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)
    
    return Model(inputs=input1, outputs=softmax)



def EEGNet_old(nb_classes, Chans = 64, Samples = 128, regRate = 0.0001,
           dropoutRate = 0.25, kernels = [(2, 32), (8, 4)], strides = (2, 4)):
    """ Keras Implementation of EEGNet_v1 (https://arxiv.org/abs/1611.08024v2)

    This model is the original EEGNet model proposed on arxiv
            https://arxiv.org/abs/1611.08024v2
    
    with a few modifications: we use striding instead of max-pooling as this 
    helped slightly in classification performance while also providing a 
    computational speed-up. 
    
    Note that we no longer recommend the use of this architecture, as the new
    version of EEGNet performs much better overall and has nicer properties.
    
    Inputs:
        
        nb_classes     : total number of final categories
        Chans, Samples : number of EEG channels and samples, respectively
        regRate        : regularization rate for L1 and L2 regularizations
        dropoutRate    : dropout fraction
        kernels        : the 2nd and 3rd layer kernel dimensions (default is 
                         the [2, 32] x [8, 4] configuration)
        strides        : the stride size (note that this replaces the max-pool
                         used in the original paper)
    
    """

    # start the model
    input_main   = Input((Chans, Samples))
    layer1       = Conv2D(16, (Chans, 1), input_shape=(Chans, Samples, 1),
                                 kernel_regularizer = l1_l2(l1=regRate, l2=regRate))(input_main)
    layer1       = BatchNormalization()(layer1)
    layer1       = Activation('elu')(layer1)
    layer1       = Dropout(dropoutRate)(layer1)
    
    permute_dims = 2, 1, 3
    permute1     = Permute(permute_dims)(layer1)
    
    layer2       = Conv2D(4, kernels[0], padding = 'same', 
                            kernel_regularizer=l1_l2(l1=0.0, l2=regRate),
                            strides = strides)(permute1)
    layer2       = BatchNormalization()(layer2)
    layer2       = Activation('elu')(layer2)
    layer2       = Dropout(dropoutRate)(layer2)
    
    layer3       = Conv2D(4, kernels[1], padding = 'same',
                            kernel_regularizer=l1_l2(l1=0.0, l2=regRate),
                            strides = strides)(layer2)
    layer3       = BatchNormalization()(layer3)
    layer3       = Activation('elu')(layer3)
    layer3       = Dropout(dropoutRate)(layer3)
    
    flatten      = Flatten(name = 'flatten')(layer3)
    
    dense        = Dense(nb_classes, name = 'dense')(flatten)
    softmax      = Activation('softmax', name = 'softmax')(dense)
    
    return Model(inputs=input_main, outputs=softmax)



def DeepConvNet(nb_classes, Chans = 64, Samples = 256,
                dropoutRate = 0.5):
    """ Keras implementation of the Deep Convolutional Network as described in
    Schirrmeister et. al. (2017), Human Brain Mapping.
    
    This implementation assumes the input is a 2-second EEG signal sampled at 
    128Hz, as opposed to signals sampled at 250Hz as described in the original
    paper. We also perform temporal convolutions of length (1, 5) as opposed
    to (1, 10) due to this sampling rate difference. 
    
    Note that we use the max_norm constraint on all convolutional layers, as 
    well as the classification layer. We also change the defaults for the
    BatchNormalization layer. We used this based on a personal communication 
    with the original authors.
    
                      ours        original paper
    pool_size        1, 2        1, 3
    strides          1, 2        1, 3
    conv filters     1, 5        1, 10
    
    Note that this implementation has not been verified by the original 
    authors. 
    
    """

    # start the model
    input_main   = Input((Chans, Samples, 1))
    block1       = Conv2D(25, (1, 5), 
                                 input_shape=(Chans, Samples, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(input_main)
    block1       = Conv2D(25, (Chans, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block1       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block1)
    block1       = Activation('elu')(block1)
    block1       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block1)
    block1       = Dropout(dropoutRate)(block1)
  
    block2       = Conv2D(50, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block2       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block2)
    block2       = Activation('elu')(block2)
    block2       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block2)
    block2       = Dropout(dropoutRate)(block2)
    
    block3       = Conv2D(100, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block2)
    block3       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block3)
    block3       = Activation('elu')(block3)
    block3       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block3)
    block3       = Dropout(dropoutRate)(block3)
    
    block4       = Conv2D(200, (1, 5),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(block3)
    block4       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block4)
    block4       = Activation('elu')(block4)
    block4       = MaxPooling2D(pool_size=(1, 2), strides=(1, 2))(block4)
    block4       = Dropout(dropoutRate)(block4)
    
    flatten      = Flatten()(block4)
    
    dense        = Dense(nb_classes, kernel_constraint = max_norm(0.5))(flatten)
    softmax      = Activation('softmax')(dense)
    
    return Model(inputs=input_main, outputs=softmax)


# need these for ShallowConvNet
def square(x):
    return K.square(x)

def log(x):
    return K.log(K.clip(x, min_value = 1e-7, max_value = 10000))   


def ShallowConvNet(nb_classes, Chans = 64, Samples = 128, dropoutRate = 0.5):
    """ Keras implementation of the Shallow Convolutional Network as described
    in Schirrmeister et. al. (2017), Human Brain Mapping.
    
    Assumes the input is a 2-second EEG signal sampled at 128Hz. Note that in 
    the original paper, they do temporal convolutions of length 25 for EEG
    data sampled at 250Hz. We instead use length 13 since the sampling rate is 
    roughly half of the 250Hz which the paper used. The pool_size and stride
    in later layers is also approximately half of what is used in the paper.
    
    Note that we use the max_norm constraint on all convolutional layers, as 
    well as the classification layer. We also change the defaults for the
    BatchNormalization layer. We used this based on a personal communication 
    with the original authors.
    
                     ours        original paper
    pool_size        1, 35       1, 75
    strides          1, 7        1, 15
    conv filters     1, 13       1, 25    
    
    Note that this implementation has not been verified by the original 
    authors. We do note that this implementation reproduces the results in the
    original paper with minor deviations. 
    """

    # start the model
    input_main   = Input((Chans, Samples, 1))
    block1       = Conv2D(40, (1, 13), 
                                 input_shape=(Chans, Samples, 1),
                                 kernel_constraint = max_norm(2., axis=(0,1,2)))(input_main)
    block1       = Conv2D(40, (Chans, 1), use_bias=False, 
                          kernel_constraint = max_norm(2., axis=(0,1,2)))(block1)
    block1       = BatchNormalization(epsilon=1e-05, momentum=0.9)(block1)
    block1       = Activation(square)(block1)
    block1       = AveragePooling2D(pool_size=(1, 35), strides=(1, 7))(block1)
    block1       = Activation(log)(block1)
    block1       = Dropout(dropoutRate)(block1)
    flatten      = Flatten()(block1)
    dense        = Dense(nb_classes, kernel_constraint = max_norm(0.5))(flatten)
    softmax      = Activation('softmax')(dense)
    
    return Model(inputs=input_main, outputs=softmax)

# %% [markdown]
# # Train Classifier
#
# The code in the following code blocks were written by our team to train and evaluate the opensource EEGNet, ShallowConvNet, and DeepConvNet models which are implemented above.

# %% [markdown]
# ## Delta Classifier

# %%
import tensorflow as tf
# from arl_eegmodels.EEGModels import EEGNet, DeepConvNet, ShallowConvNet
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# To be used for training the model on the opensource dataset

# Train data - 70% of opensource dataset
# Validation data - 30% of opensource dataset
# Test data - data collected from EEG


# Define initial model parameters
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy()
optimizer = 'adam'
metrics = ['accuracy']
epochs = 500
channels = num_desired_channels
classes = 2
dropout = 0.25
F1 = 8
F2 = 16
samples = 60

# EEGNet Implementation
model = EEGNet(nb_classes=classes, Chans=num_desired_channels, Samples=samples, dropoutRate=dropout, F1=F1, F2=F2)
model.compile(loss=loss_fn, optimizer=optimizer, metrics=metrics)
# eeg_net_checkpoint = ModelCheckpoint(filepath='/trained_models/eeg_net_checkpoint.h5', verbose=1, save_best_only=True)

# Fit and train the model
eegnet_history = model.fit(
    delta_x_train, delta_y_train, batch_size=16, epochs=epochs, verbose=2, validation_data=(delta_x_test, delta_y_test)
)

# Evaluate accuracy on test data
probabilities = model.predict(delta_x_test)
predictions = probabilities.argmax(axis=-1)

accuracy = accuracy_score(delta_y_test, predictions)
conf_matrix = confusion_matrix(delta_y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)
f1 = f1_score(delta_y_test, predictions)
# roc_auc = roc_auc_score(y_test, probabilities)


print('EEGNet Accuracy Metrics')
print(f'Accuracy: {accuracy}')
print(f'F1 Score: {f1}')
# print(confusion_matrix)
disp.plot()
plt.show()
# print(f'AUC Score: {roc_auc}')

# EEGNet Accuracy Plot
plt.plot(eegnet_history.history['accuracy'])
plt.plot(eegnet_history.history['val_accuracy'])
plt.title('EEGNet Accuracy During Training')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()

# EEGNet Loss Plot
plt.plot(eegnet_history.history['loss'])
plt.plot(eegnet_history.history['val_loss'])
plt.title('EEGNet Loss During Training')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()


# ShallowConvNet Implementation
shallow_conv_net_model = ShallowConvNet(nb_classes=classes, Chans=num_desired_channels, Samples=samples, dropoutRate=dropout)
shallow_conv_net_model.compile(loss=loss_fn, optimizer=optimizer, metrics=metrics)
# shallow_conv_net_checkpoint = ModelCheckpoint(
#     filepath='/trained_models/shallow_conv_net_checkpoint.h5', verbose=1, save_best_only=True
# )

# Fit and train the model
shallowconvnet_history = shallow_conv_net_model.fit(
    delta_x_train, delta_y_train, batch_size=16, epochs=epochs, verbose=2, validation_data=(delta_x_test, delta_y_test)
)

# Evaluate accuracy on test data
probabilities = shallow_conv_net_model.predict(delta_x_test)
predictions = probabilities.argmax(axis=-1)

accuracy = accuracy_score(delta_y_test, predictions)
conf_matrix = confusion_matrix(delta_y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)
f1 = f1_score(delta_y_test, predictions)
# roc_auc = roc_auc_score(y_test, probabilities)


print('Shallow Conv Net Accuracy Metrics')
print(f'Accuracy: {accuracy}')
print(f'F1 Score: {f1}')
# print(confusion_matrix)
disp.plot()
plt.show()
# print(f'AUC Score: {roc_auc}')

# ShallowConvNet Accuracy Plot
plt.plot(shallowconvnet_history.history['accuracy'])
plt.plot(shallowconvnet_history.history['val_accuracy'])
plt.title('ShallowConvNet Accuracy During Training')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()

# ShallowConvNet Loss Plot
plt.plot(shallowconvnet_history.history['loss'])
plt.plot(shallowconvnet_history.history['val_loss'])
plt.title('ShallowConvNet Loss During Training')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()
# Out:
# Epoch 1/500
# 2/2 - 14s - loss: 0.8708 - accuracy: 0.4643 - val_loss: 0.6985 - val_accuracy: 0.4167 - 14s/epoch - 7s/step
# Epoch 2/500
# 2/2 - 0s - loss: 0.6952 - accuracy: 0.5357 - val_loss: 0.6944 - val_accuracy: 0.5000 - 70ms/epoch - 35ms/step
# Epoch 3/500
# 2/2 - 0s - loss: 0.6856 - accuracy: 0.5357 - val_loss: 0.6931 - val_accuracy: 0.5833 - 73ms/epoch - 37ms/step
# Epoch 4/500
# 2/2 - 0s - loss: 0.6920 - accuracy: 0.4643 - val_loss: 0.6925 - val_accuracy: 0.5833 - 75ms/epoch - 38ms/step
# Epoch 5/500
# 2/2 - 0s - loss: 0.6778 - accuracy: 0.5000 - val_loss: 0.6924 - val_accuracy: 0.5833 - 99ms/epoch - 50ms/step
# Epoch 6/500
# 2/2 - 0s - loss: 0.6825 - accuracy: 0.6071 - val_loss: 0.6923 - val_accuracy: 0.5833 - 68ms/epoch - 34ms/step
# Epoch 7/500
# 2/2 - 0s - loss: 0.6983 - accuracy: 0.4643 - val_loss: 0.6924 - val_accuracy: 0.5833 - 72ms/epoch - 36ms/step
# Epoch 8/500
# 2/2 - 0s - loss: 0.6603 - accuracy: 0.7143 - val_loss: 0.6924 - val_accuracy: 0.5833 - 73ms/epoch - 36ms/step
# Epoch 9/500
# 2/2 - 0s - loss: 0.6783 - accuracy: 0.6071 - val_loss: 0.6925 - val_accuracy: 0.5833 - 55ms/epoch - 28ms/step
# Epoch 10/500
# 2/2 - 0s - loss: 0.6532 - accuracy: 0.6786 - val_loss: 0.6926 - val_accuracy: 0.5833 - 53ms/epoch - 27ms/step
# Epoch 11/500
# 2/2 - 0s - loss: 0.6648 - accuracy: 0.7143 - val_loss: 0.6927 - val_accuracy: 0.5833 - 67ms/epoch - 34ms/step
# Epoch 12/500
# 2/2 - 0s - loss: 0.6784 - accuracy: 0.5357 - val_loss: 0.6927 - val_accuracy: 0.5833 - 73ms/epoch - 36ms/step
# Epoch 13/500
# 2/2 - 0s - loss: 0.6730 - accuracy: 0.6071 - val_loss: 0.6929 - val_accuracy: 0.5000 - 67ms/epoch - 33ms/step
# Epoch 14/500
# 2/2 - 0s - loss: 0.6398 - accuracy: 0.7857 - val_loss: 0.6930 - val_accuracy: 0.5000 - 68ms/epoch - 34ms/step
# Epoch 15/500
# 2/2 - 0s - loss: 0.6573 - accuracy: 0.6429 - val_loss: 0.6932 - val_accuracy: 0.5000 - 72ms/epoch - 36ms/step
# Epoch 16/500
# 2/2 - 0s - loss: 0.6705 - accuracy: 0.6429 - val_loss: 0.6933 - val_accuracy: 0.5000 - 59ms/epoch - 29ms/step
# Epoch 17/500
# 2/2 - 0s - loss: 0.6669 - accuracy: 0.5357 - val_loss: 0.6934 - val_accuracy: 0.5000 - 79ms/epoch - 40ms/step
# Epoch 18/500
# 2/2 - 0s - loss: 0.6474 - accuracy: 0.7143 - val_loss: 0.6935 - val_accuracy: 0.5000 - 58ms/epoch - 29ms/step
# Epoch 19/500
# 2/2 - 0s - loss: 0.6579 - accuracy: 0.6071 - val_loss: 0.6936 - val_accuracy: 0.5000 - 68ms/epoch - 34ms/step
# Epoch 20/500
# 2/2 - 0s - loss: 0.6587 - accuracy: 0.7143 - val_loss: 0.6939 - val_accuracy: 0.5000 - 119ms/epoch - 59ms/step
# Epoch 21/500
# 2/2 - 0s - loss: 0.6526 - accuracy: 0.6071 - val_loss: 0.6942 - val_accuracy: 0.5000 - 122ms/epoch - 61ms/step
# Epoch 22/500
# 2/2 - 0s - loss: 0.6671 - accuracy: 0.5714 - val_loss: 0.6943 - val_accuracy: 0.5000 - 150ms/epoch - 75ms/step
# Epoch 23/500
# 2/2 - 0s - loss: 0.6096 - accuracy: 0.7857 - val_loss: 0.6946 - val_accuracy: 0.5000 - 141ms/epoch - 70ms/step
# Epoch 24/500
# 2/2 - 0s - loss: 0.6497 - accuracy: 0.6071 - val_loss: 0.6949 - val_accuracy: 0.5000 - 108ms/epoch - 54ms/step
# Epoch 25/500
# 2/2 - 0s - loss: 0.6443 - accuracy: 0.7143 - val_loss: 0.6952 - val_accuracy: 0.5000 - 148ms/epoch - 74ms/step
# Epoch 26/500
# 2/2 - 0s - loss: 0.6661 - accuracy: 0.5714 - val_loss: 0.6956 - val_accuracy: 0.5000 - 201ms/epoch - 101ms/step
# Epoch 27/500
# 2/2 - 0s - loss: 0.6305 - accuracy: 0.6786 - val_loss: 0.6960 - val_accuracy: 0.5000 - 96ms/epoch - 48ms/step
# Epoch 28/500
# 2/2 - 0s - loss: 0.6124 - accuracy: 0.6786 - val_loss: 0.6964 - val_accuracy: 0.5000 - 110ms/epoch - 55ms/step
# Epoch 29/500
# 2/2 - 0s - loss: 0.6282 - accuracy: 0.6429 - val_loss: 0.6969 - val_accuracy: 0.4167 - 202ms/epoch - 101ms/step
# Epoch 30/500
# 2/2 - 0s - loss: 0.6156 - accuracy: 0.6786 - val_loss: 0.6975 - val_accuracy: 0.4167 - 138ms/epoch - 69ms/step
# Epoch 31/500
# 2/2 - 0s - loss: 0.6084 - accuracy: 0.6429 - val_loss: 0.6980 - val_accuracy: 0.4167 - 153ms/epoch - 76ms/step
# Epoch 32/500
# 2/2 - 0s - loss: 0.6158 - accuracy: 0.6786 - val_loss: 0.6986 - val_accuracy: 0.4167 - 178ms/epoch - 89ms/step
# Epoch 33/500
# 2/2 - 0s - loss: 0.6263 - accuracy: 0.6786 - val_loss: 0.6991 - val_accuracy: 0.4167 - 173ms/epoch - 87ms/step
# Epoch 34/500
# 2/2 - 0s - loss: 0.6199 - accuracy: 0.7857 - val_loss: 0.6994 - val_accuracy: 0.4167 - 139ms/epoch - 70ms/step
# Epoch 35/500
# 2/2 - 0s - loss: 0.6093 - accuracy: 0.6429 - val_loss: 0.6997 - val_accuracy: 0.4167 - 99ms/epoch - 50ms/step
# Epoch 36/500
# 2/2 - 0s - loss: 0.6269 - accuracy: 0.6071 - val_loss: 0.7001 - val_accuracy: 0.4167 - 138ms/epoch - 69ms/step
# Epoch 37/500
# 2/2 - 0s - loss: 0.5902 - accuracy: 0.7857 - val_loss: 0.7005 - val_accuracy: 0.4167 - 165ms/epoch - 82ms/step
# Epoch 38/500
# 2/2 - 0s - loss: 0.5588 - accuracy: 0.7857 - val_loss: 0.7010 - val_accuracy: 0.4167 - 119ms/epoch - 59ms/step
# Epoch 39/500
# 2/2 - 0s - loss: 0.5736 - accuracy: 0.7857 - val_loss: 0.7017 - val_accuracy: 0.4167 - 102ms/epoch - 51ms/step
# Epoch 40/500
# 2/2 - 0s - loss: 0.6039 - accuracy: 0.6429 - val_loss: 0.7025 - val_accuracy: 0.4167 - 71ms/epoch - 36ms/step
# Epoch 41/500
# 2/2 - 0s - loss: 0.6129 - accuracy: 0.6429 - val_loss: 0.7034 - val_accuracy: 0.4167 - 70ms/epoch - 35ms/step
# Epoch 42/500
# 2/2 - 0s - loss: 0.5672 - accuracy: 0.7143 - val_loss: 0.7044 - val_accuracy: 0.4167 - 73ms/epoch - 36ms/step
# Epoch 43/500
# 2/2 - 0s - loss: 0.6004 - accuracy: 0.7500 - val_loss: 0.7056 - val_accuracy: 0.3333 - 76ms/epoch - 38ms/step
# Epoch 44/500
# 2/2 - 0s - loss: 0.5668 - accuracy: 0.6786 - val_loss: 0.7068 - val_accuracy: 0.3333 - 105ms/epoch - 52ms/step
# Epoch 45/500
# 2/2 - 0s - loss: 0.5748 - accuracy: 0.6786 - val_loss: 0.7078 - val_accuracy: 0.3333 - 70ms/epoch - 35ms/step
# Epoch 46/500
# 2/2 - 0s - loss: 0.5645 - accuracy: 0.7500 - val_loss: 0.7089 - val_accuracy: 0.2500 - 78ms/epoch - 39ms/step
# Epoch 47/500
# 2/2 - 0s - loss: 0.5437 - accuracy: 0.7857 - val_loss: 0.7100 - val_accuracy: 0.2500 - 86ms/epoch - 43ms/step
# Epoch 48/500
# 2/2 - 0s - loss: 0.5678 - accuracy: 0.6786 - val_loss: 0.7112 - val_accuracy: 0.2500 - 74ms/epoch - 37ms/step
# Epoch 49/500
# 2/2 - 0s - loss: 0.5400 - accuracy: 0.7857 - val_loss: 0.7122 - val_accuracy: 0.2500 - 102ms/epoch - 51ms/step
# Epoch 50/500
# 2/2 - 0s - loss: 0.5791 - accuracy: 0.6429 - val_loss: 0.7131 - val_accuracy: 0.2500 - 76ms/epoch - 38ms/step
# Epoch 51/500
# 2/2 - 0s - loss: 0.5495 - accuracy: 0.7143 - val_loss: 0.7140 - val_accuracy: 0.3333 - 111ms/epoch - 55ms/step
# Epoch 52/500
# 2/2 - 0s - loss: 0.5232 - accuracy: 0.7857 - val_loss: 0.7148 - val_accuracy: 0.3333 - 147ms/epoch - 73ms/step
# Epoch 53/500
# 2/2 - 0s - loss: 0.5005 - accuracy: 0.8571 - val_loss: 0.7156 - val_accuracy: 0.3333 - 85ms/epoch - 42ms/step
# Epoch 54/500
# 2/2 - 0s - loss: 0.5188 - accuracy: 0.7857 - val_loss: 0.7166 - val_accuracy: 0.3333 - 79ms/epoch - 39ms/step
# Epoch 55/500
# 2/2 - 0s - loss: 0.4978 - accuracy: 0.8214 - val_loss: 0.7175 - val_accuracy: 0.3333 - 65ms/epoch - 32ms/step
# Epoch 56/500
# 2/2 - 0s - loss: 0.5152 - accuracy: 0.7500 - val_loss: 0.7186 - val_accuracy: 0.3333 - 139ms/epoch - 70ms/step
# Epoch 57/500
# 2/2 - 0s - loss: 0.5087 - accuracy: 0.7500 - val_loss: 0.7198 - val_accuracy: 0.3333 - 109ms/epoch - 54ms/step
# Epoch 58/500
# 2/2 - 0s - loss: 0.5229 - accuracy: 0.8571 - val_loss: 0.7207 - val_accuracy: 0.3333 - 73ms/epoch - 36ms/step
# Epoch 59/500
# 2/2 - 0s - loss: 0.5049 - accuracy: 0.8571 - val_loss: 0.7218 - val_accuracy: 0.3333 - 74ms/epoch - 37ms/step
# Epoch 60/500
# 2/2 - 0s - loss: 0.4500 - accuracy: 0.8214 - val_loss: 0.7229 - val_accuracy: 0.3333 - 91ms/epoch - 46ms/step
# Epoch 61/500
# 2/2 - 0s - loss: 0.4713 - accuracy: 0.8214 - val_loss: 0.7241 - val_accuracy: 0.3333 - 77ms/epoch - 39ms/step
# Epoch 62/500
# 2/2 - 0s - loss: 0.5193 - accuracy: 0.8214 - val_loss: 0.7261 - val_accuracy: 0.3333 - 174ms/epoch - 87ms/step
# Epoch 63/500
# 2/2 - 0s - loss: 0.4836 - accuracy: 0.8929 - val_loss: 0.7284 - val_accuracy: 0.3333 - 78ms/epoch - 39ms/step
# Epoch 64/500
# 2/2 - 0s - loss: 0.4941 - accuracy: 0.8929 - val_loss: 0.7304 - val_accuracy: 0.3333 - 147ms/epoch - 73ms/step
# Epoch 65/500
# 2/2 - 0s - loss: 0.4879 - accuracy: 0.8214 - val_loss: 0.7320 - val_accuracy: 0.3333 - 143ms/epoch - 72ms/step
# Epoch 66/500
# 2/2 - 0s - loss: 0.4414 - accuracy: 0.9286 - val_loss: 0.7337 - val_accuracy: 0.3333 - 75ms/epoch - 38ms/step
# Epoch 67/500
# 2/2 - 0s - loss: 0.4632 - accuracy: 0.8571 - val_loss: 0.7359 - val_accuracy: 0.3333 - 84ms/epoch - 42ms/step
# Epoch 68/500
# 2/2 - 0s - loss: 0.4287 - accuracy: 0.8571 - val_loss: 0.7376 - val_accuracy: 0.3333 - 60ms/epoch - 30ms/step
# Epoch 69/500
# 2/2 - 0s - loss: 0.4342 - accuracy: 0.8929 - val_loss: 0.7393 - val_accuracy: 0.3333 - 118ms/epoch - 59ms/step
# Epoch 70/500
# 2/2 - 0s - loss: 0.4574 - accuracy: 0.8929 - val_loss: 0.7393 - val_accuracy: 0.3333 - 88ms/epoch - 44ms/step
# Epoch 71/500
# 2/2 - 0s - loss: 0.5367 - accuracy: 0.6786 - val_loss: 0.7394 - val_accuracy: 0.3333 - 101ms/epoch - 50ms/step
# Epoch 72/500
# 2/2 - 0s - loss: 0.4908 - accuracy: 0.8214 - val_loss: 0.7399 - val_accuracy: 0.3333 - 84ms/epoch - 42ms/step
# Epoch 73/500
# 2/2 - 0s - loss: 0.4385 - accuracy: 0.8571 - val_loss: 0.7406 - val_accuracy: 0.3333 - 80ms/epoch - 40ms/step
# Epoch 74/500
# 2/2 - 0s - loss: 0.4468 - accuracy: 0.8929 - val_loss: 0.7417 - val_accuracy: 0.3333 - 82ms/epoch - 41ms/step
# Epoch 75/500
# 2/2 - 0s - loss: 0.4620 - accuracy: 0.8214 - val_loss: 0.7429 - val_accuracy: 0.3333 - 87ms/epoch - 43ms/step
# Epoch 76/500
# 2/2 - 0s - loss: 0.4524 - accuracy: 0.8571 - val_loss: 0.7445 - val_accuracy: 0.3333 - 88ms/epoch - 44ms/step
# Epoch 77/500
# 2/2 - 0s - loss: 0.4427 - accuracy: 0.8571 - val_loss: 0.7461 - val_accuracy: 0.3333 - 146ms/epoch - 73ms/step
# Epoch 78/500
# 2/2 - 0s - loss: 0.4615 - accuracy: 0.8571 - val_loss: 0.7472 - val_accuracy: 0.3333 - 154ms/epoch - 77ms/step
# Epoch 79/500
# 2/2 - 0s - loss: 0.4444 - accuracy: 0.8571 - val_loss: 0.7488 - val_accuracy: 0.3333 - 148ms/epoch - 74ms/step
# Epoch 80/500
# 2/2 - 0s - loss: 0.4356 - accuracy: 0.8571 - val_loss: 0.7495 - val_accuracy: 0.3333 - 84ms/epoch - 42ms/step
# Epoch 81/500
# 2/2 - 0s - loss: 0.3781 - accuracy: 0.9286 - val_loss: 0.7493 - val_accuracy: 0.3333 - 62ms/epoch - 31ms/step
# Epoch 82/500
# 2/2 - 0s - loss: 0.4496 - accuracy: 0.8214 - val_loss: 0.7499 - val_accuracy: 0.3333 - 56ms/epoch - 28ms/step
# Epoch 83/500
# 2/2 - 0s - loss: 0.4035 - accuracy: 0.9286 - val_loss: 0.7513 - val_accuracy: 0.3333 - 60ms/epoch - 30ms/step
# Epoch 84/500
# 2/2 - 0s - loss: 0.3857 - accuracy: 0.8929 - val_loss: 0.7526 - val_accuracy: 0.3333 - 87ms/epoch - 44ms/step
# Epoch 85/500
# 2/2 - 0s - loss: 0.4173 - accuracy: 0.8929 - val_loss: 0.7534 - val_accuracy: 0.3333 - 170ms/epoch - 85ms/step
# Epoch 86/500
# 2/2 - 0s - loss: 0.4693 - accuracy: 0.7500 - val_loss: 0.7551 - val_accuracy: 0.3333 - 69ms/epoch - 34ms/step
# Epoch 87/500
# 2/2 - 0s - loss: 0.4400 - accuracy: 0.7857 - val_loss: 0.7567 - val_accuracy: 0.3333 - 80ms/epoch - 40ms/step
# Epoch 88/500
# 2/2 - 0s - loss: 0.4637 - accuracy: 0.7500 - val_loss: 0.7585 - val_accuracy: 0.3333 - 107ms/epoch - 53ms/step
# Epoch 89/500
# 2/2 - 0s - loss: 0.4053 - accuracy: 0.8929 - val_loss: 0.7596 - val_accuracy: 0.3333 - 143ms/epoch - 71ms/step
# Epoch 90/500
# 2/2 - 0s - loss: 0.3778 - accuracy: 0.9643 - val_loss: 0.7614 - val_accuracy: 0.3333 - 93ms/epoch - 47ms/step
# Epoch 91/500
# 2/2 - 0s - loss: 0.3684 - accuracy: 0.9286 - val_loss: 0.7634 - val_accuracy: 0.3333 - 97ms/epoch - 49ms/step
# Epoch 92/500
# 2/2 - 0s - loss: 0.3828 - accuracy: 0.9286 - val_loss: 0.7658 - val_accuracy: 0.3333 - 105ms/epoch - 53ms/step
# Epoch 93/500
# 2/2 - 0s - loss: 0.4197 - accuracy: 0.7857 - val_loss: 0.7688 - val_accuracy: 0.3333 - 78ms/epoch - 39ms/step
# Epoch 94/500
# 2/2 - 0s - loss: 0.3592 - accuracy: 0.8929 - val_loss: 0.7722 - val_accuracy: 0.3333 - 73ms/epoch - 37ms/step
# Epoch 95/500
# 2/2 - 0s - loss: 0.3893 - accuracy: 0.8214 - val_loss: 0.7738 - val_accuracy: 0.3333 - 102ms/epoch - 51ms/step
# Epoch 96/500
# 2/2 - 0s - loss: 0.3837 - accuracy: 0.9286 - val_loss: 0.7758 - val_accuracy: 0.3333 - 69ms/epoch - 35ms/step
# Epoch 97/500
# 2/2 - 0s - loss: 0.4082 - accuracy: 0.8929 - val_loss: 0.7767 - val_accuracy: 0.3333 - 104ms/epoch - 52ms/step
# Epoch 98/500
# 2/2 - 0s - loss: 0.3762 - accuracy: 0.8929 - val_loss: 0.7774 - val_accuracy: 0.3333 - 76ms/epoch - 38ms/step
# Epoch 99/500
# 2/2 - 0s - loss: 0.4008 - accuracy: 0.8571 - val_loss: 0.7785 - val_accuracy: 0.3333 - 85ms/epoch - 42ms/step
# Epoch 100/500
# 2/2 - 0s - loss: 0.3068 - accuracy: 0.9286 - val_loss: 0.7807 - val_accuracy: 0.3333 - 79ms/epoch - 39ms/step
# Epoch 101/500
# 2/2 - 0s - loss: 0.3575 - accuracy: 0.8929 - val_loss: 0.7830 - val_accuracy: 0.3333 - 75ms/epoch - 37ms/step
# Epoch 102/500
# 2/2 - 0s - loss: 0.3890 - accuracy: 0.8214 - val_loss: 0.7850 - val_accuracy: 0.3333 - 74ms/epoch - 37ms/step
# Epoch 103/500
# 2/2 - 0s - loss: 0.3977 - accuracy: 0.8929 - val_loss: 0.7871 - val_accuracy: 0.3333 - 78ms/epoch - 39ms/step
# Epoch 104/500
# 2/2 - 0s - loss: 0.3871 - accuracy: 0.8571 - val_loss: 0.7881 - val_accuracy: 0.3333 - 75ms/epoch - 37ms/step
# Epoch 105/500
# 2/2 - 0s - loss: 0.3336 - accuracy: 0.9286 - val_loss: 0.7891 - val_accuracy: 0.3333 - 75ms/epoch - 38ms/step
# Epoch 106/500
# 2/2 - 0s - loss: 0.3848 - accuracy: 0.8929 - val_loss: 0.7907 - val_accuracy: 0.3333 - 80ms/epoch - 40ms/step
# Epoch 107/500
# 2/2 - 0s - loss: 0.3211 - accuracy: 0.9286 - val_loss: 0.7928 - val_accuracy: 0.3333 - 75ms/epoch - 38ms/step
# Epoch 108/500
# 2/2 - 0s - loss: 0.4040 - accuracy: 0.8214 - val_loss: 0.7954 - val_accuracy: 0.3333 - 73ms/epoch - 37ms/step
# Epoch 109/500
# 2/2 - 0s - loss: 0.3921 - accuracy: 0.8929 - val_loss: 0.7976 - val_accuracy: 0.3333 - 93ms/epoch - 46ms/step
# Epoch 110/500
# 2/2 - 0s - loss: 0.3542 - accuracy: 0.8571 - val_loss: 0.7995 - val_accuracy: 0.3333 - 100ms/epoch - 50ms/step
# Epoch 111/500
# 2/2 - 0s - loss: 0.3394 - accuracy: 0.8929 - val_loss: 0.8009 - val_accuracy: 0.3333 - 80ms/epoch - 40ms/step
# Epoch 112/500
# 2/2 - 0s - loss: 0.3422 - accuracy: 0.9286 - val_loss: 0.8030 - val_accuracy: 0.3333 - 90ms/epoch - 45ms/step
# Epoch 113/500
# 2/2 - 0s - loss: 0.3510 - accuracy: 0.8929 - val_loss: 0.8059 - val_accuracy: 0.3333 - 88ms/epoch - 44ms/step
# Epoch 114/500
# 2/2 - 0s - loss: 0.3372 - accuracy: 0.9286 - val_loss: 0.8089 - val_accuracy: 0.3333 - 117ms/epoch - 58ms/step
# Epoch 115/500
# 2/2 - 0s - loss: 0.3819 - accuracy: 0.8571 - val_loss: 0.8125 - val_accuracy: 0.3333 - 76ms/epoch - 38ms/step
# Epoch 116/500
# 2/2 - 0s - loss: 0.3229 - accuracy: 0.9643 - val_loss: 0.8160 - val_accuracy: 0.3333 - 57ms/epoch - 28ms/step
# Epoch 117/500
# 2/2 - 0s - loss: 0.3609 - accuracy: 0.9286 - val_loss: 0.8192 - val_accuracy: 0.3333 - 92ms/epoch - 46ms/step
# Epoch 118/500
# 2/2 - 0s - loss: 0.3354 - accuracy: 0.9286 - val_loss: 0.8220 - val_accuracy: 0.3333 - 73ms/epoch - 37ms/step
# Epoch 119/500
# 2/2 - 0s - loss: 0.2836 - accuracy: 1.0000 - val_loss: 0.8250 - val_accuracy: 0.3333 - 81ms/epoch - 41ms/step
# Epoch 120/500
# 2/2 - 0s - loss: 0.3813 - accuracy: 0.8571 - val_loss: 0.8282 - val_accuracy: 0.3333 - 137ms/epoch - 69ms/step
# Epoch 121/500
# 2/2 - 0s - loss: 0.3469 - accuracy: 0.9286 - val_loss: 0.8307 - val_accuracy: 0.3333 - 121ms/epoch - 60ms/step
# Epoch 122/500
# 2/2 - 0s - loss: 0.2655 - accuracy: 1.0000 - val_loss: 0.8335 - val_accuracy: 0.3333 - 154ms/epoch - 77ms/step
# Epoch 123/500
# 2/2 - 0s - loss: 0.3094 - accuracy: 0.8929 - val_loss: 0.8366 - val_accuracy: 0.3333 - 222ms/epoch - 111ms/step
# Epoch 124/500
# 2/2 - 0s - loss: 0.3288 - accuracy: 0.9286 - val_loss: 0.8402 - val_accuracy: 0.3333 - 169ms/epoch - 85ms/step
# Epoch 125/500
# 2/2 - 0s - loss: 0.2764 - accuracy: 0.9643 - val_loss: 0.8440 - val_accuracy: 0.3333 - 145ms/epoch - 73ms/step
# Epoch 126/500
# 2/2 - 0s - loss: 0.3106 - accuracy: 0.9286 - val_loss: 0.8468 - val_accuracy: 0.3333 - 112ms/epoch - 56ms/step
# Epoch 127/500
# 2/2 - 0s - loss: 0.3050 - accuracy: 0.9643 - val_loss: 0.8494 - val_accuracy: 0.3333 - 118ms/epoch - 59ms/step
# Epoch 128/500
# 2/2 - 0s - loss: 0.3315 - accuracy: 0.9286 - val_loss: 0.8514 - val_accuracy: 0.3333 - 177ms/epoch - 88ms/step
# Epoch 129/500
# 2/2 - 0s - loss: 0.3341 - accuracy: 0.8929 - val_loss: 0.8532 - val_accuracy: 0.3333 - 197ms/epoch - 99ms/step
# Epoch 130/500
# 2/2 - 0s - loss: 0.3744 - accuracy: 0.8214 - val_loss: 0.8565 - val_accuracy: 0.4167 - 184ms/epoch - 92ms/step
# Epoch 131/500
# 2/2 - 0s - loss: 0.3335 - accuracy: 0.8571 - val_loss: 0.8612 - val_accuracy: 0.4167 - 254ms/epoch - 127ms/step
# Epoch 132/500
# 2/2 - 0s - loss: 0.2779 - accuracy: 0.9643 - val_loss: 0.8637 - val_accuracy: 0.3333 - 201ms/epoch - 100ms/step
# Epoch 133/500
# 2/2 - 0s - loss: 0.3677 - accuracy: 0.8571 - val_loss: 0.8679 - val_accuracy: 0.4167 - 165ms/epoch - 82ms/step
# Epoch 134/500
# 2/2 - 0s - loss: 0.2755 - accuracy: 0.9643 - val_loss: 0.8710 - val_accuracy: 0.4167 - 277ms/epoch - 139ms/step
# Epoch 135/500
# 2/2 - 0s - loss: 0.2799 - accuracy: 1.0000 - val_loss: 0.8705 - val_accuracy: 0.4167 - 229ms/epoch - 114ms/step
# Epoch 136/500
# 2/2 - 0s - loss: 0.2522 - accuracy: 0.9643 - val_loss: 0.8681 - val_accuracy: 0.4167 - 187ms/epoch - 94ms/step
# Epoch 137/500
# 2/2 - 0s - loss: 0.3226 - accuracy: 0.8929 - val_loss: 0.8660 - val_accuracy: 0.3333 - 137ms/epoch - 69ms/step
# Epoch 138/500
# 2/2 - 0s - loss: 0.3183 - accuracy: 0.8929 - val_loss: 0.8639 - val_accuracy: 0.4167 - 152ms/epoch - 76ms/step
# Epoch 139/500
# 2/2 - 0s - loss: 0.2603 - accuracy: 1.0000 - val_loss: 0.8632 - val_accuracy: 0.4167 - 130ms/epoch - 65ms/step
# Epoch 140/500
# 2/2 - 0s - loss: 0.2524 - accuracy: 0.9643 - val_loss: 0.8632 - val_accuracy: 0.4167 - 112ms/epoch - 56ms/step
# Epoch 141/500
# 2/2 - 0s - loss: 0.2413 - accuracy: 1.0000 - val_loss: 0.8643 - val_accuracy: 0.3333 - 195ms/epoch - 98ms/step
# Epoch 142/500
# 2/2 - 0s - loss: 0.2753 - accuracy: 0.9643 - val_loss: 0.8665 - val_accuracy: 0.3333 - 104ms/epoch - 52ms/step
# Epoch 143/500
# 2/2 - 0s - loss: 0.2518 - accuracy: 0.9643 - val_loss: 0.8699 - val_accuracy: 0.3333 - 120ms/epoch - 60ms/step
# Epoch 144/500
# 2/2 - 0s - loss: 0.3208 - accuracy: 0.9643 - val_loss: 0.8729 - val_accuracy: 0.3333 - 157ms/epoch - 79ms/step
# Epoch 145/500
# 2/2 - 0s - loss: 0.2949 - accuracy: 0.9643 - val_loss: 0.8786 - val_accuracy: 0.3333 - 231ms/epoch - 115ms/step
# Epoch 146/500
# 2/2 - 0s - loss: 0.3994 - accuracy: 0.8214 - val_loss: 0.8834 - val_accuracy: 0.3333 - 267ms/epoch - 133ms/step
# Epoch 147/500
# 2/2 - 0s - loss: 0.2380 - accuracy: 0.9643 - val_loss: 0.8886 - val_accuracy: 0.4167 - 265ms/epoch - 133ms/step
# Epoch 148/500
# 2/2 - 0s - loss: 0.2501 - accuracy: 1.0000 - val_loss: 0.8962 - val_accuracy: 0.4167 - 181ms/epoch - 90ms/step
# Epoch 149/500
# 2/2 - 0s - loss: 0.2800 - accuracy: 0.9643 - val_loss: 0.9046 - val_accuracy: 0.4167 - 200ms/epoch - 100ms/step
# Epoch 150/500
# 2/2 - 0s - loss: 0.2313 - accuracy: 1.0000 - val_loss: 0.9097 - val_accuracy: 0.4167 - 112ms/epoch - 56ms/step
# Epoch 151/500
# 2/2 - 0s - loss: 0.2144 - accuracy: 1.0000 - val_loss: 0.9107 - val_accuracy: 0.4167 - 161ms/epoch - 80ms/step
# Epoch 152/500
# 2/2 - 0s - loss: 0.2625 - accuracy: 0.9643 - val_loss: 0.9093 - val_accuracy: 0.3333 - 112ms/epoch - 56ms/step
# Epoch 153/500
# 2/2 - 0s - loss: 0.2421 - accuracy: 1.0000 - val_loss: 0.9065 - val_accuracy: 0.4167 - 72ms/epoch - 36ms/step
# Epoch 154/500
# 2/2 - 0s - loss: 0.2459 - accuracy: 0.9643 - val_loss: 0.9061 - val_accuracy: 0.3333 - 70ms/epoch - 35ms/step
# Epoch 155/500
# 2/2 - 0s - loss: 0.2408 - accuracy: 0.9643 - val_loss: 0.9065 - val_accuracy: 0.3333 - 49ms/epoch - 24ms/step
# Epoch 156/500
# 2/2 - 0s - loss: 0.2424 - accuracy: 1.0000 - val_loss: 0.9081 - val_accuracy: 0.3333 - 55ms/epoch - 27ms/step
# Epoch 157/500
# 2/2 - 0s - loss: 0.2209 - accuracy: 1.0000 - val_loss: 0.9100 - val_accuracy: 0.3333 - 73ms/epoch - 37ms/step
# Epoch 158/500
# 2/2 - 0s - loss: 0.2270 - accuracy: 1.0000 - val_loss: 0.9145 - val_accuracy: 0.3333 - 71ms/epoch - 35ms/step
# Epoch 159/500
# 2/2 - 0s - loss: 0.2397 - accuracy: 1.0000 - val_loss: 0.9181 - val_accuracy: 0.3333 - 52ms/epoch - 26ms/step
# Epoch 160/500
# 2/2 - 0s - loss: 0.1845 - accuracy: 1.0000 - val_loss: 0.9213 - val_accuracy: 0.3333 - 55ms/epoch - 28ms/step
# Epoch 161/500
# 2/2 - 0s - loss: 0.2415 - accuracy: 1.0000 - val_loss: 0.9228 - val_accuracy: 0.3333 - 70ms/epoch - 35ms/step
# Epoch 162/500
# 2/2 - 0s - loss: 0.2607 - accuracy: 1.0000 - val_loss: 0.9221 - val_accuracy: 0.3333 - 56ms/epoch - 28ms/step
# Epoch 163/500
# 2/2 - 0s - loss: 0.1954 - accuracy: 1.0000 - val_loss: 0.9214 - val_accuracy: 0.3333 - 68ms/epoch - 34ms/step
# Epoch 164/500
# 2/2 - 0s - loss: 0.2149 - accuracy: 1.0000 - val_loss: 0.9222 - val_accuracy: 0.3333 - 55ms/epoch - 28ms/step
# Epoch 165/500
# 2/2 - 0s - loss: 0.3225 - accuracy: 0.8929 - val_loss: 0.9248 - val_accuracy: 0.3333 - 67ms/epoch - 34ms/step
# Epoch 166/500
# 2/2 - 0s - loss: 0.2393 - accuracy: 1.0000 - val_loss: 0.9276 - val_accuracy: 0.4167 - 52ms/epoch - 26ms/step
# Epoch 167/500
# 2/2 - 0s - loss: 0.2443 - accuracy: 0.9286 - val_loss: 0.9293 - val_accuracy: 0.3333 - 41ms/epoch - 21ms/step
# Epoch 168/500
# 2/2 - 0s - loss: 0.2022 - accuracy: 1.0000 - val_loss: 0.9320 - val_accuracy: 0.3333 - 39ms/epoch - 19ms/step
# Epoch 169/500
# 2/2 - 0s - loss: 0.2219 - accuracy: 0.9643 - val_loss: 0.9382 - val_accuracy: 0.4167 - 38ms/epoch - 19ms/step
# Epoch 170/500
# 2/2 - 0s - loss: 0.2883 - accuracy: 0.9286 - val_loss: 0.9435 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 171/500
# 2/2 - 0s - loss: 0.2433 - accuracy: 0.9643 - val_loss: 0.9481 - val_accuracy: 0.4167 - 60ms/epoch - 30ms/step
# Epoch 172/500
# 2/2 - 0s - loss: 0.2047 - accuracy: 1.0000 - val_loss: 0.9512 - val_accuracy: 0.4167 - 41ms/epoch - 21ms/step
# Epoch 173/500
# 2/2 - 0s - loss: 0.1944 - accuracy: 1.0000 - val_loss: 0.9540 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 174/500
# 2/2 - 0s - loss: 0.2033 - accuracy: 1.0000 - val_loss: 0.9595 - val_accuracy: 0.3333 - 38ms/epoch - 19ms/step
# Epoch 175/500
# 2/2 - 0s - loss: 0.1850 - accuracy: 1.0000 - val_loss: 0.9676 - val_accuracy: 0.3333 - 53ms/epoch - 26ms/step
# Epoch 176/500
# 2/2 - 0s - loss: 0.1806 - accuracy: 1.0000 - val_loss: 0.9757 - val_accuracy: 0.3333 - 38ms/epoch - 19ms/step
# Epoch 177/500
# 2/2 - 0s - loss: 0.2076 - accuracy: 1.0000 - val_loss: 0.9859 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 178/500
# 2/2 - 0s - loss: 0.2350 - accuracy: 0.9286 - val_loss: 0.9990 - val_accuracy: 0.3333 - 41ms/epoch - 21ms/step
# Epoch 179/500
# 2/2 - 0s - loss: 0.2129 - accuracy: 1.0000 - val_loss: 1.0093 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 180/500
# 2/2 - 0s - loss: 0.2134 - accuracy: 0.9643 - val_loss: 1.0148 - val_accuracy: 0.3333 - 39ms/epoch - 19ms/step
# Epoch 181/500
# 2/2 - 0s - loss: 0.1852 - accuracy: 1.0000 - val_loss: 1.0159 - val_accuracy: 0.3333 - 39ms/epoch - 19ms/step
# Epoch 182/500
# 2/2 - 0s - loss: 0.1627 - accuracy: 1.0000 - val_loss: 1.0163 - val_accuracy: 0.3333 - 65ms/epoch - 33ms/step
# Epoch 183/500
# 2/2 - 0s - loss: 0.1952 - accuracy: 1.0000 - val_loss: 1.0144 - val_accuracy: 0.3333 - 43ms/epoch - 21ms/step
# Epoch 184/500
# 2/2 - 0s - loss: 0.1972 - accuracy: 1.0000 - val_loss: 1.0126 - val_accuracy: 0.3333 - 39ms/epoch - 20ms/step
# Epoch 185/500
# 2/2 - 0s - loss: 0.2151 - accuracy: 1.0000 - val_loss: 1.0141 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 186/500
# 2/2 - 0s - loss: 0.1723 - accuracy: 1.0000 - val_loss: 1.0166 - val_accuracy: 0.4167 - 57ms/epoch - 28ms/step
# Epoch 187/500
# 2/2 - 0s - loss: 0.1881 - accuracy: 1.0000 - val_loss: 1.0259 - val_accuracy: 0.3333 - 62ms/epoch - 31ms/step
# Epoch 188/500
# 2/2 - 0s - loss: 0.2385 - accuracy: 0.9643 - val_loss: 1.0353 - val_accuracy: 0.3333 - 42ms/epoch - 21ms/step
# Epoch 189/500
# 2/2 - 0s - loss: 0.1552 - accuracy: 1.0000 - val_loss: 1.0423 - val_accuracy: 0.3333 - 44ms/epoch - 22ms/step
# Epoch 190/500
# 2/2 - 0s - loss: 0.2200 - accuracy: 0.9286 - val_loss: 1.0451 - val_accuracy: 0.3333 - 43ms/epoch - 21ms/step
# Epoch 191/500
# 2/2 - 0s - loss: 0.2013 - accuracy: 0.9643 - val_loss: 1.0462 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 192/500
# 2/2 - 0s - loss: 0.1747 - accuracy: 1.0000 - val_loss: 1.0477 - val_accuracy: 0.4167 - 37ms/epoch - 19ms/step
# Epoch 193/500
# 2/2 - 0s - loss: 0.1942 - accuracy: 0.9643 - val_loss: 1.0485 - val_accuracy: 0.3333 - 38ms/epoch - 19ms/step
# Epoch 194/500
# 2/2 - 0s - loss: 0.2424 - accuracy: 0.9286 - val_loss: 1.0535 - val_accuracy: 0.3333 - 45ms/epoch - 22ms/step
# Epoch 195/500
# 2/2 - 0s - loss: 0.1809 - accuracy: 1.0000 - val_loss: 1.0582 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 196/500
# 2/2 - 0s - loss: 0.1619 - accuracy: 1.0000 - val_loss: 1.0637 - val_accuracy: 0.2500 - 42ms/epoch - 21ms/step
# Epoch 197/500
# 2/2 - 0s - loss: 0.1746 - accuracy: 1.0000 - val_loss: 1.0733 - val_accuracy: 0.3333 - 48ms/epoch - 24ms/step
# Epoch 198/500
# 2/2 - 0s - loss: 0.1558 - accuracy: 1.0000 - val_loss: 1.0797 - val_accuracy: 0.3333 - 55ms/epoch - 27ms/step
# Epoch 199/500
# 2/2 - 0s - loss: 0.1950 - accuracy: 1.0000 - val_loss: 1.0794 - val_accuracy: 0.3333 - 39ms/epoch - 20ms/step
# Epoch 200/500
# 2/2 - 0s - loss: 0.1918 - accuracy: 1.0000 - val_loss: 1.0735 - val_accuracy: 0.3333 - 47ms/epoch - 23ms/step
# Epoch 201/500
# 2/2 - 0s - loss: 0.1388 - accuracy: 1.0000 - val_loss: 1.0695 - val_accuracy: 0.3333 - 41ms/epoch - 21ms/step
# Epoch 202/500
# 2/2 - 0s - loss: 0.2110 - accuracy: 0.9643 - val_loss: 1.0706 - val_accuracy: 0.3333 - 58ms/epoch - 29ms/step
# Epoch 203/500
# 2/2 - 0s - loss: 0.1793 - accuracy: 1.0000 - val_loss: 1.0718 - val_accuracy: 0.3333 - 46ms/epoch - 23ms/step
# Epoch 204/500
# 2/2 - 0s - loss: 0.1577 - accuracy: 1.0000 - val_loss: 1.0748 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 205/500
# 2/2 - 0s - loss: 0.1852 - accuracy: 1.0000 - val_loss: 1.0787 - val_accuracy: 0.3333 - 38ms/epoch - 19ms/step
# Epoch 206/500
# 2/2 - 0s - loss: 0.1605 - accuracy: 1.0000 - val_loss: 1.0832 - val_accuracy: 0.3333 - 43ms/epoch - 22ms/step
# Epoch 207/500
# 2/2 - 0s - loss: 0.1750 - accuracy: 1.0000 - val_loss: 1.0899 - val_accuracy: 0.3333 - 41ms/epoch - 21ms/step
# Epoch 208/500
# 2/2 - 0s - loss: 0.1696 - accuracy: 0.9643 - val_loss: 1.0930 - val_accuracy: 0.3333 - 41ms/epoch - 20ms/step
# Epoch 209/500
# 2/2 - 0s - loss: 0.1615 - accuracy: 1.0000 - val_loss: 1.0972 - val_accuracy: 0.3333 - 39ms/epoch - 20ms/step
# Epoch 210/500
# 2/2 - 0s - loss: 0.1663 - accuracy: 1.0000 - val_loss: 1.1021 - val_accuracy: 0.3333 - 43ms/epoch - 22ms/step
# Epoch 211/500
# 2/2 - 0s - loss: 0.1833 - accuracy: 1.0000 - val_loss: 1.1017 - val_accuracy: 0.3333 - 39ms/epoch - 20ms/step
# Epoch 212/500
# 2/2 - 0s - loss: 0.1553 - accuracy: 1.0000 - val_loss: 1.0950 - val_accuracy: 0.2500 - 38ms/epoch - 19ms/step
# Epoch 213/500
# 2/2 - 0s - loss: 0.1761 - accuracy: 0.9643 - val_loss: 1.0871 - val_accuracy: 0.2500 - 40ms/epoch - 20ms/step
# Epoch 214/500
# 2/2 - 0s - loss: 0.1423 - accuracy: 1.0000 - val_loss: 1.0783 - val_accuracy: 0.2500 - 64ms/epoch - 32ms/step
# Epoch 215/500
# 2/2 - 0s - loss: 0.1388 - accuracy: 1.0000 - val_loss: 1.0692 - val_accuracy: 0.2500 - 39ms/epoch - 20ms/step
# Epoch 216/500
# 2/2 - 0s - loss: 0.1468 - accuracy: 1.0000 - val_loss: 1.0615 - val_accuracy: 0.2500 - 62ms/epoch - 31ms/step
# Epoch 217/500
# 2/2 - 0s - loss: 0.1569 - accuracy: 1.0000 - val_loss: 1.0651 - val_accuracy: 0.2500 - 40ms/epoch - 20ms/step
# Epoch 218/500
# 2/2 - 0s - loss: 0.1269 - accuracy: 1.0000 - val_loss: 1.0707 - val_accuracy: 0.3333 - 43ms/epoch - 21ms/step
# Epoch 219/500
# 2/2 - 0s - loss: 0.1437 - accuracy: 1.0000 - val_loss: 1.0812 - val_accuracy: 0.5000 - 51ms/epoch - 25ms/step
# Epoch 220/500
# 2/2 - 0s - loss: 0.1327 - accuracy: 1.0000 - val_loss: 1.0941 - val_accuracy: 0.5000 - 63ms/epoch - 32ms/step
# Epoch 221/500
# 2/2 - 0s - loss: 0.1513 - accuracy: 1.0000 - val_loss: 1.1027 - val_accuracy: 0.5000 - 46ms/epoch - 23ms/step
# Epoch 222/500
# 2/2 - 0s - loss: 0.1896 - accuracy: 1.0000 - val_loss: 1.1088 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 223/500
# 2/2 - 0s - loss: 0.1822 - accuracy: 1.0000 - val_loss: 1.1127 - val_accuracy: 0.4167 - 39ms/epoch - 19ms/step
# Epoch 224/500
# 2/2 - 0s - loss: 0.1444 - accuracy: 1.0000 - val_loss: 1.1160 - val_accuracy: 0.5000 - 44ms/epoch - 22ms/step
# Epoch 225/500
# 2/2 - 0s - loss: 0.1334 - accuracy: 1.0000 - val_loss: 1.1209 - val_accuracy: 0.5000 - 56ms/epoch - 28ms/step
# Epoch 226/500
# 2/2 - 0s - loss: 0.1190 - accuracy: 1.0000 - val_loss: 1.1221 - val_accuracy: 0.4167 - 42ms/epoch - 21ms/step
# Epoch 227/500
# 2/2 - 0s - loss: 0.1497 - accuracy: 1.0000 - val_loss: 1.1235 - val_accuracy: 0.3333 - 39ms/epoch - 19ms/step
# Epoch 228/500
# 2/2 - 0s - loss: 0.1267 - accuracy: 1.0000 - val_loss: 1.1280 - val_accuracy: 0.3333 - 51ms/epoch - 25ms/step
# Epoch 229/500
# 2/2 - 0s - loss: 0.1455 - accuracy: 1.0000 - val_loss: 1.1256 - val_accuracy: 0.2500 - 40ms/epoch - 20ms/step
# Epoch 230/500
# 2/2 - 0s - loss: 0.1268 - accuracy: 0.9643 - val_loss: 1.1225 - val_accuracy: 0.2500 - 42ms/epoch - 21ms/step
# Epoch 231/500
# 2/2 - 0s - loss: 0.1285 - accuracy: 1.0000 - val_loss: 1.1224 - val_accuracy: 0.2500 - 40ms/epoch - 20ms/step
# Epoch 232/500
# 2/2 - 0s - loss: 0.1666 - accuracy: 1.0000 - val_loss: 1.1242 - val_accuracy: 0.2500 - 49ms/epoch - 24ms/step
# Epoch 233/500
# 2/2 - 0s - loss: 0.1360 - accuracy: 1.0000 - val_loss: 1.1300 - val_accuracy: 0.2500 - 73ms/epoch - 37ms/step
# Epoch 234/500
# 2/2 - 0s - loss: 0.1412 - accuracy: 1.0000 - val_loss: 1.1410 - val_accuracy: 0.2500 - 41ms/epoch - 21ms/step
# Epoch 235/500
# 2/2 - 0s - loss: 0.1499 - accuracy: 1.0000 - val_loss: 1.1521 - val_accuracy: 0.3333 - 42ms/epoch - 21ms/step
# Epoch 236/500
# 2/2 - 0s - loss: 0.1240 - accuracy: 1.0000 - val_loss: 1.1658 - val_accuracy: 0.4167 - 41ms/epoch - 20ms/step
# Epoch 237/500
# 2/2 - 0s - loss: 0.1242 - accuracy: 1.0000 - val_loss: 1.1774 - val_accuracy: 0.4167 - 46ms/epoch - 23ms/step
# Epoch 238/500
# 2/2 - 0s - loss: 0.1987 - accuracy: 1.0000 - val_loss: 1.1844 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 239/500
# 2/2 - 0s - loss: 0.1143 - accuracy: 1.0000 - val_loss: 1.1909 - val_accuracy: 0.4167 - 39ms/epoch - 19ms/step
# Epoch 240/500
# 2/2 - 0s - loss: 0.1175 - accuracy: 1.0000 - val_loss: 1.1962 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 241/500
# 2/2 - 0s - loss: 0.1382 - accuracy: 1.0000 - val_loss: 1.2040 - val_accuracy: 0.4167 - 39ms/epoch - 19ms/step
# Epoch 242/500
# 2/2 - 0s - loss: 0.1327 - accuracy: 1.0000 - val_loss: 1.2120 - val_accuracy: 0.4167 - 58ms/epoch - 29ms/step
# Epoch 243/500
# 2/2 - 0s - loss: 0.1840 - accuracy: 0.9643 - val_loss: 1.2284 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 244/500
# 2/2 - 0s - loss: 0.1214 - accuracy: 1.0000 - val_loss: 1.2423 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 245/500
# 2/2 - 0s - loss: 0.1134 - accuracy: 1.0000 - val_loss: 1.2576 - val_accuracy: 0.3333 - 58ms/epoch - 29ms/step
# Epoch 246/500
# 2/2 - 0s - loss: 0.1086 - accuracy: 1.0000 - val_loss: 1.2668 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 247/500
# 2/2 - 0s - loss: 0.1252 - accuracy: 1.0000 - val_loss: 1.2755 - val_accuracy: 0.3333 - 56ms/epoch - 28ms/step
# Epoch 248/500
# 2/2 - 0s - loss: 0.1342 - accuracy: 1.0000 - val_loss: 1.2819 - val_accuracy: 0.4167 - 46ms/epoch - 23ms/step
# Epoch 249/500
# 2/2 - 0s - loss: 0.1074 - accuracy: 1.0000 - val_loss: 1.2832 - val_accuracy: 0.4167 - 57ms/epoch - 28ms/step
# Epoch 250/500
# 2/2 - 0s - loss: 0.1234 - accuracy: 1.0000 - val_loss: 1.2779 - val_accuracy: 0.3333 - 39ms/epoch - 20ms/step
# Epoch 251/500
# 2/2 - 0s - loss: 0.1074 - accuracy: 1.0000 - val_loss: 1.2724 - val_accuracy: 0.3333 - 38ms/epoch - 19ms/step
# Epoch 252/500
# 2/2 - 0s - loss: 0.1116 - accuracy: 1.0000 - val_loss: 1.2698 - val_accuracy: 0.3333 - 39ms/epoch - 20ms/step
# Epoch 253/500
# 2/2 - 0s - loss: 0.1108 - accuracy: 1.0000 - val_loss: 1.2690 - val_accuracy: 0.3333 - 59ms/epoch - 30ms/step
# Epoch 254/500
# 2/2 - 0s - loss: 0.1236 - accuracy: 0.9643 - val_loss: 1.2660 - val_accuracy: 0.4167 - 57ms/epoch - 29ms/step
# Epoch 255/500
# 2/2 - 0s - loss: 0.1124 - accuracy: 1.0000 - val_loss: 1.2692 - val_accuracy: 0.4167 - 41ms/epoch - 21ms/step
# Epoch 256/500
# 2/2 - 0s - loss: 0.1315 - accuracy: 1.0000 - val_loss: 1.2754 - val_accuracy: 0.4167 - 39ms/epoch - 20ms/step
# Epoch 257/500
# 2/2 - 0s - loss: 0.1957 - accuracy: 1.0000 - val_loss: 1.2765 - val_accuracy: 0.4167 - 44ms/epoch - 22ms/step
# Epoch 258/500
# 2/2 - 0s - loss: 0.1323 - accuracy: 1.0000 - val_loss: 1.2815 - val_accuracy: 0.4167 - 55ms/epoch - 28ms/step
# Epoch 259/500
# 2/2 - 0s - loss: 0.1504 - accuracy: 0.9643 - val_loss: 1.2787 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 260/500
# 2/2 - 0s - loss: 0.1446 - accuracy: 1.0000 - val_loss: 1.2696 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 261/500
# 2/2 - 0s - loss: 0.1421 - accuracy: 1.0000 - val_loss: 1.2608 - val_accuracy: 0.3333 - 42ms/epoch - 21ms/step
# Epoch 262/500
# 2/2 - 0s - loss: 0.0978 - accuracy: 1.0000 - val_loss: 1.2549 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 263/500
# 2/2 - 0s - loss: 0.1169 - accuracy: 1.0000 - val_loss: 1.2557 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 264/500
# 2/2 - 0s - loss: 0.1075 - accuracy: 1.0000 - val_loss: 1.2641 - val_accuracy: 0.4167 - 41ms/epoch - 21ms/step
# Epoch 265/500
# 2/2 - 0s - loss: 0.0956 - accuracy: 1.0000 - val_loss: 1.2725 - val_accuracy: 0.3333 - 39ms/epoch - 20ms/step
# Epoch 266/500
# 2/2 - 0s - loss: 0.1129 - accuracy: 1.0000 - val_loss: 1.2783 - val_accuracy: 0.3333 - 38ms/epoch - 19ms/step
# Epoch 267/500
# 2/2 - 0s - loss: 0.1057 - accuracy: 1.0000 - val_loss: 1.2837 - val_accuracy: 0.3333 - 41ms/epoch - 21ms/step
# Epoch 268/500
# 2/2 - 0s - loss: 0.1155 - accuracy: 1.0000 - val_loss: 1.2848 - val_accuracy: 0.3333 - 39ms/epoch - 19ms/step
# Epoch 269/500
# 2/2 - 0s - loss: 0.1235 - accuracy: 1.0000 - val_loss: 1.2886 - val_accuracy: 0.3333 - 39ms/epoch - 19ms/step
# Epoch 270/500
# 2/2 - 0s - loss: 0.1332 - accuracy: 1.0000 - val_loss: 1.2893 - val_accuracy: 0.4167 - 38ms/epoch - 19ms/step
# Epoch 271/500
# 2/2 - 0s - loss: 0.1186 - accuracy: 1.0000 - val_loss: 1.2866 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 272/500
# 2/2 - 0s - loss: 0.1287 - accuracy: 1.0000 - val_loss: 1.2852 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 273/500
# 2/2 - 0s - loss: 0.1058 - accuracy: 1.0000 - val_loss: 1.2901 - val_accuracy: 0.3333 - 56ms/epoch - 28ms/step
# Epoch 274/500
# 2/2 - 0s - loss: 0.1245 - accuracy: 1.0000 - val_loss: 1.3075 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 275/500
# 2/2 - 0s - loss: 0.1182 - accuracy: 1.0000 - val_loss: 1.3243 - val_accuracy: 0.3333 - 53ms/epoch - 26ms/step
# Epoch 276/500
# 2/2 - 0s - loss: 0.1178 - accuracy: 1.0000 - val_loss: 1.3327 - val_accuracy: 0.3333 - 54ms/epoch - 27ms/step
# Epoch 277/500
# 2/2 - 0s - loss: 0.1088 - accuracy: 1.0000 - val_loss: 1.3352 - val_accuracy: 0.4167 - 49ms/epoch - 24ms/step
# Epoch 278/500
# 2/2 - 0s - loss: 0.1082 - accuracy: 1.0000 - val_loss: 1.3298 - val_accuracy: 0.4167 - 55ms/epoch - 28ms/step
# Epoch 279/500
# 2/2 - 0s - loss: 0.1419 - accuracy: 0.9643 - val_loss: 1.3207 - val_accuracy: 0.4167 - 41ms/epoch - 20ms/step
# Epoch 280/500
# 2/2 - 0s - loss: 0.1160 - accuracy: 1.0000 - val_loss: 1.3077 - val_accuracy: 0.4167 - 55ms/epoch - 27ms/step
# Epoch 281/500
# 2/2 - 0s - loss: 0.1107 - accuracy: 1.0000 - val_loss: 1.3009 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 282/500
# 2/2 - 0s - loss: 0.1095 - accuracy: 1.0000 - val_loss: 1.2959 - val_accuracy: 0.3333 - 55ms/epoch - 27ms/step
# Epoch 283/500
# 2/2 - 0s - loss: 0.1008 - accuracy: 1.0000 - val_loss: 1.2894 - val_accuracy: 0.3333 - 39ms/epoch - 20ms/step
# Epoch 284/500
# 2/2 - 0s - loss: 0.0950 - accuracy: 1.0000 - val_loss: 1.2866 - val_accuracy: 0.3333 - 41ms/epoch - 21ms/step
# Epoch 285/500
# 2/2 - 0s - loss: 0.0978 - accuracy: 1.0000 - val_loss: 1.2899 - val_accuracy: 0.3333 - 39ms/epoch - 19ms/step
# Epoch 286/500
# 2/2 - 0s - loss: 0.1404 - accuracy: 1.0000 - val_loss: 1.2951 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 287/500
# 2/2 - 0s - loss: 0.1109 - accuracy: 1.0000 - val_loss: 1.3078 - val_accuracy: 0.4167 - 56ms/epoch - 28ms/step
# Epoch 288/500
# 2/2 - 0s - loss: 0.1244 - accuracy: 1.0000 - val_loss: 1.3300 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 289/500
# 2/2 - 0s - loss: 0.1083 - accuracy: 1.0000 - val_loss: 1.3485 - val_accuracy: 0.5000 - 44ms/epoch - 22ms/step
# Epoch 290/500
# 2/2 - 0s - loss: 0.1081 - accuracy: 1.0000 - val_loss: 1.3653 - val_accuracy: 0.5000 - 41ms/epoch - 20ms/step
# Epoch 291/500
# 2/2 - 0s - loss: 0.1147 - accuracy: 1.0000 - val_loss: 1.3705 - val_accuracy: 0.5000 - 41ms/epoch - 21ms/step
# Epoch 292/500
# 2/2 - 0s - loss: 0.1024 - accuracy: 1.0000 - val_loss: 1.3663 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 293/500
# 2/2 - 0s - loss: 0.1023 - accuracy: 1.0000 - val_loss: 1.3567 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 294/500
# 2/2 - 0s - loss: 0.1066 - accuracy: 1.0000 - val_loss: 1.3427 - val_accuracy: 0.5000 - 41ms/epoch - 20ms/step
# Epoch 295/500
# 2/2 - 0s - loss: 0.0982 - accuracy: 1.0000 - val_loss: 1.3273 - val_accuracy: 0.3333 - 52ms/epoch - 26ms/step
# Epoch 296/500
# 2/2 - 0s - loss: 0.1599 - accuracy: 0.9643 - val_loss: 1.3321 - val_accuracy: 0.3333 - 39ms/epoch - 19ms/step
# Epoch 297/500
# 2/2 - 0s - loss: 0.0943 - accuracy: 1.0000 - val_loss: 1.3381 - val_accuracy: 0.3333 - 41ms/epoch - 20ms/step
# Epoch 298/500
# 2/2 - 0s - loss: 0.1170 - accuracy: 1.0000 - val_loss: 1.3497 - val_accuracy: 0.3333 - 38ms/epoch - 19ms/step
# Epoch 299/500
# 2/2 - 0s - loss: 0.1387 - accuracy: 1.0000 - val_loss: 1.3605 - val_accuracy: 0.2500 - 38ms/epoch - 19ms/step
# Epoch 300/500
# 2/2 - 0s - loss: 0.0989 - accuracy: 1.0000 - val_loss: 1.3705 - val_accuracy: 0.2500 - 55ms/epoch - 28ms/step
# Epoch 301/500
# 2/2 - 0s - loss: 0.0923 - accuracy: 1.0000 - val_loss: 1.3790 - val_accuracy: 0.2500 - 42ms/epoch - 21ms/step
# Epoch 302/500
# 2/2 - 0s - loss: 0.1342 - accuracy: 1.0000 - val_loss: 1.3850 - val_accuracy: 0.2500 - 40ms/epoch - 20ms/step
# Epoch 303/500
# 2/2 - 0s - loss: 0.1008 - accuracy: 1.0000 - val_loss: 1.3919 - val_accuracy: 0.4167 - 51ms/epoch - 26ms/step
# Epoch 304/500
# 2/2 - 0s - loss: 0.0927 - accuracy: 1.0000 - val_loss: 1.3934 - val_accuracy: 0.4167 - 67ms/epoch - 34ms/step
# Epoch 305/500
# 2/2 - 0s - loss: 0.0969 - accuracy: 1.0000 - val_loss: 1.3944 - val_accuracy: 0.2500 - 56ms/epoch - 28ms/step
# Epoch 306/500
# 2/2 - 0s - loss: 0.0896 - accuracy: 1.0000 - val_loss: 1.3943 - val_accuracy: 0.2500 - 43ms/epoch - 21ms/step
# Epoch 307/500
# 2/2 - 0s - loss: 0.1010 - accuracy: 1.0000 - val_loss: 1.3978 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 308/500
# 2/2 - 0s - loss: 0.2096 - accuracy: 0.9643 - val_loss: 1.4087 - val_accuracy: 0.3333 - 38ms/epoch - 19ms/step
# Epoch 309/500
# 2/2 - 0s - loss: 0.0857 - accuracy: 1.0000 - val_loss: 1.4122 - val_accuracy: 0.3333 - 39ms/epoch - 19ms/step
# Epoch 310/500
# 2/2 - 0s - loss: 0.1267 - accuracy: 1.0000 - val_loss: 1.4227 - val_accuracy: 0.2500 - 42ms/epoch - 21ms/step
# Epoch 311/500
# 2/2 - 0s - loss: 0.1200 - accuracy: 1.0000 - val_loss: 1.4323 - val_accuracy: 0.2500 - 39ms/epoch - 19ms/step
# Epoch 312/500
# 2/2 - 0s - loss: 0.0789 - accuracy: 1.0000 - val_loss: 1.4364 - val_accuracy: 0.2500 - 58ms/epoch - 29ms/step
# Epoch 313/500
# 2/2 - 0s - loss: 0.1004 - accuracy: 1.0000 - val_loss: 1.4322 - val_accuracy: 0.2500 - 42ms/epoch - 21ms/step
# Epoch 314/500
# 2/2 - 0s - loss: 0.0943 - accuracy: 1.0000 - val_loss: 1.4238 - val_accuracy: 0.2500 - 43ms/epoch - 22ms/step
# Epoch 315/500
# 2/2 - 0s - loss: 0.1006 - accuracy: 1.0000 - val_loss: 1.4135 - val_accuracy: 0.4167 - 47ms/epoch - 24ms/step
# Epoch 316/500
# 2/2 - 0s - loss: 0.0816 - accuracy: 1.0000 - val_loss: 1.3971 - val_accuracy: 0.4167 - 39ms/epoch - 20ms/step
# Epoch 317/500
# 2/2 - 0s - loss: 0.0876 - accuracy: 1.0000 - val_loss: 1.3832 - val_accuracy: 0.4167 - 39ms/epoch - 20ms/step
# Epoch 318/500
# 2/2 - 0s - loss: 0.0867 - accuracy: 1.0000 - val_loss: 1.3683 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 319/500
# 2/2 - 0s - loss: 0.1155 - accuracy: 1.0000 - val_loss: 1.3526 - val_accuracy: 0.3333 - 38ms/epoch - 19ms/step
# Epoch 320/500
# 2/2 - 0s - loss: 0.0879 - accuracy: 1.0000 - val_loss: 1.3477 - val_accuracy: 0.3333 - 55ms/epoch - 28ms/step
# Epoch 321/500
# 2/2 - 0s - loss: 0.1117 - accuracy: 1.0000 - val_loss: 1.3483 - val_accuracy: 0.3333 - 60ms/epoch - 30ms/step
# Epoch 322/500
# 2/2 - 0s - loss: 0.0933 - accuracy: 1.0000 - val_loss: 1.3538 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 323/500
# 2/2 - 0s - loss: 0.0774 - accuracy: 1.0000 - val_loss: 1.3588 - val_accuracy: 0.3333 - 38ms/epoch - 19ms/step
# Epoch 324/500
# 2/2 - 0s - loss: 0.1181 - accuracy: 1.0000 - val_loss: 1.3624 - val_accuracy: 0.3333 - 58ms/epoch - 29ms/step
# Epoch 325/500
# 2/2 - 0s - loss: 0.0790 - accuracy: 1.0000 - val_loss: 1.3694 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 326/500
# 2/2 - 0s - loss: 0.1094 - accuracy: 1.0000 - val_loss: 1.3818 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 327/500
# 2/2 - 0s - loss: 0.0945 - accuracy: 1.0000 - val_loss: 1.3887 - val_accuracy: 0.4167 - 55ms/epoch - 27ms/step
# Epoch 328/500
# 2/2 - 0s - loss: 0.0962 - accuracy: 1.0000 - val_loss: 1.3973 - val_accuracy: 0.4167 - 41ms/epoch - 21ms/step
# Epoch 329/500
# 2/2 - 0s - loss: 0.0881 - accuracy: 1.0000 - val_loss: 1.4025 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 330/500
# 2/2 - 0s - loss: 0.0980 - accuracy: 0.9643 - val_loss: 1.4012 - val_accuracy: 0.4167 - 39ms/epoch - 19ms/step
# Epoch 331/500
# 2/2 - 0s - loss: 0.0930 - accuracy: 1.0000 - val_loss: 1.4008 - val_accuracy: 0.4167 - 57ms/epoch - 28ms/step
# Epoch 332/500
# 2/2 - 0s - loss: 0.1076 - accuracy: 1.0000 - val_loss: 1.3985 - val_accuracy: 0.3333 - 42ms/epoch - 21ms/step
# Epoch 333/500
# 2/2 - 0s - loss: 0.0746 - accuracy: 1.0000 - val_loss: 1.3914 - val_accuracy: 0.3333 - 56ms/epoch - 28ms/step
# Epoch 334/500
# 2/2 - 0s - loss: 0.0865 - accuracy: 1.0000 - val_loss: 1.3845 - val_accuracy: 0.3333 - 49ms/epoch - 24ms/step
# Epoch 335/500
# 2/2 - 0s - loss: 0.1023 - accuracy: 1.0000 - val_loss: 1.3827 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 336/500
# 2/2 - 0s - loss: 0.1540 - accuracy: 0.9643 - val_loss: 1.4018 - val_accuracy: 0.3333 - 39ms/epoch - 19ms/step
# Epoch 337/500
# 2/2 - 0s - loss: 0.0895 - accuracy: 1.0000 - val_loss: 1.4190 - val_accuracy: 0.3333 - 39ms/epoch - 19ms/step
# Epoch 338/500
# 2/2 - 0s - loss: 0.0802 - accuracy: 1.0000 - val_loss: 1.4321 - val_accuracy: 0.3333 - 41ms/epoch - 20ms/step
# Epoch 339/500
# 2/2 - 0s - loss: 0.0717 - accuracy: 1.0000 - val_loss: 1.4400 - val_accuracy: 0.3333 - 41ms/epoch - 21ms/step
# Epoch 340/500
# 2/2 - 0s - loss: 0.0976 - accuracy: 1.0000 - val_loss: 1.4403 - val_accuracy: 0.3333 - 41ms/epoch - 21ms/step
# Epoch 341/500
# 2/2 - 0s - loss: 0.0809 - accuracy: 1.0000 - val_loss: 1.4438 - val_accuracy: 0.3333 - 38ms/epoch - 19ms/step
# Epoch 342/500
# 2/2 - 0s - loss: 0.0920 - accuracy: 1.0000 - val_loss: 1.4452 - val_accuracy: 0.3333 - 57ms/epoch - 29ms/step
# Epoch 343/500
# 2/2 - 0s - loss: 0.0899 - accuracy: 1.0000 - val_loss: 1.4422 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 344/500
# 2/2 - 0s - loss: 0.0868 - accuracy: 1.0000 - val_loss: 1.4337 - val_accuracy: 0.3333 - 38ms/epoch - 19ms/step
# Epoch 345/500
# 2/2 - 0s - loss: 0.0851 - accuracy: 1.0000 - val_loss: 1.4287 - val_accuracy: 0.4167 - 37ms/epoch - 19ms/step
# Epoch 346/500
# 2/2 - 0s - loss: 0.1408 - accuracy: 1.0000 - val_loss: 1.4185 - val_accuracy: 0.3333 - 39ms/epoch - 19ms/step
# Epoch 347/500
# 2/2 - 0s - loss: 0.0677 - accuracy: 1.0000 - val_loss: 1.4130 - val_accuracy: 0.3333 - 38ms/epoch - 19ms/step
# Epoch 348/500
# 2/2 - 0s - loss: 0.0931 - accuracy: 1.0000 - val_loss: 1.4139 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 349/500
# 2/2 - 0s - loss: 0.0847 - accuracy: 1.0000 - val_loss: 1.4154 - val_accuracy: 0.3333 - 41ms/epoch - 20ms/step
# Epoch 350/500
# 2/2 - 0s - loss: 0.0983 - accuracy: 0.9643 - val_loss: 1.4138 - val_accuracy: 0.3333 - 38ms/epoch - 19ms/step
# Epoch 351/500
# 2/2 - 0s - loss: 0.1067 - accuracy: 1.0000 - val_loss: 1.4053 - val_accuracy: 0.3333 - 38ms/epoch - 19ms/step
# Epoch 352/500
# 2/2 - 0s - loss: 0.1099 - accuracy: 1.0000 - val_loss: 1.3932 - val_accuracy: 0.3333 - 54ms/epoch - 27ms/step
# Epoch 353/500
# 2/2 - 0s - loss: 0.1109 - accuracy: 1.0000 - val_loss: 1.3873 - val_accuracy: 0.4167 - 38ms/epoch - 19ms/step
# Epoch 354/500
# 2/2 - 0s - loss: 0.1138 - accuracy: 1.0000 - val_loss: 1.3863 - val_accuracy: 0.4167 - 42ms/epoch - 21ms/step
# Epoch 355/500
# 2/2 - 0s - loss: 0.0932 - accuracy: 1.0000 - val_loss: 1.3826 - val_accuracy: 0.4167 - 49ms/epoch - 24ms/step
# Epoch 356/500
# 2/2 - 0s - loss: 0.0858 - accuracy: 1.0000 - val_loss: 1.3786 - val_accuracy: 0.4167 - 47ms/epoch - 23ms/step
# Epoch 357/500
# 2/2 - 0s - loss: 0.0938 - accuracy: 1.0000 - val_loss: 1.3794 - val_accuracy: 0.4167 - 53ms/epoch - 27ms/step
# Epoch 358/500
# 2/2 - 0s - loss: 0.0736 - accuracy: 1.0000 - val_loss: 1.3798 - val_accuracy: 0.4167 - 41ms/epoch - 20ms/step
# Epoch 359/500
# 2/2 - 0s - loss: 0.0775 - accuracy: 1.0000 - val_loss: 1.3749 - val_accuracy: 0.4167 - 38ms/epoch - 19ms/step
# Epoch 360/500
# 2/2 - 0s - loss: 0.1117 - accuracy: 1.0000 - val_loss: 1.3748 - val_accuracy: 0.3333 - 39ms/epoch - 19ms/step
# Epoch 361/500
# 2/2 - 0s - loss: 0.0723 - accuracy: 1.0000 - val_loss: 1.3813 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 362/500
# 2/2 - 0s - loss: 0.0910 - accuracy: 1.0000 - val_loss: 1.3829 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 363/500
# 2/2 - 0s - loss: 0.0647 - accuracy: 1.0000 - val_loss: 1.3864 - val_accuracy: 0.3333 - 49ms/epoch - 25ms/step
# Epoch 364/500
# 2/2 - 0s - loss: 0.0816 - accuracy: 1.0000 - val_loss: 1.3902 - val_accuracy: 0.3333 - 52ms/epoch - 26ms/step
# Epoch 365/500
# 2/2 - 0s - loss: 0.0951 - accuracy: 1.0000 - val_loss: 1.3967 - val_accuracy: 0.3333 - 60ms/epoch - 30ms/step
# Epoch 366/500
# 2/2 - 0s - loss: 0.0816 - accuracy: 1.0000 - val_loss: 1.3987 - val_accuracy: 0.3333 - 68ms/epoch - 34ms/step
# Epoch 367/500
# 2/2 - 0s - loss: 0.0911 - accuracy: 1.0000 - val_loss: 1.4050 - val_accuracy: 0.3333 - 63ms/epoch - 31ms/step
# Epoch 368/500
# 2/2 - 0s - loss: 0.0924 - accuracy: 1.0000 - val_loss: 1.4113 - val_accuracy: 0.3333 - 68ms/epoch - 34ms/step
# Epoch 369/500
# 2/2 - 0s - loss: 0.0779 - accuracy: 1.0000 - val_loss: 1.4203 - val_accuracy: 0.3333 - 59ms/epoch - 29ms/step
# Epoch 370/500
# 2/2 - 0s - loss: 0.0980 - accuracy: 1.0000 - val_loss: 1.4260 - val_accuracy: 0.4167 - 54ms/epoch - 27ms/step
# Epoch 371/500
# 2/2 - 0s - loss: 0.0755 - accuracy: 1.0000 - val_loss: 1.4356 - val_accuracy: 0.3333 - 54ms/epoch - 27ms/step
# Epoch 372/500
# 2/2 - 0s - loss: 0.0723 - accuracy: 1.0000 - val_loss: 1.4430 - val_accuracy: 0.3333 - 56ms/epoch - 28ms/step
# Epoch 373/500
# 2/2 - 0s - loss: 0.0721 - accuracy: 1.0000 - val_loss: 1.4455 - val_accuracy: 0.3333 - 63ms/epoch - 32ms/step
# Epoch 374/500
# 2/2 - 0s - loss: 0.0783 - accuracy: 1.0000 - val_loss: 1.4444 - val_accuracy: 0.3333 - 56ms/epoch - 28ms/step
# Epoch 375/500
# 2/2 - 0s - loss: 0.0926 - accuracy: 1.0000 - val_loss: 1.4499 - val_accuracy: 0.4167 - 55ms/epoch - 27ms/step
# Epoch 376/500
# 2/2 - 0s - loss: 0.0956 - accuracy: 1.0000 - val_loss: 1.4539 - val_accuracy: 0.4167 - 53ms/epoch - 26ms/step
# Epoch 377/500
# 2/2 - 0s - loss: 0.0803 - accuracy: 1.0000 - val_loss: 1.4533 - val_accuracy: 0.4167 - 71ms/epoch - 36ms/step
# Epoch 378/500
# 2/2 - 0s - loss: 0.0681 - accuracy: 1.0000 - val_loss: 1.4494 - val_accuracy: 0.4167 - 70ms/epoch - 35ms/step
# Epoch 379/500
# 2/2 - 0s - loss: 0.0788 - accuracy: 1.0000 - val_loss: 1.4465 - val_accuracy: 0.4167 - 71ms/epoch - 35ms/step
# Epoch 380/500
# 2/2 - 0s - loss: 0.0808 - accuracy: 1.0000 - val_loss: 1.4445 - val_accuracy: 0.4167 - 51ms/epoch - 26ms/step
# Epoch 381/500
# 2/2 - 0s - loss: 0.0784 - accuracy: 1.0000 - val_loss: 1.4407 - val_accuracy: 0.4167 - 66ms/epoch - 33ms/step
# Epoch 382/500
# 2/2 - 0s - loss: 0.0716 - accuracy: 1.0000 - val_loss: 1.4447 - val_accuracy: 0.4167 - 73ms/epoch - 37ms/step
# Epoch 383/500
# 2/2 - 0s - loss: 0.0658 - accuracy: 1.0000 - val_loss: 1.4432 - val_accuracy: 0.4167 - 65ms/epoch - 32ms/step
# Epoch 384/500
# 2/2 - 0s - loss: 0.0841 - accuracy: 1.0000 - val_loss: 1.4419 - val_accuracy: 0.4167 - 72ms/epoch - 36ms/step
# Epoch 385/500
# 2/2 - 0s - loss: 0.0743 - accuracy: 1.0000 - val_loss: 1.4431 - val_accuracy: 0.4167 - 66ms/epoch - 33ms/step
# Epoch 386/500
# 2/2 - 0s - loss: 0.0800 - accuracy: 1.0000 - val_loss: 1.4502 - val_accuracy: 0.4167 - 74ms/epoch - 37ms/step
# Epoch 387/500
# 2/2 - 0s - loss: 0.0591 - accuracy: 1.0000 - val_loss: 1.4603 - val_accuracy: 0.4167 - 73ms/epoch - 36ms/step
# Epoch 388/500
# ...
# Epoch 374/500
# 2/2 - 0s - loss: 0.0363 - accuracy: 1.0000 - val_loss: 1.1607 - val_accuracy: 0.5833 - 48ms/epoch - 24ms/step
# Epoch 375/500
# 2/2 - 0s - loss: 0.0469 - accuracy: 1.0000 - val_loss: 1.1381 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 376/500
# 2/2 - 0s - loss: 0.0530 - accuracy: 1.0000 - val_loss: 1.1126 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 377/500
# 2/2 - 0s - loss: 0.0289 - accuracy: 1.0000 - val_loss: 1.0839 - val_accuracy: 0.5000 - 43ms/epoch - 21ms/step
# Epoch 378/500
# 2/2 - 0s - loss: 0.0326 - accuracy: 1.0000 - val_loss: 1.0713 - val_accuracy: 0.5000 - 57ms/epoch - 29ms/step
# Epoch 379/500
# 2/2 - 0s - loss: 0.0364 - accuracy: 1.0000 - val_loss: 1.0674 - val_accuracy: 0.5833 - 41ms/epoch - 21ms/step
# Epoch 380/500
# 2/2 - 0s - loss: 0.0591 - accuracy: 1.0000 - val_loss: 1.0783 - val_accuracy: 0.5000 - 83ms/epoch - 42ms/step
# Epoch 381/500
# 2/2 - 0s - loss: 0.0530 - accuracy: 1.0000 - val_loss: 1.0804 - val_accuracy: 0.4167 - 41ms/epoch - 21ms/step
# Epoch 382/500
# 2/2 - 0s - loss: 0.0501 - accuracy: 1.0000 - val_loss: 1.1011 - val_accuracy: 0.4167 - 42ms/epoch - 21ms/step
# Epoch 383/500
# 2/2 - 0s - loss: 0.0369 - accuracy: 1.0000 - val_loss: 1.1149 - val_accuracy: 0.5000 - 41ms/epoch - 21ms/step
# Epoch 384/500
# 2/2 - 0s - loss: 0.0382 - accuracy: 1.0000 - val_loss: 1.1321 - val_accuracy: 0.5000 - 62ms/epoch - 31ms/step
# Epoch 385/500
# 2/2 - 0s - loss: 0.0326 - accuracy: 1.0000 - val_loss: 1.1446 - val_accuracy: 0.5000 - 43ms/epoch - 22ms/step
# Epoch 386/500
# 2/2 - 0s - loss: 0.0362 - accuracy: 1.0000 - val_loss: 1.1516 - val_accuracy: 0.5000 - 39ms/epoch - 20ms/step
# Epoch 387/500
# 2/2 - 0s - loss: 0.0486 - accuracy: 1.0000 - val_loss: 1.1343 - val_accuracy: 0.5000 - 51ms/epoch - 26ms/step
# Epoch 388/500
# 2/2 - 0s - loss: 0.0437 - accuracy: 1.0000 - val_loss: 1.1278 - val_accuracy: 0.5000 - 43ms/epoch - 22ms/step
# Epoch 389/500
# 2/2 - 0s - loss: 0.0356 - accuracy: 1.0000 - val_loss: 1.1251 - val_accuracy: 0.4167 - 41ms/epoch - 21ms/step
# Epoch 390/500
# 2/2 - 0s - loss: 0.0330 - accuracy: 1.0000 - val_loss: 1.1214 - val_accuracy: 0.4167 - 41ms/epoch - 20ms/step
# Epoch 391/500
# 2/2 - 0s - loss: 0.0340 - accuracy: 1.0000 - val_loss: 1.1217 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 392/500
# 2/2 - 0s - loss: 0.0482 - accuracy: 1.0000 - val_loss: 1.1282 - val_accuracy: 0.5000 - 43ms/epoch - 21ms/step
# Epoch 393/500
# 2/2 - 0s - loss: 0.0383 - accuracy: 1.0000 - val_loss: 1.1476 - val_accuracy: 0.5000 - 42ms/epoch - 21ms/step
# Epoch 394/500
# 2/2 - 0s - loss: 0.0399 - accuracy: 1.0000 - val_loss: 1.1792 - val_accuracy: 0.5833 - 44ms/epoch - 22ms/step
# Epoch 395/500
# 2/2 - 0s - loss: 0.0378 - accuracy: 1.0000 - val_loss: 1.2105 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 396/500
# 2/2 - 0s - loss: 0.0324 - accuracy: 1.0000 - val_loss: 1.2339 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 397/500
# 2/2 - 0s - loss: 0.0367 - accuracy: 1.0000 - val_loss: 1.2409 - val_accuracy: 0.5000 - 42ms/epoch - 21ms/step
# Epoch 398/500
# 2/2 - 0s - loss: 0.0462 - accuracy: 1.0000 - val_loss: 1.2393 - val_accuracy: 0.5000 - 38ms/epoch - 19ms/step
# Epoch 399/500
# 2/2 - 0s - loss: 0.0394 - accuracy: 1.0000 - val_loss: 1.2095 - val_accuracy: 0.5833 - 45ms/epoch - 22ms/step
# Epoch 400/500
# 2/2 - 0s - loss: 0.0371 - accuracy: 1.0000 - val_loss: 1.1879 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 401/500
# 2/2 - 0s - loss: 0.0420 - accuracy: 1.0000 - val_loss: 1.1656 - val_accuracy: 0.5833 - 41ms/epoch - 21ms/step
# Epoch 402/500
# 2/2 - 0s - loss: 0.0639 - accuracy: 1.0000 - val_loss: 1.1523 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 403/500
# 2/2 - 0s - loss: 0.0380 - accuracy: 1.0000 - val_loss: 1.1533 - val_accuracy: 0.4167 - 44ms/epoch - 22ms/step
# Epoch 404/500
# 2/2 - 0s - loss: 0.0340 - accuracy: 1.0000 - val_loss: 1.1500 - val_accuracy: 0.4167 - 48ms/epoch - 24ms/step
# Epoch 405/500
# 2/2 - 0s - loss: 0.0503 - accuracy: 1.0000 - val_loss: 1.1541 - val_accuracy: 0.4167 - 46ms/epoch - 23ms/step
# Epoch 406/500
# 2/2 - 0s - loss: 0.0716 - accuracy: 1.0000 - val_loss: 1.1615 - val_accuracy: 0.4167 - 41ms/epoch - 21ms/step
# Epoch 407/500
# 2/2 - 0s - loss: 0.0319 - accuracy: 1.0000 - val_loss: 1.1581 - val_accuracy: 0.5000 - 53ms/epoch - 27ms/step
# Epoch 408/500
# 2/2 - 0s - loss: 0.0640 - accuracy: 1.0000 - val_loss: 1.1586 - val_accuracy: 0.5000 - 56ms/epoch - 28ms/step
# Epoch 409/500
# 2/2 - 0s - loss: 0.0340 - accuracy: 1.0000 - val_loss: 1.1650 - val_accuracy: 0.5000 - 39ms/epoch - 20ms/step
# Epoch 410/500
# 2/2 - 0s - loss: 0.0350 - accuracy: 1.0000 - val_loss: 1.1682 - val_accuracy: 0.5000 - 46ms/epoch - 23ms/step
# Epoch 411/500
# 2/2 - 0s - loss: 0.0408 - accuracy: 1.0000 - val_loss: 1.1635 - val_accuracy: 0.5000 - 41ms/epoch - 21ms/step
# Epoch 412/500
# 2/2 - 0s - loss: 0.0365 - accuracy: 1.0000 - val_loss: 1.1507 - val_accuracy: 0.5000 - 43ms/epoch - 21ms/step
# Epoch 413/500
# 2/2 - 0s - loss: 0.0555 - accuracy: 1.0000 - val_loss: 1.1382 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 414/500
# 2/2 - 0s - loss: 0.0278 - accuracy: 1.0000 - val_loss: 1.1269 - val_accuracy: 0.4167 - 41ms/epoch - 20ms/step
# Epoch 415/500
# 2/2 - 0s - loss: 0.0346 - accuracy: 1.0000 - val_loss: 1.1157 - val_accuracy: 0.5000 - 41ms/epoch - 20ms/step
# Epoch 416/500
# 2/2 - 0s - loss: 0.0338 - accuracy: 1.0000 - val_loss: 1.1127 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 417/500
# 2/2 - 0s - loss: 0.0387 - accuracy: 1.0000 - val_loss: 1.1124 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 418/500
# 2/2 - 0s - loss: 0.0442 - accuracy: 1.0000 - val_loss: 1.1232 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 419/500
# 2/2 - 0s - loss: 0.0384 - accuracy: 1.0000 - val_loss: 1.1349 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 420/500
# 2/2 - 0s - loss: 0.0434 - accuracy: 1.0000 - val_loss: 1.1453 - val_accuracy: 0.5833 - 41ms/epoch - 21ms/step
# Epoch 421/500
# 2/2 - 0s - loss: 0.0369 - accuracy: 1.0000 - val_loss: 1.1286 - val_accuracy: 0.5833 - 41ms/epoch - 21ms/step
# Epoch 422/500
# 2/2 - 0s - loss: 0.0375 - accuracy: 1.0000 - val_loss: 1.0948 - val_accuracy: 0.5000 - 57ms/epoch - 29ms/step
# Epoch 423/500
# 2/2 - 0s - loss: 0.0402 - accuracy: 1.0000 - val_loss: 1.0750 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 424/500
# 2/2 - 0s - loss: 0.0326 - accuracy: 1.0000 - val_loss: 1.0663 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 425/500
# 2/2 - 0s - loss: 0.0449 - accuracy: 1.0000 - val_loss: 1.0960 - val_accuracy: 0.5000 - 41ms/epoch - 20ms/step
# Epoch 426/500
# 2/2 - 0s - loss: 0.0523 - accuracy: 1.0000 - val_loss: 1.1227 - val_accuracy: 0.5000 - 48ms/epoch - 24ms/step
# Epoch 427/500
# 2/2 - 0s - loss: 0.0490 - accuracy: 1.0000 - val_loss: 1.1573 - val_accuracy: 0.5000 - 46ms/epoch - 23ms/step
# Epoch 428/500
# 2/2 - 0s - loss: 0.0406 - accuracy: 1.0000 - val_loss: 1.1754 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 429/500
# 2/2 - 0s - loss: 0.0327 - accuracy: 1.0000 - val_loss: 1.1916 - val_accuracy: 0.4167 - 38ms/epoch - 19ms/step
# Epoch 430/500
# 2/2 - 0s - loss: 0.0435 - accuracy: 1.0000 - val_loss: 1.1974 - val_accuracy: 0.4167 - 43ms/epoch - 21ms/step
# Epoch 431/500
# 2/2 - 0s - loss: 0.0528 - accuracy: 1.0000 - val_loss: 1.2002 - val_accuracy: 0.4167 - 45ms/epoch - 22ms/step
# Epoch 432/500
# 2/2 - 0s - loss: 0.0348 - accuracy: 1.0000 - val_loss: 1.1886 - val_accuracy: 0.4167 - 39ms/epoch - 20ms/step
# Epoch 433/500
# 2/2 - 0s - loss: 0.0389 - accuracy: 1.0000 - val_loss: 1.1731 - val_accuracy: 0.4167 - 60ms/epoch - 30ms/step
# Epoch 434/500
# 2/2 - 0s - loss: 0.0447 - accuracy: 1.0000 - val_loss: 1.1654 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 435/500
# 2/2 - 0s - loss: 0.0391 - accuracy: 1.0000 - val_loss: 1.1651 - val_accuracy: 0.4167 - 57ms/epoch - 29ms/step
# Epoch 436/500
# 2/2 - 0s - loss: 0.0384 - accuracy: 1.0000 - val_loss: 1.1656 - val_accuracy: 0.4167 - 59ms/epoch - 30ms/step
# Epoch 437/500
# 2/2 - 0s - loss: 0.0646 - accuracy: 1.0000 - val_loss: 1.1748 - val_accuracy: 0.4167 - 41ms/epoch - 20ms/step
# Epoch 438/500
# 2/2 - 0s - loss: 0.0482 - accuracy: 1.0000 - val_loss: 1.1726 - val_accuracy: 0.4167 - 45ms/epoch - 22ms/step
# Epoch 439/500
# 2/2 - 0s - loss: 0.0383 - accuracy: 1.0000 - val_loss: 1.1655 - val_accuracy: 0.4167 - 39ms/epoch - 19ms/step
# Epoch 440/500
# 2/2 - 0s - loss: 0.0979 - accuracy: 0.9643 - val_loss: 1.1623 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 441/500
# 2/2 - 0s - loss: 0.0406 - accuracy: 1.0000 - val_loss: 1.1718 - val_accuracy: 0.5000 - 43ms/epoch - 21ms/step
# Epoch 442/500
# 2/2 - 0s - loss: 0.0379 - accuracy: 1.0000 - val_loss: 1.1671 - val_accuracy: 0.5000 - 41ms/epoch - 20ms/step
# Epoch 443/500
# 2/2 - 0s - loss: 0.0601 - accuracy: 1.0000 - val_loss: 1.1629 - val_accuracy: 0.5833 - 41ms/epoch - 21ms/step
# Epoch 444/500
# 2/2 - 0s - loss: 0.0377 - accuracy: 1.0000 - val_loss: 1.1643 - val_accuracy: 0.5000 - 51ms/epoch - 25ms/step
# Epoch 445/500
# 2/2 - 0s - loss: 0.0482 - accuracy: 1.0000 - val_loss: 1.1800 - val_accuracy: 0.5000 - 57ms/epoch - 29ms/step
# Epoch 446/500
# 2/2 - 0s - loss: 0.0443 - accuracy: 1.0000 - val_loss: 1.1809 - val_accuracy: 0.5000 - 44ms/epoch - 22ms/step
# Epoch 447/500
# 2/2 - 0s - loss: 0.0361 - accuracy: 1.0000 - val_loss: 1.1669 - val_accuracy: 0.5000 - 65ms/epoch - 32ms/step
# Epoch 448/500
# 2/2 - 0s - loss: 0.0732 - accuracy: 1.0000 - val_loss: 1.1298 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 449/500
# 2/2 - 0s - loss: 0.0386 - accuracy: 1.0000 - val_loss: 1.1128 - val_accuracy: 0.5833 - 60ms/epoch - 30ms/step
# Epoch 450/500
# 2/2 - 0s - loss: 0.0316 - accuracy: 1.0000 - val_loss: 1.1099 - val_accuracy: 0.5000 - 42ms/epoch - 21ms/step
# Epoch 451/500
# 2/2 - 0s - loss: 0.0394 - accuracy: 1.0000 - val_loss: 1.1234 - val_accuracy: 0.5000 - 44ms/epoch - 22ms/step
# Epoch 452/500
# 2/2 - 0s - loss: 0.0342 - accuracy: 1.0000 - val_loss: 1.1437 - val_accuracy: 0.5000 - 42ms/epoch - 21ms/step
# Epoch 453/500
# 2/2 - 0s - loss: 0.0450 - accuracy: 1.0000 - val_loss: 1.1595 - val_accuracy: 0.5000 - 43ms/epoch - 22ms/step
# Epoch 454/500
# 2/2 - 0s - loss: 0.0412 - accuracy: 1.0000 - val_loss: 1.1732 - val_accuracy: 0.5000 - 46ms/epoch - 23ms/step
# Epoch 455/500
# 2/2 - 0s - loss: 0.0418 - accuracy: 1.0000 - val_loss: 1.1885 - val_accuracy: 0.5000 - 41ms/epoch - 20ms/step
# Epoch 456/500
# 2/2 - 0s - loss: 0.0429 - accuracy: 1.0000 - val_loss: 1.2101 - val_accuracy: 0.4167 - 38ms/epoch - 19ms/step
# Epoch 457/500
# 2/2 - 0s - loss: 0.0457 - accuracy: 1.0000 - val_loss: 1.2243 - val_accuracy: 0.5000 - 41ms/epoch - 20ms/step
# Epoch 458/500
# 2/2 - 0s - loss: 0.0423 - accuracy: 1.0000 - val_loss: 1.2304 - val_accuracy: 0.5000 - 42ms/epoch - 21ms/step
# Epoch 459/500
# 2/2 - 0s - loss: 0.0483 - accuracy: 1.0000 - val_loss: 1.2411 - val_accuracy: 0.5000 - 39ms/epoch - 20ms/step
# Epoch 460/500
# 2/2 - 0s - loss: 0.0405 - accuracy: 1.0000 - val_loss: 1.2280 - val_accuracy: 0.5000 - 51ms/epoch - 25ms/step
# Epoch 461/500
# 2/2 - 0s - loss: 0.0265 - accuracy: 1.0000 - val_loss: 1.2194 - val_accuracy: 0.5000 - 41ms/epoch - 20ms/step
# Epoch 462/500
# 2/2 - 0s - loss: 0.0368 - accuracy: 1.0000 - val_loss: 1.2177 - val_accuracy: 0.5833 - 59ms/epoch - 30ms/step
# Epoch 463/500
# 2/2 - 0s - loss: 0.0688 - accuracy: 1.0000 - val_loss: 1.2002 - val_accuracy: 0.5833 - 57ms/epoch - 28ms/step
# Epoch 464/500
# 2/2 - 0s - loss: 0.0293 - accuracy: 1.0000 - val_loss: 1.1889 - val_accuracy: 0.5000 - 48ms/epoch - 24ms/step
# Epoch 465/500
# 2/2 - 0s - loss: 0.0456 - accuracy: 1.0000 - val_loss: 1.1840 - val_accuracy: 0.5000 - 52ms/epoch - 26ms/step
# Epoch 466/500
# 2/2 - 0s - loss: 0.0714 - accuracy: 1.0000 - val_loss: 1.1555 - val_accuracy: 0.5833 - 43ms/epoch - 21ms/step
# Epoch 467/500
# 2/2 - 0s - loss: 0.0290 - accuracy: 1.0000 - val_loss: 1.1471 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 468/500
# 2/2 - 0s - loss: 0.0342 - accuracy: 1.0000 - val_loss: 1.1446 - val_accuracy: 0.5833 - 47ms/epoch - 24ms/step
# Epoch 469/500
# 2/2 - 0s - loss: 0.0330 - accuracy: 1.0000 - val_loss: 1.1390 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 470/500
# 2/2 - 0s - loss: 0.0410 - accuracy: 1.0000 - val_loss: 1.1457 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 471/500
# 2/2 - 0s - loss: 0.0395 - accuracy: 1.0000 - val_loss: 1.1589 - val_accuracy: 0.4167 - 49ms/epoch - 24ms/step
# Epoch 472/500
# 2/2 - 0s - loss: 0.0376 - accuracy: 1.0000 - val_loss: 1.1843 - val_accuracy: 0.4167 - 45ms/epoch - 23ms/step
# Epoch 473/500
# 2/2 - 0s - loss: 0.0585 - accuracy: 1.0000 - val_loss: 1.2164 - val_accuracy: 0.5000 - 44ms/epoch - 22ms/step
# Epoch 474/500
# 2/2 - 0s - loss: 0.0342 - accuracy: 1.0000 - val_loss: 1.2332 - val_accuracy: 0.5000 - 44ms/epoch - 22ms/step
# Epoch 475/500
# 2/2 - 0s - loss: 0.0334 - accuracy: 1.0000 - val_loss: 1.2372 - val_accuracy: 0.5000 - 51ms/epoch - 25ms/step
# Epoch 476/500
# 2/2 - 0s - loss: 0.0389 - accuracy: 1.0000 - val_loss: 1.2153 - val_accuracy: 0.5000 - 46ms/epoch - 23ms/step
# Epoch 477/500
# 2/2 - 0s - loss: 0.0404 - accuracy: 1.0000 - val_loss: 1.1939 - val_accuracy: 0.5000 - 42ms/epoch - 21ms/step
# Epoch 478/500
# 2/2 - 0s - loss: 0.0383 - accuracy: 1.0000 - val_loss: 1.1638 - val_accuracy: 0.5000 - 45ms/epoch - 23ms/step
# Epoch 479/500
# 2/2 - 0s - loss: 0.0454 - accuracy: 1.0000 - val_loss: 1.1521 - val_accuracy: 0.5000 - 62ms/epoch - 31ms/step
# Epoch 480/500
# 2/2 - 0s - loss: 0.0335 - accuracy: 1.0000 - val_loss: 1.1520 - val_accuracy: 0.5000 - 57ms/epoch - 28ms/step
# Epoch 481/500
# 2/2 - 0s - loss: 0.0467 - accuracy: 1.0000 - val_loss: 1.1639 - val_accuracy: 0.5833 - 44ms/epoch - 22ms/step
# Epoch 482/500
# 2/2 - 0s - loss: 0.0386 - accuracy: 1.0000 - val_loss: 1.1678 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 483/500
# 2/2 - 0s - loss: 0.0338 - accuracy: 1.0000 - val_loss: 1.1734 - val_accuracy: 0.6667 - 68ms/epoch - 34ms/step
# Epoch 484/500
# 2/2 - 0s - loss: 0.0317 - accuracy: 1.0000 - val_loss: 1.1774 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 485/500
# 2/2 - 0s - loss: 0.0451 - accuracy: 1.0000 - val_loss: 1.1840 - val_accuracy: 0.6667 - 56ms/epoch - 28ms/step
# Epoch 486/500
# 2/2 - 0s - loss: 0.0426 - accuracy: 1.0000 - val_loss: 1.1780 - val_accuracy: 0.6667 - 60ms/epoch - 30ms/step
# Epoch 487/500
# 2/2 - 0s - loss: 0.0310 - accuracy: 1.0000 - val_loss: 1.1737 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 488/500
# 2/2 - 0s - loss: 0.0344 - accuracy: 1.0000 - val_loss: 1.1617 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 489/500
# 2/2 - 0s - loss: 0.0355 - accuracy: 1.0000 - val_loss: 1.1528 - val_accuracy: 0.5833 - 61ms/epoch - 31ms/step
# Epoch 490/500
# 2/2 - 0s - loss: 0.0370 - accuracy: 1.0000 - val_loss: 1.1403 - val_accuracy: 0.5000 - 41ms/epoch - 20ms/step
# Epoch 491/500
# 2/2 - 0s - loss: 0.0387 - accuracy: 1.0000 - val_loss: 1.1374 - val_accuracy: 0.4167 - 41ms/epoch - 20ms/step
# Epoch 492/500
# 2/2 - 0s - loss: 0.0578 - accuracy: 1.0000 - val_loss: 1.1504 - val_accuracy: 0.5000 - 43ms/epoch - 21ms/step
# Epoch 493/500
# 2/2 - 0s - loss: 0.0425 - accuracy: 1.0000 - val_loss: 1.1471 - val_accuracy: 0.5000 - 43ms/epoch - 22ms/step
# Epoch 494/500
# 2/2 - 0s - loss: 0.0332 - accuracy: 1.0000 - val_loss: 1.1486 - val_accuracy: 0.5000 - 38ms/epoch - 19ms/step
# Epoch 495/500
# 2/2 - 0s - loss: 0.0319 - accuracy: 1.0000 - val_loss: 1.1543 - val_accuracy: 0.5000 - 42ms/epoch - 21ms/step
# Epoch 496/500
# 2/2 - 0s - loss: 0.0531 - accuracy: 1.0000 - val_loss: 1.1515 - val_accuracy: 0.4167 - 42ms/epoch - 21ms/step
# Epoch 497/500
# 2/2 - 0s - loss: 0.0471 - accuracy: 1.0000 - val_loss: 1.1516 - val_accuracy: 0.5000 - 47ms/epoch - 24ms/step
# Epoch 498/500
# 2/2 - 0s - loss: 0.0543 - accuracy: 1.0000 - val_loss: 1.1496 - val_accuracy: 0.5833 - 46ms/epoch - 23ms/step
# Epoch 499/500
# 2/2 - 0s - loss: 0.0520 - accuracy: 1.0000 - val_loss: 1.1715 - val_accuracy: 0.5833 - 46ms/epoch - 23ms/step
# Epoch 500/500
# 2/2 - 0s - loss: 0.0422 - accuracy: 1.0000 - val_loss: 1.1905 - val_accuracy: 0.5833 - 45ms/epoch - 22ms/step
# 1/1 [==============================] - 0s 85ms/step
# Shallow Conv Net Accuracy Metrics
# Accuracy: 0.5833333333333334
# F1 Score: 0.5454545454545454

# %% [markdown]
# ## Theta Classifier

# %%
import tensorflow as tf
# from arl_eegmodels.EEGModels import EEGNet, DeepConvNet, ShallowConvNet
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# To be used for training the model on the opensource dataset

# Train data - 70% of opensource dataset
# Validation data - 30% of opensource dataset
# Test data - data collected from EEG


# Define initial model parameters
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy()
optimizer = 'adam'
metrics = ['accuracy']
epochs = 500
channels = num_desired_channels
classes = 2
dropout = 0.25
F1 = 8
F2 = 16
samples = 60

# EEGNet Implementation
model = EEGNet(nb_classes=classes, Chans=num_desired_channels, Samples=samples, dropoutRate=dropout, F1=F1, F2=F2)
model.compile(loss=loss_fn, optimizer=optimizer, metrics=metrics)
# eeg_net_checkpoint = ModelCheckpoint(filepath='/trained_models/eeg_net_checkpoint.h5', verbose=1, save_best_only=True)

# Fit and train the model
eegnet_history = model.fit(
    theta_x_train, theta_y_train, batch_size=16, epochs=epochs, verbose=2, validation_data=(theta_x_test, theta_y_test)
)

# Evaluate accuracy on test data
probabilities = model.predict(theta_x_test)
predictions = probabilities.argmax(axis=-1)

accuracy = accuracy_score(theta_y_test, predictions)
conf_matrix = confusion_matrix(theta_y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)
f1 = f1_score(theta_y_test, predictions)
# roc_auc = roc_auc_score(y_test, probabilities)


print('EEGNet Accuracy Metrics')
print(f'Accuracy: {accuracy}')
print(f'F1 Score: {f1}')
# print(confusion_matrix)
disp.plot()
plt.show()
# print(f'AUC Score: {roc_auc}')

# EEGNet Accuracy Plot
plt.plot(eegnet_history.history['accuracy'])
plt.plot(eegnet_history.history['val_accuracy'])
plt.title('EEGNet Accuracy During Training')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()

# EEGNet Loss Plot
plt.plot(eegnet_history.history['loss'])
plt.plot(eegnet_history.history['val_loss'])
plt.title('EEGNet Loss During Training')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()


# ShallowConvNet Implementation
shallow_conv_net_model = ShallowConvNet(nb_classes=classes, Chans=num_desired_channels, Samples=samples, dropoutRate=dropout)
shallow_conv_net_model.compile(loss=loss_fn, optimizer=optimizer, metrics=metrics)
# shallow_conv_net_checkpoint = ModelCheckpoint(
#     filepath='/trained_models/shallow_conv_net_checkpoint.h5', verbose=1, save_best_only=True
# )

# Fit and train the model
shallowconvnet_history = shallow_conv_net_model.fit(
    theta_x_train, theta_y_train, batch_size=16, epochs=epochs, verbose=2, validation_data=(theta_x_test, theta_y_test)
)

# Evaluate accuracy on test data
probabilities = shallow_conv_net_model.predict(theta_x_test)
predictions = probabilities.argmax(axis=-1)

accuracy = accuracy_score(theta_y_test, predictions)
conf_matrix = confusion_matrix(theta_y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)
f1 = f1_score(theta_y_test, predictions)
# roc_auc = roc_auc_score(y_test, probabilities)


print('Shallow Conv Net Accuracy Metrics')
print(f'Accuracy: {accuracy}')
print(f'F1 Score: {f1}')
# print(confusion_matrix)
disp.plot()
plt.show()
# print(f'AUC Score: {roc_auc}')

# ShallowConvNet Accuracy Plot
plt.plot(shallowconvnet_history.history['accuracy'])
plt.plot(shallowconvnet_history.history['val_accuracy'])
plt.title('ShallowConvNet Accuracy During Training')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()

# ShallowConvNet Loss Plot
plt.plot(shallowconvnet_history.history['loss'])
plt.plot(shallowconvnet_history.history['val_loss'])
plt.title('ShallowConvNet Loss During Training')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()
# Out:
# Epoch 1/500
# 2/2 - 3s - loss: 0.7571 - accuracy: 0.2857 - val_loss: 0.6911 - val_accuracy: 0.5000 - 3s/epoch - 1s/step
# Epoch 2/500
# 2/2 - 0s - loss: 0.6982 - accuracy: 0.4643 - val_loss: 0.6924 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 3/500
# 2/2 - 0s - loss: 0.6923 - accuracy: 0.4286 - val_loss: 0.6929 - val_accuracy: 0.5833 - 41ms/epoch - 21ms/step
# Epoch 4/500
# 2/2 - 0s - loss: 0.6861 - accuracy: 0.4643 - val_loss: 0.6931 - val_accuracy: 0.5833 - 57ms/epoch - 28ms/step
# Epoch 5/500
# 2/2 - 0s - loss: 0.6996 - accuracy: 0.4286 - val_loss: 0.6932 - val_accuracy: 0.4167 - 43ms/epoch - 21ms/step
# Epoch 6/500
# 2/2 - 0s - loss: 0.6897 - accuracy: 0.5714 - val_loss: 0.6930 - val_accuracy: 0.4167 - 38ms/epoch - 19ms/step
# Epoch 7/500
# 2/2 - 0s - loss: 0.6684 - accuracy: 0.6071 - val_loss: 0.6928 - val_accuracy: 0.4167 - 57ms/epoch - 29ms/step
# Epoch 8/500
# 2/2 - 0s - loss: 0.6599 - accuracy: 0.5714 - val_loss: 0.6927 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 9/500
# 2/2 - 0s - loss: 0.6563 - accuracy: 0.6786 - val_loss: 0.6927 - val_accuracy: 0.4167 - 39ms/epoch - 20ms/step
# Epoch 10/500
# 2/2 - 0s - loss: 0.6543 - accuracy: 0.7143 - val_loss: 0.6927 - val_accuracy: 0.4167 - 38ms/epoch - 19ms/step
# Epoch 11/500
# 2/2 - 0s - loss: 0.6603 - accuracy: 0.6429 - val_loss: 0.6928 - val_accuracy: 0.4167 - 56ms/epoch - 28ms/step
# Epoch 12/500
# 2/2 - 0s - loss: 0.6615 - accuracy: 0.6071 - val_loss: 0.6928 - val_accuracy: 0.4167 - 61ms/epoch - 31ms/step
# Epoch 13/500
# 2/2 - 0s - loss: 0.6381 - accuracy: 0.6786 - val_loss: 0.6927 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 14/500
# 2/2 - 0s - loss: 0.6295 - accuracy: 0.7500 - val_loss: 0.6925 - val_accuracy: 0.4167 - 39ms/epoch - 20ms/step
# Epoch 15/500
# 2/2 - 0s - loss: 0.6213 - accuracy: 0.7857 - val_loss: 0.6921 - val_accuracy: 0.4167 - 37ms/epoch - 19ms/step
# Epoch 16/500
# 2/2 - 0s - loss: 0.6400 - accuracy: 0.7143 - val_loss: 0.6917 - val_accuracy: 0.4167 - 46ms/epoch - 23ms/step
# Epoch 17/500
# 2/2 - 0s - loss: 0.6218 - accuracy: 0.6786 - val_loss: 0.6911 - val_accuracy: 0.3333 - 43ms/epoch - 21ms/step
# Epoch 18/500
# 2/2 - 0s - loss: 0.6115 - accuracy: 0.7857 - val_loss: 0.6903 - val_accuracy: 0.3333 - 43ms/epoch - 22ms/step
# Epoch 19/500
# 2/2 - 0s - loss: 0.5935 - accuracy: 0.7500 - val_loss: 0.6893 - val_accuracy: 0.4167 - 54ms/epoch - 27ms/step
# Epoch 20/500
# 2/2 - 0s - loss: 0.6111 - accuracy: 0.7143 - val_loss: 0.6881 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 21/500
# 2/2 - 0s - loss: 0.6008 - accuracy: 0.7857 - val_loss: 0.6867 - val_accuracy: 0.5833 - 55ms/epoch - 28ms/step
# Epoch 22/500
# 2/2 - 0s - loss: 0.5737 - accuracy: 0.8214 - val_loss: 0.6853 - val_accuracy: 0.6667 - 46ms/epoch - 23ms/step
# Epoch 23/500
# 2/2 - 0s - loss: 0.6011 - accuracy: 0.7143 - val_loss: 0.6839 - val_accuracy: 0.6667 - 39ms/epoch - 19ms/step
# Epoch 24/500
# 2/2 - 0s - loss: 0.5591 - accuracy: 0.7857 - val_loss: 0.6822 - val_accuracy: 0.8333 - 38ms/epoch - 19ms/step
# Epoch 25/500
# 2/2 - 0s - loss: 0.5623 - accuracy: 0.7857 - val_loss: 0.6807 - val_accuracy: 0.9167 - 42ms/epoch - 21ms/step
# Epoch 26/500
# 2/2 - 0s - loss: 0.5565 - accuracy: 0.7857 - val_loss: 0.6794 - val_accuracy: 0.8333 - 55ms/epoch - 27ms/step
# Epoch 27/500
# 2/2 - 0s - loss: 0.5399 - accuracy: 0.7500 - val_loss: 0.6781 - val_accuracy: 0.7500 - 39ms/epoch - 19ms/step
# Epoch 28/500
# 2/2 - 0s - loss: 0.5724 - accuracy: 0.7857 - val_loss: 0.6769 - val_accuracy: 0.7500 - 56ms/epoch - 28ms/step
# Epoch 29/500
# 2/2 - 0s - loss: 0.5540 - accuracy: 0.7857 - val_loss: 0.6757 - val_accuracy: 0.7500 - 57ms/epoch - 28ms/step
# Epoch 30/500
# 2/2 - 0s - loss: 0.5497 - accuracy: 0.8214 - val_loss: 0.6746 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 31/500
# 2/2 - 0s - loss: 0.5296 - accuracy: 0.7857 - val_loss: 0.6734 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 32/500
# 2/2 - 0s - loss: 0.5358 - accuracy: 0.8214 - val_loss: 0.6722 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 33/500
# 2/2 - 0s - loss: 0.5449 - accuracy: 0.8214 - val_loss: 0.6712 - val_accuracy: 0.6667 - 45ms/epoch - 22ms/step
# Epoch 34/500
# 2/2 - 0s - loss: 0.5260 - accuracy: 0.8214 - val_loss: 0.6702 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 35/500
# 2/2 - 0s - loss: 0.5553 - accuracy: 0.7500 - val_loss: 0.6693 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 36/500
# 2/2 - 0s - loss: 0.4956 - accuracy: 0.8571 - val_loss: 0.6686 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 37/500
# 2/2 - 0s - loss: 0.5398 - accuracy: 0.8571 - val_loss: 0.6678 - val_accuracy: 0.6667 - 55ms/epoch - 27ms/step
# Epoch 38/500
# 2/2 - 0s - loss: 0.5401 - accuracy: 0.7500 - val_loss: 0.6673 - val_accuracy: 0.6667 - 41ms/epoch - 21ms/step
# Epoch 39/500
# 2/2 - 0s - loss: 0.4959 - accuracy: 0.8214 - val_loss: 0.6667 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 40/500
# 2/2 - 0s - loss: 0.5044 - accuracy: 0.8571 - val_loss: 0.6662 - val_accuracy: 0.6667 - 55ms/epoch - 27ms/step
# Epoch 41/500
# 2/2 - 0s - loss: 0.4870 - accuracy: 0.8571 - val_loss: 0.6658 - val_accuracy: 0.6667 - 57ms/epoch - 28ms/step
# Epoch 42/500
# 2/2 - 0s - loss: 0.5101 - accuracy: 0.8214 - val_loss: 0.6652 - val_accuracy: 0.6667 - 41ms/epoch - 20ms/step
# Epoch 43/500
# 2/2 - 0s - loss: 0.5031 - accuracy: 0.8571 - val_loss: 0.6645 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 44/500
# 2/2 - 0s - loss: 0.4985 - accuracy: 0.8214 - val_loss: 0.6641 - val_accuracy: 0.6667 - 57ms/epoch - 28ms/step
# Epoch 45/500
# 2/2 - 0s - loss: 0.4350 - accuracy: 0.8214 - val_loss: 0.6638 - val_accuracy: 0.6667 - 43ms/epoch - 21ms/step
# Epoch 46/500
# 2/2 - 0s - loss: 0.4444 - accuracy: 0.8929 - val_loss: 0.6635 - val_accuracy: 0.6667 - 57ms/epoch - 28ms/step
# Epoch 47/500
# 2/2 - 0s - loss: 0.4794 - accuracy: 0.8571 - val_loss: 0.6630 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 48/500
# 2/2 - 0s - loss: 0.4714 - accuracy: 0.8214 - val_loss: 0.6626 - val_accuracy: 0.6667 - 57ms/epoch - 28ms/step
# Epoch 49/500
# 2/2 - 0s - loss: 0.4723 - accuracy: 0.8214 - val_loss: 0.6619 - val_accuracy: 0.6667 - 60ms/epoch - 30ms/step
# Epoch 50/500
# 2/2 - 0s - loss: 0.4481 - accuracy: 0.8571 - val_loss: 0.6613 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 51/500
# 2/2 - 0s - loss: 0.4412 - accuracy: 0.8571 - val_loss: 0.6606 - val_accuracy: 0.6667 - 57ms/epoch - 28ms/step
# Epoch 52/500
# 2/2 - 0s - loss: 0.4344 - accuracy: 0.8571 - val_loss: 0.6600 - val_accuracy: 0.6667 - 41ms/epoch - 20ms/step
# Epoch 53/500
# 2/2 - 0s - loss: 0.4039 - accuracy: 0.8571 - val_loss: 0.6597 - val_accuracy: 0.6667 - 44ms/epoch - 22ms/step
# Epoch 54/500
# 2/2 - 0s - loss: 0.4305 - accuracy: 0.8571 - val_loss: 0.6594 - val_accuracy: 0.6667 - 39ms/epoch - 19ms/step
# Epoch 55/500
# 2/2 - 0s - loss: 0.4001 - accuracy: 0.8929 - val_loss: 0.6591 - val_accuracy: 0.6667 - 38ms/epoch - 19ms/step
# Epoch 56/500
# 2/2 - 0s - loss: 0.4529 - accuracy: 0.8571 - val_loss: 0.6591 - val_accuracy: 0.6667 - 48ms/epoch - 24ms/step
# Epoch 57/500
# 2/2 - 0s - loss: 0.4160 - accuracy: 0.9286 - val_loss: 0.6591 - val_accuracy: 0.6667 - 39ms/epoch - 20ms/step
# Epoch 58/500
# 2/2 - 0s - loss: 0.4261 - accuracy: 0.8571 - val_loss: 0.6589 - val_accuracy: 0.6667 - 50ms/epoch - 25ms/step
# Epoch 59/500
# 2/2 - 0s - loss: 0.4026 - accuracy: 0.8571 - val_loss: 0.6588 - val_accuracy: 0.7500 - 39ms/epoch - 20ms/step
# Epoch 60/500
# 2/2 - 0s - loss: 0.3838 - accuracy: 0.8929 - val_loss: 0.6585 - val_accuracy: 0.6667 - 56ms/epoch - 28ms/step
# Epoch 61/500
# 2/2 - 0s - loss: 0.4000 - accuracy: 0.8929 - val_loss: 0.6581 - val_accuracy: 0.6667 - 58ms/epoch - 29ms/step
# Epoch 62/500
# 2/2 - 0s - loss: 0.3870 - accuracy: 0.9286 - val_loss: 0.6577 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 63/500
# 2/2 - 0s - loss: 0.4059 - accuracy: 0.8571 - val_loss: 0.6573 - val_accuracy: 0.6667 - 43ms/epoch - 22ms/step
# Epoch 64/500
# 2/2 - 0s - loss: 0.4000 - accuracy: 0.9286 - val_loss: 0.6573 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 65/500
# 2/2 - 0s - loss: 0.3784 - accuracy: 0.8571 - val_loss: 0.6570 - val_accuracy: 0.6667 - 58ms/epoch - 29ms/step
# Epoch 66/500
# 2/2 - 0s - loss: 0.3854 - accuracy: 0.8929 - val_loss: 0.6565 - val_accuracy: 0.6667 - 41ms/epoch - 21ms/step
# Epoch 67/500
# 2/2 - 0s - loss: 0.3890 - accuracy: 0.8571 - val_loss: 0.6561 - val_accuracy: 0.6667 - 38ms/epoch - 19ms/step
# Epoch 68/500
# 2/2 - 0s - loss: 0.3650 - accuracy: 0.8929 - val_loss: 0.6553 - val_accuracy: 0.6667 - 59ms/epoch - 29ms/step
# Epoch 69/500
# 2/2 - 0s - loss: 0.3732 - accuracy: 0.9286 - val_loss: 0.6543 - val_accuracy: 0.6667 - 77ms/epoch - 38ms/step
# Epoch 70/500
# 2/2 - 0s - loss: 0.3557 - accuracy: 0.9286 - val_loss: 0.6533 - val_accuracy: 0.6667 - 55ms/epoch - 28ms/step
# Epoch 71/500
# 2/2 - 0s - loss: 0.3333 - accuracy: 0.9643 - val_loss: 0.6523 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 72/500
# 2/2 - 0s - loss: 0.3598 - accuracy: 0.8929 - val_loss: 0.6517 - val_accuracy: 0.6667 - 58ms/epoch - 29ms/step
# Epoch 73/500
# 2/2 - 0s - loss: 0.3665 - accuracy: 0.8571 - val_loss: 0.6514 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 74/500
# 2/2 - 0s - loss: 0.3540 - accuracy: 0.8929 - val_loss: 0.6507 - val_accuracy: 0.6667 - 38ms/epoch - 19ms/step
# Epoch 75/500
# 2/2 - 0s - loss: 0.3636 - accuracy: 0.8214 - val_loss: 0.6504 - val_accuracy: 0.6667 - 68ms/epoch - 34ms/step
# Epoch 76/500
# 2/2 - 0s - loss: 0.3512 - accuracy: 0.9643 - val_loss: 0.6503 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 77/500
# 2/2 - 0s - loss: 0.3679 - accuracy: 0.8929 - val_loss: 0.6501 - val_accuracy: 0.6667 - 39ms/epoch - 19ms/step
# Epoch 78/500
# 2/2 - 0s - loss: 0.3592 - accuracy: 0.8929 - val_loss: 0.6501 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 79/500
# 2/2 - 0s - loss: 0.3880 - accuracy: 0.8571 - val_loss: 0.6512 - val_accuracy: 0.6667 - 41ms/epoch - 21ms/step
# Epoch 80/500
# 2/2 - 0s - loss: 0.3247 - accuracy: 0.9286 - val_loss: 0.6523 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 81/500
# 2/2 - 0s - loss: 0.3041 - accuracy: 0.9643 - val_loss: 0.6536 - val_accuracy: 0.6667 - 38ms/epoch - 19ms/step
# Epoch 82/500
# 2/2 - 0s - loss: 0.3312 - accuracy: 1.0000 - val_loss: 0.6539 - val_accuracy: 0.6667 - 39ms/epoch - 19ms/step
# Epoch 83/500
# 2/2 - 0s - loss: 0.3221 - accuracy: 0.8929 - val_loss: 0.6530 - val_accuracy: 0.6667 - 52ms/epoch - 26ms/step
# Epoch 84/500
# 2/2 - 0s - loss: 0.3341 - accuracy: 0.8929 - val_loss: 0.6512 - val_accuracy: 0.6667 - 56ms/epoch - 28ms/step
# Epoch 85/500
# 2/2 - 0s - loss: 0.3033 - accuracy: 0.9643 - val_loss: 0.6491 - val_accuracy: 0.6667 - 39ms/epoch - 20ms/step
# Epoch 86/500
# 2/2 - 0s - loss: 0.3281 - accuracy: 0.8929 - val_loss: 0.6483 - val_accuracy: 0.5833 - 44ms/epoch - 22ms/step
# Epoch 87/500
# 2/2 - 0s - loss: 0.3309 - accuracy: 0.9286 - val_loss: 0.6478 - val_accuracy: 0.5833 - 38ms/epoch - 19ms/step
# Epoch 88/500
# 2/2 - 0s - loss: 0.3193 - accuracy: 0.8929 - val_loss: 0.6479 - val_accuracy: 0.5000 - 39ms/epoch - 19ms/step
# Epoch 89/500
# 2/2 - 0s - loss: 0.3167 - accuracy: 0.9286 - val_loss: 0.6472 - val_accuracy: 0.5000 - 56ms/epoch - 28ms/step
# Epoch 90/500
# 2/2 - 0s - loss: 0.3249 - accuracy: 0.9643 - val_loss: 0.6461 - val_accuracy: 0.5833 - 43ms/epoch - 22ms/step
# Epoch 91/500
# 2/2 - 0s - loss: 0.3207 - accuracy: 0.8571 - val_loss: 0.6445 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 92/500
# 2/2 - 0s - loss: 0.2659 - accuracy: 0.9643 - val_loss: 0.6435 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 93/500
# 2/2 - 0s - loss: 0.3394 - accuracy: 0.9643 - val_loss: 0.6428 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 94/500
# 2/2 - 0s - loss: 0.2842 - accuracy: 0.9643 - val_loss: 0.6422 - val_accuracy: 0.6667 - 61ms/epoch - 31ms/step
# Epoch 95/500
# 2/2 - 0s - loss: 0.3111 - accuracy: 0.9286 - val_loss: 0.6420 - val_accuracy: 0.6667 - 63ms/epoch - 31ms/step
# Epoch 96/500
# 2/2 - 0s - loss: 0.2796 - accuracy: 0.9286 - val_loss: 0.6425 - val_accuracy: 0.6667 - 61ms/epoch - 31ms/step
# Epoch 97/500
# 2/2 - 0s - loss: 0.2964 - accuracy: 0.9643 - val_loss: 0.6434 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 98/500
# 2/2 - 0s - loss: 0.3205 - accuracy: 0.9286 - val_loss: 0.6447 - val_accuracy: 0.5833 - 59ms/epoch - 29ms/step
# Epoch 99/500
# 2/2 - 0s - loss: 0.2836 - accuracy: 0.9286 - val_loss: 0.6473 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 100/500
# 2/2 - 0s - loss: 0.2739 - accuracy: 0.9643 - val_loss: 0.6501 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 101/500
# 2/2 - 0s - loss: 0.2700 - accuracy: 0.9643 - val_loss: 0.6529 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 102/500
# 2/2 - 0s - loss: 0.3081 - accuracy: 0.9286 - val_loss: 0.6574 - val_accuracy: 0.5000 - 39ms/epoch - 19ms/step
# Epoch 103/500
# 2/2 - 0s - loss: 0.2590 - accuracy: 1.0000 - val_loss: 0.6616 - val_accuracy: 0.5000 - 47ms/epoch - 23ms/step
# Epoch 104/500
# 2/2 - 0s - loss: 0.2548 - accuracy: 1.0000 - val_loss: 0.6629 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 105/500
# 2/2 - 0s - loss: 0.2796 - accuracy: 0.9286 - val_loss: 0.6640 - val_accuracy: 0.5000 - 39ms/epoch - 19ms/step
# Epoch 106/500
# 2/2 - 0s - loss: 0.2808 - accuracy: 0.9286 - val_loss: 0.6640 - val_accuracy: 0.5000 - 39ms/epoch - 20ms/step
# Epoch 107/500
# 2/2 - 0s - loss: 0.2425 - accuracy: 0.9286 - val_loss: 0.6643 - val_accuracy: 0.5000 - 56ms/epoch - 28ms/step
# Epoch 108/500
# 2/2 - 0s - loss: 0.2706 - accuracy: 0.9643 - val_loss: 0.6666 - val_accuracy: 0.5000 - 57ms/epoch - 28ms/step
# Epoch 109/500
# 2/2 - 0s - loss: 0.2594 - accuracy: 0.9643 - val_loss: 0.6676 - val_accuracy: 0.5000 - 57ms/epoch - 28ms/step
# Epoch 110/500
# 2/2 - 0s - loss: 0.2278 - accuracy: 1.0000 - val_loss: 0.6686 - val_accuracy: 0.5000 - 50ms/epoch - 25ms/step
# Epoch 111/500
# 2/2 - 0s - loss: 0.2628 - accuracy: 0.9643 - val_loss: 0.6718 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 112/500
# 2/2 - 0s - loss: 0.2317 - accuracy: 1.0000 - val_loss: 0.6742 - val_accuracy: 0.5000 - 54ms/epoch - 27ms/step
# Epoch 113/500
# 2/2 - 0s - loss: 0.2352 - accuracy: 1.0000 - val_loss: 0.6722 - val_accuracy: 0.5000 - 41ms/epoch - 20ms/step
# Epoch 114/500
# 2/2 - 0s - loss: 0.2654 - accuracy: 0.9643 - val_loss: 0.6679 - val_accuracy: 0.5000 - 50ms/epoch - 25ms/step
# Epoch 115/500
# 2/2 - 0s - loss: 0.2534 - accuracy: 0.9643 - val_loss: 0.6632 - val_accuracy: 0.5000 - 41ms/epoch - 21ms/step
# Epoch 116/500
# 2/2 - 0s - loss: 0.2466 - accuracy: 0.9643 - val_loss: 0.6602 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 117/500
# 2/2 - 0s - loss: 0.2659 - accuracy: 1.0000 - val_loss: 0.6578 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 118/500
# 2/2 - 0s - loss: 0.2332 - accuracy: 1.0000 - val_loss: 0.6578 - val_accuracy: 0.5833 - 38ms/epoch - 19ms/step
# Epoch 119/500
# 2/2 - 0s - loss: 0.2390 - accuracy: 0.9643 - val_loss: 0.6569 - val_accuracy: 0.6667 - 43ms/epoch - 21ms/step
# Epoch 120/500
# 2/2 - 0s - loss: 0.2210 - accuracy: 1.0000 - val_loss: 0.6559 - val_accuracy: 0.6667 - 39ms/epoch - 20ms/step
# Epoch 121/500
# 2/2 - 0s - loss: 0.2661 - accuracy: 0.9286 - val_loss: 0.6571 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 122/500
# 2/2 - 0s - loss: 0.2200 - accuracy: 1.0000 - val_loss: 0.6615 - val_accuracy: 0.5833 - 39ms/epoch - 19ms/step
# Epoch 123/500
# 2/2 - 0s - loss: 0.2165 - accuracy: 1.0000 - val_loss: 0.6654 - val_accuracy: 0.5000 - 44ms/epoch - 22ms/step
# Epoch 124/500
# 2/2 - 0s - loss: 0.2051 - accuracy: 1.0000 - val_loss: 0.6694 - val_accuracy: 0.5000 - 39ms/epoch - 20ms/step
# Epoch 125/500
# 2/2 - 0s - loss: 0.2362 - accuracy: 1.0000 - val_loss: 0.6681 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 126/500
# 2/2 - 0s - loss: 0.2379 - accuracy: 0.9286 - val_loss: 0.6640 - val_accuracy: 0.5833 - 54ms/epoch - 27ms/step
# Epoch 127/500
# 2/2 - 0s - loss: 0.2180 - accuracy: 0.9643 - val_loss: 0.6628 - val_accuracy: 0.5833 - 43ms/epoch - 22ms/step
# Epoch 128/500
# 2/2 - 0s - loss: 0.2502 - accuracy: 1.0000 - val_loss: 0.6627 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 129/500
# 2/2 - 0s - loss: 0.2421 - accuracy: 0.9286 - val_loss: 0.6644 - val_accuracy: 0.5833 - 55ms/epoch - 28ms/step
# Epoch 130/500
# 2/2 - 0s - loss: 0.1953 - accuracy: 1.0000 - val_loss: 0.6677 - val_accuracy: 0.5833 - 47ms/epoch - 23ms/step
# Epoch 131/500
# 2/2 - 0s - loss: 0.1968 - accuracy: 1.0000 - val_loss: 0.6742 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 132/500
# 2/2 - 0s - loss: 0.2383 - accuracy: 0.9286 - val_loss: 0.6804 - val_accuracy: 0.5000 - 58ms/epoch - 29ms/step
# Epoch 133/500
# 2/2 - 0s - loss: 0.2340 - accuracy: 0.9643 - val_loss: 0.6858 - val_accuracy: 0.5000 - 44ms/epoch - 22ms/step
# Epoch 134/500
# 2/2 - 0s - loss: 0.2059 - accuracy: 1.0000 - val_loss: 0.6882 - val_accuracy: 0.5000 - 48ms/epoch - 24ms/step
# Epoch 135/500
# 2/2 - 0s - loss: 0.2352 - accuracy: 0.9643 - val_loss: 0.6839 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 136/500
# 2/2 - 0s - loss: 0.1925 - accuracy: 1.0000 - val_loss: 0.6804 - val_accuracy: 0.5833 - 47ms/epoch - 24ms/step
# Epoch 137/500
# 2/2 - 0s - loss: 0.2145 - accuracy: 1.0000 - val_loss: 0.6790 - val_accuracy: 0.5833 - 55ms/epoch - 28ms/step
# Epoch 138/500
# 2/2 - 0s - loss: 0.2067 - accuracy: 1.0000 - val_loss: 0.6772 - val_accuracy: 0.5833 - 55ms/epoch - 27ms/step
# Epoch 139/500
# 2/2 - 0s - loss: 0.2595 - accuracy: 0.9286 - val_loss: 0.6777 - val_accuracy: 0.5833 - 44ms/epoch - 22ms/step
# Epoch 140/500
# 2/2 - 0s - loss: 0.1881 - accuracy: 1.0000 - val_loss: 0.6808 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 141/500
# 2/2 - 0s - loss: 0.2245 - accuracy: 0.9643 - val_loss: 0.6867 - val_accuracy: 0.5833 - 55ms/epoch - 28ms/step
# Epoch 142/500
# 2/2 - 0s - loss: 0.1836 - accuracy: 1.0000 - val_loss: 0.6970 - val_accuracy: 0.5000 - 38ms/epoch - 19ms/step
# Epoch 143/500
# 2/2 - 0s - loss: 0.1967 - accuracy: 1.0000 - val_loss: 0.7047 - val_accuracy: 0.5000 - 55ms/epoch - 27ms/step
# Epoch 144/500
# 2/2 - 0s - loss: 0.2106 - accuracy: 0.9643 - val_loss: 0.7081 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 145/500
# 2/2 - 0s - loss: 0.1909 - accuracy: 1.0000 - val_loss: 0.7087 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 146/500
# 2/2 - 0s - loss: 0.2066 - accuracy: 0.9643 - val_loss: 0.7088 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 147/500
# 2/2 - 0s - loss: 0.2023 - accuracy: 1.0000 - val_loss: 0.7098 - val_accuracy: 0.5833 - 39ms/epoch - 19ms/step
# Epoch 148/500
# 2/2 - 0s - loss: 0.1794 - accuracy: 1.0000 - val_loss: 0.7112 - val_accuracy: 0.5833 - 44ms/epoch - 22ms/step
# Epoch 149/500
# 2/2 - 0s - loss: 0.1685 - accuracy: 1.0000 - val_loss: 0.7123 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 150/500
# 2/2 - 0s - loss: 0.2076 - accuracy: 1.0000 - val_loss: 0.7076 - val_accuracy: 0.5833 - 64ms/epoch - 32ms/step
# Epoch 151/500
# 2/2 - 0s - loss: 0.1737 - accuracy: 1.0000 - val_loss: 0.6988 - val_accuracy: 0.5833 - 47ms/epoch - 24ms/step
# Epoch 152/500
# 2/2 - 0s - loss: 0.1757 - accuracy: 1.0000 - val_loss: 0.6937 - val_accuracy: 0.5833 - 80ms/epoch - 40ms/step
# Epoch 153/500
# 2/2 - 0s - loss: 0.2186 - accuracy: 1.0000 - val_loss: 0.6939 - val_accuracy: 0.5833 - 65ms/epoch - 32ms/step
# Epoch 154/500
# 2/2 - 0s - loss: 0.2008 - accuracy: 1.0000 - val_loss: 0.6943 - val_accuracy: 0.5833 - 77ms/epoch - 39ms/step
# Epoch 155/500
# 2/2 - 0s - loss: 0.1804 - accuracy: 1.0000 - val_loss: 0.6960 - val_accuracy: 0.5833 - 61ms/epoch - 31ms/step
# Epoch 156/500
# 2/2 - 0s - loss: 0.1806 - accuracy: 1.0000 - val_loss: 0.6981 - val_accuracy: 0.5833 - 76ms/epoch - 38ms/step
# Epoch 157/500
# 2/2 - 0s - loss: 0.1595 - accuracy: 1.0000 - val_loss: 0.7004 - val_accuracy: 0.5833 - 75ms/epoch - 37ms/step
# Epoch 158/500
# 2/2 - 0s - loss: 0.1670 - accuracy: 1.0000 - val_loss: 0.7083 - val_accuracy: 0.5833 - 70ms/epoch - 35ms/step
# Epoch 159/500
# 2/2 - 0s - loss: 0.2355 - accuracy: 0.9643 - val_loss: 0.7192 - val_accuracy: 0.5833 - 72ms/epoch - 36ms/step
# Epoch 160/500
# 2/2 - 0s - loss: 0.1912 - accuracy: 0.9643 - val_loss: 0.7278 - val_accuracy: 0.5833 - 55ms/epoch - 27ms/step
# Epoch 161/500
# 2/2 - 0s - loss: 0.2575 - accuracy: 0.8929 - val_loss: 0.7266 - val_accuracy: 0.5833 - 69ms/epoch - 34ms/step
# Epoch 162/500
# 2/2 - 0s - loss: 0.1723 - accuracy: 1.0000 - val_loss: 0.7247 - val_accuracy: 0.5833 - 67ms/epoch - 34ms/step
# Epoch 163/500
# 2/2 - 0s - loss: 0.1697 - accuracy: 1.0000 - val_loss: 0.7253 - val_accuracy: 0.5833 - 77ms/epoch - 38ms/step
# Epoch 164/500
# 2/2 - 0s - loss: 0.1999 - accuracy: 1.0000 - val_loss: 0.7282 - val_accuracy: 0.5833 - 74ms/epoch - 37ms/step
# Epoch 165/500
# 2/2 - 0s - loss: 0.1580 - accuracy: 1.0000 - val_loss: 0.7284 - val_accuracy: 0.5833 - 68ms/epoch - 34ms/step
# Epoch 166/500
# 2/2 - 0s - loss: 0.1871 - accuracy: 1.0000 - val_loss: 0.7234 - val_accuracy: 0.5833 - 79ms/epoch - 40ms/step
# Epoch 167/500
# 2/2 - 0s - loss: 0.1899 - accuracy: 1.0000 - val_loss: 0.7159 - val_accuracy: 0.5833 - 76ms/epoch - 38ms/step
# Epoch 168/500
# 2/2 - 0s - loss: 0.1835 - accuracy: 1.0000 - val_loss: 0.7097 - val_accuracy: 0.5833 - 71ms/epoch - 35ms/step
# Epoch 169/500
# 2/2 - 0s - loss: 0.1897 - accuracy: 1.0000 - val_loss: 0.7049 - val_accuracy: 0.6667 - 72ms/epoch - 36ms/step
# Epoch 170/500
# 2/2 - 0s - loss: 0.1585 - accuracy: 1.0000 - val_loss: 0.7047 - val_accuracy: 0.6667 - 60ms/epoch - 30ms/step
# Epoch 171/500
# 2/2 - 0s - loss: 0.1869 - accuracy: 1.0000 - val_loss: 0.7116 - val_accuracy: 0.6667 - 62ms/epoch - 31ms/step
# Epoch 172/500
# 2/2 - 0s - loss: 0.1560 - accuracy: 1.0000 - val_loss: 0.7220 - val_accuracy: 0.5833 - 73ms/epoch - 36ms/step
# Epoch 173/500
# 2/2 - 0s - loss: 0.1662 - accuracy: 1.0000 - val_loss: 0.7305 - val_accuracy: 0.5833 - 75ms/epoch - 37ms/step
# Epoch 174/500
# 2/2 - 0s - loss: 0.1779 - accuracy: 1.0000 - val_loss: 0.7350 - val_accuracy: 0.5833 - 71ms/epoch - 35ms/step
# Epoch 175/500
# 2/2 - 0s - loss: 0.1535 - accuracy: 1.0000 - val_loss: 0.7374 - val_accuracy: 0.5833 - 65ms/epoch - 33ms/step
# Epoch 176/500
# 2/2 - 0s - loss: 0.1603 - accuracy: 1.0000 - val_loss: 0.7370 - val_accuracy: 0.5833 - 66ms/epoch - 33ms/step
# Epoch 177/500
# 2/2 - 0s - loss: 0.1823 - accuracy: 0.9643 - val_loss: 0.7276 - val_accuracy: 0.5833 - 55ms/epoch - 27ms/step
# Epoch 178/500
# 2/2 - 0s - loss: 0.1476 - accuracy: 1.0000 - val_loss: 0.7228 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 179/500
# 2/2 - 0s - loss: 0.1462 - accuracy: 1.0000 - val_loss: 0.7184 - val_accuracy: 0.5833 - 69ms/epoch - 34ms/step
# Epoch 180/500
# 2/2 - 0s - loss: 0.1509 - accuracy: 1.0000 - val_loss: 0.7142 - val_accuracy: 0.6667 - 76ms/epoch - 38ms/step
# Epoch 181/500
# 2/2 - 0s - loss: 0.1565 - accuracy: 1.0000 - val_loss: 0.7098 - val_accuracy: 0.6667 - 63ms/epoch - 32ms/step
# Epoch 182/500
# 2/2 - 0s - loss: 0.1771 - accuracy: 1.0000 - val_loss: 0.7034 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 183/500
# 2/2 - 0s - loss: 0.1629 - accuracy: 1.0000 - val_loss: 0.7017 - val_accuracy: 0.5833 - 72ms/epoch - 36ms/step
# Epoch 184/500
# 2/2 - 0s - loss: 0.1582 - accuracy: 1.0000 - val_loss: 0.7043 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 185/500
# 2/2 - 0s - loss: 0.1744 - accuracy: 1.0000 - val_loss: 0.7095 - val_accuracy: 0.6667 - 57ms/epoch - 28ms/step
# Epoch 186/500
# 2/2 - 0s - loss: 0.1683 - accuracy: 0.9643 - val_loss: 0.7232 - val_accuracy: 0.5833 - 68ms/epoch - 34ms/step
# Epoch 187/500
# 2/2 - 0s - loss: 0.1938 - accuracy: 1.0000 - val_loss: 0.7345 - val_accuracy: 0.5833 - 73ms/epoch - 37ms/step
# Epoch 188/500
# 2/2 - 0s - loss: 0.1490 - accuracy: 1.0000 - val_loss: 0.7389 - val_accuracy: 0.5833 - 81ms/epoch - 40ms/step
# Epoch 189/500
# 2/2 - 0s - loss: 0.1597 - accuracy: 1.0000 - val_loss: 0.7413 - val_accuracy: 0.5833 - 73ms/epoch - 36ms/step
# Epoch 190/500
# 2/2 - 0s - loss: 0.1463 - accuracy: 1.0000 - val_loss: 0.7463 - val_accuracy: 0.5833 - 76ms/epoch - 38ms/step
# Epoch 191/500
# 2/2 - 0s - loss: 0.1570 - accuracy: 1.0000 - val_loss: 0.7419 - val_accuracy: 0.5833 - 74ms/epoch - 37ms/step
# Epoch 192/500
# 2/2 - 0s - loss: 0.1412 - accuracy: 1.0000 - val_loss: 0.7406 - val_accuracy: 0.6667 - 69ms/epoch - 34ms/step
# Epoch 193/500
# 2/2 - 0s - loss: 0.1611 - accuracy: 1.0000 - val_loss: 0.7373 - val_accuracy: 0.5833 - 75ms/epoch - 38ms/step
# Epoch 194/500
# 2/2 - 0s - loss: 0.1720 - accuracy: 1.0000 - val_loss: 0.7299 - val_accuracy: 0.5833 - 85ms/epoch - 43ms/step
# Epoch 195/500
# 2/2 - 0s - loss: 0.1319 - accuracy: 1.0000 - val_loss: 0.7246 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 196/500
# 2/2 - 0s - loss: 0.1417 - accuracy: 0.9643 - val_loss: 0.7261 - val_accuracy: 0.5833 - 69ms/epoch - 35ms/step
# Epoch 197/500
# 2/2 - 0s - loss: 0.1414 - accuracy: 1.0000 - val_loss: 0.7326 - val_accuracy: 0.5833 - 67ms/epoch - 34ms/step
# Epoch 198/500
# 2/2 - 0s - loss: 0.1364 - accuracy: 1.0000 - val_loss: 0.7410 - val_accuracy: 0.5833 - 59ms/epoch - 30ms/step
# Epoch 199/500
# 2/2 - 0s - loss: 0.1208 - accuracy: 1.0000 - val_loss: 0.7500 - val_accuracy: 0.5833 - 63ms/epoch - 31ms/step
# Epoch 200/500
# 2/2 - 0s - loss: 0.1743 - accuracy: 1.0000 - val_loss: 0.7614 - val_accuracy: 0.6667 - 59ms/epoch - 29ms/step
# Epoch 201/500
# 2/2 - 0s - loss: 0.1238 - accuracy: 1.0000 - val_loss: 0.7732 - val_accuracy: 0.5833 - 57ms/epoch - 28ms/step
# Epoch 202/500
# 2/2 - 0s - loss: 0.1449 - accuracy: 1.0000 - val_loss: 0.7852 - val_accuracy: 0.5833 - 75ms/epoch - 37ms/step
# Epoch 203/500
# 2/2 - 0s - loss: 0.1467 - accuracy: 1.0000 - val_loss: 0.7948 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 204/500
# 2/2 - 0s - loss: 0.1270 - accuracy: 1.0000 - val_loss: 0.7946 - val_accuracy: 0.5833 - 57ms/epoch - 29ms/step
# Epoch 205/500
# 2/2 - 0s - loss: 0.1556 - accuracy: 1.0000 - val_loss: 0.7789 - val_accuracy: 0.5833 - 61ms/epoch - 30ms/step
# Epoch 206/500
# 2/2 - 0s - loss: 0.1583 - accuracy: 0.9643 - val_loss: 0.7665 - val_accuracy: 0.5833 - 46ms/epoch - 23ms/step
# Epoch 207/500
# 2/2 - 0s - loss: 0.1238 - accuracy: 1.0000 - val_loss: 0.7543 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 208/500
# 2/2 - 0s - loss: 0.1394 - accuracy: 1.0000 - val_loss: 0.7439 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 209/500
# 2/2 - 0s - loss: 0.1636 - accuracy: 1.0000 - val_loss: 0.7384 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 210/500
# 2/2 - 0s - loss: 0.1508 - accuracy: 1.0000 - val_loss: 0.7344 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 211/500
# 2/2 - 0s - loss: 0.1206 - accuracy: 1.0000 - val_loss: 0.7339 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 212/500
# 2/2 - 0s - loss: 0.1675 - accuracy: 1.0000 - val_loss: 0.7369 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 213/500
# 2/2 - 0s - loss: 0.1259 - accuracy: 1.0000 - val_loss: 0.7452 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 214/500
# 2/2 - 0s - loss: 0.1335 - accuracy: 1.0000 - val_loss: 0.7594 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 215/500
# 2/2 - 0s - loss: 0.1340 - accuracy: 1.0000 - val_loss: 0.7782 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 216/500
# 2/2 - 0s - loss: 0.1302 - accuracy: 1.0000 - val_loss: 0.7939 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 217/500
# 2/2 - 0s - loss: 0.1625 - accuracy: 1.0000 - val_loss: 0.8018 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 218/500
# 2/2 - 0s - loss: 0.1133 - accuracy: 1.0000 - val_loss: 0.8124 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 219/500
# 2/2 - 0s - loss: 0.1597 - accuracy: 1.0000 - val_loss: 0.8067 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 220/500
# 2/2 - 0s - loss: 0.1287 - accuracy: 1.0000 - val_loss: 0.7937 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 221/500
# 2/2 - 0s - loss: 0.1392 - accuracy: 1.0000 - val_loss: 0.7764 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 222/500
# 2/2 - 0s - loss: 0.1480 - accuracy: 1.0000 - val_loss: 0.7722 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 223/500
# 2/2 - 0s - loss: 0.1404 - accuracy: 1.0000 - val_loss: 0.7665 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 224/500
# 2/2 - 0s - loss: 0.1326 - accuracy: 1.0000 - val_loss: 0.7602 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 225/500
# 2/2 - 0s - loss: 0.1552 - accuracy: 1.0000 - val_loss: 0.7627 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 226/500
# 2/2 - 0s - loss: 0.1084 - accuracy: 1.0000 - val_loss: 0.7683 - val_accuracy: 0.6667 - 39ms/epoch - 20ms/step
# Epoch 227/500
# 2/2 - 0s - loss: 0.1271 - accuracy: 1.0000 - val_loss: 0.7836 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 228/500
# 2/2 - 0s - loss: 0.1159 - accuracy: 1.0000 - val_loss: 0.7928 - val_accuracy: 0.5833 - 38ms/epoch - 19ms/step
# Epoch 229/500
# 2/2 - 0s - loss: 0.1376 - accuracy: 1.0000 - val_loss: 0.7993 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 230/500
# 2/2 - 0s - loss: 0.1104 - accuracy: 1.0000 - val_loss: 0.7946 - val_accuracy: 0.5833 - 61ms/epoch - 31ms/step
# Epoch 231/500
# 2/2 - 0s - loss: 0.1239 - accuracy: 1.0000 - val_loss: 0.7807 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 232/500
# 2/2 - 0s - loss: 0.1282 - accuracy: 1.0000 - val_loss: 0.7723 - val_accuracy: 0.5833 - 57ms/epoch - 28ms/step
# Epoch 233/500
# 2/2 - 0s - loss: 0.1030 - accuracy: 1.0000 - val_loss: 0.7754 - val_accuracy: 0.5000 - 41ms/epoch - 20ms/step
# Epoch 234/500
# 2/2 - 0s - loss: 0.1265 - accuracy: 1.0000 - val_loss: 0.7857 - val_accuracy: 0.5000 - 41ms/epoch - 21ms/step
# Epoch 235/500
# 2/2 - 0s - loss: 0.0942 - accuracy: 1.0000 - val_loss: 0.7876 - val_accuracy: 0.5000 - 41ms/epoch - 21ms/step
# Epoch 236/500
# 2/2 - 0s - loss: 0.1310 - accuracy: 1.0000 - val_loss: 0.7791 - val_accuracy: 0.5833 - 57ms/epoch - 28ms/step
# Epoch 237/500
# 2/2 - 0s - loss: 0.1102 - accuracy: 1.0000 - val_loss: 0.7718 - val_accuracy: 0.5833 - 41ms/epoch - 21ms/step
# Epoch 238/500
# 2/2 - 0s - loss: 0.1301 - accuracy: 1.0000 - val_loss: 0.7664 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 239/500
# 2/2 - 0s - loss: 0.1164 - accuracy: 1.0000 - val_loss: 0.7660 - val_accuracy: 0.5833 - 43ms/epoch - 22ms/step
# Epoch 240/500
# 2/2 - 0s - loss: 0.1526 - accuracy: 1.0000 - val_loss: 0.7610 - val_accuracy: 0.5833 - 50ms/epoch - 25ms/step
# Epoch 241/500
# 2/2 - 0s - loss: 0.1190 - accuracy: 1.0000 - val_loss: 0.7570 - val_accuracy: 0.5833 - 41ms/epoch - 21ms/step
# Epoch 242/500
# 2/2 - 0s - loss: 0.1328 - accuracy: 1.0000 - val_loss: 0.7656 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 243/500
# 2/2 - 0s - loss: 0.1053 - accuracy: 1.0000 - val_loss: 0.7796 - val_accuracy: 0.6667 - 43ms/epoch - 21ms/step
# Epoch 244/500
# 2/2 - 0s - loss: 0.1134 - accuracy: 1.0000 - val_loss: 0.7858 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 245/500
# 2/2 - 0s - loss: 0.0944 - accuracy: 1.0000 - val_loss: 0.7821 - val_accuracy: 0.5833 - 43ms/epoch - 21ms/step
# Epoch 246/500
# 2/2 - 0s - loss: 0.1033 - accuracy: 1.0000 - val_loss: 0.7839 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 247/500
# 2/2 - 0s - loss: 0.1168 - accuracy: 1.0000 - val_loss: 0.7856 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 248/500
# 2/2 - 0s - loss: 0.1162 - accuracy: 1.0000 - val_loss: 0.7875 - val_accuracy: 0.5833 - 43ms/epoch - 22ms/step
# Epoch 249/500
# 2/2 - 0s - loss: 0.1262 - accuracy: 1.0000 - val_loss: 0.7868 - val_accuracy: 0.5000 - 56ms/epoch - 28ms/step
# Epoch 250/500
# 2/2 - 0s - loss: 0.1079 - accuracy: 1.0000 - val_loss: 0.7839 - val_accuracy: 0.5000 - 62ms/epoch - 31ms/step
# Epoch 251/500
# 2/2 - 0s - loss: 0.1072 - accuracy: 1.0000 - val_loss: 0.7713 - val_accuracy: 0.5833 - 41ms/epoch - 21ms/step
# Epoch 252/500
# 2/2 - 0s - loss: 0.1171 - accuracy: 1.0000 - val_loss: 0.7606 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 253/500
# 2/2 - 0s - loss: 0.1119 - accuracy: 1.0000 - val_loss: 0.7539 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 254/500
# 2/2 - 0s - loss: 0.1302 - accuracy: 1.0000 - val_loss: 0.7542 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 255/500
# 2/2 - 0s - loss: 0.1054 - accuracy: 1.0000 - val_loss: 0.7610 - val_accuracy: 0.5833 - 41ms/epoch - 21ms/step
# Epoch 256/500
# 2/2 - 0s - loss: 0.1003 - accuracy: 1.0000 - val_loss: 0.7661 - val_accuracy: 0.5833 - 57ms/epoch - 29ms/step
# Epoch 257/500
# 2/2 - 0s - loss: 0.1097 - accuracy: 1.0000 - val_loss: 0.7747 - val_accuracy: 0.5833 - 44ms/epoch - 22ms/step
# Epoch 258/500
# 2/2 - 0s - loss: 0.0918 - accuracy: 1.0000 - val_loss: 0.7822 - val_accuracy: 0.5833 - 57ms/epoch - 28ms/step
# Epoch 259/500
# 2/2 - 0s - loss: 0.1126 - accuracy: 1.0000 - val_loss: 0.7824 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 260/500
# 2/2 - 0s - loss: 0.0973 - accuracy: 1.0000 - val_loss: 0.7845 - val_accuracy: 0.5833 - 59ms/epoch - 29ms/step
# Epoch 261/500
# 2/2 - 0s - loss: 0.1231 - accuracy: 1.0000 - val_loss: 0.7965 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 262/500
# 2/2 - 0s - loss: 0.1059 - accuracy: 1.0000 - val_loss: 0.8080 - val_accuracy: 0.5833 - 61ms/epoch - 31ms/step
# Epoch 263/500
# 2/2 - 0s - loss: 0.0961 - accuracy: 1.0000 - val_loss: 0.8172 - val_accuracy: 0.5000 - 46ms/epoch - 23ms/step
# Epoch 264/500
# 2/2 - 0s - loss: 0.0840 - accuracy: 1.0000 - val_loss: 0.8235 - val_accuracy: 0.5000 - 43ms/epoch - 22ms/step
# Epoch 265/500
# 2/2 - 0s - loss: 0.1316 - accuracy: 1.0000 - val_loss: 0.8280 - val_accuracy: 0.5000 - 59ms/epoch - 30ms/step
# Epoch 266/500
# 2/2 - 0s - loss: 0.1102 - accuracy: 1.0000 - val_loss: 0.8192 - val_accuracy: 0.5833 - 62ms/epoch - 31ms/step
# Epoch 267/500
# 2/2 - 0s - loss: 0.1091 - accuracy: 1.0000 - val_loss: 0.8185 - val_accuracy: 0.5833 - 43ms/epoch - 22ms/step
# Epoch 268/500
# 2/2 - 0s - loss: 0.1069 - accuracy: 1.0000 - val_loss: 0.8164 - val_accuracy: 0.5833 - 53ms/epoch - 26ms/step
# Epoch 269/500
# 2/2 - 0s - loss: 0.1259 - accuracy: 1.0000 - val_loss: 0.7937 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 270/500
# 2/2 - 0s - loss: 0.0929 - accuracy: 1.0000 - val_loss: 0.7730 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 271/500
# 2/2 - 0s - loss: 0.1178 - accuracy: 1.0000 - val_loss: 0.7653 - val_accuracy: 0.6667 - 44ms/epoch - 22ms/step
# Epoch 272/500
# 2/2 - 0s - loss: 0.1121 - accuracy: 1.0000 - val_loss: 0.7567 - val_accuracy: 0.6667 - 58ms/epoch - 29ms/step
# Epoch 273/500
# 2/2 - 0s - loss: 0.0823 - accuracy: 1.0000 - val_loss: 0.7484 - val_accuracy: 0.6667 - 45ms/epoch - 22ms/step
# Epoch 274/500
# 2/2 - 0s - loss: 0.1134 - accuracy: 1.0000 - val_loss: 0.7488 - val_accuracy: 0.5833 - 41ms/epoch - 21ms/step
# Epoch 275/500
# 2/2 - 0s - loss: 0.0942 - accuracy: 1.0000 - val_loss: 0.7609 - val_accuracy: 0.5833 - 44ms/epoch - 22ms/step
# Epoch 276/500
# 2/2 - 0s - loss: 0.1187 - accuracy: 1.0000 - val_loss: 0.7793 - val_accuracy: 0.5833 - 44ms/epoch - 22ms/step
# Epoch 277/500
# 2/2 - 0s - loss: 0.1107 - accuracy: 1.0000 - val_loss: 0.8014 - val_accuracy: 0.6667 - 56ms/epoch - 28ms/step
# Epoch 278/500
# 2/2 - 0s - loss: 0.1144 - accuracy: 1.0000 - val_loss: 0.8054 - val_accuracy: 0.6667 - 44ms/epoch - 22ms/step
# Epoch 279/500
# 2/2 - 0s - loss: 0.0861 - accuracy: 1.0000 - val_loss: 0.8056 - val_accuracy: 0.5833 - 61ms/epoch - 30ms/step
# Epoch 280/500
# 2/2 - 0s - loss: 0.1156 - accuracy: 1.0000 - val_loss: 0.8071 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 281/500
# 2/2 - 0s - loss: 0.1134 - accuracy: 1.0000 - val_loss: 0.8087 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 282/500
# 2/2 - 0s - loss: 0.0873 - accuracy: 1.0000 - val_loss: 0.8099 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 283/500
# 2/2 - 0s - loss: 0.0995 - accuracy: 1.0000 - val_loss: 0.8122 - val_accuracy: 0.5833 - 57ms/epoch - 28ms/step
# Epoch 284/500
# 2/2 - 0s - loss: 0.0992 - accuracy: 1.0000 - val_loss: 0.8164 - val_accuracy: 0.6667 - 44ms/epoch - 22ms/step
# Epoch 285/500
# 2/2 - 0s - loss: 0.1003 - accuracy: 1.0000 - val_loss: 0.8213 - val_accuracy: 0.6667 - 39ms/epoch - 20ms/step
# Epoch 286/500
# 2/2 - 0s - loss: 0.1083 - accuracy: 1.0000 - val_loss: 0.8216 - val_accuracy: 0.6667 - 57ms/epoch - 29ms/step
# Epoch 287/500
# 2/2 - 0s - loss: 0.1084 - accuracy: 1.0000 - val_loss: 0.8165 - val_accuracy: 0.6667 - 39ms/epoch - 19ms/step
# Epoch 288/500
# 2/2 - 0s - loss: 0.1181 - accuracy: 1.0000 - val_loss: 0.8140 - val_accuracy: 0.5833 - 39ms/epoch - 19ms/step
# Epoch 289/500
# 2/2 - 0s - loss: 0.1003 - accuracy: 1.0000 - val_loss: 0.8138 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 290/500
# 2/2 - 0s - loss: 0.0977 - accuracy: 1.0000 - val_loss: 0.8084 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 291/500
# 2/2 - 0s - loss: 0.1162 - accuracy: 1.0000 - val_loss: 0.7963 - val_accuracy: 0.5833 - 55ms/epoch - 27ms/step
# Epoch 292/500
# 2/2 - 0s - loss: 0.1001 - accuracy: 1.0000 - val_loss: 0.7927 - val_accuracy: 0.6667 - 45ms/epoch - 22ms/step
# Epoch 293/500
# 2/2 - 0s - loss: 0.1062 - accuracy: 1.0000 - val_loss: 0.7998 - val_accuracy: 0.7500 - 40ms/epoch - 20ms/step
# Epoch 294/500
# 2/2 - 0s - loss: 0.0929 - accuracy: 1.0000 - val_loss: 0.8009 - val_accuracy: 0.7500 - 40ms/epoch - 20ms/step
# Epoch 295/500
# 2/2 - 0s - loss: 0.1116 - accuracy: 1.0000 - val_loss: 0.7959 - val_accuracy: 0.7500 - 40ms/epoch - 20ms/step
# Epoch 296/500
# 2/2 - 0s - loss: 0.0843 - accuracy: 1.0000 - val_loss: 0.7930 - val_accuracy: 0.7500 - 41ms/epoch - 20ms/step
# Epoch 297/500
# 2/2 - 0s - loss: 0.1123 - accuracy: 1.0000 - val_loss: 0.7927 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 298/500
# 2/2 - 0s - loss: 0.0845 - accuracy: 1.0000 - val_loss: 0.7983 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 299/500
# 2/2 - 0s - loss: 0.0893 - accuracy: 1.0000 - val_loss: 0.8050 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 300/500
# 2/2 - 0s - loss: 0.0904 - accuracy: 1.0000 - val_loss: 0.8132 - val_accuracy: 0.5833 - 44ms/epoch - 22ms/step
# Epoch 301/500
# 2/2 - 0s - loss: 0.1211 - accuracy: 1.0000 - val_loss: 0.8143 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 302/500
# 2/2 - 0s - loss: 0.0878 - accuracy: 1.0000 - val_loss: 0.8165 - val_accuracy: 0.5833 - 46ms/epoch - 23ms/step
# Epoch 303/500
# 2/2 - 0s - loss: 0.0970 - accuracy: 1.0000 - val_loss: 0.8255 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 304/500
# 2/2 - 0s - loss: 0.1113 - accuracy: 1.0000 - val_loss: 0.8364 - val_accuracy: 0.5833 - 43ms/epoch - 21ms/step
# Epoch 305/500
# 2/2 - 0s - loss: 0.1369 - accuracy: 1.0000 - val_loss: 0.8383 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 306/500
# 2/2 - 0s - loss: 0.0937 - accuracy: 1.0000 - val_loss: 0.8182 - val_accuracy: 0.5833 - 39ms/epoch - 19ms/step
# Epoch 307/500
# 2/2 - 0s - loss: 0.1018 - accuracy: 1.0000 - val_loss: 0.8021 - val_accuracy: 0.5833 - 51ms/epoch - 25ms/step
# Epoch 308/500
# 2/2 - 0s - loss: 0.0982 - accuracy: 1.0000 - val_loss: 0.7878 - val_accuracy: 0.5833 - 39ms/epoch - 19ms/step
# Epoch 309/500
# 2/2 - 0s - loss: 0.0959 - accuracy: 1.0000 - val_loss: 0.7755 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 310/500
# 2/2 - 0s - loss: 0.1036 - accuracy: 1.0000 - val_loss: 0.7721 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 311/500
# 2/2 - 0s - loss: 0.1006 - accuracy: 1.0000 - val_loss: 0.7834 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 312/500
# 2/2 - 0s - loss: 0.0846 - accuracy: 1.0000 - val_loss: 0.7924 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 313/500
# 2/2 - 0s - loss: 0.0841 - accuracy: 1.0000 - val_loss: 0.7985 - val_accuracy: 0.5833 - 39ms/epoch - 19ms/step
# Epoch 314/500
# 2/2 - 0s - loss: 0.0996 - accuracy: 1.0000 - val_loss: 0.8078 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 315/500
# 2/2 - 0s - loss: 0.0983 - accuracy: 1.0000 - val_loss: 0.8121 - val_accuracy: 0.5833 - 39ms/epoch - 19ms/step
# Epoch 316/500
# 2/2 - 0s - loss: 0.0869 - accuracy: 1.0000 - val_loss: 0.8250 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 317/500
# 2/2 - 0s - loss: 0.1099 - accuracy: 0.9643 - val_loss: 0.8292 - val_accuracy: 0.5833 - 60ms/epoch - 30ms/step
# Epoch 318/500
# 2/2 - 0s - loss: 0.0881 - accuracy: 1.0000 - val_loss: 0.8326 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 319/500
# 2/2 - 0s - loss: 0.1181 - accuracy: 1.0000 - val_loss: 0.8420 - val_accuracy: 0.5833 - 39ms/epoch - 19ms/step
# Epoch 320/500
# 2/2 - 0s - loss: 0.0772 - accuracy: 1.0000 - val_loss: 0.8428 - val_accuracy: 0.5833 - 39ms/epoch - 19ms/step
# Epoch 321/500
# 2/2 - 0s - loss: 0.0796 - accuracy: 1.0000 - val_loss: 0.8399 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 322/500
# 2/2 - 0s - loss: 0.1153 - accuracy: 0.9643 - val_loss: 0.8212 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 323/500
# 2/2 - 0s - loss: 0.0819 - accuracy: 1.0000 - val_loss: 0.8065 - val_accuracy: 0.5833 - 43ms/epoch - 22ms/step
# Epoch 324/500
# 2/2 - 0s - loss: 0.0785 - accuracy: 1.0000 - val_loss: 0.7969 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 325/500
# 2/2 - 0s - loss: 0.0985 - accuracy: 1.0000 - val_loss: 0.7970 - val_accuracy: 0.6667 - 38ms/epoch - 19ms/step
# Epoch 326/500
# 2/2 - 0s - loss: 0.0887 - accuracy: 1.0000 - val_loss: 0.7998 - val_accuracy: 0.7500 - 38ms/epoch - 19ms/step
# Epoch 327/500
# 2/2 - 0s - loss: 0.0958 - accuracy: 1.0000 - val_loss: 0.8066 - val_accuracy: 0.7500 - 37ms/epoch - 19ms/step
# Epoch 328/500
# 2/2 - 0s - loss: 0.0925 - accuracy: 1.0000 - val_loss: 0.8083 - val_accuracy: 0.7500 - 50ms/epoch - 25ms/step
# Epoch 329/500
# 2/2 - 0s - loss: 0.0773 - accuracy: 1.0000 - val_loss: 0.8074 - val_accuracy: 0.6667 - 54ms/epoch - 27ms/step
# Epoch 330/500
# 2/2 - 0s - loss: 0.0905 - accuracy: 1.0000 - val_loss: 0.8104 - val_accuracy: 0.5833 - 39ms/epoch - 19ms/step
# Epoch 331/500
# 2/2 - 0s - loss: 0.0817 - accuracy: 1.0000 - val_loss: 0.8203 - val_accuracy: 0.5833 - 44ms/epoch - 22ms/step
# Epoch 332/500
# 2/2 - 0s - loss: 0.0677 - accuracy: 1.0000 - val_loss: 0.8256 - val_accuracy: 0.5833 - 37ms/epoch - 19ms/step
# Epoch 333/500
# 2/2 - 0s - loss: 0.1379 - accuracy: 0.9643 - val_loss: 0.8230 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 334/500
# 2/2 - 0s - loss: 0.0755 - accuracy: 1.0000 - val_loss: 0.8144 - val_accuracy: 0.5833 - 39ms/epoch - 19ms/step
# Epoch 335/500
# 2/2 - 0s - loss: 0.0867 - accuracy: 1.0000 - val_loss: 0.8005 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 336/500
# 2/2 - 0s - loss: 0.0744 - accuracy: 1.0000 - val_loss: 0.7994 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 337/500
# 2/2 - 0s - loss: 0.0813 - accuracy: 1.0000 - val_loss: 0.8067 - val_accuracy: 0.5833 - 41ms/epoch - 21ms/step
# Epoch 338/500
# 2/2 - 0s - loss: 0.1166 - accuracy: 1.0000 - val_loss: 0.8193 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 339/500
# 2/2 - 0s - loss: 0.0938 - accuracy: 1.0000 - val_loss: 0.8414 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 340/500
# 2/2 - 0s - loss: 0.0785 - accuracy: 1.0000 - val_loss: 0.8664 - val_accuracy: 0.5833 - 61ms/epoch - 30ms/step
# Epoch 341/500
# 2/2 - 0s - loss: 0.0683 - accuracy: 1.0000 - val_loss: 0.8805 - val_accuracy: 0.5833 - 43ms/epoch - 21ms/step
# Epoch 342/500
# 2/2 - 0s - loss: 0.0828 - accuracy: 1.0000 - val_loss: 0.8923 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 343/500
# 2/2 - 0s - loss: 0.0988 - accuracy: 1.0000 - val_loss: 0.8961 - val_accuracy: 0.5833 - 38ms/epoch - 19ms/step
# Epoch 344/500
# 2/2 - 0s - loss: 0.0760 - accuracy: 1.0000 - val_loss: 0.8852 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 345/500
# 2/2 - 0s - loss: 0.0862 - accuracy: 1.0000 - val_loss: 0.8698 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 346/500
# 2/2 - 0s - loss: 0.1105 - accuracy: 0.9643 - val_loss: 0.8491 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 347/500
# 2/2 - 0s - loss: 0.0800 - accuracy: 1.0000 - val_loss: 0.8331 - val_accuracy: 0.5833 - 60ms/epoch - 30ms/step
# Epoch 348/500
# 2/2 - 0s - loss: 0.0911 - accuracy: 1.0000 - val_loss: 0.8269 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 349/500
# 2/2 - 0s - loss: 0.0852 - accuracy: 1.0000 - val_loss: 0.8327 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 350/500
# 2/2 - 0s - loss: 0.0905 - accuracy: 1.0000 - val_loss: 0.8316 - val_accuracy: 0.6667 - 56ms/epoch - 28ms/step
# Epoch 351/500
# 2/2 - 0s - loss: 0.0872 - accuracy: 1.0000 - val_loss: 0.8255 - val_accuracy: 0.6667 - 56ms/epoch - 28ms/step
# Epoch 352/500
# 2/2 - 0s - loss: 0.0820 - accuracy: 1.0000 - val_loss: 0.8253 - val_accuracy: 0.5833 - 57ms/epoch - 28ms/step
# Epoch 353/500
# 2/2 - 0s - loss: 0.0888 - accuracy: 1.0000 - val_loss: 0.8335 - val_accuracy: 0.5833 - 47ms/epoch - 24ms/step
# Epoch 354/500
# 2/2 - 0s - loss: 0.0689 - accuracy: 1.0000 - val_loss: 0.8510 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 355/500
# 2/2 - 0s - loss: 0.0625 - accuracy: 1.0000 - val_loss: 0.8685 - val_accuracy: 0.5833 - 55ms/epoch - 28ms/step
# Epoch 356/500
# 2/2 - 0s - loss: 0.0665 - accuracy: 1.0000 - val_loss: 0.8850 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 357/500
# 2/2 - 0s - loss: 0.0646 - accuracy: 1.0000 - val_loss: 0.8872 - val_accuracy: 0.5833 - 60ms/epoch - 30ms/step
# Epoch 358/500
# 2/2 - 0s - loss: 0.0755 - accuracy: 1.0000 - val_loss: 0.8914 - val_accuracy: 0.5833 - 43ms/epoch - 21ms/step
# Epoch 359/500
# 2/2 - 0s - loss: 0.0771 - accuracy: 1.0000 - val_loss: 0.8821 - val_accuracy: 0.6667 - 57ms/epoch - 29ms/step
# Epoch 360/500
# 2/2 - 0s - loss: 0.0826 - accuracy: 1.0000 - val_loss: 0.8725 - val_accuracy: 0.6667 - 39ms/epoch - 20ms/step
# Epoch 361/500
# 2/2 - 0s - loss: 0.0557 - accuracy: 1.0000 - val_loss: 0.8501 - val_accuracy: 0.5833 - 46ms/epoch - 23ms/step
# Epoch 362/500
# 2/2 - 0s - loss: 0.0774 - accuracy: 1.0000 - val_loss: 0.8257 - val_accuracy: 0.5833 - 61ms/epoch - 31ms/step
# Epoch 363/500
# 2/2 - 0s - loss: 0.0654 - accuracy: 1.0000 - val_loss: 0.8237 - val_accuracy: 0.6667 - 56ms/epoch - 28ms/step
# Epoch 364/500
# 2/2 - 0s - loss: 0.0754 - accuracy: 1.0000 - val_loss: 0.8326 - val_accuracy: 0.6667 - 47ms/epoch - 24ms/step
# Epoch 365/500
# 2/2 - 0s - loss: 0.0739 - accuracy: 1.0000 - val_loss: 0.8377 - val_accuracy: 0.6667 - 46ms/epoch - 23ms/step
# Epoch 366/500
# 2/2 - 0s - loss: 0.0770 - accuracy: 1.0000 - val_loss: 0.8421 - val_accuracy: 0.6667 - 39ms/epoch - 20ms/step
# Epoch 367/500
# 2/2 - 0s - loss: 0.0702 - accuracy: 1.0000 - val_loss: 0.8505 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 368/500
# 2/2 - 0s - loss: 0.0935 - accuracy: 1.0000 - val_loss: 0.8638 - val_accuracy: 0.5833 - 51ms/epoch - 25ms/step
# Epoch 369/500
# 2/2 - 0s - loss: 0.0742 - accuracy: 1.0000 - val_loss: 0.8693 - val_accuracy: 0.5833 - 41ms/epoch - 21ms/step
# Epoch 370/500
# 2/2 - 0s - loss: 0.0723 - accuracy: 1.0000 - val_loss: 0.8726 - val_accuracy: 0.5833 - 57ms/epoch - 28ms/step
# Epoch 371/500
# 2/2 - 0s - loss: 0.0779 - accuracy: 1.0000 - val_loss: 0.8559 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 372/500
# 2/2 - 0s - loss: 0.0814 - accuracy: 1.0000 - val_loss: 0.8345 - val_accuracy: 0.5833 - 49ms/epoch - 25ms/step
# Epoch 373/500
# 2/2 - 0s - loss: 0.0852 - accuracy: 1.0000 - val_loss: 0.8108 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 374/500
# 2/2 - 0s - loss: 0.0766 - accuracy: 1.0000 - val_loss: 0.7939 - val_accuracy: 0.6667 - 43ms/epoch - 22ms/step
# Epoch 375/500
# 2/2 - 0s - loss: 0.0527 - accuracy: 1.0000 - val_loss: 0.7843 - val_accuracy: 0.6667 - 39ms/epoch - 19ms/step
# Epoch 376/500
# 2/2 - 0s - loss: 0.1023 - accuracy: 1.0000 - val_loss: 0.7861 - val_accuracy: 0.6667 - 39ms/epoch - 20ms/step
# Epoch 377/500
# 2/2 - 0s - loss: 0.0791 - accuracy: 1.0000 - val_loss: 0.7888 - val_accuracy: 0.6667 - 45ms/epoch - 23ms/step
# Epoch 378/500
# 2/2 - 0s - loss: 0.0642 - accuracy: 1.0000 - val_loss: 0.7901 - val_accuracy: 0.6667 - 56ms/epoch - 28ms/step
# Epoch 379/500
# 2/2 - 0s - loss: 0.0649 - accuracy: 1.0000 - val_loss: 0.7924 - val_accuracy: 0.6667 - 39ms/epoch - 20ms/step
# Epoch 380/500
# 2/2 - 0s - loss: 0.0635 - accuracy: 1.0000 - val_loss: 0.7940 - val_accuracy: 0.6667 - 56ms/epoch - 28ms/step
# Epoch 381/500
# 2/2 - 0s - loss: 0.0730 - accuracy: 1.0000 - val_loss: 0.7963 - val_accuracy: 0.6667 - 45ms/epoch - 22ms/step
# Epoch 382/500
# 2/2 - 0s - loss: 0.0754 - accuracy: 1.0000 - val_loss: 0.8023 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 383/500
# 2/2 - 0s - loss: 0.0591 - accuracy: 1.0000 - val_loss: 0.8157 - val_accuracy: 0.5833 - 65ms/epoch - 32ms/step
# Epoch 384/500
# 2/2 - 0s - loss: 0.0671 - accuracy: 1.0000 - val_loss: 0.8368 - val_accuracy: 0.6667 - 59ms/epoch - 30ms/step
# Epoch 385/500
# 2/2 - 0s - loss: 0.0776 - accuracy: 1.0000 - val_loss: 0.8444 - val_accuracy: 0.6667 - 41ms/epoch - 20ms/step
# Epoch 386/500
# 2/2 - 0s - loss: 0.0782 - accuracy: 1.0000 - val_loss: 0.8275 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 387/500
# 2/2 - 0s - loss: 0.0766 - accuracy: 1.0000 - val_loss: 0.8059 - val_accuracy: 0.5833 - 67ms/epoch - 33ms/step
# Epoch 388/500
# 2/2 - 0s - loss: 0.0933 - accuracy: 1.0000 - val_loss: 0.7936 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# ...
# Epoch 374/500
# 2/2 - 0s - loss: 0.0391 - accuracy: 1.0000 - val_loss: 0.6207 - val_accuracy: 0.6667 - 74ms/epoch - 37ms/step
# Epoch 375/500
# 2/2 - 0s - loss: 0.0235 - accuracy: 1.0000 - val_loss: 0.6086 - val_accuracy: 0.6667 - 71ms/epoch - 35ms/step
# Epoch 376/500
# 2/2 - 0s - loss: 0.0284 - accuracy: 1.0000 - val_loss: 0.5967 - val_accuracy: 0.6667 - 75ms/epoch - 38ms/step
# Epoch 377/500
# 2/2 - 0s - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.5826 - val_accuracy: 0.6667 - 60ms/epoch - 30ms/step
# Epoch 378/500
# 2/2 - 0s - loss: 0.0609 - accuracy: 1.0000 - val_loss: 0.5697 - val_accuracy: 0.6667 - 63ms/epoch - 31ms/step
# Epoch 379/500
# 2/2 - 0s - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.5539 - val_accuracy: 0.6667 - 43ms/epoch - 22ms/step
# Epoch 380/500
# 2/2 - 0s - loss: 0.0394 - accuracy: 1.0000 - val_loss: 0.5472 - val_accuracy: 0.6667 - 41ms/epoch - 21ms/step
# Epoch 381/500
# 2/2 - 0s - loss: 0.0267 - accuracy: 1.0000 - val_loss: 0.5514 - val_accuracy: 0.6667 - 46ms/epoch - 23ms/step
# Epoch 382/500
# 2/2 - 0s - loss: 0.0360 - accuracy: 1.0000 - val_loss: 0.5625 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 383/500
# 2/2 - 0s - loss: 0.0318 - accuracy: 1.0000 - val_loss: 0.5732 - val_accuracy: 0.6667 - 41ms/epoch - 20ms/step
# Epoch 384/500
# 2/2 - 0s - loss: 0.0264 - accuracy: 1.0000 - val_loss: 0.5816 - val_accuracy: 0.6667 - 41ms/epoch - 20ms/step
# Epoch 385/500
# 2/2 - 0s - loss: 0.0321 - accuracy: 1.0000 - val_loss: 0.5920 - val_accuracy: 0.6667 - 54ms/epoch - 27ms/step
# Epoch 386/500
# 2/2 - 0s - loss: 0.0438 - accuracy: 1.0000 - val_loss: 0.5992 - val_accuracy: 0.7500 - 40ms/epoch - 20ms/step
# Epoch 387/500
# 2/2 - 0s - loss: 0.0259 - accuracy: 1.0000 - val_loss: 0.6028 - val_accuracy: 0.7500 - 41ms/epoch - 21ms/step
# Epoch 388/500
# 2/2 - 0s - loss: 0.0389 - accuracy: 1.0000 - val_loss: 0.6119 - val_accuracy: 0.7500 - 55ms/epoch - 28ms/step
# Epoch 389/500
# 2/2 - 0s - loss: 0.0273 - accuracy: 1.0000 - val_loss: 0.6245 - val_accuracy: 0.6667 - 44ms/epoch - 22ms/step
# Epoch 390/500
# 2/2 - 0s - loss: 0.0265 - accuracy: 1.0000 - val_loss: 0.6339 - val_accuracy: 0.5833 - 65ms/epoch - 33ms/step
# Epoch 391/500
# 2/2 - 0s - loss: 0.0315 - accuracy: 1.0000 - val_loss: 0.6351 - val_accuracy: 0.6667 - 65ms/epoch - 32ms/step
# Epoch 392/500
# 2/2 - 0s - loss: 0.0315 - accuracy: 1.0000 - val_loss: 0.6355 - val_accuracy: 0.7500 - 47ms/epoch - 23ms/step
# Epoch 393/500
# 2/2 - 0s - loss: 0.0288 - accuracy: 1.0000 - val_loss: 0.6379 - val_accuracy: 0.7500 - 57ms/epoch - 29ms/step
# Epoch 394/500
# 2/2 - 0s - loss: 0.0255 - accuracy: 1.0000 - val_loss: 0.6385 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 395/500
# 2/2 - 0s - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.6314 - val_accuracy: 0.6667 - 41ms/epoch - 21ms/step
# Epoch 396/500
# 2/2 - 0s - loss: 0.0363 - accuracy: 1.0000 - val_loss: 0.6262 - val_accuracy: 0.6667 - 57ms/epoch - 29ms/step
# Epoch 397/500
# 2/2 - 0s - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.6139 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 398/500
# 2/2 - 0s - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.6009 - val_accuracy: 0.6667 - 43ms/epoch - 21ms/step
# Epoch 399/500
# 2/2 - 0s - loss: 0.0328 - accuracy: 1.0000 - val_loss: 0.5856 - val_accuracy: 0.6667 - 43ms/epoch - 21ms/step
# Epoch 400/500
# 2/2 - 0s - loss: 0.0309 - accuracy: 1.0000 - val_loss: 0.5730 - val_accuracy: 0.6667 - 41ms/epoch - 21ms/step
# Epoch 401/500
# 2/2 - 0s - loss: 0.0407 - accuracy: 1.0000 - val_loss: 0.5586 - val_accuracy: 0.6667 - 47ms/epoch - 23ms/step
# Epoch 402/500
# 2/2 - 0s - loss: 0.0361 - accuracy: 1.0000 - val_loss: 0.5527 - val_accuracy: 0.6667 - 41ms/epoch - 21ms/step
# Epoch 403/500
# 2/2 - 0s - loss: 0.0300 - accuracy: 1.0000 - val_loss: 0.5533 - val_accuracy: 0.6667 - 53ms/epoch - 26ms/step
# Epoch 404/500
# 2/2 - 0s - loss: 0.0521 - accuracy: 1.0000 - val_loss: 0.5667 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 405/500
# 2/2 - 0s - loss: 0.0274 - accuracy: 1.0000 - val_loss: 0.5795 - val_accuracy: 0.6667 - 41ms/epoch - 20ms/step
# Epoch 406/500
# 2/2 - 0s - loss: 0.0747 - accuracy: 1.0000 - val_loss: 0.5970 - val_accuracy: 0.6667 - 63ms/epoch - 32ms/step
# Epoch 407/500
# 2/2 - 0s - loss: 0.0657 - accuracy: 1.0000 - val_loss: 0.6086 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 408/500
# 2/2 - 0s - loss: 0.0576 - accuracy: 1.0000 - val_loss: 0.6356 - val_accuracy: 0.6667 - 57ms/epoch - 29ms/step
# Epoch 409/500
# 2/2 - 0s - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.6586 - val_accuracy: 0.6667 - 41ms/epoch - 20ms/step
# Epoch 410/500
# 2/2 - 0s - loss: 0.0279 - accuracy: 1.0000 - val_loss: 0.6753 - val_accuracy: 0.5833 - 41ms/epoch - 21ms/step
# Epoch 411/500
# 2/2 - 0s - loss: 0.0272 - accuracy: 1.0000 - val_loss: 0.6761 - val_accuracy: 0.5833 - 65ms/epoch - 33ms/step
# Epoch 412/500
# 2/2 - 0s - loss: 0.0227 - accuracy: 1.0000 - val_loss: 0.6783 - val_accuracy: 0.5833 - 43ms/epoch - 22ms/step
# Epoch 413/500
# 2/2 - 0s - loss: 0.0610 - accuracy: 1.0000 - val_loss: 0.6770 - val_accuracy: 0.5833 - 60ms/epoch - 30ms/step
# Epoch 414/500
# 2/2 - 0s - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.6896 - val_accuracy: 0.5833 - 49ms/epoch - 24ms/step
# Epoch 415/500
# 2/2 - 0s - loss: 0.0301 - accuracy: 1.0000 - val_loss: 0.6934 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 416/500
# 2/2 - 0s - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.6884 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 417/500
# 2/2 - 0s - loss: 0.0285 - accuracy: 1.0000 - val_loss: 0.6790 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 418/500
# 2/2 - 0s - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.6619 - val_accuracy: 0.6667 - 63ms/epoch - 32ms/step
# Epoch 419/500
# 2/2 - 0s - loss: 0.0293 - accuracy: 1.0000 - val_loss: 0.6528 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 420/500
# 2/2 - 0s - loss: 0.0339 - accuracy: 1.0000 - val_loss: 0.6438 - val_accuracy: 0.7500 - 41ms/epoch - 20ms/step
# Epoch 421/500
# 2/2 - 0s - loss: 0.0363 - accuracy: 1.0000 - val_loss: 0.6336 - val_accuracy: 0.7500 - 73ms/epoch - 36ms/step
# Epoch 422/500
# 2/2 - 0s - loss: 0.0586 - accuracy: 1.0000 - val_loss: 0.6240 - val_accuracy: 0.6667 - 43ms/epoch - 21ms/step
# Epoch 423/500
# 2/2 - 0s - loss: 0.0232 - accuracy: 1.0000 - val_loss: 0.6229 - val_accuracy: 0.6667 - 47ms/epoch - 23ms/step
# Epoch 424/500
# 2/2 - 0s - loss: 0.0423 - accuracy: 1.0000 - val_loss: 0.6247 - val_accuracy: 0.6667 - 43ms/epoch - 22ms/step
# Epoch 425/500
# 2/2 - 0s - loss: 0.0265 - accuracy: 1.0000 - val_loss: 0.6324 - val_accuracy: 0.6667 - 43ms/epoch - 22ms/step
# Epoch 426/500
# 2/2 - 0s - loss: 0.0580 - accuracy: 1.0000 - val_loss: 0.6300 - val_accuracy: 0.6667 - 45ms/epoch - 22ms/step
# Epoch 427/500
# 2/2 - 0s - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.6231 - val_accuracy: 0.6667 - 57ms/epoch - 29ms/step
# Epoch 428/500
# 2/2 - 0s - loss: 0.0244 - accuracy: 1.0000 - val_loss: 0.6206 - val_accuracy: 0.6667 - 45ms/epoch - 23ms/step
# Epoch 429/500
# 2/2 - 0s - loss: 0.0280 - accuracy: 1.0000 - val_loss: 0.6251 - val_accuracy: 0.6667 - 69ms/epoch - 34ms/step
# Epoch 430/500
# 2/2 - 0s - loss: 0.0244 - accuracy: 1.0000 - val_loss: 0.6332 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 431/500
# 2/2 - 0s - loss: 0.0269 - accuracy: 1.0000 - val_loss: 0.6420 - val_accuracy: 0.5833 - 43ms/epoch - 21ms/step
# Epoch 432/500
# 2/2 - 0s - loss: 0.0386 - accuracy: 1.0000 - val_loss: 0.6500 - val_accuracy: 0.5833 - 51ms/epoch - 25ms/step
# Epoch 433/500
# 2/2 - 0s - loss: 0.0309 - accuracy: 1.0000 - val_loss: 0.6520 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 434/500
# 2/2 - 0s - loss: 0.0382 - accuracy: 1.0000 - val_loss: 0.6482 - val_accuracy: 0.5833 - 43ms/epoch - 21ms/step
# Epoch 435/500
# 2/2 - 0s - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.6379 - val_accuracy: 0.6667 - 45ms/epoch - 22ms/step
# Epoch 436/500
# 2/2 - 0s - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.6297 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 437/500
# 2/2 - 0s - loss: 0.0295 - accuracy: 1.0000 - val_loss: 0.6203 - val_accuracy: 0.7500 - 43ms/epoch - 22ms/step
# Epoch 438/500
# 2/2 - 0s - loss: 0.0285 - accuracy: 1.0000 - val_loss: 0.6154 - val_accuracy: 0.6667 - 41ms/epoch - 20ms/step
# Epoch 439/500
# 2/2 - 0s - loss: 0.0451 - accuracy: 1.0000 - val_loss: 0.6024 - val_accuracy: 0.6667 - 49ms/epoch - 25ms/step
# Epoch 440/500
# 2/2 - 0s - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.5930 - val_accuracy: 0.6667 - 63ms/epoch - 31ms/step
# Epoch 441/500
# 2/2 - 0s - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.5896 - val_accuracy: 0.5833 - 44ms/epoch - 22ms/step
# Epoch 442/500
# 2/2 - 0s - loss: 0.0333 - accuracy: 1.0000 - val_loss: 0.5889 - val_accuracy: 0.5833 - 45ms/epoch - 23ms/step
# Epoch 443/500
# 2/2 - 0s - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.5844 - val_accuracy: 0.5833 - 45ms/epoch - 22ms/step
# Epoch 444/500
# 2/2 - 0s - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.5793 - val_accuracy: 0.5833 - 43ms/epoch - 21ms/step
# Epoch 445/500
# 2/2 - 0s - loss: 0.0336 - accuracy: 1.0000 - val_loss: 0.5845 - val_accuracy: 0.6667 - 49ms/epoch - 25ms/step
# Epoch 446/500
# 2/2 - 0s - loss: 0.0387 - accuracy: 1.0000 - val_loss: 0.5892 - val_accuracy: 0.6667 - 56ms/epoch - 28ms/step
# Epoch 447/500
# 2/2 - 0s - loss: 0.0512 - accuracy: 1.0000 - val_loss: 0.6124 - val_accuracy: 0.6667 - 47ms/epoch - 24ms/step
# Epoch 448/500
# 2/2 - 0s - loss: 0.0258 - accuracy: 1.0000 - val_loss: 0.6361 - val_accuracy: 0.6667 - 47ms/epoch - 24ms/step
# Epoch 449/500
# 2/2 - 0s - loss: 0.0452 - accuracy: 1.0000 - val_loss: 0.6524 - val_accuracy: 0.6667 - 41ms/epoch - 20ms/step
# Epoch 450/500
# 2/2 - 0s - loss: 0.0294 - accuracy: 1.0000 - val_loss: 0.6538 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 451/500
# 2/2 - 0s - loss: 0.0336 - accuracy: 1.0000 - val_loss: 0.6421 - val_accuracy: 0.6667 - 43ms/epoch - 21ms/step
# Epoch 452/500
# 2/2 - 0s - loss: 0.0259 - accuracy: 1.0000 - val_loss: 0.6296 - val_accuracy: 0.6667 - 61ms/epoch - 30ms/step
# Epoch 453/500
# 2/2 - 0s - loss: 0.0402 - accuracy: 1.0000 - val_loss: 0.6110 - val_accuracy: 0.7500 - 41ms/epoch - 21ms/step
# Epoch 454/500
# 2/2 - 0s - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.6007 - val_accuracy: 0.7500 - 44ms/epoch - 22ms/step
# Epoch 455/500
# 2/2 - 0s - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.5985 - val_accuracy: 0.7500 - 40ms/epoch - 20ms/step
# Epoch 456/500
# 2/2 - 0s - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.6033 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 457/500
# 2/2 - 0s - loss: 0.0397 - accuracy: 1.0000 - val_loss: 0.6133 - val_accuracy: 0.6667 - 48ms/epoch - 24ms/step
# Epoch 458/500
# 2/2 - 0s - loss: 0.0390 - accuracy: 1.0000 - val_loss: 0.6107 - val_accuracy: 0.7500 - 46ms/epoch - 23ms/step
# Epoch 459/500
# 2/2 - 0s - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.6054 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 460/500
# 2/2 - 0s - loss: 0.0247 - accuracy: 1.0000 - val_loss: 0.6070 - val_accuracy: 0.7500 - 40ms/epoch - 20ms/step
# Epoch 461/500
# 2/2 - 0s - loss: 0.0357 - accuracy: 1.0000 - val_loss: 0.6002 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 462/500
# 2/2 - 0s - loss: 0.0249 - accuracy: 1.0000 - val_loss: 0.5940 - val_accuracy: 0.7500 - 66ms/epoch - 33ms/step
# Epoch 463/500
# 2/2 - 0s - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.5951 - val_accuracy: 0.7500 - 59ms/epoch - 30ms/step
# Epoch 464/500
# 2/2 - 0s - loss: 0.0514 - accuracy: 1.0000 - val_loss: 0.5928 - val_accuracy: 0.7500 - 43ms/epoch - 22ms/step
# Epoch 465/500
# 2/2 - 0s - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.5983 - val_accuracy: 0.7500 - 44ms/epoch - 22ms/step
# Epoch 466/500
# 2/2 - 0s - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.6061 - val_accuracy: 0.7500 - 43ms/epoch - 22ms/step
# Epoch 467/500
# 2/2 - 0s - loss: 0.0229 - accuracy: 1.0000 - val_loss: 0.6130 - val_accuracy: 0.7500 - 45ms/epoch - 23ms/step
# Epoch 468/500
# 2/2 - 0s - loss: 0.0518 - accuracy: 1.0000 - val_loss: 0.6185 - val_accuracy: 0.7500 - 45ms/epoch - 23ms/step
# Epoch 469/500
# 2/2 - 0s - loss: 0.0475 - accuracy: 1.0000 - val_loss: 0.6160 - val_accuracy: 0.7500 - 44ms/epoch - 22ms/step
# Epoch 470/500
# 2/2 - 0s - loss: 0.0303 - accuracy: 1.0000 - val_loss: 0.6142 - val_accuracy: 0.6667 - 45ms/epoch - 23ms/step
# Epoch 471/500
# 2/2 - 0s - loss: 0.0236 - accuracy: 1.0000 - val_loss: 0.6119 - val_accuracy: 0.5000 - 51ms/epoch - 25ms/step
# Epoch 472/500
# 2/2 - 0s - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.6121 - val_accuracy: 0.5000 - 41ms/epoch - 20ms/step
# Epoch 473/500
# 2/2 - 0s - loss: 0.0296 - accuracy: 1.0000 - val_loss: 0.6159 - val_accuracy: 0.5833 - 41ms/epoch - 21ms/step
# Epoch 474/500
# 2/2 - 0s - loss: 0.0587 - accuracy: 1.0000 - val_loss: 0.6186 - val_accuracy: 0.6667 - 43ms/epoch - 21ms/step
# Epoch 475/500
# 2/2 - 0s - loss: 0.0276 - accuracy: 1.0000 - val_loss: 0.6246 - val_accuracy: 0.6667 - 43ms/epoch - 21ms/step
# Epoch 476/500
# 2/2 - 0s - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.6283 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 477/500
# 2/2 - 0s - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.6284 - val_accuracy: 0.6667 - 64ms/epoch - 32ms/step
# Epoch 478/500
# 2/2 - 0s - loss: 0.0240 - accuracy: 1.0000 - val_loss: 0.6248 - val_accuracy: 0.6667 - 44ms/epoch - 22ms/step
# Epoch 479/500
# 2/2 - 0s - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.6231 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 480/500
# 2/2 - 0s - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.6217 - val_accuracy: 0.6667 - 41ms/epoch - 21ms/step
# Epoch 481/500
# 2/2 - 0s - loss: 0.0332 - accuracy: 1.0000 - val_loss: 0.6095 - val_accuracy: 0.7500 - 60ms/epoch - 30ms/step
# Epoch 482/500
# 2/2 - 0s - loss: 0.0267 - accuracy: 1.0000 - val_loss: 0.5953 - val_accuracy: 0.7500 - 41ms/epoch - 21ms/step
# Epoch 483/500
# 2/2 - 0s - loss: 0.0166 - accuracy: 1.0000 - val_loss: 0.5896 - val_accuracy: 0.7500 - 58ms/epoch - 29ms/step
# Epoch 484/500
# 2/2 - 0s - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.5846 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 485/500
# 2/2 - 0s - loss: 0.0254 - accuracy: 1.0000 - val_loss: 0.5810 - val_accuracy: 0.7500 - 47ms/epoch - 23ms/step
# Epoch 486/500
# 2/2 - 0s - loss: 0.0386 - accuracy: 1.0000 - val_loss: 0.5770 - val_accuracy: 0.7500 - 38ms/epoch - 19ms/step
# Epoch 487/500
# 2/2 - 0s - loss: 0.0401 - accuracy: 1.0000 - val_loss: 0.5812 - val_accuracy: 0.7500 - 56ms/epoch - 28ms/step
# Epoch 488/500
# 2/2 - 0s - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.5928 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 489/500
# 2/2 - 0s - loss: 0.0209 - accuracy: 1.0000 - val_loss: 0.6041 - val_accuracy: 0.6667 - 48ms/epoch - 24ms/step
# Epoch 490/500
# 2/2 - 0s - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.6153 - val_accuracy: 0.6667 - 51ms/epoch - 25ms/step
# Epoch 491/500
# 2/2 - 0s - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.6245 - val_accuracy: 0.6667 - 41ms/epoch - 21ms/step
# Epoch 492/500
# 2/2 - 0s - loss: 0.0323 - accuracy: 1.0000 - val_loss: 0.6270 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 493/500
# 2/2 - 0s - loss: 0.0249 - accuracy: 1.0000 - val_loss: 0.6295 - val_accuracy: 0.5833 - 43ms/epoch - 22ms/step
# Epoch 494/500
# 2/2 - 0s - loss: 0.0330 - accuracy: 1.0000 - val_loss: 0.6315 - val_accuracy: 0.5000 - 41ms/epoch - 21ms/step
# Epoch 495/500
# 2/2 - 0s - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.6274 - val_accuracy: 0.5000 - 57ms/epoch - 28ms/step
# Epoch 496/500
# 2/2 - 0s - loss: 0.0342 - accuracy: 1.0000 - val_loss: 0.6181 - val_accuracy: 0.5833 - 43ms/epoch - 22ms/step
# Epoch 497/500
# 2/2 - 0s - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.6130 - val_accuracy: 0.5833 - 57ms/epoch - 28ms/step
# Epoch 498/500
# 2/2 - 0s - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.6060 - val_accuracy: 0.5833 - 41ms/epoch - 21ms/step
# Epoch 499/500
# 2/2 - 0s - loss: 0.0307 - accuracy: 1.0000 - val_loss: 0.5970 - val_accuracy: 0.5833 - 61ms/epoch - 31ms/step
# Epoch 500/500
# 2/2 - 0s - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.5862 - val_accuracy: 0.6667 - 61ms/epoch - 30ms/step
# 1/1 [==============================] - 0s 87ms/step
# Shallow Conv Net Accuracy Metrics
# Accuracy: 0.6666666666666666
# F1 Score: 0.7142857142857143

# %% [markdown]
# ## Alpha Classifier

# %%
import tensorflow as tf
# from arl_eegmodels.EEGModels import EEGNet, DeepConvNet, ShallowConvNet
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# To be used for training the model on the opensource dataset

# Train data - 70% of opensource dataset
# Validation data - 30% of opensource dataset
# Test data - data collected from EEG


# Define initial model parameters
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy()
optimizer = 'adam'
metrics = ['accuracy']
epochs = 500
channels = num_desired_channels
classes = 2
dropout = 0.25
F1 = 8
F2 = 16
samples = 60

# EEGNet Implementation
model = EEGNet(nb_classes=classes, Chans=num_desired_channels, Samples=samples, dropoutRate=dropout, F1=F1, F2=F2)
model.compile(loss=loss_fn, optimizer=optimizer, metrics=metrics)
# eeg_net_checkpoint = ModelCheckpoint(filepath='/trained_models/eeg_net_checkpoint.h5', verbose=1, save_best_only=True)

# Fit and train the model
eegnet_history = model.fit(
    alpha_x_train, alpha_y_train, batch_size=16, epochs=epochs, verbose=2, validation_data=(alpha_x_test, alpha_y_test)
)

# Evaluate accuracy on test data
probabilities = model.predict(alpha_x_test)
predictions = probabilities.argmax(axis=-1)

accuracy = accuracy_score(alpha_y_test, predictions)
conf_matrix = confusion_matrix(alpha_y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)
f1 = f1_score(alpha_y_test, predictions)
# roc_auc = roc_auc_score(y_test, probabilities)


print('EEGNet Accuracy Metrics')
print(f'Accuracy: {accuracy}')
print(f'F1 Score: {f1}')
# print(confusion_matrix)
disp.plot()
plt.show()
# print(f'AUC Score: {roc_auc}')

# EEGNet Accuracy Plot
plt.plot(eegnet_history.history['accuracy'])
plt.plot(eegnet_history.history['val_accuracy'])
plt.title('EEGNet Accuracy During Training')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()

# EEGNet Loss Plot
plt.plot(eegnet_history.history['loss'])
plt.plot(eegnet_history.history['val_loss'])
plt.title('EEGNet Loss During Training')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()


# ShallowConvNet Implementation
shallow_conv_net_model = ShallowConvNet(nb_classes=classes, Chans=num_desired_channels, Samples=samples, dropoutRate=dropout)
shallow_conv_net_model.compile(loss=loss_fn, optimizer=optimizer, metrics=metrics)
# shallow_conv_net_checkpoint = ModelCheckpoint(
#     filepath='/trained_models/shallow_conv_net_checkpoint.h5', verbose=1, save_best_only=True
# )

# Fit and train the model
shallowconvnet_history = shallow_conv_net_model.fit(
    alpha_x_train, alpha_y_train, batch_size=16, epochs=epochs, verbose=2, validation_data=(alpha_x_test, alpha_y_test)
)

# Evaluate accuracy on test data
probabilities = shallow_conv_net_model.predict(alpha_x_test)
predictions = probabilities.argmax(axis=-1)

accuracy = accuracy_score(alpha_y_test, predictions)
conf_matrix = confusion_matrix(alpha_y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)
f1 = f1_score(alpha_y_test, predictions)
# roc_auc = roc_auc_score(y_test, probabilities)


print('Shallow Conv Net Accuracy Metrics')
print(f'Accuracy: {accuracy}')
print(f'F1 Score: {f1}')
# print(confusion_matrix)
disp.plot()
plt.show()
# print(f'AUC Score: {roc_auc}')

# ShallowConvNet Accuracy Plot
plt.plot(shallowconvnet_history.history['accuracy'])
plt.plot(shallowconvnet_history.history['val_accuracy'])
plt.title('ShallowConvNet Accuracy During Training')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()

# ShallowConvNet Loss Plot
plt.plot(shallowconvnet_history.history['loss'])
plt.plot(shallowconvnet_history.history['val_loss'])
plt.title('ShallowConvNet Loss During Training')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()
# Out:
# Epoch 1/500
# 2/2 - 3s - loss: 0.8117 - accuracy: 0.5714 - val_loss: 0.7626 - val_accuracy: 0.4167 - 3s/epoch - 1s/step
# Epoch 2/500
# 2/2 - 0s - loss: 0.6808 - accuracy: 0.5000 - val_loss: 0.7336 - val_accuracy: 0.4167 - 61ms/epoch - 30ms/step
# Epoch 3/500
# 2/2 - 0s - loss: 0.6809 - accuracy: 0.5714 - val_loss: 0.7217 - val_accuracy: 0.4167 - 43ms/epoch - 22ms/step
# Epoch 4/500
# 2/2 - 0s - loss: 0.6897 - accuracy: 0.5357 - val_loss: 0.7151 - val_accuracy: 0.4167 - 56ms/epoch - 28ms/step
# Epoch 5/500
# 2/2 - 0s - loss: 0.6763 - accuracy: 0.5357 - val_loss: 0.7112 - val_accuracy: 0.4167 - 42ms/epoch - 21ms/step
# Epoch 6/500
# 2/2 - 0s - loss: 0.6771 - accuracy: 0.6786 - val_loss: 0.7085 - val_accuracy: 0.4167 - 42ms/epoch - 21ms/step
# Epoch 7/500
# 2/2 - 0s - loss: 0.6614 - accuracy: 0.6071 - val_loss: 0.7066 - val_accuracy: 0.4167 - 41ms/epoch - 21ms/step
# Epoch 8/500
# 2/2 - 0s - loss: 0.6762 - accuracy: 0.5714 - val_loss: 0.7049 - val_accuracy: 0.4167 - 43ms/epoch - 21ms/step
# Epoch 9/500
# 2/2 - 0s - loss: 0.6581 - accuracy: 0.5714 - val_loss: 0.7036 - val_accuracy: 0.4167 - 42ms/epoch - 21ms/step
# Epoch 10/500
# 2/2 - 0s - loss: 0.6694 - accuracy: 0.6429 - val_loss: 0.7026 - val_accuracy: 0.4167 - 56ms/epoch - 28ms/step
# Epoch 11/500
# 2/2 - 0s - loss: 0.6673 - accuracy: 0.6429 - val_loss: 0.7018 - val_accuracy: 0.4167 - 50ms/epoch - 25ms/step
# Epoch 12/500
# 2/2 - 0s - loss: 0.6790 - accuracy: 0.4643 - val_loss: 0.7010 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 13/500
# 2/2 - 0s - loss: 0.6649 - accuracy: 0.6429 - val_loss: 0.7003 - val_accuracy: 0.4167 - 41ms/epoch - 20ms/step
# Epoch 14/500
# 2/2 - 0s - loss: 0.6635 - accuracy: 0.6786 - val_loss: 0.6998 - val_accuracy: 0.4167 - 52ms/epoch - 26ms/step
# Epoch 15/500
# 2/2 - 0s - loss: 0.6649 - accuracy: 0.6071 - val_loss: 0.6994 - val_accuracy: 0.3333 - 39ms/epoch - 20ms/step
# Epoch 16/500
# 2/2 - 0s - loss: 0.6503 - accuracy: 0.6071 - val_loss: 0.6989 - val_accuracy: 0.3333 - 40ms/epoch - 20ms/step
# Epoch 17/500
# 2/2 - 0s - loss: 0.6362 - accuracy: 0.7500 - val_loss: 0.6988 - val_accuracy: 0.3333 - 39ms/epoch - 20ms/step
# Epoch 18/500
# 2/2 - 0s - loss: 0.6478 - accuracy: 0.6071 - val_loss: 0.6986 - val_accuracy: 0.4167 - 41ms/epoch - 20ms/step
# Epoch 19/500
# 2/2 - 0s - loss: 0.6405 - accuracy: 0.6786 - val_loss: 0.6986 - val_accuracy: 0.4167 - 58ms/epoch - 29ms/step
# Epoch 20/500
# 2/2 - 0s - loss: 0.6343 - accuracy: 0.6429 - val_loss: 0.6985 - val_accuracy: 0.4167 - 42ms/epoch - 21ms/step
# Epoch 21/500
# 2/2 - 0s - loss: 0.6622 - accuracy: 0.6429 - val_loss: 0.6986 - val_accuracy: 0.4167 - 67ms/epoch - 33ms/step
# Epoch 22/500
# 2/2 - 0s - loss: 0.6175 - accuracy: 0.6429 - val_loss: 0.6988 - val_accuracy: 0.4167 - 41ms/epoch - 20ms/step
# Epoch 23/500
# 2/2 - 0s - loss: 0.6551 - accuracy: 0.6786 - val_loss: 0.6987 - val_accuracy: 0.4167 - 56ms/epoch - 28ms/step
# Epoch 24/500
# 2/2 - 0s - loss: 0.6227 - accuracy: 0.6786 - val_loss: 0.6987 - val_accuracy: 0.4167 - 55ms/epoch - 28ms/step
# Epoch 25/500
# 2/2 - 0s - loss: 0.6421 - accuracy: 0.6429 - val_loss: 0.6985 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 26/500
# 2/2 - 0s - loss: 0.6424 - accuracy: 0.7143 - val_loss: 0.6983 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 27/500
# 2/2 - 0s - loss: 0.6081 - accuracy: 0.7143 - val_loss: 0.6979 - val_accuracy: 0.4167 - 56ms/epoch - 28ms/step
# Epoch 28/500
# 2/2 - 0s - loss: 0.6277 - accuracy: 0.7143 - val_loss: 0.6976 - val_accuracy: 0.4167 - 60ms/epoch - 30ms/step
# Epoch 29/500
# 2/2 - 0s - loss: 0.5948 - accuracy: 0.7500 - val_loss: 0.6976 - val_accuracy: 0.4167 - 41ms/epoch - 21ms/step
# Epoch 30/500
# 2/2 - 0s - loss: 0.6115 - accuracy: 0.7500 - val_loss: 0.6977 - val_accuracy: 0.4167 - 67ms/epoch - 33ms/step
# Epoch 31/500
# 2/2 - 0s - loss: 0.6137 - accuracy: 0.7500 - val_loss: 0.6972 - val_accuracy: 0.4167 - 42ms/epoch - 21ms/step
# Epoch 32/500
# 2/2 - 0s - loss: 0.6238 - accuracy: 0.7857 - val_loss: 0.6967 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 33/500
# 2/2 - 0s - loss: 0.5945 - accuracy: 0.7857 - val_loss: 0.6963 - val_accuracy: 0.4167 - 39ms/epoch - 20ms/step
# Epoch 34/500
# 2/2 - 0s - loss: 0.6216 - accuracy: 0.6786 - val_loss: 0.6960 - val_accuracy: 0.4167 - 39ms/epoch - 20ms/step
# Epoch 35/500
# 2/2 - 0s - loss: 0.5908 - accuracy: 0.7500 - val_loss: 0.6957 - val_accuracy: 0.4167 - 39ms/epoch - 20ms/step
# Epoch 36/500
# 2/2 - 0s - loss: 0.5920 - accuracy: 0.6786 - val_loss: 0.6956 - val_accuracy: 0.4167 - 39ms/epoch - 19ms/step
# Epoch 37/500
# 2/2 - 0s - loss: 0.6214 - accuracy: 0.7500 - val_loss: 0.6954 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 38/500
# 2/2 - 0s - loss: 0.5941 - accuracy: 0.7500 - val_loss: 0.6954 - val_accuracy: 0.4167 - 39ms/epoch - 19ms/step
# Epoch 39/500
# 2/2 - 0s - loss: 0.5771 - accuracy: 0.8571 - val_loss: 0.6951 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 40/500
# 2/2 - 0s - loss: 0.5584 - accuracy: 0.8214 - val_loss: 0.6949 - val_accuracy: 0.4167 - 62ms/epoch - 31ms/step
# Epoch 41/500
# 2/2 - 0s - loss: 0.5698 - accuracy: 0.8214 - val_loss: 0.6945 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 42/500
# 2/2 - 0s - loss: 0.5776 - accuracy: 0.7500 - val_loss: 0.6942 - val_accuracy: 0.4167 - 39ms/epoch - 20ms/step
# Epoch 43/500
# 2/2 - 0s - loss: 0.5604 - accuracy: 0.7857 - val_loss: 0.6936 - val_accuracy: 0.4167 - 58ms/epoch - 29ms/step
# Epoch 44/500
# 2/2 - 0s - loss: 0.6039 - accuracy: 0.7857 - val_loss: 0.6928 - val_accuracy: 0.4167 - 57ms/epoch - 28ms/step
# Epoch 45/500
# 2/2 - 0s - loss: 0.5533 - accuracy: 0.7143 - val_loss: 0.6918 - val_accuracy: 0.4167 - 39ms/epoch - 20ms/step
# Epoch 46/500
# 2/2 - 0s - loss: 0.5365 - accuracy: 0.8214 - val_loss: 0.6909 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 47/500
# 2/2 - 0s - loss: 0.5181 - accuracy: 0.8571 - val_loss: 0.6902 - val_accuracy: 0.5833 - 62ms/epoch - 31ms/step
# Epoch 48/500
# 2/2 - 0s - loss: 0.5552 - accuracy: 0.8214 - val_loss: 0.6898 - val_accuracy: 0.5833 - 75ms/epoch - 38ms/step
# Epoch 49/500
# 2/2 - 0s - loss: 0.5095 - accuracy: 0.8571 - val_loss: 0.6891 - val_accuracy: 0.5833 - 70ms/epoch - 35ms/step
# Epoch 50/500
# 2/2 - 0s - loss: 0.5067 - accuracy: 0.8571 - val_loss: 0.6882 - val_accuracy: 0.5833 - 55ms/epoch - 27ms/step
# Epoch 51/500
# 2/2 - 0s - loss: 0.5054 - accuracy: 0.8571 - val_loss: 0.6880 - val_accuracy: 0.5833 - 72ms/epoch - 36ms/step
# Epoch 52/500
# 2/2 - 0s - loss: 0.5138 - accuracy: 0.8214 - val_loss: 0.6884 - val_accuracy: 0.5833 - 75ms/epoch - 37ms/step
# Epoch 53/500
# 2/2 - 0s - loss: 0.5370 - accuracy: 0.7857 - val_loss: 0.6885 - val_accuracy: 0.5833 - 57ms/epoch - 28ms/step
# Epoch 54/500
# 2/2 - 0s - loss: 0.4619 - accuracy: 0.7857 - val_loss: 0.6890 - val_accuracy: 0.5833 - 76ms/epoch - 38ms/step
# Epoch 55/500
# 2/2 - 0s - loss: 0.5056 - accuracy: 0.7857 - val_loss: 0.6886 - val_accuracy: 0.5833 - 70ms/epoch - 35ms/step
# Epoch 56/500
# 2/2 - 0s - loss: 0.4903 - accuracy: 0.8214 - val_loss: 0.6888 - val_accuracy: 0.5833 - 69ms/epoch - 35ms/step
# Epoch 57/500
# 2/2 - 0s - loss: 0.5094 - accuracy: 0.7857 - val_loss: 0.6893 - val_accuracy: 0.5833 - 71ms/epoch - 35ms/step
# Epoch 58/500
# 2/2 - 0s - loss: 0.5061 - accuracy: 0.7500 - val_loss: 0.6901 - val_accuracy: 0.5833 - 71ms/epoch - 35ms/step
# Epoch 59/500
# 2/2 - 0s - loss: 0.5411 - accuracy: 0.8214 - val_loss: 0.6898 - val_accuracy: 0.5833 - 75ms/epoch - 38ms/step
# Epoch 60/500
# 2/2 - 0s - loss: 0.4820 - accuracy: 0.7857 - val_loss: 0.6903 - val_accuracy: 0.5833 - 69ms/epoch - 34ms/step
# Epoch 61/500
# 2/2 - 0s - loss: 0.4579 - accuracy: 0.8571 - val_loss: 0.6906 - val_accuracy: 0.5833 - 79ms/epoch - 39ms/step
# Epoch 62/500
# 2/2 - 0s - loss: 0.4565 - accuracy: 0.8214 - val_loss: 0.6911 - val_accuracy: 0.5833 - 75ms/epoch - 37ms/step
# Epoch 63/500
# 2/2 - 0s - loss: 0.4991 - accuracy: 0.7857 - val_loss: 0.6914 - val_accuracy: 0.5833 - 68ms/epoch - 34ms/step
# Epoch 64/500
# 2/2 - 0s - loss: 0.5033 - accuracy: 0.8214 - val_loss: 0.6908 - val_accuracy: 0.5833 - 78ms/epoch - 39ms/step
# Epoch 65/500
# 2/2 - 0s - loss: 0.4886 - accuracy: 0.8214 - val_loss: 0.6898 - val_accuracy: 0.5833 - 70ms/epoch - 35ms/step
# Epoch 66/500
# 2/2 - 0s - loss: 0.4549 - accuracy: 0.8571 - val_loss: 0.6889 - val_accuracy: 0.5833 - 64ms/epoch - 32ms/step
# Epoch 67/500
# 2/2 - 0s - loss: 0.4940 - accuracy: 0.7857 - val_loss: 0.6879 - val_accuracy: 0.5833 - 80ms/epoch - 40ms/step
# Epoch 68/500
# 2/2 - 0s - loss: 0.4520 - accuracy: 0.8214 - val_loss: 0.6870 - val_accuracy: 0.5833 - 69ms/epoch - 35ms/step
# Epoch 69/500
# 2/2 - 0s - loss: 0.4566 - accuracy: 0.7857 - val_loss: 0.6869 - val_accuracy: 0.5833 - 70ms/epoch - 35ms/step
# Epoch 70/500
# 2/2 - 0s - loss: 0.4343 - accuracy: 0.7857 - val_loss: 0.6869 - val_accuracy: 0.5833 - 76ms/epoch - 38ms/step
# Epoch 71/500
# 2/2 - 0s - loss: 0.4251 - accuracy: 0.8214 - val_loss: 0.6875 - val_accuracy: 0.5833 - 69ms/epoch - 35ms/step
# Epoch 72/500
# 2/2 - 0s - loss: 0.4503 - accuracy: 0.8214 - val_loss: 0.6881 - val_accuracy: 0.5833 - 70ms/epoch - 35ms/step
# Epoch 73/500
# 2/2 - 0s - loss: 0.4501 - accuracy: 0.8571 - val_loss: 0.6870 - val_accuracy: 0.5833 - 70ms/epoch - 35ms/step
# Epoch 74/500
# 2/2 - 0s - loss: 0.4185 - accuracy: 0.8571 - val_loss: 0.6862 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 75/500
# 2/2 - 0s - loss: 0.4607 - accuracy: 0.8571 - val_loss: 0.6863 - val_accuracy: 0.5833 - 57ms/epoch - 29ms/step
# Epoch 76/500
# 2/2 - 0s - loss: 0.4540 - accuracy: 0.7857 - val_loss: 0.6855 - val_accuracy: 0.5833 - 61ms/epoch - 30ms/step
# Epoch 77/500
# 2/2 - 0s - loss: 0.4421 - accuracy: 0.8571 - val_loss: 0.6856 - val_accuracy: 0.5833 - 85ms/epoch - 43ms/step
# Epoch 78/500
# 2/2 - 0s - loss: 0.4294 - accuracy: 0.8571 - val_loss: 0.6864 - val_accuracy: 0.5833 - 60ms/epoch - 30ms/step
# Epoch 79/500
# 2/2 - 0s - loss: 0.4060 - accuracy: 0.8929 - val_loss: 0.6857 - val_accuracy: 0.5833 - 51ms/epoch - 26ms/step
# Epoch 80/500
# 2/2 - 0s - loss: 0.4521 - accuracy: 0.7857 - val_loss: 0.6853 - val_accuracy: 0.5833 - 75ms/epoch - 38ms/step
# Epoch 81/500
# 2/2 - 0s - loss: 0.3780 - accuracy: 0.8571 - val_loss: 0.6851 - val_accuracy: 0.5833 - 67ms/epoch - 34ms/step
# Epoch 82/500
# 2/2 - 0s - loss: 0.4600 - accuracy: 0.8571 - val_loss: 0.6852 - val_accuracy: 0.5833 - 72ms/epoch - 36ms/step
# Epoch 83/500
# 2/2 - 0s - loss: 0.3880 - accuracy: 0.8571 - val_loss: 0.6852 - val_accuracy: 0.5833 - 87ms/epoch - 44ms/step
# Epoch 84/500
# 2/2 - 0s - loss: 0.3891 - accuracy: 0.8929 - val_loss: 0.6839 - val_accuracy: 0.5833 - 73ms/epoch - 36ms/step
# Epoch 85/500
# 2/2 - 0s - loss: 0.4388 - accuracy: 0.7857 - val_loss: 0.6826 - val_accuracy: 0.5833 - 72ms/epoch - 36ms/step
# Epoch 86/500
# 2/2 - 0s - loss: 0.4009 - accuracy: 0.8929 - val_loss: 0.6824 - val_accuracy: 0.5833 - 75ms/epoch - 37ms/step
# Epoch 87/500
# 2/2 - 0s - loss: 0.3664 - accuracy: 0.8929 - val_loss: 0.6825 - val_accuracy: 0.5833 - 66ms/epoch - 33ms/step
# Epoch 88/500
# 2/2 - 0s - loss: 0.3720 - accuracy: 0.8929 - val_loss: 0.6828 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 89/500
# 2/2 - 0s - loss: 0.3903 - accuracy: 0.9286 - val_loss: 0.6829 - val_accuracy: 0.5833 - 71ms/epoch - 35ms/step
# Epoch 90/500
# 2/2 - 0s - loss: 0.4143 - accuracy: 0.8214 - val_loss: 0.6832 - val_accuracy: 0.5833 - 66ms/epoch - 33ms/step
# Epoch 91/500
# 2/2 - 0s - loss: 0.3943 - accuracy: 0.8929 - val_loss: 0.6840 - val_accuracy: 0.5833 - 76ms/epoch - 38ms/step
# Epoch 92/500
# 2/2 - 0s - loss: 0.3923 - accuracy: 0.8571 - val_loss: 0.6843 - val_accuracy: 0.5833 - 62ms/epoch - 31ms/step
# Epoch 93/500
# 2/2 - 0s - loss: 0.3932 - accuracy: 0.9286 - val_loss: 0.6856 - val_accuracy: 0.5833 - 80ms/epoch - 40ms/step
# Epoch 94/500
# 2/2 - 0s - loss: 0.4340 - accuracy: 0.7857 - val_loss: 0.6870 - val_accuracy: 0.5833 - 54ms/epoch - 27ms/step
# Epoch 95/500
# 2/2 - 0s - loss: 0.4060 - accuracy: 0.8214 - val_loss: 0.6847 - val_accuracy: 0.5833 - 76ms/epoch - 38ms/step
# Epoch 96/500
# 2/2 - 0s - loss: 0.3380 - accuracy: 0.9643 - val_loss: 0.6818 - val_accuracy: 0.5833 - 67ms/epoch - 33ms/step
# Epoch 97/500
# 2/2 - 0s - loss: 0.3943 - accuracy: 0.8214 - val_loss: 0.6780 - val_accuracy: 0.5833 - 73ms/epoch - 36ms/step
# Epoch 98/500
# 2/2 - 0s - loss: 0.3816 - accuracy: 0.8929 - val_loss: 0.6769 - val_accuracy: 0.6667 - 69ms/epoch - 35ms/step
# Epoch 99/500
# 2/2 - 0s - loss: 0.3404 - accuracy: 0.9286 - val_loss: 0.6767 - val_accuracy: 0.6667 - 58ms/epoch - 29ms/step
# Epoch 100/500
# 2/2 - 0s - loss: 0.3725 - accuracy: 0.8929 - val_loss: 0.6763 - val_accuracy: 0.6667 - 62ms/epoch - 31ms/step
# Epoch 101/500
# 2/2 - 0s - loss: 0.3921 - accuracy: 0.8571 - val_loss: 0.6749 - val_accuracy: 0.6667 - 72ms/epoch - 36ms/step
# Epoch 102/500
# 2/2 - 0s - loss: 0.4316 - accuracy: 0.8214 - val_loss: 0.6731 - val_accuracy: 0.6667 - 68ms/epoch - 34ms/step
# Epoch 103/500
# 2/2 - 0s - loss: 0.3061 - accuracy: 1.0000 - val_loss: 0.6727 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 104/500
# 2/2 - 0s - loss: 0.3762 - accuracy: 0.8571 - val_loss: 0.6735 - val_accuracy: 0.6667 - 43ms/epoch - 22ms/step
# Epoch 105/500
# 2/2 - 0s - loss: 0.3709 - accuracy: 0.8214 - val_loss: 0.6740 - val_accuracy: 0.6667 - 54ms/epoch - 27ms/step
# Epoch 106/500
# 2/2 - 0s - loss: 0.3563 - accuracy: 0.8929 - val_loss: 0.6747 - val_accuracy: 0.6667 - 57ms/epoch - 29ms/step
# Epoch 107/500
# 2/2 - 0s - loss: 0.3090 - accuracy: 0.9286 - val_loss: 0.6750 - val_accuracy: 0.6667 - 58ms/epoch - 29ms/step
# Epoch 108/500
# 2/2 - 0s - loss: 0.2961 - accuracy: 0.9643 - val_loss: 0.6756 - val_accuracy: 0.6667 - 64ms/epoch - 32ms/step
# Epoch 109/500
# 2/2 - 0s - loss: 0.3254 - accuracy: 0.9286 - val_loss: 0.6764 - val_accuracy: 0.6667 - 41ms/epoch - 21ms/step
# Epoch 110/500
# 2/2 - 0s - loss: 0.2990 - accuracy: 0.9643 - val_loss: 0.6767 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 111/500
# 2/2 - 0s - loss: 0.3239 - accuracy: 0.8929 - val_loss: 0.6762 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 112/500
# 2/2 - 0s - loss: 0.3270 - accuracy: 0.9643 - val_loss: 0.6786 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 113/500
# 2/2 - 0s - loss: 0.2917 - accuracy: 1.0000 - val_loss: 0.6805 - val_accuracy: 0.5833 - 48ms/epoch - 24ms/step
# Epoch 114/500
# 2/2 - 0s - loss: 0.3082 - accuracy: 0.9286 - val_loss: 0.6824 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 115/500
# 2/2 - 0s - loss: 0.2863 - accuracy: 0.9643 - val_loss: 0.6839 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 116/500
# 2/2 - 0s - loss: 0.3253 - accuracy: 0.9643 - val_loss: 0.6836 - val_accuracy: 0.5833 - 57ms/epoch - 29ms/step
# Epoch 117/500
# 2/2 - 0s - loss: 0.3256 - accuracy: 0.9643 - val_loss: 0.6786 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 118/500
# 2/2 - 0s - loss: 0.2982 - accuracy: 0.9643 - val_loss: 0.6765 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 119/500
# 2/2 - 0s - loss: 0.3143 - accuracy: 0.8929 - val_loss: 0.6749 - val_accuracy: 0.6667 - 44ms/epoch - 22ms/step
# Epoch 120/500
# 2/2 - 0s - loss: 0.2657 - accuracy: 1.0000 - val_loss: 0.6752 - val_accuracy: 0.7500 - 40ms/epoch - 20ms/step
# Epoch 121/500
# 2/2 - 0s - loss: 0.3161 - accuracy: 0.9643 - val_loss: 0.6771 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 122/500
# 2/2 - 0s - loss: 0.2989 - accuracy: 0.9286 - val_loss: 0.6795 - val_accuracy: 0.6667 - 41ms/epoch - 20ms/step
# Epoch 123/500
# 2/2 - 0s - loss: 0.2849 - accuracy: 0.9643 - val_loss: 0.6798 - val_accuracy: 0.5833 - 46ms/epoch - 23ms/step
# Epoch 124/500
# 2/2 - 0s - loss: 0.3024 - accuracy: 0.9286 - val_loss: 0.6811 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 125/500
# 2/2 - 0s - loss: 0.2415 - accuracy: 1.0000 - val_loss: 0.6794 - val_accuracy: 0.5000 - 46ms/epoch - 23ms/step
# Epoch 126/500
# 2/2 - 0s - loss: 0.2876 - accuracy: 0.9643 - val_loss: 0.6780 - val_accuracy: 0.5000 - 38ms/epoch - 19ms/step
# Epoch 127/500
# 2/2 - 0s - loss: 0.2773 - accuracy: 1.0000 - val_loss: 0.6777 - val_accuracy: 0.5833 - 38ms/epoch - 19ms/step
# Epoch 128/500
# 2/2 - 0s - loss: 0.3169 - accuracy: 0.9643 - val_loss: 0.6780 - val_accuracy: 0.5000 - 63ms/epoch - 32ms/step
# Epoch 129/500
# 2/2 - 0s - loss: 0.2245 - accuracy: 1.0000 - val_loss: 0.6811 - val_accuracy: 0.5000 - 41ms/epoch - 20ms/step
# Epoch 130/500
# 2/2 - 0s - loss: 0.2789 - accuracy: 1.0000 - val_loss: 0.6850 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 131/500
# 2/2 - 0s - loss: 0.2812 - accuracy: 0.9643 - val_loss: 0.6889 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 132/500
# 2/2 - 0s - loss: 0.2371 - accuracy: 1.0000 - val_loss: 0.6913 - val_accuracy: 0.5833 - 39ms/epoch - 19ms/step
# Epoch 133/500
# 2/2 - 0s - loss: 0.2751 - accuracy: 0.9643 - val_loss: 0.6909 - val_accuracy: 0.6667 - 39ms/epoch - 20ms/step
# Epoch 134/500
# 2/2 - 0s - loss: 0.2718 - accuracy: 0.9643 - val_loss: 0.6872 - val_accuracy: 0.5833 - 38ms/epoch - 19ms/step
# Epoch 135/500
# 2/2 - 0s - loss: 0.2310 - accuracy: 1.0000 - val_loss: 0.6839 - val_accuracy: 0.5833 - 43ms/epoch - 21ms/step
# Epoch 136/500
# 2/2 - 0s - loss: 0.2492 - accuracy: 1.0000 - val_loss: 0.6822 - val_accuracy: 0.5000 - 39ms/epoch - 20ms/step
# Epoch 137/500
# 2/2 - 0s - loss: 0.2678 - accuracy: 0.9286 - val_loss: 0.6817 - val_accuracy: 0.5000 - 41ms/epoch - 20ms/step
# Epoch 138/500
# 2/2 - 0s - loss: 0.2228 - accuracy: 1.0000 - val_loss: 0.6821 - val_accuracy: 0.5833 - 39ms/epoch - 19ms/step
# Epoch 139/500
# 2/2 - 0s - loss: 0.2367 - accuracy: 0.9643 - val_loss: 0.6877 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 140/500
# 2/2 - 0s - loss: 0.2479 - accuracy: 1.0000 - val_loss: 0.6999 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 141/500
# 2/2 - 0s - loss: 0.3039 - accuracy: 0.9643 - val_loss: 0.7109 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 142/500
# 2/2 - 0s - loss: 0.2908 - accuracy: 0.9286 - val_loss: 0.7181 - val_accuracy: 0.5833 - 57ms/epoch - 29ms/step
# Epoch 143/500
# 2/2 - 0s - loss: 0.2750 - accuracy: 0.9643 - val_loss: 0.7273 - val_accuracy: 0.5833 - 39ms/epoch - 19ms/step
# Epoch 144/500
# 2/2 - 0s - loss: 0.2692 - accuracy: 0.9643 - val_loss: 0.7270 - val_accuracy: 0.5833 - 57ms/epoch - 28ms/step
# Epoch 145/500
# 2/2 - 0s - loss: 0.2459 - accuracy: 0.9286 - val_loss: 0.7233 - val_accuracy: 0.6667 - 53ms/epoch - 27ms/step
# Epoch 146/500
# 2/2 - 0s - loss: 0.2478 - accuracy: 0.9643 - val_loss: 0.7147 - val_accuracy: 0.6667 - 56ms/epoch - 28ms/step
# Epoch 147/500
# 2/2 - 0s - loss: 0.2246 - accuracy: 1.0000 - val_loss: 0.7097 - val_accuracy: 0.4167 - 43ms/epoch - 22ms/step
# Epoch 148/500
# 2/2 - 0s - loss: 0.2242 - accuracy: 0.9643 - val_loss: 0.7111 - val_accuracy: 0.4167 - 47ms/epoch - 23ms/step
# Epoch 149/500
# 2/2 - 0s - loss: 0.2125 - accuracy: 0.9643 - val_loss: 0.7130 - val_accuracy: 0.4167 - 40ms/epoch - 20ms/step
# Epoch 150/500
# 2/2 - 0s - loss: 0.2534 - accuracy: 1.0000 - val_loss: 0.7213 - val_accuracy: 0.5833 - 39ms/epoch - 19ms/step
# Epoch 151/500
# 2/2 - 0s - loss: 0.2188 - accuracy: 1.0000 - val_loss: 0.7355 - val_accuracy: 0.6667 - 46ms/epoch - 23ms/step
# Epoch 152/500
# 2/2 - 0s - loss: 0.2322 - accuracy: 1.0000 - val_loss: 0.7488 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 153/500
# 2/2 - 0s - loss: 0.3080 - accuracy: 0.8929 - val_loss: 0.7488 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 154/500
# 2/2 - 0s - loss: 0.2090 - accuracy: 0.9643 - val_loss: 0.7450 - val_accuracy: 0.5833 - 43ms/epoch - 22ms/step
# Epoch 155/500
# 2/2 - 0s - loss: 0.1989 - accuracy: 1.0000 - val_loss: 0.7358 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 156/500
# 2/2 - 0s - loss: 0.2075 - accuracy: 1.0000 - val_loss: 0.7317 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 157/500
# 2/2 - 0s - loss: 0.1887 - accuracy: 1.0000 - val_loss: 0.7310 - val_accuracy: 0.5833 - 43ms/epoch - 21ms/step
# Epoch 158/500
# 2/2 - 0s - loss: 0.2447 - accuracy: 1.0000 - val_loss: 0.7307 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 159/500
# 2/2 - 0s - loss: 0.1816 - accuracy: 1.0000 - val_loss: 0.7312 - val_accuracy: 0.5000 - 41ms/epoch - 20ms/step
# Epoch 160/500
# 2/2 - 0s - loss: 0.2015 - accuracy: 0.9643 - val_loss: 0.7347 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 161/500
# 2/2 - 0s - loss: 0.1519 - accuracy: 1.0000 - val_loss: 0.7416 - val_accuracy: 0.5833 - 46ms/epoch - 23ms/step
# Epoch 162/500
# 2/2 - 0s - loss: 0.2537 - accuracy: 1.0000 - val_loss: 0.7548 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 163/500
# 2/2 - 0s - loss: 0.2097 - accuracy: 1.0000 - val_loss: 0.7662 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 164/500
# 2/2 - 0s - loss: 0.1904 - accuracy: 1.0000 - val_loss: 0.7802 - val_accuracy: 0.5833 - 60ms/epoch - 30ms/step
# Epoch 165/500
# 2/2 - 0s - loss: 0.1817 - accuracy: 1.0000 - val_loss: 0.7991 - val_accuracy: 0.5833 - 66ms/epoch - 33ms/step
# Epoch 166/500
# 2/2 - 0s - loss: 0.2174 - accuracy: 0.9643 - val_loss: 0.8013 - val_accuracy: 0.5833 - 48ms/epoch - 24ms/step
# Epoch 167/500
# 2/2 - 0s - loss: 0.1687 - accuracy: 1.0000 - val_loss: 0.7879 - val_accuracy: 0.5833 - 57ms/epoch - 29ms/step
# Epoch 168/500
# 2/2 - 0s - loss: 0.2189 - accuracy: 1.0000 - val_loss: 0.7673 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 169/500
# 2/2 - 0s - loss: 0.1940 - accuracy: 1.0000 - val_loss: 0.7514 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 170/500
# 2/2 - 0s - loss: 0.2076 - accuracy: 0.9643 - val_loss: 0.7474 - val_accuracy: 0.6667 - 43ms/epoch - 21ms/step
# Epoch 171/500
# 2/2 - 0s - loss: 0.2584 - accuracy: 0.9643 - val_loss: 0.7575 - val_accuracy: 0.5833 - 55ms/epoch - 28ms/step
# Epoch 172/500
# 2/2 - 0s - loss: 0.2373 - accuracy: 0.9286 - val_loss: 0.7689 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 173/500
# 2/2 - 0s - loss: 0.2137 - accuracy: 1.0000 - val_loss: 0.7745 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 174/500
# 2/2 - 0s - loss: 0.2152 - accuracy: 0.9643 - val_loss: 0.7776 - val_accuracy: 0.5833 - 43ms/epoch - 22ms/step
# Epoch 175/500
# 2/2 - 0s - loss: 0.1854 - accuracy: 1.0000 - val_loss: 0.7850 - val_accuracy: 0.5833 - 55ms/epoch - 28ms/step
# Epoch 176/500
# 2/2 - 0s - loss: 0.1703 - accuracy: 1.0000 - val_loss: 0.7937 - val_accuracy: 0.5000 - 41ms/epoch - 21ms/step
# Epoch 177/500
# 2/2 - 0s - loss: 0.2311 - accuracy: 0.9286 - val_loss: 0.7916 - val_accuracy: 0.5000 - 41ms/epoch - 20ms/step
# Epoch 178/500
# 2/2 - 0s - loss: 0.1471 - accuracy: 1.0000 - val_loss: 0.7914 - val_accuracy: 0.5000 - 45ms/epoch - 23ms/step
# Epoch 179/500
# 2/2 - 0s - loss: 0.1833 - accuracy: 1.0000 - val_loss: 0.7845 - val_accuracy: 0.5000 - 39ms/epoch - 20ms/step
# Epoch 180/500
# 2/2 - 0s - loss: 0.1571 - accuracy: 1.0000 - val_loss: 0.7840 - val_accuracy: 0.5833 - 43ms/epoch - 22ms/step
# Epoch 181/500
# 2/2 - 0s - loss: 0.1695 - accuracy: 1.0000 - val_loss: 0.7905 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 182/500
# 2/2 - 0s - loss: 0.1986 - accuracy: 1.0000 - val_loss: 0.8012 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 183/500
# 2/2 - 0s - loss: 0.1608 - accuracy: 1.0000 - val_loss: 0.8095 - val_accuracy: 0.5833 - 54ms/epoch - 27ms/step
# Epoch 184/500
# 2/2 - 0s - loss: 0.1396 - accuracy: 1.0000 - val_loss: 0.8118 - val_accuracy: 0.5833 - 49ms/epoch - 24ms/step
# Epoch 185/500
# 2/2 - 0s - loss: 0.1544 - accuracy: 1.0000 - val_loss: 0.8097 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 186/500
# 2/2 - 0s - loss: 0.1516 - accuracy: 1.0000 - val_loss: 0.8010 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 187/500
# 2/2 - 0s - loss: 0.1615 - accuracy: 1.0000 - val_loss: 0.8005 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 188/500
# 2/2 - 0s - loss: 0.1649 - accuracy: 1.0000 - val_loss: 0.8111 - val_accuracy: 0.5833 - 38ms/epoch - 19ms/step
# Epoch 189/500
# 2/2 - 0s - loss: 0.1698 - accuracy: 0.9643 - val_loss: 0.8304 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 190/500
# 2/2 - 0s - loss: 0.1840 - accuracy: 1.0000 - val_loss: 0.8363 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 191/500
# 2/2 - 0s - loss: 0.1583 - accuracy: 1.0000 - val_loss: 0.8335 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 192/500
# 2/2 - 0s - loss: 0.1409 - accuracy: 1.0000 - val_loss: 0.8250 - val_accuracy: 0.5000 - 43ms/epoch - 22ms/step
# Epoch 193/500
# 2/2 - 0s - loss: 0.1608 - accuracy: 0.9643 - val_loss: 0.8189 - val_accuracy: 0.5000 - 56ms/epoch - 28ms/step
# Epoch 194/500
# 2/2 - 0s - loss: 0.1474 - accuracy: 1.0000 - val_loss: 0.8127 - val_accuracy: 0.5000 - 56ms/epoch - 28ms/step
# Epoch 195/500
# 2/2 - 0s - loss: 0.1710 - accuracy: 1.0000 - val_loss: 0.8169 - val_accuracy: 0.5000 - 41ms/epoch - 20ms/step
# Epoch 196/500
# 2/2 - 0s - loss: 0.1413 - accuracy: 1.0000 - val_loss: 0.8358 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 197/500
# 2/2 - 0s - loss: 0.1517 - accuracy: 1.0000 - val_loss: 0.8580 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 198/500
# 2/2 - 0s - loss: 0.1862 - accuracy: 1.0000 - val_loss: 0.8677 - val_accuracy: 0.5833 - 63ms/epoch - 31ms/step
# Epoch 199/500
# 2/2 - 0s - loss: 0.2317 - accuracy: 0.9643 - val_loss: 0.8561 - val_accuracy: 0.5833 - 67ms/epoch - 34ms/step
# Epoch 200/500
# 2/2 - 0s - loss: 0.1588 - accuracy: 1.0000 - val_loss: 0.8457 - val_accuracy: 0.5833 - 60ms/epoch - 30ms/step
# Epoch 201/500
# 2/2 - 0s - loss: 0.1430 - accuracy: 1.0000 - val_loss: 0.8484 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 202/500
# 2/2 - 0s - loss: 0.1264 - accuracy: 1.0000 - val_loss: 0.8476 - val_accuracy: 0.5000 - 41ms/epoch - 20ms/step
# Epoch 203/500
# 2/2 - 0s - loss: 0.1332 - accuracy: 1.0000 - val_loss: 0.8470 - val_accuracy: 0.5000 - 52ms/epoch - 26ms/step
# Epoch 204/500
# 2/2 - 0s - loss: 0.1477 - accuracy: 1.0000 - val_loss: 0.8411 - val_accuracy: 0.5000 - 42ms/epoch - 21ms/step
# Epoch 205/500
# 2/2 - 0s - loss: 0.1252 - accuracy: 1.0000 - val_loss: 0.8298 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 206/500
# 2/2 - 0s - loss: 0.1998 - accuracy: 1.0000 - val_loss: 0.8284 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 207/500
# 2/2 - 0s - loss: 0.1590 - accuracy: 0.9643 - val_loss: 0.8309 - val_accuracy: 0.5000 - 45ms/epoch - 22ms/step
# Epoch 208/500
# 2/2 - 0s - loss: 0.1588 - accuracy: 1.0000 - val_loss: 0.8517 - val_accuracy: 0.5000 - 41ms/epoch - 21ms/step
# Epoch 209/500
# 2/2 - 0s - loss: 0.1388 - accuracy: 1.0000 - val_loss: 0.8786 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 210/500
# 2/2 - 0s - loss: 0.1380 - accuracy: 1.0000 - val_loss: 0.8851 - val_accuracy: 0.5833 - 60ms/epoch - 30ms/step
# Epoch 211/500
# 2/2 - 0s - loss: 0.1351 - accuracy: 1.0000 - val_loss: 0.8921 - val_accuracy: 0.5833 - 59ms/epoch - 30ms/step
# Epoch 212/500
# 2/2 - 0s - loss: 0.1785 - accuracy: 1.0000 - val_loss: 0.9032 - val_accuracy: 0.5833 - 41ms/epoch - 21ms/step
# Epoch 213/500
# 2/2 - 0s - loss: 0.1369 - accuracy: 1.0000 - val_loss: 0.9069 - val_accuracy: 0.5833 - 49ms/epoch - 24ms/step
# Epoch 214/500
# 2/2 - 0s - loss: 0.1281 - accuracy: 1.0000 - val_loss: 0.8971 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 215/500
# 2/2 - 0s - loss: 0.1427 - accuracy: 0.9643 - val_loss: 0.8892 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 216/500
# 2/2 - 0s - loss: 0.1229 - accuracy: 1.0000 - val_loss: 0.8909 - val_accuracy: 0.5833 - 39ms/epoch - 19ms/step
# Epoch 217/500
# 2/2 - 0s - loss: 0.0953 - accuracy: 1.0000 - val_loss: 0.8914 - val_accuracy: 0.5833 - 43ms/epoch - 22ms/step
# Epoch 218/500
# 2/2 - 0s - loss: 0.1239 - accuracy: 1.0000 - val_loss: 0.9065 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 219/500
# 2/2 - 0s - loss: 0.1236 - accuracy: 1.0000 - val_loss: 0.9253 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 220/500
# 2/2 - 0s - loss: 0.1261 - accuracy: 1.0000 - val_loss: 0.9270 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 221/500
# 2/2 - 0s - loss: 0.1538 - accuracy: 1.0000 - val_loss: 0.9387 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 222/500
# 2/2 - 0s - loss: 0.1365 - accuracy: 1.0000 - val_loss: 0.9502 - val_accuracy: 0.5833 - 59ms/epoch - 30ms/step
# Epoch 223/500
# 2/2 - 0s - loss: 0.1204 - accuracy: 1.0000 - val_loss: 0.9473 - val_accuracy: 0.5833 - 49ms/epoch - 25ms/step
# Epoch 224/500
# 2/2 - 0s - loss: 0.1138 - accuracy: 1.0000 - val_loss: 0.9342 - val_accuracy: 0.5833 - 57ms/epoch - 28ms/step
# Epoch 225/500
# 2/2 - 0s - loss: 0.1034 - accuracy: 1.0000 - val_loss: 0.9266 - val_accuracy: 0.5833 - 48ms/epoch - 24ms/step
# Epoch 226/500
# 2/2 - 0s - loss: 0.1312 - accuracy: 1.0000 - val_loss: 0.9232 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 227/500
# 2/2 - 0s - loss: 0.1133 - accuracy: 1.0000 - val_loss: 0.9270 - val_accuracy: 0.5000 - 41ms/epoch - 20ms/step
# Epoch 228/500
# 2/2 - 0s - loss: 0.1201 - accuracy: 1.0000 - val_loss: 0.9526 - val_accuracy: 0.5833 - 43ms/epoch - 22ms/step
# Epoch 229/500
# 2/2 - 0s - loss: 0.1106 - accuracy: 1.0000 - val_loss: 0.9688 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 230/500
# 2/2 - 0s - loss: 0.1192 - accuracy: 1.0000 - val_loss: 0.9680 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 231/500
# 2/2 - 0s - loss: 0.1638 - accuracy: 0.9643 - val_loss: 1.0170 - val_accuracy: 0.5833 - 45ms/epoch - 23ms/step
# Epoch 232/500
# 2/2 - 0s - loss: 0.1050 - accuracy: 1.0000 - val_loss: 1.0729 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 233/500
# 2/2 - 0s - loss: 0.1170 - accuracy: 1.0000 - val_loss: 1.0974 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 234/500
# 2/2 - 0s - loss: 0.1204 - accuracy: 1.0000 - val_loss: 1.0635 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 235/500
# 2/2 - 0s - loss: 0.1640 - accuracy: 1.0000 - val_loss: 1.0365 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 236/500
# 2/2 - 0s - loss: 0.1038 - accuracy: 1.0000 - val_loss: 1.0111 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 237/500
# 2/2 - 0s - loss: 0.1117 - accuracy: 1.0000 - val_loss: 0.9782 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 238/500
# 2/2 - 0s - loss: 0.1250 - accuracy: 1.0000 - val_loss: 0.9624 - val_accuracy: 0.5833 - 57ms/epoch - 29ms/step
# Epoch 239/500
# 2/2 - 0s - loss: 0.1192 - accuracy: 1.0000 - val_loss: 0.9570 - val_accuracy: 0.5833 - 39ms/epoch - 19ms/step
# Epoch 240/500
# 2/2 - 0s - loss: 0.1178 - accuracy: 1.0000 - val_loss: 0.9541 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 241/500
# 2/2 - 0s - loss: 0.1037 - accuracy: 1.0000 - val_loss: 0.9611 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 242/500
# 2/2 - 0s - loss: 0.1107 - accuracy: 1.0000 - val_loss: 0.9663 - val_accuracy: 0.5833 - 44ms/epoch - 22ms/step
# Epoch 243/500
# 2/2 - 0s - loss: 0.0935 - accuracy: 1.0000 - val_loss: 0.9678 - val_accuracy: 0.5833 - 46ms/epoch - 23ms/step
# Epoch 244/500
# 2/2 - 0s - loss: 0.1294 - accuracy: 1.0000 - val_loss: 1.0038 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 245/500
# 2/2 - 0s - loss: 0.1310 - accuracy: 1.0000 - val_loss: 1.0208 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 246/500
# 2/2 - 0s - loss: 0.0925 - accuracy: 1.0000 - val_loss: 1.0462 - val_accuracy: 0.5833 - 47ms/epoch - 23ms/step
# Epoch 247/500
# 2/2 - 0s - loss: 0.1155 - accuracy: 1.0000 - val_loss: 1.0469 - val_accuracy: 0.5833 - 41ms/epoch - 21ms/step
# Epoch 248/500
# 2/2 - 0s - loss: 0.1126 - accuracy: 1.0000 - val_loss: 1.0089 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 249/500
# 2/2 - 0s - loss: 0.1145 - accuracy: 1.0000 - val_loss: 0.9727 - val_accuracy: 0.5833 - 55ms/epoch - 28ms/step
# Epoch 250/500
# 2/2 - 0s - loss: 0.1058 - accuracy: 1.0000 - val_loss: 0.9308 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 251/500
# 2/2 - 0s - loss: 0.1217 - accuracy: 1.0000 - val_loss: 0.9257 - val_accuracy: 0.5833 - 61ms/epoch - 30ms/step
# Epoch 252/500
# 2/2 - 0s - loss: 0.1058 - accuracy: 1.0000 - val_loss: 0.9198 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 253/500
# 2/2 - 0s - loss: 0.1123 - accuracy: 1.0000 - val_loss: 0.9039 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 254/500
# 2/2 - 0s - loss: 0.0977 - accuracy: 1.0000 - val_loss: 0.8930 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 255/500
# 2/2 - 0s - loss: 0.1117 - accuracy: 1.0000 - val_loss: 0.8879 - val_accuracy: 0.5833 - 61ms/epoch - 31ms/step
# Epoch 256/500
# 2/2 - 0s - loss: 0.1107 - accuracy: 1.0000 - val_loss: 0.8900 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 257/500
# 2/2 - 0s - loss: 0.0992 - accuracy: 1.0000 - val_loss: 0.9054 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 258/500
# 2/2 - 0s - loss: 0.1171 - accuracy: 1.0000 - val_loss: 0.9335 - val_accuracy: 0.5833 - 90ms/epoch - 45ms/step
# Epoch 259/500
# 2/2 - 0s - loss: 0.0965 - accuracy: 1.0000 - val_loss: 0.9371 - val_accuracy: 0.5833 - 193ms/epoch - 97ms/step
# Epoch 260/500
# 2/2 - 0s - loss: 0.1295 - accuracy: 1.0000 - val_loss: 0.9312 - val_accuracy: 0.5833 - 137ms/epoch - 69ms/step
# Epoch 261/500
# 2/2 - 0s - loss: 0.1310 - accuracy: 1.0000 - val_loss: 0.9227 - val_accuracy: 0.5833 - 95ms/epoch - 48ms/step
# Epoch 262/500
# 2/2 - 0s - loss: 0.1120 - accuracy: 1.0000 - val_loss: 0.9184 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 263/500
# 2/2 - 0s - loss: 0.1015 - accuracy: 1.0000 - val_loss: 0.9285 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 264/500
# 2/2 - 0s - loss: 0.1076 - accuracy: 1.0000 - val_loss: 0.9515 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 265/500
# 2/2 - 0s - loss: 0.1192 - accuracy: 0.9643 - val_loss: 1.0084 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 266/500
# 2/2 - 0s - loss: 0.1221 - accuracy: 1.0000 - val_loss: 1.0287 - val_accuracy: 0.5833 - 43ms/epoch - 22ms/step
# Epoch 267/500
# 2/2 - 0s - loss: 0.1175 - accuracy: 0.9643 - val_loss: 1.0442 - val_accuracy: 0.5833 - 55ms/epoch - 28ms/step
# Epoch 268/500
# 2/2 - 0s - loss: 0.1258 - accuracy: 1.0000 - val_loss: 1.0545 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 269/500
# 2/2 - 0s - loss: 0.1089 - accuracy: 1.0000 - val_loss: 1.0577 - val_accuracy: 0.5000 - 39ms/epoch - 20ms/step
# Epoch 270/500
# 2/2 - 0s - loss: 0.0944 - accuracy: 1.0000 - val_loss: 1.0511 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 271/500
# 2/2 - 0s - loss: 0.1096 - accuracy: 1.0000 - val_loss: 1.0313 - val_accuracy: 0.5833 - 166ms/epoch - 83ms/step
# Epoch 272/500
# 2/2 - 0s - loss: 0.0961 - accuracy: 1.0000 - val_loss: 1.0240 - val_accuracy: 0.5833 - 154ms/epoch - 77ms/step
# Epoch 273/500
# 2/2 - 0s - loss: 0.1175 - accuracy: 1.0000 - val_loss: 0.9900 - val_accuracy: 0.5000 - 97ms/epoch - 49ms/step
# Epoch 274/500
# 2/2 - 0s - loss: 0.1216 - accuracy: 1.0000 - val_loss: 0.9940 - val_accuracy: 0.5000 - 95ms/epoch - 47ms/step
# Epoch 275/500
# 2/2 - 0s - loss: 0.0841 - accuracy: 1.0000 - val_loss: 1.0227 - val_accuracy: 0.5000 - 45ms/epoch - 22ms/step
# Epoch 276/500
# 2/2 - 0s - loss: 0.0924 - accuracy: 1.0000 - val_loss: 1.0393 - val_accuracy: 0.5000 - 41ms/epoch - 21ms/step
# Epoch 277/500
# 2/2 - 0s - loss: 0.0905 - accuracy: 1.0000 - val_loss: 1.0304 - val_accuracy: 0.5000 - 59ms/epoch - 29ms/step
# Epoch 278/500
# 2/2 - 0s - loss: 0.0951 - accuracy: 1.0000 - val_loss: 1.0070 - val_accuracy: 0.5000 - 39ms/epoch - 20ms/step
# Epoch 279/500
# 2/2 - 0s - loss: 0.0906 - accuracy: 1.0000 - val_loss: 0.9894 - val_accuracy: 0.5000 - 57ms/epoch - 29ms/step
# Epoch 280/500
# 2/2 - 0s - loss: 0.1095 - accuracy: 1.0000 - val_loss: 0.9704 - val_accuracy: 0.5000 - 72ms/epoch - 36ms/step
# Epoch 281/500
# 2/2 - 0s - loss: 0.1131 - accuracy: 1.0000 - val_loss: 0.9578 - val_accuracy: 0.5000 - 65ms/epoch - 33ms/step
# Epoch 282/500
# 2/2 - 0s - loss: 0.0923 - accuracy: 1.0000 - val_loss: 0.9466 - val_accuracy: 0.5000 - 60ms/epoch - 30ms/step
# Epoch 283/500
# 2/2 - 0s - loss: 0.0921 - accuracy: 1.0000 - val_loss: 0.9476 - val_accuracy: 0.5000 - 56ms/epoch - 28ms/step
# Epoch 284/500
# 2/2 - 0s - loss: 0.1117 - accuracy: 1.0000 - val_loss: 0.9572 - val_accuracy: 0.5000 - 69ms/epoch - 34ms/step
# Epoch 285/500
# 2/2 - 0s - loss: 0.1111 - accuracy: 1.0000 - val_loss: 0.9652 - val_accuracy: 0.5000 - 83ms/epoch - 42ms/step
# Epoch 286/500
# 2/2 - 0s - loss: 0.0919 - accuracy: 1.0000 - val_loss: 0.9699 - val_accuracy: 0.5833 - 60ms/epoch - 30ms/step
# Epoch 287/500
# 2/2 - 0s - loss: 0.1108 - accuracy: 1.0000 - val_loss: 0.9729 - val_accuracy: 0.5833 - 77ms/epoch - 38ms/step
# Epoch 288/500
# 2/2 - 0s - loss: 0.0967 - accuracy: 1.0000 - val_loss: 0.9754 - val_accuracy: 0.5833 - 68ms/epoch - 34ms/step
# Epoch 289/500
# 2/2 - 0s - loss: 0.0791 - accuracy: 1.0000 - val_loss: 0.9651 - val_accuracy: 0.5833 - 68ms/epoch - 34ms/step
# Epoch 290/500
# 2/2 - 0s - loss: 0.0869 - accuracy: 1.0000 - val_loss: 0.9649 - val_accuracy: 0.5833 - 67ms/epoch - 33ms/step
# Epoch 291/500
# 2/2 - 0s - loss: 0.0804 - accuracy: 1.0000 - val_loss: 0.9684 - val_accuracy: 0.5833 - 74ms/epoch - 37ms/step
# Epoch 292/500
# 2/2 - 0s - loss: 0.0879 - accuracy: 1.0000 - val_loss: 0.9643 - val_accuracy: 0.5833 - 72ms/epoch - 36ms/step
# Epoch 293/500
# 2/2 - 0s - loss: 0.1055 - accuracy: 1.0000 - val_loss: 0.9493 - val_accuracy: 0.5833 - 70ms/epoch - 35ms/step
# Epoch 294/500
# 2/2 - 0s - loss: 0.1074 - accuracy: 1.0000 - val_loss: 0.9360 - val_accuracy: 0.5833 - 68ms/epoch - 34ms/step
# Epoch 295/500
# 2/2 - 0s - loss: 0.1130 - accuracy: 1.0000 - val_loss: 0.9366 - val_accuracy: 0.5833 - 75ms/epoch - 37ms/step
# Epoch 296/500
# 2/2 - 0s - loss: 0.1329 - accuracy: 0.9643 - val_loss: 0.9368 - val_accuracy: 0.5833 - 77ms/epoch - 38ms/step
# Epoch 297/500
# 2/2 - 0s - loss: 0.0911 - accuracy: 1.0000 - val_loss: 0.9596 - val_accuracy: 0.5833 - 71ms/epoch - 36ms/step
# Epoch 298/500
# 2/2 - 0s - loss: 0.0923 - accuracy: 1.0000 - val_loss: 0.9809 - val_accuracy: 0.5833 - 62ms/epoch - 31ms/step
# Epoch 299/500
# 2/2 - 0s - loss: 0.0929 - accuracy: 1.0000 - val_loss: 1.0024 - val_accuracy: 0.5833 - 72ms/epoch - 36ms/step
# Epoch 300/500
# 2/2 - 0s - loss: 0.0983 - accuracy: 1.0000 - val_loss: 1.0386 - val_accuracy: 0.5833 - 77ms/epoch - 39ms/step
# Epoch 301/500
# 2/2 - 0s - loss: 0.1011 - accuracy: 1.0000 - val_loss: 1.0804 - val_accuracy: 0.5000 - 75ms/epoch - 37ms/step
# Epoch 302/500
# 2/2 - 0s - loss: 0.0847 - accuracy: 1.0000 - val_loss: 1.1327 - val_accuracy: 0.5000 - 72ms/epoch - 36ms/step
# Epoch 303/500
# 2/2 - 0s - loss: 0.1024 - accuracy: 1.0000 - val_loss: 1.1555 - val_accuracy: 0.5833 - 71ms/epoch - 36ms/step
# Epoch 304/500
# 2/2 - 0s - loss: 0.1321 - accuracy: 1.0000 - val_loss: 1.1220 - val_accuracy: 0.5000 - 73ms/epoch - 36ms/step
# Epoch 305/500
# 2/2 - 0s - loss: 0.1081 - accuracy: 1.0000 - val_loss: 1.0686 - val_accuracy: 0.5833 - 74ms/epoch - 37ms/step
# Epoch 306/500
# 2/2 - 0s - loss: 0.0815 - accuracy: 1.0000 - val_loss: 1.0700 - val_accuracy: 0.5833 - 68ms/epoch - 34ms/step
# Epoch 307/500
# 2/2 - 0s - loss: 0.0868 - accuracy: 1.0000 - val_loss: 1.0518 - val_accuracy: 0.5833 - 72ms/epoch - 36ms/step
# Epoch 308/500
# 2/2 - 0s - loss: 0.1005 - accuracy: 1.0000 - val_loss: 1.0396 - val_accuracy: 0.5833 - 70ms/epoch - 35ms/step
# Epoch 309/500
# 2/2 - 0s - loss: 0.1052 - accuracy: 1.0000 - val_loss: 0.9934 - val_accuracy: 0.5833 - 74ms/epoch - 37ms/step
# Epoch 310/500
# 2/2 - 0s - loss: 0.1295 - accuracy: 0.9643 - val_loss: 1.0226 - val_accuracy: 0.5833 - 80ms/epoch - 40ms/step
# Epoch 311/500
# 2/2 - 0s - loss: 0.0811 - accuracy: 1.0000 - val_loss: 1.0427 - val_accuracy: 0.5833 - 71ms/epoch - 35ms/step
# Epoch 312/500
# 2/2 - 0s - loss: 0.0751 - accuracy: 1.0000 - val_loss: 1.0565 - val_accuracy: 0.5833 - 72ms/epoch - 36ms/step
# Epoch 313/500
# 2/2 - 0s - loss: 0.0707 - accuracy: 1.0000 - val_loss: 1.0642 - val_accuracy: 0.5833 - 61ms/epoch - 31ms/step
# Epoch 314/500
# 2/2 - 0s - loss: 0.0987 - accuracy: 1.0000 - val_loss: 1.0471 - val_accuracy: 0.5833 - 60ms/epoch - 30ms/step
# Epoch 315/500
# 2/2 - 0s - loss: 0.0886 - accuracy: 1.0000 - val_loss: 1.0368 - val_accuracy: 0.5833 - 73ms/epoch - 36ms/step
# Epoch 316/500
# 2/2 - 0s - loss: 0.1142 - accuracy: 1.0000 - val_loss: 1.0015 - val_accuracy: 0.5833 - 73ms/epoch - 36ms/step
# Epoch 317/500
# 2/2 - 0s - loss: 0.0815 - accuracy: 1.0000 - val_loss: 0.9867 - val_accuracy: 0.5833 - 76ms/epoch - 38ms/step
# Epoch 318/500
# 2/2 - 0s - loss: 0.0937 - accuracy: 1.0000 - val_loss: 0.9780 - val_accuracy: 0.5833 - 73ms/epoch - 37ms/step
# Epoch 319/500
# 2/2 - 0s - loss: 0.0811 - accuracy: 1.0000 - val_loss: 0.9694 - val_accuracy: 0.5833 - 74ms/epoch - 37ms/step
# Epoch 320/500
# 2/2 - 0s - loss: 0.0934 - accuracy: 1.0000 - val_loss: 0.9695 - val_accuracy: 0.5833 - 74ms/epoch - 37ms/step
# Epoch 321/500
# 2/2 - 0s - loss: 0.0877 - accuracy: 1.0000 - val_loss: 0.9844 - val_accuracy: 0.5833 - 57ms/epoch - 29ms/step
# Epoch 322/500
# 2/2 - 0s - loss: 0.1624 - accuracy: 1.0000 - val_loss: 1.0021 - val_accuracy: 0.5833 - 83ms/epoch - 42ms/step
# Epoch 323/500
# 2/2 - 0s - loss: 0.0958 - accuracy: 1.0000 - val_loss: 1.0771 - val_accuracy: 0.5000 - 76ms/epoch - 38ms/step
# Epoch 324/500
# 2/2 - 0s - loss: 0.1466 - accuracy: 0.9643 - val_loss: 1.1687 - val_accuracy: 0.5833 - 67ms/epoch - 34ms/step
# Epoch 325/500
# 2/2 - 0s - loss: 0.1295 - accuracy: 0.9643 - val_loss: 1.2713 - val_accuracy: 0.5833 - 63ms/epoch - 31ms/step
# Epoch 326/500
# 2/2 - 0s - loss: 0.1294 - accuracy: 1.0000 - val_loss: 1.2506 - val_accuracy: 0.5833 - 132ms/epoch - 66ms/step
# Epoch 327/500
# 2/2 - 0s - loss: 0.1059 - accuracy: 1.0000 - val_loss: 1.1381 - val_accuracy: 0.5833 - 135ms/epoch - 68ms/step
# Epoch 328/500
# 2/2 - 0s - loss: 0.0961 - accuracy: 1.0000 - val_loss: 1.0348 - val_accuracy: 0.5833 - 62ms/epoch - 31ms/step
# Epoch 329/500
# 2/2 - 0s - loss: 0.0870 - accuracy: 1.0000 - val_loss: 0.9821 - val_accuracy: 0.5833 - 74ms/epoch - 37ms/step
# Epoch 330/500
# 2/2 - 0s - loss: 0.0670 - accuracy: 1.0000 - val_loss: 0.9569 - val_accuracy: 0.5833 - 61ms/epoch - 30ms/step
# Epoch 331/500
# 2/2 - 0s - loss: 0.0855 - accuracy: 1.0000 - val_loss: 0.9480 - val_accuracy: 0.5833 - 72ms/epoch - 36ms/step
# Epoch 332/500
# 2/2 - 0s - loss: 0.0901 - accuracy: 1.0000 - val_loss: 0.9468 - val_accuracy: 0.5833 - 63ms/epoch - 31ms/step
# Epoch 333/500
# 2/2 - 0s - loss: 0.0807 - accuracy: 1.0000 - val_loss: 0.9630 - val_accuracy: 0.5833 - 66ms/epoch - 33ms/step
# Epoch 334/500
# 2/2 - 0s - loss: 0.2110 - accuracy: 0.8929 - val_loss: 1.0271 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 335/500
# 2/2 - 0s - loss: 0.0792 - accuracy: 1.0000 - val_loss: 1.0625 - val_accuracy: 0.5833 - 51ms/epoch - 26ms/step
# Epoch 336/500
# 2/2 - 0s - loss: 0.0864 - accuracy: 1.0000 - val_loss: 1.0865 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 337/500
# 2/2 - 0s - loss: 0.0891 - accuracy: 1.0000 - val_loss: 1.0777 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 338/500
# 2/2 - 0s - loss: 0.0921 - accuracy: 1.0000 - val_loss: 1.0499 - val_accuracy: 0.5833 - 43ms/epoch - 21ms/step
# Epoch 339/500
# 2/2 - 0s - loss: 0.1161 - accuracy: 0.9643 - val_loss: 1.0426 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 340/500
# 2/2 - 0s - loss: 0.0867 - accuracy: 1.0000 - val_loss: 1.0569 - val_accuracy: 0.5833 - 55ms/epoch - 28ms/step
# Epoch 341/500
# 2/2 - 0s - loss: 0.0971 - accuracy: 1.0000 - val_loss: 1.0837 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 342/500
# 2/2 - 0s - loss: 0.0855 - accuracy: 1.0000 - val_loss: 1.1201 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 343/500
# 2/2 - 0s - loss: 0.0621 - accuracy: 1.0000 - val_loss: 1.1278 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 344/500
# 2/2 - 0s - loss: 0.0878 - accuracy: 1.0000 - val_loss: 1.1123 - val_accuracy: 0.5833 - 57ms/epoch - 29ms/step
# Epoch 345/500
# 2/2 - 0s - loss: 0.0853 - accuracy: 1.0000 - val_loss: 1.0572 - val_accuracy: 0.5833 - 41ms/epoch - 21ms/step
# Epoch 346/500
# 2/2 - 0s - loss: 0.0923 - accuracy: 1.0000 - val_loss: 0.9960 - val_accuracy: 0.5000 - 41ms/epoch - 21ms/step
# Epoch 347/500
# 2/2 - 0s - loss: 0.0822 - accuracy: 1.0000 - val_loss: 0.9686 - val_accuracy: 0.5000 - 41ms/epoch - 20ms/step
# Epoch 348/500
# 2/2 - 0s - loss: 0.0865 - accuracy: 1.0000 - val_loss: 0.9692 - val_accuracy: 0.5000 - 62ms/epoch - 31ms/step
# Epoch 349/500
# 2/2 - 0s - loss: 0.0859 - accuracy: 1.0000 - val_loss: 0.9879 - val_accuracy: 0.5000 - 58ms/epoch - 29ms/step
# Epoch 350/500
# 2/2 - 0s - loss: 0.0876 - accuracy: 1.0000 - val_loss: 0.9967 - val_accuracy: 0.5000 - 66ms/epoch - 33ms/step
# Epoch 351/500
# 2/2 - 0s - loss: 0.0810 - accuracy: 1.0000 - val_loss: 1.0096 - val_accuracy: 0.5833 - 58ms/epoch - 29ms/step
# Epoch 352/500
# 2/2 - 0s - loss: 0.0652 - accuracy: 1.0000 - val_loss: 1.0149 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 353/500
# 2/2 - 0s - loss: 0.0829 - accuracy: 1.0000 - val_loss: 1.0152 - val_accuracy: 0.5833 - 75ms/epoch - 37ms/step
# Epoch 354/500
# 2/2 - 0s - loss: 0.0774 - accuracy: 1.0000 - val_loss: 1.0013 - val_accuracy: 0.5833 - 39ms/epoch - 20ms/step
# Epoch 355/500
# 2/2 - 0s - loss: 0.0608 - accuracy: 1.0000 - val_loss: 0.9945 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 356/500
# 2/2 - 0s - loss: 0.0760 - accuracy: 1.0000 - val_loss: 0.9802 - val_accuracy: 0.5833 - 39ms/epoch - 19ms/step
# Epoch 357/500
# 2/2 - 0s - loss: 0.0806 - accuracy: 1.0000 - val_loss: 0.9689 - val_accuracy: 0.5833 - 57ms/epoch - 29ms/step
# Epoch 358/500
# 2/2 - 0s - loss: 0.0847 - accuracy: 1.0000 - val_loss: 0.9682 - val_accuracy: 0.5833 - 48ms/epoch - 24ms/step
# Epoch 359/500
# 2/2 - 0s - loss: 0.0717 - accuracy: 1.0000 - val_loss: 0.9609 - val_accuracy: 0.5000 - 39ms/epoch - 20ms/step
# Epoch 360/500
# 2/2 - 0s - loss: 0.0641 - accuracy: 1.0000 - val_loss: 0.9583 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 361/500
# 2/2 - 0s - loss: 0.0808 - accuracy: 1.0000 - val_loss: 0.9806 - val_accuracy: 0.5000 - 44ms/epoch - 22ms/step
# Epoch 362/500
# 2/2 - 0s - loss: 0.0698 - accuracy: 1.0000 - val_loss: 0.9997 - val_accuracy: 0.5833 - 42ms/epoch - 21ms/step
# Epoch 363/500
# 2/2 - 0s - loss: 0.0659 - accuracy: 1.0000 - val_loss: 1.0221 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 364/500
# 2/2 - 0s - loss: 0.0922 - accuracy: 1.0000 - val_loss: 1.0451 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 365/500
# 2/2 - 0s - loss: 0.0754 - accuracy: 1.0000 - val_loss: 1.0611 - val_accuracy: 0.5000 - 58ms/epoch - 29ms/step
# Epoch 366/500
# 2/2 - 0s - loss: 0.0891 - accuracy: 1.0000 - val_loss: 1.0612 - val_accuracy: 0.5000 - 56ms/epoch - 28ms/step
# Epoch 367/500
# 2/2 - 0s - loss: 0.0817 - accuracy: 1.0000 - val_loss: 1.0307 - val_accuracy: 0.5833 - 38ms/epoch - 19ms/step
# Epoch 368/500
# 2/2 - 0s - loss: 0.0759 - accuracy: 1.0000 - val_loss: 1.0011 - val_accuracy: 0.5833 - 46ms/epoch - 23ms/step
# Epoch 369/500
# 2/2 - 0s - loss: 0.0827 - accuracy: 1.0000 - val_loss: 0.9668 - val_accuracy: 0.5833 - 41ms/epoch - 21ms/step
# Epoch 370/500
# 2/2 - 0s - loss: 0.0683 - accuracy: 1.0000 - val_loss: 0.9433 - val_accuracy: 0.5000 - 39ms/epoch - 20ms/step
# Epoch 371/500
# 2/2 - 0s - loss: 0.0779 - accuracy: 1.0000 - val_loss: 0.9391 - val_accuracy: 0.5000 - 38ms/epoch - 19ms/step
# Epoch 372/500
# 2/2 - 0s - loss: 0.0751 - accuracy: 1.0000 - val_loss: 0.9390 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 373/500
# 2/2 - 0s - loss: 0.0667 - accuracy: 1.0000 - val_loss: 0.9426 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 374/500
# 2/2 - 0s - loss: 0.0620 - accuracy: 1.0000 - val_loss: 0.9639 - val_accuracy: 0.5000 - 62ms/epoch - 31ms/step
# Epoch 375/500
# 2/2 - 0s - loss: 0.0656 - accuracy: 1.0000 - val_loss: 0.9795 - val_accuracy: 0.5000 - 41ms/epoch - 21ms/step
# Epoch 376/500
# 2/2 - 0s - loss: 0.0764 - accuracy: 1.0000 - val_loss: 0.9895 - val_accuracy: 0.5000 - 46ms/epoch - 23ms/step
# Epoch 377/500
# 2/2 - 0s - loss: 0.0786 - accuracy: 1.0000 - val_loss: 0.9848 - val_accuracy: 0.5000 - 58ms/epoch - 29ms/step
# Epoch 378/500
# 2/2 - 0s - loss: 0.0632 - accuracy: 1.0000 - val_loss: 0.9709 - val_accuracy: 0.5000 - 44ms/epoch - 22ms/step
# Epoch 379/500
# 2/2 - 0s - loss: 0.0674 - accuracy: 1.0000 - val_loss: 0.9596 - val_accuracy: 0.5000 - 38ms/epoch - 19ms/step
# Epoch 380/500
# 2/2 - 0s - loss: 0.0567 - accuracy: 1.0000 - val_loss: 0.9489 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 381/500
# 2/2 - 0s - loss: 0.0539 - accuracy: 1.0000 - val_loss: 0.9466 - val_accuracy: 0.5000 - 57ms/epoch - 29ms/step
# Epoch 382/500
# 2/2 - 0s - loss: 0.0905 - accuracy: 1.0000 - val_loss: 0.9530 - val_accuracy: 0.5000 - 56ms/epoch - 28ms/step
# Epoch 383/500
# 2/2 - 0s - loss: 0.0605 - accuracy: 1.0000 - val_loss: 0.9649 - val_accuracy: 0.5000 - 57ms/epoch - 29ms/step
# Epoch 384/500
# 2/2 - 0s - loss: 0.0610 - accuracy: 1.0000 - val_loss: 0.9842 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 385/500
# 2/2 - 0s - loss: 0.0568 - accuracy: 1.0000 - val_loss: 1.0013 - val_accuracy: 0.5833 - 43ms/epoch - 21ms/step
# Epoch 386/500
# 2/2 - 0s - loss: 0.0702 - accuracy: 1.0000 - val_loss: 1.0525 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 387/500
# 2/2 - 0s - loss: 0.0673 - accuracy: 1.0000 - val_loss: 1.0963 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 388/500
# ...
# Epoch 379/500
# 2/2 - 0s - loss: 0.0479 - accuracy: 1.0000 - val_loss: 1.9090 - val_accuracy: 0.2500 - 57ms/epoch - 29ms/step
# Epoch 380/500
# 2/2 - 0s - loss: 0.0583 - accuracy: 1.0000 - val_loss: 1.9086 - val_accuracy: 0.2500 - 40ms/epoch - 20ms/step
# Epoch 381/500
# 2/2 - 0s - loss: 0.0549 - accuracy: 1.0000 - val_loss: 1.9044 - val_accuracy: 0.2500 - 68ms/epoch - 34ms/step
# Epoch 382/500
# 2/2 - 0s - loss: 0.0550 - accuracy: 1.0000 - val_loss: 1.8923 - val_accuracy: 0.2500 - 40ms/epoch - 20ms/step
# Epoch 383/500
# 2/2 - 0s - loss: 0.0424 - accuracy: 1.0000 - val_loss: 1.8875 - val_accuracy: 0.2500 - 40ms/epoch - 20ms/step
# Epoch 384/500
# 2/2 - 0s - loss: 0.0589 - accuracy: 1.0000 - val_loss: 1.8784 - val_accuracy: 0.2500 - 41ms/epoch - 20ms/step
# Epoch 385/500
# 2/2 - 0s - loss: 0.0573 - accuracy: 1.0000 - val_loss: 1.8789 - val_accuracy: 0.2500 - 45ms/epoch - 23ms/step
# Epoch 386/500
# 2/2 - 0s - loss: 0.0376 - accuracy: 1.0000 - val_loss: 1.8761 - val_accuracy: 0.2500 - 42ms/epoch - 21ms/step
# Epoch 387/500
# 2/2 - 0s - loss: 0.0507 - accuracy: 1.0000 - val_loss: 1.8751 - val_accuracy: 0.2500 - 47ms/epoch - 24ms/step
# Epoch 388/500
# 2/2 - 0s - loss: 0.0386 - accuracy: 1.0000 - val_loss: 1.8810 - val_accuracy: 0.2500 - 61ms/epoch - 31ms/step
# Epoch 389/500
# 2/2 - 0s - loss: 0.0565 - accuracy: 1.0000 - val_loss: 1.8933 - val_accuracy: 0.2500 - 41ms/epoch - 21ms/step
# Epoch 390/500
# 2/2 - 0s - loss: 0.0462 - accuracy: 1.0000 - val_loss: 1.9042 - val_accuracy: 0.2500 - 42ms/epoch - 21ms/step
# Epoch 391/500
# 2/2 - 0s - loss: 0.1265 - accuracy: 0.9643 - val_loss: 1.9217 - val_accuracy: 0.2500 - 45ms/epoch - 22ms/step
# Epoch 392/500
# 2/2 - 0s - loss: 0.0474 - accuracy: 1.0000 - val_loss: 1.9266 - val_accuracy: 0.2500 - 61ms/epoch - 31ms/step
# Epoch 393/500
# 2/2 - 0s - loss: 0.0457 - accuracy: 1.0000 - val_loss: 1.9330 - val_accuracy: 0.2500 - 47ms/epoch - 23ms/step
# Epoch 394/500
# 2/2 - 0s - loss: 0.0540 - accuracy: 1.0000 - val_loss: 1.9338 - val_accuracy: 0.2500 - 42ms/epoch - 21ms/step
# Epoch 395/500
# 2/2 - 0s - loss: 0.0674 - accuracy: 1.0000 - val_loss: 1.9235 - val_accuracy: 0.2500 - 45ms/epoch - 22ms/step
# Epoch 396/500
# 2/2 - 0s - loss: 0.0488 - accuracy: 1.0000 - val_loss: 1.9175 - val_accuracy: 0.2500 - 39ms/epoch - 19ms/step
# Epoch 397/500
# 2/2 - 0s - loss: 0.0646 - accuracy: 1.0000 - val_loss: 1.9173 - val_accuracy: 0.2500 - 41ms/epoch - 20ms/step
# Epoch 398/500
# 2/2 - 0s - loss: 0.0691 - accuracy: 1.0000 - val_loss: 1.9025 - val_accuracy: 0.2500 - 47ms/epoch - 24ms/step
# Epoch 399/500
# 2/2 - 0s - loss: 0.0483 - accuracy: 1.0000 - val_loss: 1.8948 - val_accuracy: 0.2500 - 46ms/epoch - 23ms/step
# Epoch 400/500
# 2/2 - 0s - loss: 0.0384 - accuracy: 1.0000 - val_loss: 1.8882 - val_accuracy: 0.2500 - 42ms/epoch - 21ms/step
# Epoch 401/500
# 2/2 - 0s - loss: 0.0540 - accuracy: 1.0000 - val_loss: 1.8880 - val_accuracy: 0.2500 - 59ms/epoch - 30ms/step
# Epoch 402/500
# 2/2 - 0s - loss: 0.0536 - accuracy: 1.0000 - val_loss: 1.8867 - val_accuracy: 0.2500 - 41ms/epoch - 20ms/step
# Epoch 403/500
# 2/2 - 0s - loss: 0.0440 - accuracy: 1.0000 - val_loss: 1.8918 - val_accuracy: 0.2500 - 47ms/epoch - 24ms/step
# Epoch 404/500
# 2/2 - 0s - loss: 0.0438 - accuracy: 1.0000 - val_loss: 1.8977 - val_accuracy: 0.2500 - 56ms/epoch - 28ms/step
# Epoch 405/500
# 2/2 - 0s - loss: 0.0568 - accuracy: 1.0000 - val_loss: 1.8978 - val_accuracy: 0.2500 - 43ms/epoch - 21ms/step
# Epoch 406/500
# 2/2 - 0s - loss: 0.0428 - accuracy: 1.0000 - val_loss: 1.9120 - val_accuracy: 0.2500 - 56ms/epoch - 28ms/step
# Epoch 407/500
# 2/2 - 0s - loss: 0.0430 - accuracy: 1.0000 - val_loss: 1.9257 - val_accuracy: 0.2500 - 39ms/epoch - 20ms/step
# Epoch 408/500
# 2/2 - 0s - loss: 0.0471 - accuracy: 1.0000 - val_loss: 1.9445 - val_accuracy: 0.2500 - 41ms/epoch - 21ms/step
# Epoch 409/500
# 2/2 - 0s - loss: 0.0545 - accuracy: 1.0000 - val_loss: 1.9524 - val_accuracy: 0.2500 - 59ms/epoch - 30ms/step
# Epoch 410/500
# 2/2 - 0s - loss: 0.0533 - accuracy: 1.0000 - val_loss: 1.9669 - val_accuracy: 0.2500 - 41ms/epoch - 20ms/step
# Epoch 411/500
# 2/2 - 0s - loss: 0.0435 - accuracy: 1.0000 - val_loss: 1.9687 - val_accuracy: 0.2500 - 48ms/epoch - 24ms/step
# Epoch 412/500
# 2/2 - 0s - loss: 0.0483 - accuracy: 1.0000 - val_loss: 1.9631 - val_accuracy: 0.2500 - 45ms/epoch - 22ms/step
# Epoch 413/500
# 2/2 - 0s - loss: 0.0379 - accuracy: 1.0000 - val_loss: 1.9669 - val_accuracy: 0.2500 - 40ms/epoch - 20ms/step
# Epoch 414/500
# 2/2 - 0s - loss: 0.0930 - accuracy: 1.0000 - val_loss: 1.9784 - val_accuracy: 0.2500 - 58ms/epoch - 29ms/step
# Epoch 415/500
# 2/2 - 0s - loss: 0.0501 - accuracy: 1.0000 - val_loss: 1.9824 - val_accuracy: 0.2500 - 46ms/epoch - 23ms/step
# Epoch 416/500
# 2/2 - 0s - loss: 0.0508 - accuracy: 1.0000 - val_loss: 1.9843 - val_accuracy: 0.2500 - 44ms/epoch - 22ms/step
# Epoch 417/500
# 2/2 - 0s - loss: 0.0455 - accuracy: 1.0000 - val_loss: 1.9847 - val_accuracy: 0.2500 - 42ms/epoch - 21ms/step
# Epoch 418/500
# 2/2 - 0s - loss: 0.0371 - accuracy: 1.0000 - val_loss: 1.9826 - val_accuracy: 0.2500 - 41ms/epoch - 21ms/step
# Epoch 419/500
# 2/2 - 0s - loss: 0.0396 - accuracy: 1.0000 - val_loss: 1.9712 - val_accuracy: 0.2500 - 41ms/epoch - 20ms/step
# Epoch 420/500
# 2/2 - 0s - loss: 0.0401 - accuracy: 1.0000 - val_loss: 1.9634 - val_accuracy: 0.2500 - 49ms/epoch - 24ms/step
# Epoch 421/500
# 2/2 - 0s - loss: 0.0402 - accuracy: 1.0000 - val_loss: 1.9556 - val_accuracy: 0.2500 - 40ms/epoch - 20ms/step
# Epoch 422/500
# 2/2 - 0s - loss: 0.0463 - accuracy: 1.0000 - val_loss: 1.9482 - val_accuracy: 0.2500 - 58ms/epoch - 29ms/step
# Epoch 423/500
# 2/2 - 0s - loss: 0.0564 - accuracy: 1.0000 - val_loss: 1.9468 - val_accuracy: 0.2500 - 49ms/epoch - 24ms/step
# Epoch 424/500
# 2/2 - 0s - loss: 0.0867 - accuracy: 1.0000 - val_loss: 1.9408 - val_accuracy: 0.2500 - 42ms/epoch - 21ms/step
# Epoch 425/500
# 2/2 - 0s - loss: 0.0857 - accuracy: 1.0000 - val_loss: 1.9325 - val_accuracy: 0.2500 - 57ms/epoch - 29ms/step
# Epoch 426/500
# 2/2 - 0s - loss: 0.0524 - accuracy: 1.0000 - val_loss: 1.9228 - val_accuracy: 0.2500 - 42ms/epoch - 21ms/step
# Epoch 427/500
# 2/2 - 0s - loss: 0.0378 - accuracy: 1.0000 - val_loss: 1.9161 - val_accuracy: 0.2500 - 51ms/epoch - 26ms/step
# Epoch 428/500
# 2/2 - 0s - loss: 0.0701 - accuracy: 1.0000 - val_loss: 1.9022 - val_accuracy: 0.2500 - 42ms/epoch - 21ms/step
# Epoch 429/500
# 2/2 - 0s - loss: 0.0508 - accuracy: 1.0000 - val_loss: 1.9013 - val_accuracy: 0.2500 - 59ms/epoch - 30ms/step
# Epoch 430/500
# 2/2 - 0s - loss: 0.0387 - accuracy: 1.0000 - val_loss: 1.9004 - val_accuracy: 0.2500 - 49ms/epoch - 25ms/step
# Epoch 431/500
# 2/2 - 0s - loss: 0.0483 - accuracy: 1.0000 - val_loss: 1.9040 - val_accuracy: 0.2500 - 50ms/epoch - 25ms/step
# Epoch 432/500
# 2/2 - 0s - loss: 0.0371 - accuracy: 1.0000 - val_loss: 1.9060 - val_accuracy: 0.2500 - 44ms/epoch - 22ms/step
# Epoch 433/500
# 2/2 - 0s - loss: 0.0466 - accuracy: 1.0000 - val_loss: 1.9100 - val_accuracy: 0.2500 - 43ms/epoch - 22ms/step
# Epoch 434/500
# 2/2 - 0s - loss: 0.0565 - accuracy: 1.0000 - val_loss: 1.9214 - val_accuracy: 0.2500 - 42ms/epoch - 21ms/step
# Epoch 435/500
# 2/2 - 0s - loss: 0.0401 - accuracy: 1.0000 - val_loss: 1.9252 - val_accuracy: 0.2500 - 57ms/epoch - 29ms/step
# Epoch 436/500
# 2/2 - 0s - loss: 0.0389 - accuracy: 1.0000 - val_loss: 1.9273 - val_accuracy: 0.2500 - 45ms/epoch - 22ms/step
# Epoch 437/500
# 2/2 - 0s - loss: 0.0689 - accuracy: 1.0000 - val_loss: 1.9227 - val_accuracy: 0.2500 - 49ms/epoch - 25ms/step
# Epoch 438/500
# 2/2 - 0s - loss: 0.0425 - accuracy: 1.0000 - val_loss: 1.9261 - val_accuracy: 0.2500 - 44ms/epoch - 22ms/step
# Epoch 439/500
# 2/2 - 0s - loss: 0.0361 - accuracy: 1.0000 - val_loss: 1.9284 - val_accuracy: 0.2500 - 45ms/epoch - 23ms/step
# Epoch 440/500
# 2/2 - 0s - loss: 0.0391 - accuracy: 1.0000 - val_loss: 1.9324 - val_accuracy: 0.2500 - 48ms/epoch - 24ms/step
# Epoch 441/500
# 2/2 - 0s - loss: 0.0425 - accuracy: 1.0000 - val_loss: 1.9314 - val_accuracy: 0.2500 - 42ms/epoch - 21ms/step
# Epoch 442/500
# 2/2 - 0s - loss: 0.0404 - accuracy: 1.0000 - val_loss: 1.9340 - val_accuracy: 0.2500 - 59ms/epoch - 29ms/step
# Epoch 443/500
# 2/2 - 0s - loss: 0.0498 - accuracy: 1.0000 - val_loss: 1.9372 - val_accuracy: 0.2500 - 53ms/epoch - 26ms/step
# Epoch 444/500
# 2/2 - 0s - loss: 0.0397 - accuracy: 1.0000 - val_loss: 1.9402 - val_accuracy: 0.2500 - 45ms/epoch - 23ms/step
# Epoch 445/500
# 2/2 - 0s - loss: 0.0520 - accuracy: 1.0000 - val_loss: 1.9415 - val_accuracy: 0.2500 - 47ms/epoch - 24ms/step
# Epoch 446/500
# 2/2 - 0s - loss: 0.0411 - accuracy: 1.0000 - val_loss: 1.9440 - val_accuracy: 0.1667 - 60ms/epoch - 30ms/step
# Epoch 447/500
# 2/2 - 0s - loss: 0.0469 - accuracy: 1.0000 - val_loss: 1.9455 - val_accuracy: 0.1667 - 61ms/epoch - 31ms/step
# Epoch 448/500
# 2/2 - 0s - loss: 0.0441 - accuracy: 1.0000 - val_loss: 1.9485 - val_accuracy: 0.1667 - 68ms/epoch - 34ms/step
# Epoch 449/500
# 2/2 - 0s - loss: 0.0400 - accuracy: 1.0000 - val_loss: 1.9415 - val_accuracy: 0.2500 - 64ms/epoch - 32ms/step
# Epoch 450/500
# 2/2 - 0s - loss: 0.0417 - accuracy: 1.0000 - val_loss: 1.9381 - val_accuracy: 0.2500 - 58ms/epoch - 29ms/step
# Epoch 451/500
# 2/2 - 0s - loss: 0.0437 - accuracy: 1.0000 - val_loss: 1.9435 - val_accuracy: 0.2500 - 51ms/epoch - 26ms/step
# Epoch 452/500
# 2/2 - 0s - loss: 0.0450 - accuracy: 1.0000 - val_loss: 1.9424 - val_accuracy: 0.2500 - 61ms/epoch - 31ms/step
# Epoch 453/500
# 2/2 - 0s - loss: 0.0453 - accuracy: 1.0000 - val_loss: 1.9486 - val_accuracy: 0.2500 - 61ms/epoch - 31ms/step
# Epoch 454/500
# 2/2 - 0s - loss: 0.0639 - accuracy: 1.0000 - val_loss: 1.9578 - val_accuracy: 0.2500 - 45ms/epoch - 22ms/step
# Epoch 455/500
# 2/2 - 0s - loss: 0.0410 - accuracy: 1.0000 - val_loss: 1.9669 - val_accuracy: 0.1667 - 44ms/epoch - 22ms/step
# Epoch 456/500
# 2/2 - 0s - loss: 0.0425 - accuracy: 1.0000 - val_loss: 1.9659 - val_accuracy: 0.1667 - 58ms/epoch - 29ms/step
# Epoch 457/500
# 2/2 - 0s - loss: 0.0605 - accuracy: 1.0000 - val_loss: 1.9719 - val_accuracy: 0.1667 - 45ms/epoch - 22ms/step
# Epoch 458/500
# 2/2 - 0s - loss: 0.0375 - accuracy: 1.0000 - val_loss: 1.9711 - val_accuracy: 0.1667 - 47ms/epoch - 24ms/step
# Epoch 459/500
# 2/2 - 0s - loss: 0.0407 - accuracy: 1.0000 - val_loss: 1.9686 - val_accuracy: 0.1667 - 43ms/epoch - 21ms/step
# Epoch 460/500
# 2/2 - 0s - loss: 0.0531 - accuracy: 1.0000 - val_loss: 1.9715 - val_accuracy: 0.1667 - 48ms/epoch - 24ms/step
# Epoch 461/500
# 2/2 - 0s - loss: 0.0644 - accuracy: 1.0000 - val_loss: 1.9656 - val_accuracy: 0.2500 - 58ms/epoch - 29ms/step
# Epoch 462/500
# 2/2 - 0s - loss: 0.0339 - accuracy: 1.0000 - val_loss: 1.9610 - val_accuracy: 0.2500 - 43ms/epoch - 22ms/step
# Epoch 463/500
# 2/2 - 0s - loss: 0.0431 - accuracy: 1.0000 - val_loss: 1.9612 - val_accuracy: 0.2500 - 44ms/epoch - 22ms/step
# Epoch 464/500
# 2/2 - 0s - loss: 0.0474 - accuracy: 1.0000 - val_loss: 1.9528 - val_accuracy: 0.2500 - 47ms/epoch - 24ms/step
# Epoch 465/500
# 2/2 - 0s - loss: 0.0498 - accuracy: 1.0000 - val_loss: 1.9635 - val_accuracy: 0.2500 - 66ms/epoch - 33ms/step
# Epoch 466/500
# 2/2 - 0s - loss: 0.0405 - accuracy: 1.0000 - val_loss: 1.9658 - val_accuracy: 0.2500 - 64ms/epoch - 32ms/step
# Epoch 467/500
# 2/2 - 0s - loss: 0.0394 - accuracy: 1.0000 - val_loss: 1.9628 - val_accuracy: 0.2500 - 65ms/epoch - 32ms/step
# Epoch 468/500
# 2/2 - 0s - loss: 0.0592 - accuracy: 1.0000 - val_loss: 1.9682 - val_accuracy: 0.2500 - 58ms/epoch - 29ms/step
# Epoch 469/500
# 2/2 - 0s - loss: 0.0447 - accuracy: 1.0000 - val_loss: 1.9835 - val_accuracy: 0.1667 - 46ms/epoch - 23ms/step
# Epoch 470/500
# 2/2 - 0s - loss: 0.0469 - accuracy: 1.0000 - val_loss: 1.9882 - val_accuracy: 0.2500 - 66ms/epoch - 33ms/step
# Epoch 471/500
# 2/2 - 0s - loss: 0.0371 - accuracy: 1.0000 - val_loss: 1.9995 - val_accuracy: 0.2500 - 61ms/epoch - 31ms/step
# Epoch 472/500
# 2/2 - 0s - loss: 0.0508 - accuracy: 1.0000 - val_loss: 2.0047 - val_accuracy: 0.2500 - 59ms/epoch - 29ms/step
# Epoch 473/500
# 2/2 - 0s - loss: 0.0627 - accuracy: 1.0000 - val_loss: 2.0035 - val_accuracy: 0.2500 - 50ms/epoch - 25ms/step
# Epoch 474/500
# 2/2 - 0s - loss: 0.0417 - accuracy: 1.0000 - val_loss: 2.0024 - val_accuracy: 0.2500 - 60ms/epoch - 30ms/step
# Epoch 475/500
# 2/2 - 0s - loss: 0.0420 - accuracy: 1.0000 - val_loss: 2.0032 - val_accuracy: 0.2500 - 49ms/epoch - 24ms/step
# Epoch 476/500
# 2/2 - 0s - loss: 0.0433 - accuracy: 1.0000 - val_loss: 1.9991 - val_accuracy: 0.2500 - 61ms/epoch - 31ms/step
# Epoch 477/500
# 2/2 - 0s - loss: 0.0456 - accuracy: 1.0000 - val_loss: 1.9867 - val_accuracy: 0.2500 - 46ms/epoch - 23ms/step
# Epoch 478/500
# 2/2 - 0s - loss: 0.0389 - accuracy: 1.0000 - val_loss: 1.9848 - val_accuracy: 0.2500 - 42ms/epoch - 21ms/step
# Epoch 479/500
# 2/2 - 0s - loss: 0.0693 - accuracy: 1.0000 - val_loss: 1.9918 - val_accuracy: 0.2500 - 46ms/epoch - 23ms/step
# Epoch 480/500
# 2/2 - 0s - loss: 0.0550 - accuracy: 1.0000 - val_loss: 1.9850 - val_accuracy: 0.2500 - 41ms/epoch - 21ms/step
# Epoch 481/500
# 2/2 - 0s - loss: 0.0318 - accuracy: 1.0000 - val_loss: 1.9871 - val_accuracy: 0.2500 - 43ms/epoch - 22ms/step
# Epoch 482/500
# 2/2 - 0s - loss: 0.0744 - accuracy: 1.0000 - val_loss: 1.9970 - val_accuracy: 0.2500 - 65ms/epoch - 32ms/step
# Epoch 483/500
# 2/2 - 0s - loss: 0.0677 - accuracy: 1.0000 - val_loss: 1.9993 - val_accuracy: 0.2500 - 65ms/epoch - 32ms/step
# Epoch 484/500
# 2/2 - 0s - loss: 0.0310 - accuracy: 1.0000 - val_loss: 1.9930 - val_accuracy: 0.2500 - 58ms/epoch - 29ms/step
# Epoch 485/500
# 2/2 - 0s - loss: 0.0507 - accuracy: 1.0000 - val_loss: 1.9938 - val_accuracy: 0.2500 - 41ms/epoch - 21ms/step
# Epoch 486/500
# 2/2 - 0s - loss: 0.0727 - accuracy: 1.0000 - val_loss: 2.0048 - val_accuracy: 0.1667 - 59ms/epoch - 30ms/step
# Epoch 487/500
# 2/2 - 0s - loss: 0.0476 - accuracy: 1.0000 - val_loss: 1.9994 - val_accuracy: 0.1667 - 44ms/epoch - 22ms/step
# Epoch 488/500
# 2/2 - 0s - loss: 0.0393 - accuracy: 1.0000 - val_loss: 1.9958 - val_accuracy: 0.1667 - 43ms/epoch - 22ms/step
# Epoch 489/500
# 2/2 - 0s - loss: 0.0516 - accuracy: 1.0000 - val_loss: 1.9864 - val_accuracy: 0.1667 - 42ms/epoch - 21ms/step
# Epoch 490/500
# 2/2 - 0s - loss: 0.0517 - accuracy: 1.0000 - val_loss: 1.9784 - val_accuracy: 0.2500 - 63ms/epoch - 32ms/step
# Epoch 491/500
# 2/2 - 0s - loss: 0.0378 - accuracy: 1.0000 - val_loss: 1.9826 - val_accuracy: 0.2500 - 61ms/epoch - 31ms/step
# Epoch 492/500
# 2/2 - 0s - loss: 0.0627 - accuracy: 1.0000 - val_loss: 1.9755 - val_accuracy: 0.2500 - 66ms/epoch - 33ms/step
# Epoch 493/500
# 2/2 - 0s - loss: 0.0470 - accuracy: 1.0000 - val_loss: 1.9694 - val_accuracy: 0.2500 - 57ms/epoch - 29ms/step
# Epoch 494/500
# 2/2 - 0s - loss: 0.0611 - accuracy: 1.0000 - val_loss: 1.9619 - val_accuracy: 0.2500 - 60ms/epoch - 30ms/step
# Epoch 495/500
# 2/2 - 0s - loss: 0.0437 - accuracy: 1.0000 - val_loss: 1.9638 - val_accuracy: 0.2500 - 67ms/epoch - 33ms/step
# Epoch 496/500
# 2/2 - 0s - loss: 0.0451 - accuracy: 1.0000 - val_loss: 1.9685 - val_accuracy: 0.2500 - 69ms/epoch - 35ms/step
# Epoch 497/500
# 2/2 - 0s - loss: 0.0452 - accuracy: 1.0000 - val_loss: 1.9767 - val_accuracy: 0.2500 - 84ms/epoch - 42ms/step
# Epoch 498/500
# 2/2 - 0s - loss: 0.0448 - accuracy: 1.0000 - val_loss: 1.9807 - val_accuracy: 0.2500 - 70ms/epoch - 35ms/step
# Epoch 499/500
# 2/2 - 0s - loss: 0.0359 - accuracy: 1.0000 - val_loss: 1.9762 - val_accuracy: 0.2500 - 70ms/epoch - 35ms/step
# Epoch 500/500
# 2/2 - 0s - loss: 0.0354 - accuracy: 1.0000 - val_loss: 1.9768 - val_accuracy: 0.2500 - 73ms/epoch - 37ms/step
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f4fd2190d30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 113ms/step
# Shallow Conv Net Accuracy Metrics
# Accuracy: 0.25
# F1 Score: 0.18181818181818182

# %% [markdown]
# ## Beta Classifier

# %%
import tensorflow as tf
# from arl_eegmodels.EEGModels import EEGNet, DeepConvNet, ShallowConvNet
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# To be used for training the model on the opensource dataset

# Train data - 70% of opensource dataset
# Validation data - 30% of opensource dataset
# Test data - data collected from EEG


# Define initial model parameters
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy()
optimizer = 'adam'
metrics = ['accuracy']
epochs = 500
channels = num_desired_channels
classes = 2
dropout = 0.25
F1 = 8
F2 = 16
samples = 60

# EEGNet Implementation
model = EEGNet(nb_classes=classes, Chans=num_desired_channels, Samples=samples, dropoutRate=dropout, F1=F1, F2=F2)
model.compile(loss=loss_fn, optimizer=optimizer, metrics=metrics)
# eeg_net_checkpoint = ModelCheckpoint(filepath='/trained_models/eeg_net_checkpoint.h5', verbose=1, save_best_only=True)

# Fit and train the model
eegnet_history = model.fit(
    beta_x_train, beta_y_train, batch_size=16, epochs=epochs, verbose=2, validation_data=(beta_x_test, beta_y_test)
)

# Evaluate accuracy on test data
probabilities = model.predict(beta_x_test)
predictions = probabilities.argmax(axis=-1)

accuracy = accuracy_score(beta_y_test, predictions)
conf_matrix = confusion_matrix(beta_y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)
f1 = f1_score(beta_y_test, predictions)
# roc_auc = roc_auc_score(y_test, probabilities)


print('EEGNet Accuracy Metrics')
print(f'Accuracy: {accuracy}')
print(f'F1 Score: {f1}')
# print(confusion_matrix)
disp.plot()
plt.show()
# print(f'AUC Score: {roc_auc}')

# EEGNet Accuracy Plot
plt.plot(eegnet_history.history['accuracy'])
plt.plot(eegnet_history.history['val_accuracy'])
plt.title('EEGNet Accuracy During Training')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()

# EEGNet Loss Plot
plt.plot(eegnet_history.history['loss'])
plt.plot(eegnet_history.history['val_loss'])
plt.title('EEGNet Loss During Training')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()


# ShallowConvNet Implementation
shallow_conv_net_model = ShallowConvNet(nb_classes=classes, Chans=num_desired_channels, Samples=samples, dropoutRate=dropout)
shallow_conv_net_model.compile(loss=loss_fn, optimizer=optimizer, metrics=metrics)
# shallow_conv_net_checkpoint = ModelCheckpoint(
#     filepath='/trained_models/shallow_conv_net_checkpoint.h5', verbose=1, save_best_only=True
# )

# Fit and train the model
shallowconvnet_history = shallow_conv_net_model.fit(
    beta_x_train, beta_y_train, batch_size=16, epochs=epochs, verbose=2, validation_data=(beta_x_test, beta_y_test)
)

# Evaluate accuracy on test data
probabilities = shallow_conv_net_model.predict(beta_x_test)
predictions = probabilities.argmax(axis=-1)

accuracy = accuracy_score(beta_y_test, predictions)
conf_matrix = confusion_matrix(beta_y_test, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)
f1 = f1_score(beta_y_test, predictions)
# roc_auc = roc_auc_score(y_test, probabilities)


print('Shallow Conv Net Accuracy Metrics')
print(f'Accuracy: {accuracy}')
print(f'F1 Score: {f1}')
# print(confusion_matrix)
disp.plot()
plt.show()
# print(f'AUC Score: {roc_auc}')

# ShallowConvNet Accuracy Plot
plt.plot(shallowconvnet_history.history['accuracy'])
plt.plot(shallowconvnet_history.history['val_accuracy'])
plt.title('ShallowConvNet Accuracy During Training')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()

# ShallowConvNet Loss Plot
plt.plot(shallowconvnet_history.history['loss'])
plt.plot(shallowconvnet_history.history['val_loss'])
plt.title('ShallowConvNet Loss During Training')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'])
plt.show()
# Out:
# Epoch 1/500
# 2/2 - 3s - loss: 0.7366 - accuracy: 0.5000 - val_loss: 0.7311 - val_accuracy: 0.4167 - 3s/epoch - 2s/step
# Epoch 2/500
# 2/2 - 0s - loss: 0.6939 - accuracy: 0.6071 - val_loss: 0.7042 - val_accuracy: 0.4167 - 42ms/epoch - 21ms/step
# Epoch 3/500
# 2/2 - 0s - loss: 0.6958 - accuracy: 0.4286 - val_loss: 0.6949 - val_accuracy: 0.5000 - 57ms/epoch - 29ms/step
# Epoch 4/500
# 2/2 - 0s - loss: 0.6789 - accuracy: 0.6429 - val_loss: 0.6903 - val_accuracy: 0.5833 - 59ms/epoch - 30ms/step
# Epoch 5/500
# 2/2 - 0s - loss: 0.6784 - accuracy: 0.6786 - val_loss: 0.6870 - val_accuracy: 0.5833 - 68ms/epoch - 34ms/step
# Epoch 6/500
# 2/2 - 0s - loss: 0.6908 - accuracy: 0.5357 - val_loss: 0.6844 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 7/500
# 2/2 - 0s - loss: 0.6800 - accuracy: 0.5714 - val_loss: 0.6831 - val_accuracy: 0.5833 - 55ms/epoch - 27ms/step
# Epoch 8/500
# 2/2 - 0s - loss: 0.6878 - accuracy: 0.6071 - val_loss: 0.6820 - val_accuracy: 0.5833 - 44ms/epoch - 22ms/step
# Epoch 9/500
# 2/2 - 0s - loss: 0.6742 - accuracy: 0.6429 - val_loss: 0.6815 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 10/500
# 2/2 - 0s - loss: 0.6682 - accuracy: 0.7143 - val_loss: 0.6811 - val_accuracy: 0.5833 - 38ms/epoch - 19ms/step
# Epoch 11/500
# 2/2 - 0s - loss: 0.6735 - accuracy: 0.6071 - val_loss: 0.6803 - val_accuracy: 0.5833 - 38ms/epoch - 19ms/step
# Epoch 12/500
# 2/2 - 0s - loss: 0.6609 - accuracy: 0.7857 - val_loss: 0.6796 - val_accuracy: 0.5000 - 42ms/epoch - 21ms/step
# Epoch 13/500
# 2/2 - 0s - loss: 0.6663 - accuracy: 0.6786 - val_loss: 0.6788 - val_accuracy: 0.5000 - 39ms/epoch - 19ms/step
# Epoch 14/500
# 2/2 - 0s - loss: 0.6721 - accuracy: 0.5357 - val_loss: 0.6779 - val_accuracy: 0.5000 - 55ms/epoch - 28ms/step
# Epoch 15/500
# 2/2 - 0s - loss: 0.6510 - accuracy: 0.7143 - val_loss: 0.6769 - val_accuracy: 0.5000 - 38ms/epoch - 19ms/step
# Epoch 16/500
# 2/2 - 0s - loss: 0.6462 - accuracy: 0.6786 - val_loss: 0.6764 - val_accuracy: 0.5000 - 43ms/epoch - 21ms/step
# Epoch 17/500
# 2/2 - 0s - loss: 0.6508 - accuracy: 0.7500 - val_loss: 0.6756 - val_accuracy: 0.5000 - 57ms/epoch - 28ms/step
# Epoch 18/500
# 2/2 - 0s - loss: 0.6543 - accuracy: 0.7143 - val_loss: 0.6746 - val_accuracy: 0.5000 - 39ms/epoch - 20ms/step
# Epoch 19/500
# 2/2 - 0s - loss: 0.6529 - accuracy: 0.6071 - val_loss: 0.6740 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 20/500
# 2/2 - 0s - loss: 0.6361 - accuracy: 0.7500 - val_loss: 0.6732 - val_accuracy: 0.5000 - 50ms/epoch - 25ms/step
# Epoch 21/500
# 2/2 - 0s - loss: 0.6376 - accuracy: 0.6786 - val_loss: 0.6724 - val_accuracy: 0.5000 - 43ms/epoch - 22ms/step
# Epoch 22/500
# 2/2 - 0s - loss: 0.6347 - accuracy: 0.6786 - val_loss: 0.6719 - val_accuracy: 0.5000 - 39ms/epoch - 19ms/step
# Epoch 23/500
# 2/2 - 0s - loss: 0.6467 - accuracy: 0.6786 - val_loss: 0.6717 - val_accuracy: 0.5833 - 38ms/epoch - 19ms/step
# Epoch 24/500
# 2/2 - 0s - loss: 0.6281 - accuracy: 0.7857 - val_loss: 0.6712 - val_accuracy: 0.5000 - 39ms/epoch - 19ms/step
# Epoch 25/500
# 2/2 - 0s - loss: 0.6224 - accuracy: 0.7500 - val_loss: 0.6712 - val_accuracy: 0.5000 - 53ms/epoch - 27ms/step
# Epoch 26/500
# 2/2 - 0s - loss: 0.6094 - accuracy: 0.6786 - val_loss: 0.6715 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 27/500
# 2/2 - 0s - loss: 0.6045 - accuracy: 0.7500 - val_loss: 0.6708 - val_accuracy: 0.5000 - 56ms/epoch - 28ms/step
# Epoch 28/500
# 2/2 - 0s - loss: 0.6212 - accuracy: 0.7143 - val_loss: 0.6696 - val_accuracy: 0.5000 - 39ms/epoch - 20ms/step
# Epoch 29/500
# 2/2 - 0s - loss: 0.6208 - accuracy: 0.6071 - val_loss: 0.6693 - val_accuracy: 0.5000 - 56ms/epoch - 28ms/step
# Epoch 30/500
# 2/2 - 0s - loss: 0.5770 - accuracy: 0.7857 - val_loss: 0.6691 - val_accuracy: 0.5000 - 58ms/epoch - 29ms/step
# Epoch 31/500
# 2/2 - 0s - loss: 0.6018 - accuracy: 0.7857 - val_loss: 0.6687 - val_accuracy: 0.5000 - 58ms/epoch - 29ms/step
# Epoch 32/500
# 2/2 - 0s - loss: 0.5866 - accuracy: 0.7500 - val_loss: 0.6677 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 33/500
# 2/2 - 0s - loss: 0.5796 - accuracy: 0.7500 - val_loss: 0.6662 - val_accuracy: 0.5000 - 47ms/epoch - 24ms/step
# Epoch 34/500
# 2/2 - 0s - loss: 0.5519 - accuracy: 0.8929 - val_loss: 0.6649 - val_accuracy: 0.5000 - 39ms/epoch - 19ms/step
# Epoch 35/500
# 2/2 - 0s - loss: 0.5995 - accuracy: 0.7500 - val_loss: 0.6627 - val_accuracy: 0.5000 - 39ms/epoch - 20ms/step
# Epoch 36/500
# 2/2 - 0s - loss: 0.5876 - accuracy: 0.7143 - val_loss: 0.6603 - val_accuracy: 0.5000 - 46ms/epoch - 23ms/step
# Epoch 37/500
# 2/2 - 0s - loss: 0.5564 - accuracy: 0.8214 - val_loss: 0.6588 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 38/500
# 2/2 - 0s - loss: 0.5768 - accuracy: 0.7857 - val_loss: 0.6575 - val_accuracy: 0.5000 - 56ms/epoch - 28ms/step
# Epoch 39/500
# 2/2 - 0s - loss: 0.5437 - accuracy: 0.8214 - val_loss: 0.6572 - val_accuracy: 0.5000 - 40ms/epoch - 20ms/step
# Epoch 40/500
# 2/2 - 0s - loss: 0.5434 - accuracy: 0.8214 - val_loss: 0.6575 - val_accuracy: 0.5833 - 43ms/epoch - 22ms/step
# Epoch 41/500
# 2/2 - 0s - loss: 0.5303 - accuracy: 0.7500 - val_loss: 0.6570 - val_accuracy: 0.5833 - 38ms/epoch - 19ms/step
# Epoch 42/500
# 2/2 - 0s - loss: 0.5373 - accuracy: 0.7857 - val_loss: 0.6560 - val_accuracy: 0.5833 - 57ms/epoch - 29ms/step
# Epoch 43/500
# 2/2 - 0s - loss: 0.5575 - accuracy: 0.7143 - val_loss: 0.6545 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 44/500
# 2/2 - 0s - loss: 0.5531 - accuracy: 0.7857 - val_loss: 0.6534 - val_accuracy: 0.6667 - 39ms/epoch - 20ms/step
# Epoch 45/500
# 2/2 - 0s - loss: 0.5583 - accuracy: 0.6429 - val_loss: 0.6525 - val_accuracy: 0.6667 - 52ms/epoch - 26ms/step
# Epoch 46/500
# 2/2 - 0s - loss: 0.5733 - accuracy: 0.7143 - val_loss: 0.6511 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 47/500
# 2/2 - 0s - loss: 0.5707 - accuracy: 0.6786 - val_loss: 0.6503 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 48/500
# 2/2 - 0s - loss: 0.5070 - accuracy: 0.8214 - val_loss: 0.6501 - val_accuracy: 0.6667 - 41ms/epoch - 20ms/step
# Epoch 49/500
# 2/2 - 0s - loss: 0.5360 - accuracy: 0.8571 - val_loss: 0.6503 - val_accuracy: 0.6667 - 58ms/epoch - 29ms/step
# Epoch 50/500
# 2/2 - 0s - loss: 0.4967 - accuracy: 0.8214 - val_loss: 0.6507 - val_accuracy: 0.8333 - 41ms/epoch - 20ms/step
# Epoch 51/500
# 2/2 - 0s - loss: 0.5401 - accuracy: 0.8214 - val_loss: 0.6499 - val_accuracy: 0.9167 - 56ms/epoch - 28ms/step
# Epoch 52/500
# 2/2 - 0s - loss: 0.5072 - accuracy: 0.7857 - val_loss: 0.6502 - val_accuracy: 0.9167 - 59ms/epoch - 30ms/step
# Epoch 53/500
# 2/2 - 0s - loss: 0.4999 - accuracy: 0.8929 - val_loss: 0.6496 - val_accuracy: 0.9167 - 57ms/epoch - 28ms/step
# Epoch 54/500
# 2/2 - 0s - loss: 0.5196 - accuracy: 0.7857 - val_loss: 0.6486 - val_accuracy: 0.9167 - 41ms/epoch - 20ms/step
# Epoch 55/500
# 2/2 - 0s - loss: 0.4933 - accuracy: 0.8214 - val_loss: 0.6474 - val_accuracy: 0.9167 - 39ms/epoch - 20ms/step
# Epoch 56/500
# 2/2 - 0s - loss: 0.4960 - accuracy: 0.8214 - val_loss: 0.6464 - val_accuracy: 0.9167 - 46ms/epoch - 23ms/step
# Epoch 57/500
# 2/2 - 0s - loss: 0.5266 - accuracy: 0.6786 - val_loss: 0.6455 - val_accuracy: 0.9167 - 39ms/epoch - 20ms/step
# Epoch 58/500
# 2/2 - 0s - loss: 0.5014 - accuracy: 0.8214 - val_loss: 0.6442 - val_accuracy: 0.8333 - 38ms/epoch - 19ms/step
# Epoch 59/500
# 2/2 - 0s - loss: 0.5357 - accuracy: 0.6786 - val_loss: 0.6444 - val_accuracy: 0.8333 - 56ms/epoch - 28ms/step
# Epoch 60/500
# 2/2 - 0s - loss: 0.4685 - accuracy: 0.7857 - val_loss: 0.6422 - val_accuracy: 0.7500 - 47ms/epoch - 23ms/step
# Epoch 61/500
# 2/2 - 0s - loss: 0.4863 - accuracy: 0.8571 - val_loss: 0.6397 - val_accuracy: 0.7500 - 41ms/epoch - 20ms/step
# Epoch 62/500
# 2/2 - 0s - loss: 0.5290 - accuracy: 0.8571 - val_loss: 0.6379 - val_accuracy: 0.7500 - 59ms/epoch - 30ms/step
# Epoch 63/500
# 2/2 - 0s - loss: 0.4530 - accuracy: 0.8929 - val_loss: 0.6366 - val_accuracy: 0.7500 - 55ms/epoch - 27ms/step
# Epoch 64/500
# 2/2 - 0s - loss: 0.5028 - accuracy: 0.7857 - val_loss: 0.6342 - val_accuracy: 0.6667 - 45ms/epoch - 23ms/step
# Epoch 65/500
# 2/2 - 0s - loss: 0.4994 - accuracy: 0.7500 - val_loss: 0.6321 - val_accuracy: 0.6667 - 37ms/epoch - 18ms/step
# Epoch 66/500
# 2/2 - 0s - loss: 0.4819 - accuracy: 0.8214 - val_loss: 0.6301 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 67/500
# 2/2 - 0s - loss: 0.4695 - accuracy: 0.8571 - val_loss: 0.6284 - val_accuracy: 0.6667 - 44ms/epoch - 22ms/step
# Epoch 68/500
# 2/2 - 0s - loss: 0.4531 - accuracy: 0.8571 - val_loss: 0.6267 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 69/500
# 2/2 - 0s - loss: 0.4842 - accuracy: 0.7857 - val_loss: 0.6254 - val_accuracy: 0.6667 - 58ms/epoch - 29ms/step
# Epoch 70/500
# 2/2 - 0s - loss: 0.4568 - accuracy: 0.8929 - val_loss: 0.6256 - val_accuracy: 0.6667 - 47ms/epoch - 23ms/step
# Epoch 71/500
# 2/2 - 0s - loss: 0.4426 - accuracy: 0.7857 - val_loss: 0.6265 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 72/500
# 2/2 - 0s - loss: 0.4485 - accuracy: 0.8214 - val_loss: 0.6266 - val_accuracy: 0.6667 - 58ms/epoch - 29ms/step
# Epoch 73/500
# 2/2 - 0s - loss: 0.4159 - accuracy: 0.8571 - val_loss: 0.6269 - val_accuracy: 0.6667 - 41ms/epoch - 20ms/step
# Epoch 74/500
# 2/2 - 0s - loss: 0.4752 - accuracy: 0.8571 - val_loss: 0.6282 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 75/500
# 2/2 - 0s - loss: 0.4563 - accuracy: 0.8571 - val_loss: 0.6281 - val_accuracy: 0.6667 - 48ms/epoch - 24ms/step
# Epoch 76/500
# 2/2 - 0s - loss: 0.4393 - accuracy: 0.8929 - val_loss: 0.6270 - val_accuracy: 0.6667 - 41ms/epoch - 20ms/step
# Epoch 77/500
# 2/2 - 0s - loss: 0.4756 - accuracy: 0.7857 - val_loss: 0.6262 - val_accuracy: 0.6667 - 58ms/epoch - 29ms/step
# Epoch 78/500
# 2/2 - 0s - loss: 0.4896 - accuracy: 0.8214 - val_loss: 0.6269 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 79/500
# 2/2 - 0s - loss: 0.4358 - accuracy: 0.8214 - val_loss: 0.6271 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 80/500
# 2/2 - 0s - loss: 0.4363 - accuracy: 0.8571 - val_loss: 0.6283 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 81/500
# 2/2 - 0s - loss: 0.4080 - accuracy: 0.9286 - val_loss: 0.6305 - val_accuracy: 0.6667 - 39ms/epoch - 20ms/step
# Epoch 82/500
# 2/2 - 0s - loss: 0.4335 - accuracy: 0.8571 - val_loss: 0.6316 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 83/500
# 2/2 - 0s - loss: 0.4652 - accuracy: 0.8214 - val_loss: 0.6322 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 84/500
# 2/2 - 0s - loss: 0.4011 - accuracy: 0.9286 - val_loss: 0.6333 - val_accuracy: 0.6667 - 48ms/epoch - 24ms/step
# Epoch 85/500
# 2/2 - 0s - loss: 0.4217 - accuracy: 0.8929 - val_loss: 0.6316 - val_accuracy: 0.7500 - 48ms/epoch - 24ms/step
# Epoch 86/500
# 2/2 - 0s - loss: 0.3968 - accuracy: 0.8929 - val_loss: 0.6294 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 87/500
# 2/2 - 0s - loss: 0.4101 - accuracy: 0.8214 - val_loss: 0.6266 - val_accuracy: 0.6667 - 60ms/epoch - 30ms/step
# Epoch 88/500
# 2/2 - 0s - loss: 0.4174 - accuracy: 0.8929 - val_loss: 0.6249 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 89/500
# 2/2 - 0s - loss: 0.3744 - accuracy: 0.9286 - val_loss: 0.6256 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 90/500
# 2/2 - 0s - loss: 0.4070 - accuracy: 0.8929 - val_loss: 0.6266 - val_accuracy: 0.6667 - 48ms/epoch - 24ms/step
# Epoch 91/500
# 2/2 - 0s - loss: 0.3924 - accuracy: 0.9286 - val_loss: 0.6251 - val_accuracy: 0.6667 - 41ms/epoch - 20ms/step
# Epoch 92/500
# 2/2 - 0s - loss: 0.3623 - accuracy: 0.8929 - val_loss: 0.6238 - val_accuracy: 0.6667 - 57ms/epoch - 29ms/step
# Epoch 93/500
# 2/2 - 0s - loss: 0.3874 - accuracy: 0.9286 - val_loss: 0.6223 - val_accuracy: 0.6667 - 60ms/epoch - 30ms/step
# Epoch 94/500
# 2/2 - 0s - loss: 0.4365 - accuracy: 0.8214 - val_loss: 0.6206 - val_accuracy: 0.7500 - 56ms/epoch - 28ms/step
# Epoch 95/500
# 2/2 - 0s - loss: 0.3478 - accuracy: 0.9286 - val_loss: 0.6178 - val_accuracy: 0.7500 - 41ms/epoch - 21ms/step
# Epoch 96/500
# 2/2 - 0s - loss: 0.3672 - accuracy: 0.8929 - val_loss: 0.6172 - val_accuracy: 0.8333 - 43ms/epoch - 21ms/step
# Epoch 97/500
# 2/2 - 0s - loss: 0.4270 - accuracy: 0.8571 - val_loss: 0.6202 - val_accuracy: 0.8333 - 45ms/epoch - 23ms/step
# Epoch 98/500
# 2/2 - 0s - loss: 0.3773 - accuracy: 0.9286 - val_loss: 0.6212 - val_accuracy: 0.8333 - 41ms/epoch - 21ms/step
# Epoch 99/500
# 2/2 - 0s - loss: 0.3575 - accuracy: 0.9286 - val_loss: 0.6236 - val_accuracy: 0.8333 - 40ms/epoch - 20ms/step
# Epoch 100/500
# 2/2 - 0s - loss: 0.3413 - accuracy: 0.9286 - val_loss: 0.6263 - val_accuracy: 0.8333 - 40ms/epoch - 20ms/step
# Epoch 101/500
# 2/2 - 0s - loss: 0.3316 - accuracy: 0.8929 - val_loss: 0.6295 - val_accuracy: 0.7500 - 49ms/epoch - 25ms/step
# Epoch 102/500
# 2/2 - 0s - loss: 0.3068 - accuracy: 0.9643 - val_loss: 0.6304 - val_accuracy: 0.7500 - 58ms/epoch - 29ms/step
# Epoch 103/500
# 2/2 - 0s - loss: 0.3734 - accuracy: 0.8929 - val_loss: 0.6285 - val_accuracy: 0.8333 - 51ms/epoch - 26ms/step
# Epoch 104/500
# 2/2 - 0s - loss: 0.3634 - accuracy: 0.9286 - val_loss: 0.6276 - val_accuracy: 0.8333 - 56ms/epoch - 28ms/step
# Epoch 105/500
# 2/2 - 0s - loss: 0.3614 - accuracy: 0.8571 - val_loss: 0.6225 - val_accuracy: 0.7500 - 65ms/epoch - 33ms/step
# Epoch 106/500
# 2/2 - 0s - loss: 0.3729 - accuracy: 0.9286 - val_loss: 0.6207 - val_accuracy: 0.7500 - 41ms/epoch - 21ms/step
# Epoch 107/500
# 2/2 - 0s - loss: 0.3524 - accuracy: 0.9286 - val_loss: 0.6265 - val_accuracy: 0.7500 - 40ms/epoch - 20ms/step
# Epoch 108/500
# 2/2 - 0s - loss: 0.4352 - accuracy: 0.8214 - val_loss: 0.6428 - val_accuracy: 0.8333 - 39ms/epoch - 20ms/step
# Epoch 109/500
# 2/2 - 0s - loss: 0.3719 - accuracy: 0.9286 - val_loss: 0.6561 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 110/500
# 2/2 - 0s - loss: 0.3321 - accuracy: 0.9286 - val_loss: 0.6507 - val_accuracy: 0.7500 - 41ms/epoch - 20ms/step
# Epoch 111/500
# 2/2 - 0s - loss: 0.3538 - accuracy: 0.8214 - val_loss: 0.6227 - val_accuracy: 0.7500 - 40ms/epoch - 20ms/step
# Epoch 112/500
# 2/2 - 0s - loss: 0.3554 - accuracy: 0.8214 - val_loss: 0.6044 - val_accuracy: 0.7500 - 56ms/epoch - 28ms/step
# Epoch 113/500
# 2/2 - 0s - loss: 0.3035 - accuracy: 0.9286 - val_loss: 0.6050 - val_accuracy: 0.5833 - 43ms/epoch - 21ms/step
# Epoch 114/500
# 2/2 - 0s - loss: 0.3245 - accuracy: 0.9286 - val_loss: 0.6056 - val_accuracy: 0.5833 - 55ms/epoch - 28ms/step
# Epoch 115/500
# 2/2 - 0s - loss: 0.3246 - accuracy: 0.9286 - val_loss: 0.6009 - val_accuracy: 0.5833 - 66ms/epoch - 33ms/step
# Epoch 116/500
# 2/2 - 0s - loss: 0.2774 - accuracy: 1.0000 - val_loss: 0.5990 - val_accuracy: 0.7500 - 43ms/epoch - 22ms/step
# Epoch 117/500
# 2/2 - 0s - loss: 0.2863 - accuracy: 0.9643 - val_loss: 0.5984 - val_accuracy: 0.8333 - 56ms/epoch - 28ms/step
# Epoch 118/500
# 2/2 - 0s - loss: 0.2698 - accuracy: 1.0000 - val_loss: 0.5974 - val_accuracy: 0.8333 - 43ms/epoch - 21ms/step
# Epoch 119/500
# 2/2 - 0s - loss: 0.3432 - accuracy: 0.8929 - val_loss: 0.5894 - val_accuracy: 0.8333 - 38ms/epoch - 19ms/step
# Epoch 120/500
# 2/2 - 0s - loss: 0.3364 - accuracy: 0.9286 - val_loss: 0.5817 - val_accuracy: 0.7500 - 38ms/epoch - 19ms/step
# Epoch 121/500
# 2/2 - 0s - loss: 0.2857 - accuracy: 0.9643 - val_loss: 0.5791 - val_accuracy: 0.7500 - 38ms/epoch - 19ms/step
# Epoch 122/500
# 2/2 - 0s - loss: 0.3137 - accuracy: 0.9643 - val_loss: 0.5824 - val_accuracy: 0.6667 - 44ms/epoch - 22ms/step
# Epoch 123/500
# 2/2 - 0s - loss: 0.2774 - accuracy: 0.9286 - val_loss: 0.5882 - val_accuracy: 0.6667 - 45ms/epoch - 22ms/step
# Epoch 124/500
# 2/2 - 0s - loss: 0.3383 - accuracy: 0.8929 - val_loss: 0.6022 - val_accuracy: 0.7500 - 38ms/epoch - 19ms/step
# Epoch 125/500
# 2/2 - 0s - loss: 0.3361 - accuracy: 0.9286 - val_loss: 0.6196 - val_accuracy: 0.8333 - 38ms/epoch - 19ms/step
# Epoch 126/500
# 2/2 - 0s - loss: 0.2748 - accuracy: 0.9286 - val_loss: 0.6174 - val_accuracy: 0.8333 - 37ms/epoch - 19ms/step
# Epoch 127/500
# 2/2 - 0s - loss: 0.2164 - accuracy: 1.0000 - val_loss: 0.6190 - val_accuracy: 0.8333 - 47ms/epoch - 24ms/step
# Epoch 128/500
# 2/2 - 0s - loss: 0.2483 - accuracy: 0.9643 - val_loss: 0.6001 - val_accuracy: 0.7500 - 39ms/epoch - 20ms/step
# Epoch 129/500
# 2/2 - 0s - loss: 0.2833 - accuracy: 0.9286 - val_loss: 0.5859 - val_accuracy: 0.8333 - 39ms/epoch - 20ms/step
# Epoch 130/500
# 2/2 - 0s - loss: 0.2674 - accuracy: 0.9643 - val_loss: 0.5781 - val_accuracy: 0.8333 - 39ms/epoch - 20ms/step
# Epoch 131/500
# 2/2 - 0s - loss: 0.2491 - accuracy: 0.9643 - val_loss: 0.5747 - val_accuracy: 0.8333 - 44ms/epoch - 22ms/step
# Epoch 132/500
# 2/2 - 0s - loss: 0.2875 - accuracy: 0.9286 - val_loss: 0.5911 - val_accuracy: 0.8333 - 39ms/epoch - 20ms/step
# Epoch 133/500
# 2/2 - 0s - loss: 0.2375 - accuracy: 1.0000 - val_loss: 0.6139 - val_accuracy: 0.6667 - 39ms/epoch - 20ms/step
# Epoch 134/500
# 2/2 - 0s - loss: 0.2304 - accuracy: 1.0000 - val_loss: 0.6544 - val_accuracy: 0.5833 - 43ms/epoch - 22ms/step
# Epoch 135/500
# 2/2 - 0s - loss: 0.2733 - accuracy: 0.9643 - val_loss: 0.6573 - val_accuracy: 0.5833 - 41ms/epoch - 20ms/step
# Epoch 136/500
# 2/2 - 0s - loss: 0.2770 - accuracy: 0.9643 - val_loss: 0.5980 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 137/500
# 2/2 - 0s - loss: 0.2923 - accuracy: 0.9643 - val_loss: 0.5737 - val_accuracy: 0.8333 - 44ms/epoch - 22ms/step
# Epoch 138/500
# 2/2 - 0s - loss: 0.2799 - accuracy: 0.8929 - val_loss: 0.5784 - val_accuracy: 0.8333 - 40ms/epoch - 20ms/step
# Epoch 139/500
# 2/2 - 0s - loss: 0.2371 - accuracy: 0.9643 - val_loss: 0.5867 - val_accuracy: 0.7500 - 39ms/epoch - 20ms/step
# Epoch 140/500
# 2/2 - 0s - loss: 0.2491 - accuracy: 0.9643 - val_loss: 0.5955 - val_accuracy: 0.7500 - 39ms/epoch - 20ms/step
# Epoch 141/500
# 2/2 - 0s - loss: 0.2018 - accuracy: 1.0000 - val_loss: 0.5895 - val_accuracy: 0.7500 - 45ms/epoch - 22ms/step
# Epoch 142/500
# 2/2 - 0s - loss: 0.2370 - accuracy: 1.0000 - val_loss: 0.5791 - val_accuracy: 0.8333 - 38ms/epoch - 19ms/step
# Epoch 143/500
# 2/2 - 0s - loss: 0.2659 - accuracy: 1.0000 - val_loss: 0.5678 - val_accuracy: 0.8333 - 38ms/epoch - 19ms/step
# Epoch 144/500
# 2/2 - 0s - loss: 0.2416 - accuracy: 0.9643 - val_loss: 0.5598 - val_accuracy: 0.8333 - 49ms/epoch - 25ms/step
# Epoch 145/500
# 2/2 - 0s - loss: 0.2447 - accuracy: 1.0000 - val_loss: 0.5601 - val_accuracy: 0.8333 - 44ms/epoch - 22ms/step
# Epoch 146/500
# 2/2 - 0s - loss: 0.2237 - accuracy: 0.9643 - val_loss: 0.5895 - val_accuracy: 0.7500 - 43ms/epoch - 21ms/step
# Epoch 147/500
# 2/2 - 0s - loss: 0.2648 - accuracy: 0.9643 - val_loss: 0.6223 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 148/500
# 2/2 - 0s - loss: 0.2839 - accuracy: 0.9286 - val_loss: 0.5674 - val_accuracy: 0.7500 - 39ms/epoch - 20ms/step
# Epoch 149/500
# 2/2 - 0s - loss: 0.2335 - accuracy: 0.9643 - val_loss: 0.5392 - val_accuracy: 0.7500 - 40ms/epoch - 20ms/step
# Epoch 150/500
# 2/2 - 0s - loss: 0.2913 - accuracy: 0.8571 - val_loss: 0.5411 - val_accuracy: 0.8333 - 45ms/epoch - 23ms/step
# Epoch 151/500
# 2/2 - 0s - loss: 0.2232 - accuracy: 1.0000 - val_loss: 0.5811 - val_accuracy: 0.7500 - 57ms/epoch - 28ms/step
# Epoch 152/500
# 2/2 - 0s - loss: 0.2209 - accuracy: 1.0000 - val_loss: 0.6231 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 153/500
# 2/2 - 0s - loss: 0.1933 - accuracy: 0.9643 - val_loss: 0.6368 - val_accuracy: 0.6667 - 39ms/epoch - 19ms/step
# Epoch 154/500
# 2/2 - 0s - loss: 0.2880 - accuracy: 0.9286 - val_loss: 0.5703 - val_accuracy: 0.7500 - 38ms/epoch - 19ms/step
# Epoch 155/500
# 2/2 - 0s - loss: 0.1990 - accuracy: 1.0000 - val_loss: 0.5463 - val_accuracy: 0.8333 - 46ms/epoch - 23ms/step
# Epoch 156/500
# 2/2 - 0s - loss: 0.2070 - accuracy: 1.0000 - val_loss: 0.5445 - val_accuracy: 0.8333 - 40ms/epoch - 20ms/step
# Epoch 157/500
# 2/2 - 0s - loss: 0.2399 - accuracy: 0.9643 - val_loss: 0.5698 - val_accuracy: 0.7500 - 41ms/epoch - 21ms/step
# Epoch 158/500
# 2/2 - 0s - loss: 0.1722 - accuracy: 1.0000 - val_loss: 0.6268 - val_accuracy: 0.5833 - 59ms/epoch - 30ms/step
# Epoch 159/500
# 2/2 - 0s - loss: 0.1920 - accuracy: 1.0000 - val_loss: 0.6618 - val_accuracy: 0.5833 - 43ms/epoch - 22ms/step
# Epoch 160/500
# 2/2 - 0s - loss: 0.1868 - accuracy: 1.0000 - val_loss: 0.6632 - val_accuracy: 0.5833 - 40ms/epoch - 20ms/step
# Epoch 161/500
# 2/2 - 0s - loss: 0.2138 - accuracy: 0.9286 - val_loss: 0.6139 - val_accuracy: 0.7500 - 41ms/epoch - 20ms/step
# Epoch 162/500
# 2/2 - 0s - loss: 0.2058 - accuracy: 1.0000 - val_loss: 0.5733 - val_accuracy: 0.7500 - 41ms/epoch - 21ms/step
# Epoch 163/500
# 2/2 - 0s - loss: 0.1991 - accuracy: 1.0000 - val_loss: 0.5339 - val_accuracy: 0.7500 - 37ms/epoch - 19ms/step
# Epoch 164/500
# 2/2 - 0s - loss: 0.2579 - accuracy: 0.9286 - val_loss: 0.5622 - val_accuracy: 0.7500 - 38ms/epoch - 19ms/step
# Epoch 165/500
# 2/2 - 0s - loss: 0.2020 - accuracy: 1.0000 - val_loss: 0.6019 - val_accuracy: 0.6667 - 52ms/epoch - 26ms/step
# Epoch 166/500
# 2/2 - 0s - loss: 0.1801 - accuracy: 1.0000 - val_loss: 0.5882 - val_accuracy: 0.7500 - 40ms/epoch - 20ms/step
# Epoch 167/500
# 2/2 - 0s - loss: 0.1916 - accuracy: 0.9643 - val_loss: 0.5706 - val_accuracy: 0.7500 - 57ms/epoch - 28ms/step
# Epoch 168/500
# 2/2 - 0s - loss: 0.1913 - accuracy: 1.0000 - val_loss: 0.5870 - val_accuracy: 0.7500 - 43ms/epoch - 22ms/step
# Epoch 169/500
# 2/2 - 0s - loss: 0.1838 - accuracy: 1.0000 - val_loss: 0.5961 - val_accuracy: 0.7500 - 50ms/epoch - 25ms/step
# Epoch 170/500
# 2/2 - 0s - loss: 0.1756 - accuracy: 0.9643 - val_loss: 0.6111 - val_accuracy: 0.6667 - 41ms/epoch - 21ms/step
# Epoch 171/500
# 2/2 - 0s - loss: 0.2175 - accuracy: 0.9643 - val_loss: 0.6103 - val_accuracy: 0.6667 - 41ms/epoch - 21ms/step
# Epoch 172/500
# 2/2 - 0s - loss: 0.1913 - accuracy: 1.0000 - val_loss: 0.6570 - val_accuracy: 0.5833 - 62ms/epoch - 31ms/step
# Epoch 173/500
# 2/2 - 0s - loss: 0.1768 - accuracy: 1.0000 - val_loss: 0.6711 - val_accuracy: 0.5833 - 57ms/epoch - 29ms/step
# Epoch 174/500
# 2/2 - 0s - loss: 0.1596 - accuracy: 1.0000 - val_loss: 0.6054 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 175/500
# 2/2 - 0s - loss: 0.2052 - accuracy: 0.9643 - val_loss: 0.5315 - val_accuracy: 0.6667 - 46ms/epoch - 23ms/step
# Epoch 176/500
# 2/2 - 0s - loss: 0.1661 - accuracy: 1.0000 - val_loss: 0.5063 - val_accuracy: 0.8333 - 77ms/epoch - 39ms/step
# Epoch 177/500
# 2/2 - 0s - loss: 0.1972 - accuracy: 0.9643 - val_loss: 0.5065 - val_accuracy: 0.8333 - 77ms/epoch - 39ms/step
# Epoch 178/500
# 2/2 - 0s - loss: 0.1382 - accuracy: 1.0000 - val_loss: 0.5209 - val_accuracy: 0.6667 - 68ms/epoch - 34ms/step
# Epoch 179/500
# 2/2 - 0s - loss: 0.1676 - accuracy: 1.0000 - val_loss: 0.5348 - val_accuracy: 0.7500 - 73ms/epoch - 37ms/step
# Epoch 180/500
# 2/2 - 0s - loss: 0.1743 - accuracy: 1.0000 - val_loss: 0.5479 - val_accuracy: 0.7500 - 58ms/epoch - 29ms/step
# Epoch 181/500
# 2/2 - 0s - loss: 0.1574 - accuracy: 1.0000 - val_loss: 0.6248 - val_accuracy: 0.6667 - 72ms/epoch - 36ms/step
# Epoch 182/500
# 2/2 - 0s - loss: 0.1966 - accuracy: 1.0000 - val_loss: 0.6888 - val_accuracy: 0.5000 - 57ms/epoch - 28ms/step
# Epoch 183/500
# 2/2 - 0s - loss: 0.2024 - accuracy: 0.9643 - val_loss: 0.5882 - val_accuracy: 0.7500 - 71ms/epoch - 35ms/step
# Epoch 184/500
# 2/2 - 0s - loss: 0.1484 - accuracy: 1.0000 - val_loss: 0.5232 - val_accuracy: 0.6667 - 57ms/epoch - 29ms/step
# Epoch 185/500
# 2/2 - 0s - loss: 0.1684 - accuracy: 1.0000 - val_loss: 0.5347 - val_accuracy: 0.7500 - 60ms/epoch - 30ms/step
# Epoch 186/500
# 2/2 - 0s - loss: 0.1682 - accuracy: 0.9643 - val_loss: 0.6065 - val_accuracy: 0.6667 - 56ms/epoch - 28ms/step
# Epoch 187/500
# 2/2 - 0s - loss: 0.2060 - accuracy: 0.9643 - val_loss: 0.6712 - val_accuracy: 0.5833 - 56ms/epoch - 28ms/step
# Epoch 188/500
# 2/2 - 0s - loss: 0.1698 - accuracy: 1.0000 - val_loss: 0.6438 - val_accuracy: 0.6667 - 72ms/epoch - 36ms/step
# Epoch 189/500
# 2/2 - 0s - loss: 0.1312 - accuracy: 1.0000 - val_loss: 0.5787 - val_accuracy: 0.7500 - 71ms/epoch - 36ms/step
# Epoch 190/500
# 2/2 - 0s - loss: 0.1675 - accuracy: 1.0000 - val_loss: 0.4940 - val_accuracy: 0.7500 - 61ms/epoch - 31ms/step
# Epoch 191/500
# 2/2 - 0s - loss: 0.1627 - accuracy: 1.0000 - val_loss: 0.4756 - val_accuracy: 0.8333 - 81ms/epoch - 41ms/step
# Epoch 192/500
# 2/2 - 0s - loss: 0.1426 - accuracy: 1.0000 - val_loss: 0.5080 - val_accuracy: 0.7500 - 70ms/epoch - 35ms/step
# Epoch 193/500
# 2/2 - 0s - loss: 0.1437 - accuracy: 1.0000 - val_loss: 0.5106 - val_accuracy: 0.7500 - 73ms/epoch - 37ms/step
# Epoch 194/500
# 2/2 - 0s - loss: 0.1847 - accuracy: 1.0000 - val_loss: 0.5070 - val_accuracy: 0.7500 - 71ms/epoch - 35ms/step
# Epoch 195/500
# 2/2 - 0s - loss: 0.1748 - accuracy: 0.9643 - val_loss: 0.5419 - val_accuracy: 0.7500 - 69ms/epoch - 35ms/step
# Epoch 196/500
# 2/2 - 0s - loss: 0.1882 - accuracy: 1.0000 - val_loss: 0.5489 - val_accuracy: 0.7500 - 71ms/epoch - 35ms/step
# Epoch 197/500
# 2/2 - 0s - loss: 0.1357 - accuracy: 1.0000 - val_loss: 0.5043 - val_accuracy: 0.7500 - 70ms/epoch - 35ms/step
# Epoch 198/500
# 2/2 - 0s - loss: 0.1567 - accuracy: 1.0000 - val_loss: 0.4773 - val_accuracy: 0.7500 - 73ms/epoch - 37ms/step
# Epoch 199/500
# 2/2 - 0s - loss: 0.1735 - accuracy: 1.0000 - val_loss: 0.4802 - val_accuracy: 0.7500 - 71ms/epoch - 36ms/step
# Epoch 200/500
# 2/2 - 0s - loss: 0.1565 - accuracy: 1.0000 - val_loss: 0.5093 - val_accuracy: 0.7500 - 69ms/epoch - 35ms/step
# Epoch 201/500
# 2/2 - 0s - loss: 0.1432 - accuracy: 1.0000 - val_loss: 0.5765 - val_accuracy: 0.6667 - 69ms/epoch - 35ms/step
# Epoch 202/500
# 2/2 - 0s - loss: 0.1376 - accuracy: 1.0000 - val_loss: 0.6134 - val_accuracy: 0.6667 - 59ms/epoch - 30ms/step
# Epoch 203/500
# 2/2 - 0s - loss: 0.1548 - accuracy: 1.0000 - val_loss: 0.6525 - val_accuracy: 0.6667 - 69ms/epoch - 35ms/step
# Epoch 204/500
# 2/2 - 0s - loss: 0.1418 - accuracy: 1.0000 - val_loss: 0.5691 - val_accuracy: 0.7500 - 77ms/epoch - 39ms/step
# Epoch 205/500
# 2/2 - 0s - loss: 0.1752 - accuracy: 1.0000 - val_loss: 0.4855 - val_accuracy: 0.7500 - 59ms/epoch - 29ms/step
# Epoch 206/500
# 2/2 - 0s - loss: 0.2388 - accuracy: 0.9286 - val_loss: 0.4416 - val_accuracy: 0.8333 - 72ms/epoch - 36ms/step
# Epoch 207/500
# 2/2 - 0s - loss: 0.1783 - accuracy: 1.0000 - val_loss: 0.4817 - val_accuracy: 0.7500 - 78ms/epoch - 39ms/step
# Epoch 208/500
# 2/2 - 0s - loss: 0.1743 - accuracy: 0.9643 - val_loss: 0.5512 - val_accuracy: 0.7500 - 70ms/epoch - 35ms/step
# Epoch 209/500
# 2/2 - 0s - loss: 0.1971 - accuracy: 0.9643 - val_loss: 0.5138 - val_accuracy: 0.7500 - 73ms/epoch - 36ms/step
# Epoch 210/500
# 2/2 - 0s - loss: 0.1416 - accuracy: 1.0000 - val_loss: 0.4287 - val_accuracy: 0.8333 - 68ms/epoch - 34ms/step
# Epoch 211/500
# 2/2 - 0s - loss: 0.1742 - accuracy: 1.0000 - val_loss: 0.4274 - val_accuracy: 0.8333 - 75ms/epoch - 37ms/step
# Epoch 212/500
# 2/2 - 0s - loss: 0.1536 - accuracy: 1.0000 - val_loss: 0.4584 - val_accuracy: 0.8333 - 68ms/epoch - 34ms/step
# Epoch 213/500
# 2/2 - 0s - loss: 0.1427 - accuracy: 1.0000 - val_loss: 0.6501 - val_accuracy: 0.6667 - 60ms/epoch - 30ms/step
# Epoch 214/500
# 2/2 - 0s - loss: 0.1326 - accuracy: 1.0000 - val_loss: 0.7823 - val_accuracy: 0.5000 - 69ms/epoch - 35ms/step
# Epoch 215/500
# 2/2 - 0s - loss: 0.1618 - accuracy: 1.0000 - val_loss: 0.7329 - val_accuracy: 0.6667 - 70ms/epoch - 35ms/step
# Epoch 216/500
# 2/2 - 0s - loss: 0.1913 - accuracy: 0.9643 - val_loss: 0.4894 - val_accuracy: 0.7500 - 70ms/epoch - 35ms/step
# Epoch 217/500
# 2/2 - 0s - loss: 0.1421 - accuracy: 1.0000 - val_loss: 0.4181 - val_accuracy: 0.8333 - 88ms/epoch - 44ms/step
# Epoch 218/500
# 2/2 - 0s - loss: 0.1710 - accuracy: 1.0000 - val_loss: 0.4139 - val_accuracy: 0.8333 - 72ms/epoch - 36ms/step
# Epoch 219/500
# 2/2 - 0s - loss: 0.1355 - accuracy: 1.0000 - val_loss: 0.4391 - val_accuracy: 0.8333 - 67ms/epoch - 33ms/step
# Epoch 220/500
# 2/2 - 0s - loss: 0.1687 - accuracy: 0.9643 - val_loss: 0.5361 - val_accuracy: 0.7500 - 63ms/epoch - 31ms/step
# Epoch 221/500
# 2/2 - 0s - loss: 0.1213 - accuracy: 1.0000 - val_loss: 0.7054 - val_accuracy: 0.6667 - 53ms/epoch - 27ms/step
# Epoch 222/500
# 2/2 - 0s - loss: 0.1459 - accuracy: 1.0000 - val_loss: 0.7660 - val_accuracy: 0.6667 - 72ms/epoch - 36ms/step
# Epoch 223/500
# 2/2 - 0s - loss: 0.1473 - accuracy: 1.0000 - val_loss: 0.6756 - val_accuracy: 0.6667 - 91ms/epoch - 46ms/step
# Epoch 224/500
# 2/2 - 0s - loss: 0.1327 - accuracy: 1.0000 - val_loss: 0.5666 - val_accuracy: 0.7500 - 68ms/epoch - 34ms/step
# Epoch 225/500
# 2/2 - 0s - loss: 0.1166 - accuracy: 1.0000 - val_loss: 0.5304 - val_accuracy: 0.7500 - 62ms/epoch - 31ms/step
# Epoch 226/500
# 2/2 - 0s - loss: 0.1334 - accuracy: 1.0000 - val_loss: 0.4894 - val_accuracy: 0.7500 - 77ms/epoch - 39ms/step
# Epoch 227/500
# 2/2 - 0s - loss: 0.1592 - accuracy: 0.9643 - val_loss: 0.4812 - val_accuracy: 0.7500 - 57ms/epoch - 28ms/step
# Epoch 228/500
# 2/2 - 0s - loss: 0.1210 - accuracy: 1.0000 - val_loss: 0.5213 - val_accuracy: 0.7500 - 76ms/epoch - 38ms/step
# Epoch 229/500
# 2/2 - 0s - loss: 0.1333 - accuracy: 1.0000 - val_loss: 0.5159 - val_accuracy: 0.7500 - 56ms/epoch - 28ms/step
# Epoch 230/500
# 2/2 - 0s - loss: 0.1714 - accuracy: 1.0000 - val_loss: 0.5012 - val_accuracy: 0.7500 - 60ms/epoch - 30ms/step
# Epoch 231/500
# 2/2 - 0s - loss: 0.1058 - accuracy: 1.0000 - val_loss: 0.4416 - val_accuracy: 0.7500 - 60ms/epoch - 30ms/step
# Epoch 232/500
# 2/2 - 0s - loss: 0.1439 - accuracy: 1.0000 - val_loss: 0.4093 - val_accuracy: 0.9167 - 73ms/epoch - 36ms/step
# Epoch 233/500
# 2/2 - 0s - loss: 0.2052 - accuracy: 0.9643 - val_loss: 0.4272 - val_accuracy: 0.7500 - 73ms/epoch - 37ms/step
# Epoch 234/500
# 2/2 - 0s - loss: 0.1463 - accuracy: 1.0000 - val_loss: 0.4783 - val_accuracy: 0.7500 - 59ms/epoch - 29ms/step
# Epoch 235/500
# 2/2 - 0s - loss: 0.1474 - accuracy: 1.0000 - val_loss: 0.5434 - val_accuracy: 0.7500 - 47ms/epoch - 23ms/step
# Epoch 236/500
# 2/2 - 0s - loss: 0.1028 - accuracy: 1.0000 - val_loss: 0.6426 - val_accuracy: 0.6667 - 58ms/epoch - 29ms/step
# Epoch 237/500
# 2/2 - 0s - loss: 0.1357 - accuracy: 1.0000 - val_loss: 0.6231 - val_accuracy: 0.6667 - 57ms/epoch - 28ms/step
# Epoch 238/500
# 2/2 - 0s - loss: 0.1135 - accuracy: 1.0000 - val_loss: 0.5924 - val_accuracy: 0.6667 - 62ms/epoch - 31ms/step
# Epoch 239/500
# 2/2 - 0s - loss: 0.1204 - accuracy: 1.0000 - val_loss: 0.5723 - val_accuracy: 0.7500 - 39ms/epoch - 19ms/step
# Epoch 240/500
# 2/2 - 0s - loss: 0.1361 - accuracy: 1.0000 - val_loss: 0.6453 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 241/500
# 2/2 - 0s - loss: 0.1063 - accuracy: 1.0000 - val_loss: 0.7578 - val_accuracy: 0.6667 - 47ms/epoch - 23ms/step
# Epoch 242/500
# 2/2 - 0s - loss: 0.1223 - accuracy: 1.0000 - val_loss: 0.7424 - val_accuracy: 0.6667 - 41ms/epoch - 21ms/step
# Epoch 243/500
# 2/2 - 0s - loss: 0.1178 - accuracy: 1.0000 - val_loss: 0.7048 - val_accuracy: 0.6667 - 59ms/epoch - 29ms/step
# Epoch 244/500
# 2/2 - 0s - loss: 0.1235 - accuracy: 1.0000 - val_loss: 0.6441 - val_accuracy: 0.6667 - 45ms/epoch - 23ms/step
# Epoch 245/500
# 2/2 - 0s - loss: 0.1377 - accuracy: 1.0000 - val_loss: 0.5101 - val_accuracy: 0.7500 - 58ms/epoch - 29ms/step
# Epoch 246/500
# 2/2 - 0s - loss: 0.1200 - accuracy: 1.0000 - val_loss: 0.4402 - val_accuracy: 0.7500 - 57ms/epoch - 28ms/step
# Epoch 247/500
# 2/2 - 0s - loss: 0.1302 - accuracy: 1.0000 - val_loss: 0.4052 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 248/500
# 2/2 - 0s - loss: 0.1061 - accuracy: 1.0000 - val_loss: 0.4034 - val_accuracy: 0.7500 - 46ms/epoch - 23ms/step
# Epoch 249/500
# 2/2 - 0s - loss: 0.1304 - accuracy: 1.0000 - val_loss: 0.4385 - val_accuracy: 0.7500 - 40ms/epoch - 20ms/step
# Epoch 250/500
# 2/2 - 0s - loss: 0.1289 - accuracy: 1.0000 - val_loss: 0.4544 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 251/500
# 2/2 - 0s - loss: 0.1243 - accuracy: 0.9643 - val_loss: 0.4156 - val_accuracy: 0.7500 - 46ms/epoch - 23ms/step
# Epoch 252/500
# 2/2 - 0s - loss: 0.1127 - accuracy: 1.0000 - val_loss: 0.3802 - val_accuracy: 0.8333 - 41ms/epoch - 21ms/step
# Epoch 253/500
# 2/2 - 0s - loss: 0.1225 - accuracy: 1.0000 - val_loss: 0.3819 - val_accuracy: 0.8333 - 40ms/epoch - 20ms/step
# Epoch 254/500
# 2/2 - 0s - loss: 0.1466 - accuracy: 1.0000 - val_loss: 0.4376 - val_accuracy: 0.7500 - 63ms/epoch - 32ms/step
# Epoch 255/500
# 2/2 - 0s - loss: 0.1161 - accuracy: 1.0000 - val_loss: 0.6132 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 256/500
# 2/2 - 0s - loss: 0.1358 - accuracy: 1.0000 - val_loss: 0.6757 - val_accuracy: 0.6667 - 61ms/epoch - 30ms/step
# Epoch 257/500
# 2/2 - 0s - loss: 0.1172 - accuracy: 1.0000 - val_loss: 0.6264 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 258/500
# 2/2 - 0s - loss: 0.1052 - accuracy: 1.0000 - val_loss: 0.5524 - val_accuracy: 0.7500 - 58ms/epoch - 29ms/step
# Epoch 259/500
# 2/2 - 0s - loss: 0.0963 - accuracy: 1.0000 - val_loss: 0.4726 - val_accuracy: 0.7500 - 44ms/epoch - 22ms/step
# Epoch 260/500
# 2/2 - 0s - loss: 0.1669 - accuracy: 0.9286 - val_loss: 0.4899 - val_accuracy: 0.7500 - 40ms/epoch - 20ms/step
# Epoch 261/500
# 2/2 - 0s - loss: 0.0864 - accuracy: 1.0000 - val_loss: 0.5091 - val_accuracy: 0.7500 - 40ms/epoch - 20ms/step
# Epoch 262/500
# 2/2 - 0s - loss: 0.1187 - accuracy: 1.0000 - val_loss: 0.5270 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 263/500
# 2/2 - 0s - loss: 0.1170 - accuracy: 1.0000 - val_loss: 0.4903 - val_accuracy: 0.7500 - 41ms/epoch - 20ms/step
# Epoch 264/500
# 2/2 - 0s - loss: 0.1279 - accuracy: 1.0000 - val_loss: 0.4241 - val_accuracy: 0.7500 - 41ms/epoch - 20ms/step
# Epoch 265/500
# 2/2 - 0s - loss: 0.1094 - accuracy: 1.0000 - val_loss: 0.3667 - val_accuracy: 0.8333 - 39ms/epoch - 20ms/step
# Epoch 266/500
# 2/2 - 0s - loss: 0.1024 - accuracy: 1.0000 - val_loss: 0.3737 - val_accuracy: 0.8333 - 45ms/epoch - 22ms/step
# Epoch 267/500
# 2/2 - 0s - loss: 0.1481 - accuracy: 1.0000 - val_loss: 0.4701 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 268/500
# 2/2 - 0s - loss: 0.1111 - accuracy: 1.0000 - val_loss: 0.6397 - val_accuracy: 0.6667 - 59ms/epoch - 29ms/step
# Epoch 269/500
# 2/2 - 0s - loss: 0.1191 - accuracy: 1.0000 - val_loss: 0.6534 - val_accuracy: 0.6667 - 58ms/epoch - 29ms/step
# Epoch 270/500
# 2/2 - 0s - loss: 0.1233 - accuracy: 1.0000 - val_loss: 0.6591 - val_accuracy: 0.6667 - 65ms/epoch - 32ms/step
# Epoch 271/500
# 2/2 - 0s - loss: 0.1105 - accuracy: 1.0000 - val_loss: 0.6532 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 272/500
# 2/2 - 0s - loss: 0.1023 - accuracy: 1.0000 - val_loss: 0.5763 - val_accuracy: 0.7500 - 58ms/epoch - 29ms/step
# Epoch 273/500
# 2/2 - 0s - loss: 0.1097 - accuracy: 1.0000 - val_loss: 0.4915 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 274/500
# 2/2 - 0s - loss: 0.1098 - accuracy: 1.0000 - val_loss: 0.4313 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 275/500
# 2/2 - 0s - loss: 0.1278 - accuracy: 1.0000 - val_loss: 0.4283 - val_accuracy: 0.7500 - 41ms/epoch - 21ms/step
# Epoch 276/500
# 2/2 - 0s - loss: 0.0890 - accuracy: 1.0000 - val_loss: 0.4786 - val_accuracy: 0.7500 - 51ms/epoch - 25ms/step
# Epoch 277/500
# 2/2 - 0s - loss: 0.1214 - accuracy: 1.0000 - val_loss: 0.5064 - val_accuracy: 0.7500 - 45ms/epoch - 22ms/step
# Epoch 278/500
# 2/2 - 0s - loss: 0.0977 - accuracy: 1.0000 - val_loss: 0.5180 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 279/500
# 2/2 - 0s - loss: 0.1048 - accuracy: 1.0000 - val_loss: 0.5199 - val_accuracy: 0.7500 - 40ms/epoch - 20ms/step
# Epoch 280/500
# 2/2 - 0s - loss: 0.0930 - accuracy: 1.0000 - val_loss: 0.4603 - val_accuracy: 0.7500 - 40ms/epoch - 20ms/step
# Epoch 281/500
# 2/2 - 0s - loss: 0.1175 - accuracy: 1.0000 - val_loss: 0.3812 - val_accuracy: 0.8333 - 66ms/epoch - 33ms/step
# Epoch 282/500
# 2/2 - 0s - loss: 0.0957 - accuracy: 1.0000 - val_loss: 0.3964 - val_accuracy: 0.8333 - 42ms/epoch - 21ms/step
# Epoch 283/500
# 2/2 - 0s - loss: 0.1258 - accuracy: 1.0000 - val_loss: 0.3742 - val_accuracy: 0.9167 - 42ms/epoch - 21ms/step
# Epoch 284/500
# 2/2 - 0s - loss: 0.1047 - accuracy: 1.0000 - val_loss: 0.4292 - val_accuracy: 0.7500 - 57ms/epoch - 28ms/step
# Epoch 285/500
# 2/2 - 0s - loss: 0.1129 - accuracy: 1.0000 - val_loss: 0.5024 - val_accuracy: 0.7500 - 43ms/epoch - 21ms/step
# Epoch 286/500
# 2/2 - 0s - loss: 0.1004 - accuracy: 1.0000 - val_loss: 0.5138 - val_accuracy: 0.7500 - 62ms/epoch - 31ms/step
# Epoch 287/500
# 2/2 - 0s - loss: 0.1050 - accuracy: 1.0000 - val_loss: 0.5061 - val_accuracy: 0.7500 - 62ms/epoch - 31ms/step
# Epoch 288/500
# 2/2 - 0s - loss: 0.1088 - accuracy: 1.0000 - val_loss: 0.4901 - val_accuracy: 0.7500 - 41ms/epoch - 21ms/step
# Epoch 289/500
# 2/2 - 0s - loss: 0.0994 - accuracy: 1.0000 - val_loss: 0.4727 - val_accuracy: 0.7500 - 58ms/epoch - 29ms/step
# Epoch 290/500
# 2/2 - 0s - loss: 0.0956 - accuracy: 1.0000 - val_loss: 0.4579 - val_accuracy: 0.7500 - 65ms/epoch - 33ms/step
# Epoch 291/500
# 2/2 - 0s - loss: 0.0989 - accuracy: 1.0000 - val_loss: 0.4715 - val_accuracy: 0.7500 - 46ms/epoch - 23ms/step
# Epoch 292/500
# 2/2 - 0s - loss: 0.0831 - accuracy: 1.0000 - val_loss: 0.4822 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 293/500
# 2/2 - 0s - loss: 0.1151 - accuracy: 1.0000 - val_loss: 0.5190 - val_accuracy: 0.7500 - 48ms/epoch - 24ms/step
# Epoch 294/500
# 2/2 - 0s - loss: 0.0847 - accuracy: 1.0000 - val_loss: 0.5496 - val_accuracy: 0.7500 - 64ms/epoch - 32ms/step
# Epoch 295/500
# 2/2 - 0s - loss: 0.0982 - accuracy: 1.0000 - val_loss: 0.5586 - val_accuracy: 0.7500 - 41ms/epoch - 20ms/step
# Epoch 296/500
# 2/2 - 0s - loss: 0.1266 - accuracy: 1.0000 - val_loss: 0.4546 - val_accuracy: 0.7500 - 41ms/epoch - 20ms/step
# Epoch 297/500
# 2/2 - 0s - loss: 0.0921 - accuracy: 1.0000 - val_loss: 0.4234 - val_accuracy: 0.7500 - 41ms/epoch - 20ms/step
# Epoch 298/500
# 2/2 - 0s - loss: 0.0848 - accuracy: 1.0000 - val_loss: 0.4736 - val_accuracy: 0.7500 - 50ms/epoch - 25ms/step
# Epoch 299/500
# 2/2 - 0s - loss: 0.0875 - accuracy: 1.0000 - val_loss: 0.5735 - val_accuracy: 0.7500 - 41ms/epoch - 21ms/step
# Epoch 300/500
# 2/2 - 0s - loss: 0.0820 - accuracy: 1.0000 - val_loss: 0.6401 - val_accuracy: 0.6667 - 41ms/epoch - 20ms/step
# Epoch 301/500
# 2/2 - 0s - loss: 0.1152 - accuracy: 1.0000 - val_loss: 0.5131 - val_accuracy: 0.7500 - 48ms/epoch - 24ms/step
# Epoch 302/500
# 2/2 - 0s - loss: 0.0794 - accuracy: 1.0000 - val_loss: 0.3708 - val_accuracy: 0.8333 - 43ms/epoch - 22ms/step
# Epoch 303/500
# 2/2 - 0s - loss: 0.0919 - accuracy: 1.0000 - val_loss: 0.3741 - val_accuracy: 0.9167 - 42ms/epoch - 21ms/step
# Epoch 304/500
# 2/2 - 0s - loss: 0.1143 - accuracy: 1.0000 - val_loss: 0.3834 - val_accuracy: 0.6667 - 50ms/epoch - 25ms/step
# Epoch 305/500
# 2/2 - 0s - loss: 0.1115 - accuracy: 1.0000 - val_loss: 0.5801 - val_accuracy: 0.7500 - 41ms/epoch - 21ms/step
# Epoch 306/500
# 2/2 - 0s - loss: 0.0762 - accuracy: 1.0000 - val_loss: 0.8888 - val_accuracy: 0.5833 - 61ms/epoch - 31ms/step
# Epoch 307/500
# 2/2 - 0s - loss: 0.2183 - accuracy: 0.9286 - val_loss: 0.8212 - val_accuracy: 0.6667 - 41ms/epoch - 21ms/step
# Epoch 308/500
# 2/2 - 0s - loss: 0.0993 - accuracy: 1.0000 - val_loss: 0.6894 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 309/500
# 2/2 - 0s - loss: 0.0883 - accuracy: 1.0000 - val_loss: 0.5293 - val_accuracy: 0.7500 - 47ms/epoch - 23ms/step
# Epoch 310/500
# 2/2 - 0s - loss: 0.0913 - accuracy: 1.0000 - val_loss: 0.4545 - val_accuracy: 0.7500 - 64ms/epoch - 32ms/step
# Epoch 311/500
# 2/2 - 0s - loss: 0.1168 - accuracy: 1.0000 - val_loss: 0.4755 - val_accuracy: 0.7500 - 61ms/epoch - 30ms/step
# Epoch 312/500
# 2/2 - 0s - loss: 0.0987 - accuracy: 1.0000 - val_loss: 0.5448 - val_accuracy: 0.7500 - 61ms/epoch - 30ms/step
# Epoch 313/500
# 2/2 - 0s - loss: 0.0773 - accuracy: 1.0000 - val_loss: 0.5831 - val_accuracy: 0.7500 - 45ms/epoch - 23ms/step
# Epoch 314/500
# 2/2 - 0s - loss: 0.0969 - accuracy: 1.0000 - val_loss: 0.4156 - val_accuracy: 0.7500 - 40ms/epoch - 20ms/step
# Epoch 315/500
# 2/2 - 0s - loss: 0.1353 - accuracy: 0.9643 - val_loss: 0.3715 - val_accuracy: 0.8333 - 41ms/epoch - 20ms/step
# Epoch 316/500
# 2/2 - 0s - loss: 0.0995 - accuracy: 1.0000 - val_loss: 0.3847 - val_accuracy: 0.7500 - 51ms/epoch - 25ms/step
# Epoch 317/500
# 2/2 - 0s - loss: 0.0916 - accuracy: 1.0000 - val_loss: 0.3953 - val_accuracy: 0.7500 - 51ms/epoch - 25ms/step
# Epoch 318/500
# 2/2 - 0s - loss: 0.0983 - accuracy: 1.0000 - val_loss: 0.4039 - val_accuracy: 0.6667 - 59ms/epoch - 29ms/step
# Epoch 319/500
# 2/2 - 0s - loss: 0.0980 - accuracy: 1.0000 - val_loss: 0.4426 - val_accuracy: 0.5833 - 41ms/epoch - 21ms/step
# Epoch 320/500
# 2/2 - 0s - loss: 0.0944 - accuracy: 1.0000 - val_loss: 0.4148 - val_accuracy: 0.6667 - 41ms/epoch - 21ms/step
# Epoch 321/500
# 2/2 - 0s - loss: 0.0866 - accuracy: 1.0000 - val_loss: 0.4011 - val_accuracy: 0.8333 - 43ms/epoch - 21ms/step
# Epoch 322/500
# 2/2 - 0s - loss: 0.1085 - accuracy: 1.0000 - val_loss: 0.3972 - val_accuracy: 0.6667 - 57ms/epoch - 29ms/step
# Epoch 323/500
# 2/2 - 0s - loss: 0.0903 - accuracy: 1.0000 - val_loss: 0.5159 - val_accuracy: 0.7500 - 57ms/epoch - 29ms/step
# Epoch 324/500
# 2/2 - 0s - loss: 0.0864 - accuracy: 1.0000 - val_loss: 0.6832 - val_accuracy: 0.6667 - 39ms/epoch - 20ms/step
# Epoch 325/500
# 2/2 - 0s - loss: 0.1002 - accuracy: 1.0000 - val_loss: 0.7491 - val_accuracy: 0.6667 - 56ms/epoch - 28ms/step
# Epoch 326/500
# 2/2 - 0s - loss: 0.1030 - accuracy: 1.0000 - val_loss: 0.6770 - val_accuracy: 0.6667 - 44ms/epoch - 22ms/step
# Epoch 327/500
# 2/2 - 0s - loss: 0.0867 - accuracy: 1.0000 - val_loss: 0.5545 - val_accuracy: 0.7500 - 57ms/epoch - 28ms/step
# Epoch 328/500
# 2/2 - 0s - loss: 0.0882 - accuracy: 1.0000 - val_loss: 0.4806 - val_accuracy: 0.7500 - 46ms/epoch - 23ms/step
# Epoch 329/500
# 2/2 - 0s - loss: 0.0760 - accuracy: 1.0000 - val_loss: 0.4669 - val_accuracy: 0.7500 - 40ms/epoch - 20ms/step
# Epoch 330/500
# 2/2 - 0s - loss: 0.1029 - accuracy: 1.0000 - val_loss: 0.4771 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 331/500
# 2/2 - 0s - loss: 0.1113 - accuracy: 1.0000 - val_loss: 0.5037 - val_accuracy: 0.7500 - 59ms/epoch - 30ms/step
# Epoch 332/500
# 2/2 - 0s - loss: 0.0996 - accuracy: 1.0000 - val_loss: 0.4312 - val_accuracy: 0.7500 - 60ms/epoch - 30ms/step
# Epoch 333/500
# 2/2 - 0s - loss: 0.0748 - accuracy: 1.0000 - val_loss: 0.4043 - val_accuracy: 0.6667 - 40ms/epoch - 20ms/step
# Epoch 334/500
# 2/2 - 0s - loss: 0.1237 - accuracy: 1.0000 - val_loss: 0.4067 - val_accuracy: 0.6667 - 56ms/epoch - 28ms/step
# Epoch 335/500
# 2/2 - 0s - loss: 0.0786 - accuracy: 1.0000 - val_loss: 0.4326 - val_accuracy: 0.7500 - 57ms/epoch - 29ms/step
# Epoch 336/500
# 2/2 - 0s - loss: 0.0842 - accuracy: 1.0000 - val_loss: 0.4809 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 337/500
# 2/2 - 0s - loss: 0.0932 - accuracy: 1.0000 - val_loss: 0.5334 - val_accuracy: 0.7500 - 40ms/epoch - 20ms/step
# Epoch 338/500
# 2/2 - 0s - loss: 0.0736 - accuracy: 1.0000 - val_loss: 0.5883 - val_accuracy: 0.7500 - 47ms/epoch - 23ms/step
# Epoch 339/500
# 2/2 - 0s - loss: 0.0921 - accuracy: 1.0000 - val_loss: 0.5770 - val_accuracy: 0.7500 - 44ms/epoch - 22ms/step
# Epoch 340/500
# 2/2 - 0s - loss: 0.0808 - accuracy: 1.0000 - val_loss: 0.5242 - val_accuracy: 0.7500 - 41ms/epoch - 20ms/step
# Epoch 341/500
# 2/2 - 0s - loss: 0.0753 - accuracy: 1.0000 - val_loss: 0.5215 - val_accuracy: 0.6667 - 41ms/epoch - 20ms/step
# Epoch 342/500
# 2/2 - 0s - loss: 0.1003 - accuracy: 1.0000 - val_loss: 0.5354 - val_accuracy: 0.6667 - 47ms/epoch - 23ms/step
# Epoch 343/500
# 2/2 - 0s - loss: 0.0671 - accuracy: 1.0000 - val_loss: 0.5225 - val_accuracy: 0.6667 - 41ms/epoch - 21ms/step
# Epoch 344/500
# 2/2 - 0s - loss: 0.0713 - accuracy: 1.0000 - val_loss: 0.5129 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 345/500
# 2/2 - 0s - loss: 0.0842 - accuracy: 1.0000 - val_loss: 0.5119 - val_accuracy: 0.6667 - 57ms/epoch - 29ms/step
# Epoch 346/500
# 2/2 - 0s - loss: 0.0665 - accuracy: 1.0000 - val_loss: 0.4963 - val_accuracy: 0.6667 - 47ms/epoch - 24ms/step
# Epoch 347/500
# 2/2 - 0s - loss: 0.0765 - accuracy: 1.0000 - val_loss: 0.4628 - val_accuracy: 0.5833 - 47ms/epoch - 24ms/step
# Epoch 348/500
# 2/2 - 0s - loss: 0.0878 - accuracy: 1.0000 - val_loss: 0.4621 - val_accuracy: 0.7500 - 41ms/epoch - 21ms/step
# Epoch 349/500
# 2/2 - 0s - loss: 0.0692 - accuracy: 1.0000 - val_loss: 0.4621 - val_accuracy: 0.7500 - 56ms/epoch - 28ms/step
# Epoch 350/500
# 2/2 - 0s - loss: 0.0588 - accuracy: 1.0000 - val_loss: 0.4775 - val_accuracy: 0.7500 - 61ms/epoch - 30ms/step
# Epoch 351/500
# 2/2 - 0s - loss: 0.0774 - accuracy: 1.0000 - val_loss: 0.5287 - val_accuracy: 0.7500 - 43ms/epoch - 21ms/step
# Epoch 352/500
# 2/2 - 0s - loss: 0.0729 - accuracy: 1.0000 - val_loss: 0.5899 - val_accuracy: 0.7500 - 56ms/epoch - 28ms/step
# Epoch 353/500
# 2/2 - 0s - loss: 0.0807 - accuracy: 1.0000 - val_loss: 0.5605 - val_accuracy: 0.7500 - 56ms/epoch - 28ms/step
# Epoch 354/500
# 2/2 - 0s - loss: 0.1034 - accuracy: 1.0000 - val_loss: 0.4604 - val_accuracy: 0.7500 - 58ms/epoch - 29ms/step
# Epoch 355/500
# 2/2 - 0s - loss: 0.0860 - accuracy: 1.0000 - val_loss: 0.4688 - val_accuracy: 0.7500 - 58ms/epoch - 29ms/step
# Epoch 356/500
# 2/2 - 0s - loss: 0.0590 - accuracy: 1.0000 - val_loss: 0.5018 - val_accuracy: 0.7500 - 41ms/epoch - 21ms/step
# Epoch 357/500
# 2/2 - 0s - loss: 0.0662 - accuracy: 1.0000 - val_loss: 0.5680 - val_accuracy: 0.7500 - 64ms/epoch - 32ms/step
# Epoch 358/500
# 2/2 - 0s - loss: 0.0925 - accuracy: 1.0000 - val_loss: 0.5798 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 359/500
# 2/2 - 0s - loss: 0.0759 - accuracy: 1.0000 - val_loss: 0.5401 - val_accuracy: 0.7500 - 58ms/epoch - 29ms/step
# Epoch 360/500
# 2/2 - 0s - loss: 0.0917 - accuracy: 1.0000 - val_loss: 0.5466 - val_accuracy: 0.7500 - 59ms/epoch - 30ms/step
# Epoch 361/500
# 2/2 - 0s - loss: 0.0696 - accuracy: 1.0000 - val_loss: 0.5426 - val_accuracy: 0.7500 - 56ms/epoch - 28ms/step
# Epoch 362/500
# 2/2 - 0s - loss: 0.0792 - accuracy: 1.0000 - val_loss: 0.5386 - val_accuracy: 0.7500 - 57ms/epoch - 28ms/step
# Epoch 363/500
# 2/2 - 0s - loss: 0.0942 - accuracy: 1.0000 - val_loss: 0.5614 - val_accuracy: 0.7500 - 47ms/epoch - 23ms/step
# Epoch 364/500
# 2/2 - 0s - loss: 0.0798 - accuracy: 1.0000 - val_loss: 0.5652 - val_accuracy: 0.7500 - 41ms/epoch - 20ms/step
# Epoch 365/500
# 2/2 - 0s - loss: 0.0804 - accuracy: 1.0000 - val_loss: 0.6101 - val_accuracy: 0.7500 - 48ms/epoch - 24ms/step
# Epoch 366/500
# 2/2 - 0s - loss: 0.0790 - accuracy: 1.0000 - val_loss: 0.5637 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 367/500
# 2/2 - 0s - loss: 0.0941 - accuracy: 1.0000 - val_loss: 0.6304 - val_accuracy: 0.6667 - 56ms/epoch - 28ms/step
# Epoch 368/500
# 2/2 - 0s - loss: 0.0677 - accuracy: 1.0000 - val_loss: 0.6764 - val_accuracy: 0.6667 - 46ms/epoch - 23ms/step
# Epoch 369/500
# 2/2 - 0s - loss: 0.0743 - accuracy: 1.0000 - val_loss: 0.6159 - val_accuracy: 0.6667 - 62ms/epoch - 31ms/step
# Epoch 370/500
# 2/2 - 0s - loss: 0.0623 - accuracy: 1.0000 - val_loss: 0.5522 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 371/500
# 2/2 - 0s - loss: 0.0784 - accuracy: 1.0000 - val_loss: 0.5360 - val_accuracy: 0.7500 - 60ms/epoch - 30ms/step
# Epoch 372/500
# 2/2 - 0s - loss: 0.0638 - accuracy: 1.0000 - val_loss: 0.5691 - val_accuracy: 0.7500 - 65ms/epoch - 32ms/step
# Epoch 373/500
# 2/2 - 0s - loss: 0.0777 - accuracy: 1.0000 - val_loss: 0.6147 - val_accuracy: 0.7500 - 41ms/epoch - 21ms/step
# Epoch 374/500
# 2/2 - 0s - loss: 0.1186 - accuracy: 1.0000 - val_loss: 0.6286 - val_accuracy: 0.7500 - 60ms/epoch - 30ms/step
# Epoch 375/500
# 2/2 - 0s - loss: 0.1007 - accuracy: 1.0000 - val_loss: 0.4823 - val_accuracy: 0.7500 - 48ms/epoch - 24ms/step
# Epoch 376/500
# 2/2 - 0s - loss: 0.0646 - accuracy: 1.0000 - val_loss: 0.4361 - val_accuracy: 0.6667 - 44ms/epoch - 22ms/step
# Epoch 377/500
# 2/2 - 0s - loss: 0.0998 - accuracy: 1.0000 - val_loss: 0.4513 - val_accuracy: 0.8333 - 43ms/epoch - 22ms/step
# Epoch 378/500
# 2/2 - 0s - loss: 0.0928 - accuracy: 1.0000 - val_loss: 0.4403 - val_accuracy: 0.8333 - 42ms/epoch - 21ms/step
# Epoch 379/500
# 2/2 - 0s - loss: 0.0617 - accuracy: 1.0000 - val_loss: 0.5544 - val_accuracy: 0.7500 - 59ms/epoch - 29ms/step
# Epoch 380/500
# 2/2 - 0s - loss: 0.0804 - accuracy: 1.0000 - val_loss: 0.5975 - val_accuracy: 0.7500 - 50ms/epoch - 25ms/step
# Epoch 381/500
# 2/2 - 0s - loss: 0.0609 - accuracy: 1.0000 - val_loss: 0.6515 - val_accuracy: 0.7500 - 60ms/epoch - 30ms/step
# Epoch 382/500
# 2/2 - 0s - loss: 0.0687 - accuracy: 1.0000 - val_loss: 0.7016 - val_accuracy: 0.6667 - 42ms/epoch - 21ms/step
# Epoch 383/500
# 2/2 - 0s - loss: 0.0775 - accuracy: 1.0000 - val_loss: 0.6912 - val_accuracy: 0.6667 - 44ms/epoch - 22ms/step
# Epoch 384/500
# 2/2 - 0s - loss: 0.0647 - accuracy: 1.0000 - val_loss: 0.6884 - val_accuracy: 0.6667 - 66ms/epoch - 33ms/step
# Epoch 385/500
# 2/2 - 0s - loss: 0.0784 - accuracy: 1.0000 - val_loss: 0.6302 - val_accuracy: 0.7500 - 67ms/epoch - 34ms/step
# Epoch 386/500
# 2/2 - 0s - loss: 0.0592 - accuracy: 1.0000 - val_loss: 0.5311 - val_accuracy: 0.7500 - 42ms/epoch - 21ms/step
# Epoch 387/500
# 2/2 - 0s - loss: 0.0967 - accuracy: 1.0000 - val_loss: 0.4723 - val_accuracy: 0.7500 - 44ms/epoch - 22ms/step
# Epoch 388/500
# 2/2 - 0s - loss: 0.0785 - accuracy: 1.0000 - val_loss: 0.4932 - val_accuracy: 0.7500 - 46ms/epoch - 23ms/step
# ...
# 2/2 - 0s - loss: 0.0501 - accuracy: 1.0000 - val_loss: 1.4588 - val_accuracy: 0.5000 - 73ms/epoch - 36ms/step
# Epoch 374/500
# 2/2 - 0s - loss: 0.0333 - accuracy: 1.0000 - val_loss: 1.4548 - val_accuracy: 0.5000 - 71ms/epoch - 36ms/step
# Epoch 375/500
# 2/2 - 0s - loss: 0.0423 - accuracy: 1.0000 - val_loss: 1.4465 - val_accuracy: 0.5000 - 79ms/epoch - 39ms/step
# Epoch 376/500
# 2/2 - 0s - loss: 0.0483 - accuracy: 1.0000 - val_loss: 1.4411 - val_accuracy: 0.5000 - 73ms/epoch - 37ms/step
# Epoch 377/500
# 2/2 - 0s - loss: 0.0997 - accuracy: 1.0000 - val_loss: 1.4334 - val_accuracy: 0.5000 - 79ms/epoch - 40ms/step
# Epoch 378/500
# 2/2 - 0s - loss: 0.0393 - accuracy: 1.0000 - val_loss: 1.4289 - val_accuracy: 0.5000 - 73ms/epoch - 37ms/step
# Epoch 379/500
# 2/2 - 0s - loss: 0.0304 - accuracy: 1.0000 - val_loss: 1.4216 - val_accuracy: 0.5000 - 77ms/epoch - 39ms/step
# Epoch 380/500
# 2/2 - 0s - loss: 0.0342 - accuracy: 1.0000 - val_loss: 1.4164 - val_accuracy: 0.5000 - 81ms/epoch - 40ms/step
# Epoch 381/500
# 2/2 - 0s - loss: 0.0439 - accuracy: 1.0000 - val_loss: 1.4135 - val_accuracy: 0.5000 - 72ms/epoch - 36ms/step
# Epoch 382/500
# 2/2 - 0s - loss: 0.0370 - accuracy: 1.0000 - val_loss: 1.4109 - val_accuracy: 0.5000 - 79ms/epoch - 40ms/step
# Epoch 383/500
# 2/2 - 0s - loss: 0.0525 - accuracy: 1.0000 - val_loss: 1.4099 - val_accuracy: 0.5000 - 74ms/epoch - 37ms/step
# Epoch 384/500
# 2/2 - 0s - loss: 0.0509 - accuracy: 1.0000 - val_loss: 1.4116 - val_accuracy: 0.5000 - 81ms/epoch - 40ms/step
# Epoch 385/500
# 2/2 - 0s - loss: 0.0382 - accuracy: 1.0000 - val_loss: 1.4143 - val_accuracy: 0.5000 - 58ms/epoch - 29ms/step
# Epoch 386/500
# 2/2 - 0s - loss: 0.0380 - accuracy: 1.0000 - val_loss: 1.4122 - val_accuracy: 0.5000 - 68ms/epoch - 34ms/step
# Epoch 387/500
# 2/2 - 0s - loss: 0.0362 - accuracy: 1.0000 - val_loss: 1.4099 - val_accuracy: 0.5000 - 96ms/epoch - 48ms/step
# Epoch 388/500
# 2/2 - 0s - loss: 0.0626 - accuracy: 1.0000 - val_loss: 1.4027 - val_accuracy: 0.5000 - 70ms/epoch - 35ms/step
# Epoch 389/500
# 2/2 - 0s - loss: 0.0375 - accuracy: 1.0000 - val_loss: 1.4010 - val_accuracy: 0.5000 - 82ms/epoch - 41ms/step
# Epoch 390/500
# 2/2 - 0s - loss: 0.0601 - accuracy: 1.0000 - val_loss: 1.3990 - val_accuracy: 0.5000 - 89ms/epoch - 44ms/step
# Epoch 391/500
# 2/2 - 0s - loss: 0.0481 - accuracy: 1.0000 - val_loss: 1.3854 - val_accuracy: 0.5000 - 59ms/epoch - 30ms/step
# Epoch 392/500
# 2/2 - 0s - loss: 0.0486 - accuracy: 1.0000 - val_loss: 1.3851 - val_accuracy: 0.5000 - 55ms/epoch - 27ms/step
# Epoch 393/500
# 2/2 - 0s - loss: 0.0389 - accuracy: 1.0000 - val_loss: 1.3949 - val_accuracy: 0.5000 - 70ms/epoch - 35ms/step
# Epoch 394/500
# 2/2 - 0s - loss: 0.0456 - accuracy: 1.0000 - val_loss: 1.4035 - val_accuracy: 0.5000 - 74ms/epoch - 37ms/step
# Epoch 395/500
# 2/2 - 0s - loss: 0.0421 - accuracy: 1.0000 - val_loss: 1.4164 - val_accuracy: 0.5000 - 75ms/epoch - 37ms/step
# Epoch 396/500
# 2/2 - 0s - loss: 0.0441 - accuracy: 1.0000 - val_loss: 1.4341 - val_accuracy: 0.5000 - 87ms/epoch - 44ms/step
# Epoch 397/500
# 2/2 - 0s - loss: 0.0408 - accuracy: 1.0000 - val_loss: 1.4490 - val_accuracy: 0.5000 - 79ms/epoch - 40ms/step
# Epoch 398/500
# 2/2 - 0s - loss: 0.0451 - accuracy: 1.0000 - val_loss: 1.4550 - val_accuracy: 0.5000 - 75ms/epoch - 38ms/step
# Epoch 399/500
# 2/2 - 0s - loss: 0.0384 - accuracy: 1.0000 - val_loss: 1.4620 - val_accuracy: 0.5000 - 72ms/epoch - 36ms/step
# Epoch 400/500
# 2/2 - 0s - loss: 0.0459 - accuracy: 1.0000 - val_loss: 1.4592 - val_accuracy: 0.5000 - 86ms/epoch - 43ms/step
# Epoch 401/500
# 2/2 - 0s - loss: 0.0479 - accuracy: 1.0000 - val_loss: 1.4616 - val_accuracy: 0.5000 - 74ms/epoch - 37ms/step
# Epoch 402/500
# 2/2 - 0s - loss: 0.0387 - accuracy: 1.0000 - val_loss: 1.4667 - val_accuracy: 0.5000 - 60ms/epoch - 30ms/step
# Epoch 403/500
# 2/2 - 0s - loss: 0.0367 - accuracy: 1.0000 - val_loss: 1.4659 - val_accuracy: 0.5000 - 56ms/epoch - 28ms/step
# Epoch 404/500
# 2/2 - 0s - loss: 0.0528 - accuracy: 1.0000 - val_loss: 1.4531 - val_accuracy: 0.5000 - 72ms/epoch - 36ms/step
# Epoch 405/500
# 2/2 - 0s - loss: 0.0490 - accuracy: 1.0000 - val_loss: 1.4462 - val_accuracy: 0.5000 - 55ms/epoch - 28ms/step
# Epoch 406/500
# 2/2 - 0s - loss: 0.0344 - accuracy: 1.0000 - val_loss: 1.4345 - val_accuracy: 0.5000 - 74ms/epoch - 37ms/step
# Epoch 407/500
# 2/2 - 0s - loss: 0.0349 - accuracy: 1.0000 - val_loss: 1.4284 - val_accuracy: 0.5000 - 76ms/epoch - 38ms/step
# Epoch 408/500
# 2/2 - 0s - loss: 0.0314 - accuracy: 1.0000 - val_loss: 1.4300 - val_accuracy: 0.5000 - 86ms/epoch - 43ms/step
# Epoch 409/500
# 2/2 - 0s - loss: 0.0341 - accuracy: 1.0000 - val_loss: 1.4344 - val_accuracy: 0.5000 - 66ms/epoch - 33ms/step
# Epoch 410/500
# 2/2 - 0s - loss: 0.0376 - accuracy: 1.0000 - val_loss: 1.4380 - val_accuracy: 0.5000 - 75ms/epoch - 37ms/step
# Epoch 411/500
# 2/2 - 0s - loss: 0.0345 - accuracy: 1.0000 - val_loss: 1.4417 - val_accuracy: 0.5000 - 76ms/epoch - 38ms/step
# Epoch 412/500
# 2/2 - 0s - loss: 0.0417 - accuracy: 1.0000 - val_loss: 1.4407 - val_accuracy: 0.5000 - 79ms/epoch - 40ms/step
# Epoch 413/500
# 2/2 - 0s - loss: 0.0458 - accuracy: 1.0000 - val_loss: 1.4351 - val_accuracy: 0.5000 - 77ms/epoch - 38ms/step
# Epoch 414/500
# 2/2 - 0s - loss: 0.0369 - accuracy: 1.0000 - val_loss: 1.4292 - val_accuracy: 0.5000 - 94ms/epoch - 47ms/step
# Epoch 415/500
# 2/2 - 0s - loss: 0.0349 - accuracy: 1.0000 - val_loss: 1.4267 - val_accuracy: 0.5000 - 64ms/epoch - 32ms/step
# Epoch 416/500
# 2/2 - 0s - loss: 0.0310 - accuracy: 1.0000 - val_loss: 1.4294 - val_accuracy: 0.5000 - 77ms/epoch - 38ms/step
# Epoch 417/500
# 2/2 - 0s - loss: 0.0343 - accuracy: 1.0000 - val_loss: 1.4319 - val_accuracy: 0.5000 - 65ms/epoch - 32ms/step
# Epoch 418/500
# 2/2 - 0s - loss: 0.0328 - accuracy: 1.0000 - val_loss: 1.4326 - val_accuracy: 0.5000 - 71ms/epoch - 36ms/step
# Epoch 419/500
# 2/2 - 0s - loss: 0.0404 - accuracy: 1.0000 - val_loss: 1.4409 - val_accuracy: 0.5000 - 59ms/epoch - 30ms/step
# Epoch 420/500
# 2/2 - 0s - loss: 0.0344 - accuracy: 1.0000 - val_loss: 1.4462 - val_accuracy: 0.5000 - 48ms/epoch - 24ms/step
# Epoch 421/500
# 2/2 - 0s - loss: 0.0671 - accuracy: 1.0000 - val_loss: 1.4472 - val_accuracy: 0.5000 - 61ms/epoch - 30ms/step
# Epoch 422/500
# 2/2 - 0s - loss: 0.0409 - accuracy: 1.0000 - val_loss: 1.4486 - val_accuracy: 0.5000 - 47ms/epoch - 24ms/step
# Epoch 423/500
# 2/2 - 0s - loss: 0.0404 - accuracy: 1.0000 - val_loss: 1.4525 - val_accuracy: 0.5000 - 51ms/epoch - 25ms/step
# Epoch 424/500
# 2/2 - 0s - loss: 0.0346 - accuracy: 1.0000 - val_loss: 1.4576 - val_accuracy: 0.5000 - 65ms/epoch - 32ms/step
# Epoch 425/500
# 2/2 - 0s - loss: 0.0712 - accuracy: 1.0000 - val_loss: 1.4630 - val_accuracy: 0.5000 - 50ms/epoch - 25ms/step
# Epoch 426/500
# 2/2 - 0s - loss: 0.0701 - accuracy: 1.0000 - val_loss: 1.4636 - val_accuracy: 0.5000 - 64ms/epoch - 32ms/step
# Epoch 427/500
# 2/2 - 0s - loss: 0.0360 - accuracy: 1.0000 - val_loss: 1.4597 - val_accuracy: 0.5000 - 47ms/epoch - 24ms/step
# Epoch 428/500
# 2/2 - 0s - loss: 0.0531 - accuracy: 1.0000 - val_loss: 1.4518 - val_accuracy: 0.5000 - 56ms/epoch - 28ms/step
# Epoch 429/500
# 2/2 - 0s - loss: 0.0362 - accuracy: 1.0000 - val_loss: 1.4473 - val_accuracy: 0.5000 - 43ms/epoch - 22ms/step
# Epoch 430/500
# 2/2 - 0s - loss: 0.0381 - accuracy: 1.0000 - val_loss: 1.4488 - val_accuracy: 0.5000 - 47ms/epoch - 23ms/step
# Epoch 431/500
# 2/2 - 0s - loss: 0.0367 - accuracy: 1.0000 - val_loss: 1.4565 - val_accuracy: 0.5000 - 64ms/epoch - 32ms/step
# Epoch 432/500
# 2/2 - 0s - loss: 0.0613 - accuracy: 1.0000 - val_loss: 1.4627 - val_accuracy: 0.5000 - 49ms/epoch - 25ms/step
# Epoch 433/500
# 2/2 - 0s - loss: 0.0484 - accuracy: 1.0000 - val_loss: 1.4703 - val_accuracy: 0.5000 - 61ms/epoch - 31ms/step
# Epoch 434/500
# 2/2 - 0s - loss: 0.0356 - accuracy: 1.0000 - val_loss: 1.4744 - val_accuracy: 0.5000 - 47ms/epoch - 24ms/step
# Epoch 435/500
# 2/2 - 0s - loss: 0.0350 - accuracy: 1.0000 - val_loss: 1.4769 - val_accuracy: 0.5000 - 49ms/epoch - 24ms/step
# Epoch 436/500
# 2/2 - 0s - loss: 0.0299 - accuracy: 1.0000 - val_loss: 1.4779 - val_accuracy: 0.5000 - 70ms/epoch - 35ms/step
# Epoch 437/500
# 2/2 - 0s - loss: 0.0317 - accuracy: 1.0000 - val_loss: 1.4745 - val_accuracy: 0.5000 - 47ms/epoch - 23ms/step
# Epoch 438/500
# 2/2 - 0s - loss: 0.0836 - accuracy: 1.0000 - val_loss: 1.4695 - val_accuracy: 0.5000 - 64ms/epoch - 32ms/step
# Epoch 439/500
# 2/2 - 0s - loss: 0.0699 - accuracy: 1.0000 - val_loss: 1.4639 - val_accuracy: 0.5000 - 61ms/epoch - 30ms/step
# Epoch 440/500
# 2/2 - 0s - loss: 0.0337 - accuracy: 1.0000 - val_loss: 1.4609 - val_accuracy: 0.5000 - 63ms/epoch - 32ms/step
# Epoch 441/500
# 2/2 - 0s - loss: 0.0365 - accuracy: 1.0000 - val_loss: 1.4554 - val_accuracy: 0.5000 - 50ms/epoch - 25ms/step
# Epoch 442/500
# 2/2 - 0s - loss: 0.0526 - accuracy: 1.0000 - val_loss: 1.4501 - val_accuracy: 0.5000 - 47ms/epoch - 24ms/step
# Epoch 443/500
# 2/2 - 0s - loss: 0.0367 - accuracy: 1.0000 - val_loss: 1.4530 - val_accuracy: 0.5000 - 50ms/epoch - 25ms/step
# Epoch 444/500
# 2/2 - 0s - loss: 0.0366 - accuracy: 1.0000 - val_loss: 1.4548 - val_accuracy: 0.5000 - 53ms/epoch - 26ms/step
# Epoch 445/500
# 2/2 - 0s - loss: 0.0359 - accuracy: 1.0000 - val_loss: 1.4513 - val_accuracy: 0.5000 - 69ms/epoch - 34ms/step
# Epoch 446/500
# 2/2 - 0s - loss: 0.0334 - accuracy: 1.0000 - val_loss: 1.4472 - val_accuracy: 0.5000 - 71ms/epoch - 35ms/step
# Epoch 447/500
# 2/2 - 0s - loss: 0.0570 - accuracy: 1.0000 - val_loss: 1.4343 - val_accuracy: 0.5000 - 47ms/epoch - 24ms/step
# Epoch 448/500
# 2/2 - 0s - loss: 0.0378 - accuracy: 1.0000 - val_loss: 1.4167 - val_accuracy: 0.5000 - 45ms/epoch - 22ms/step
# Epoch 449/500
# 2/2 - 0s - loss: 0.0392 - accuracy: 1.0000 - val_loss: 1.4100 - val_accuracy: 0.5000 - 46ms/epoch - 23ms/step
# Epoch 450/500
# 2/2 - 0s - loss: 0.0330 - accuracy: 1.0000 - val_loss: 1.4116 - val_accuracy: 0.5000 - 49ms/epoch - 25ms/step
# Epoch 451/500
# 2/2 - 0s - loss: 0.0437 - accuracy: 1.0000 - val_loss: 1.4228 - val_accuracy: 0.5000 - 43ms/epoch - 22ms/step
# Epoch 452/500
# 2/2 - 0s - loss: 0.0340 - accuracy: 1.0000 - val_loss: 1.4385 - val_accuracy: 0.5000 - 50ms/epoch - 25ms/step
# Epoch 453/500
# 2/2 - 0s - loss: 0.0908 - accuracy: 1.0000 - val_loss: 1.4505 - val_accuracy: 0.5000 - 64ms/epoch - 32ms/step
# Epoch 454/500
# 2/2 - 0s - loss: 0.0358 - accuracy: 1.0000 - val_loss: 1.4578 - val_accuracy: 0.5000 - 64ms/epoch - 32ms/step
# Epoch 455/500
# 2/2 - 0s - loss: 0.0374 - accuracy: 1.0000 - val_loss: 1.4644 - val_accuracy: 0.5000 - 47ms/epoch - 24ms/step
# Epoch 456/500
# 2/2 - 0s - loss: 0.0352 - accuracy: 1.0000 - val_loss: 1.4675 - val_accuracy: 0.5000 - 66ms/epoch - 33ms/step
# Epoch 457/500
# 2/2 - 0s - loss: 0.0330 - accuracy: 1.0000 - val_loss: 1.4705 - val_accuracy: 0.5000 - 44ms/epoch - 22ms/step
# Epoch 458/500
# 2/2 - 0s - loss: 0.0319 - accuracy: 1.0000 - val_loss: 1.4771 - val_accuracy: 0.5000 - 45ms/epoch - 23ms/step
# Epoch 459/500
# 2/2 - 0s - loss: 0.0365 - accuracy: 1.0000 - val_loss: 1.4791 - val_accuracy: 0.5000 - 48ms/epoch - 24ms/step
# Epoch 460/500
# 2/2 - 0s - loss: 0.0334 - accuracy: 1.0000 - val_loss: 1.4799 - val_accuracy: 0.5000 - 47ms/epoch - 23ms/step
# Epoch 461/500
# 2/2 - 0s - loss: 0.0301 - accuracy: 1.0000 - val_loss: 1.4771 - val_accuracy: 0.5000 - 51ms/epoch - 25ms/step
# Epoch 462/500
# 2/2 - 0s - loss: 0.0342 - accuracy: 1.0000 - val_loss: 1.4744 - val_accuracy: 0.5000 - 80ms/epoch - 40ms/step
# Epoch 463/500
# 2/2 - 0s - loss: 0.0356 - accuracy: 1.0000 - val_loss: 1.4690 - val_accuracy: 0.5000 - 43ms/epoch - 22ms/step
# Epoch 464/500
# 2/2 - 0s - loss: 0.0345 - accuracy: 1.0000 - val_loss: 1.4621 - val_accuracy: 0.5000 - 46ms/epoch - 23ms/step
# Epoch 465/500
# 2/2 - 0s - loss: 0.0315 - accuracy: 1.0000 - val_loss: 1.4554 - val_accuracy: 0.5000 - 50ms/epoch - 25ms/step
# Epoch 466/500
# 2/2 - 0s - loss: 0.0329 - accuracy: 1.0000 - val_loss: 1.4570 - val_accuracy: 0.5000 - 48ms/epoch - 24ms/step
# Epoch 467/500
# 2/2 - 0s - loss: 0.0396 - accuracy: 1.0000 - val_loss: 1.4554 - val_accuracy: 0.5000 - 65ms/epoch - 33ms/step
# Epoch 468/500
# 2/2 - 0s - loss: 0.0468 - accuracy: 1.0000 - val_loss: 1.4601 - val_accuracy: 0.5000 - 66ms/epoch - 33ms/step
# Epoch 469/500
# 2/2 - 0s - loss: 0.0358 - accuracy: 1.0000 - val_loss: 1.4658 - val_accuracy: 0.5000 - 50ms/epoch - 25ms/step
# Epoch 470/500
# 2/2 - 0s - loss: 0.0307 - accuracy: 1.0000 - val_loss: 1.4671 - val_accuracy: 0.5000 - 46ms/epoch - 23ms/step
# Epoch 471/500
# 2/2 - 0s - loss: 0.0345 - accuracy: 1.0000 - val_loss: 1.4690 - val_accuracy: 0.5000 - 70ms/epoch - 35ms/step
# Epoch 472/500
# 2/2 - 0s - loss: 0.0322 - accuracy: 1.0000 - val_loss: 1.4764 - val_accuracy: 0.5000 - 62ms/epoch - 31ms/step
# Epoch 473/500
# 2/2 - 0s - loss: 0.0354 - accuracy: 1.0000 - val_loss: 1.4832 - val_accuracy: 0.5000 - 50ms/epoch - 25ms/step
# Epoch 474/500
# 2/2 - 0s - loss: 0.0357 - accuracy: 1.0000 - val_loss: 1.4888 - val_accuracy: 0.5000 - 46ms/epoch - 23ms/step
# Epoch 475/500
# 2/2 - 0s - loss: 0.0486 - accuracy: 1.0000 - val_loss: 1.4928 - val_accuracy: 0.5000 - 50ms/epoch - 25ms/step
# Epoch 476/500
# 2/2 - 0s - loss: 0.0369 - accuracy: 1.0000 - val_loss: 1.4954 - val_accuracy: 0.5000 - 52ms/epoch - 26ms/step
# Epoch 477/500
# 2/2 - 0s - loss: 0.0577 - accuracy: 1.0000 - val_loss: 1.4904 - val_accuracy: 0.5000 - 45ms/epoch - 23ms/step
# Epoch 478/500
# 2/2 - 0s - loss: 0.0326 - accuracy: 1.0000 - val_loss: 1.4812 - val_accuracy: 0.5000 - 62ms/epoch - 31ms/step
# Epoch 479/500
# 2/2 - 0s - loss: 0.0300 - accuracy: 1.0000 - val_loss: 1.4718 - val_accuracy: 0.5000 - 41ms/epoch - 20ms/step
# Epoch 480/500
# 2/2 - 0s - loss: 0.0392 - accuracy: 1.0000 - val_loss: 1.4696 - val_accuracy: 0.5000 - 48ms/epoch - 24ms/step
# Epoch 481/500
# 2/2 - 0s - loss: 0.0562 - accuracy: 1.0000 - val_loss: 1.4666 - val_accuracy: 0.5000 - 64ms/epoch - 32ms/step
# Epoch 482/500
# 2/2 - 0s - loss: 0.0570 - accuracy: 1.0000 - val_loss: 1.4681 - val_accuracy: 0.5000 - 63ms/epoch - 32ms/step
# Epoch 483/500
# 2/2 - 0s - loss: 0.0320 - accuracy: 1.0000 - val_loss: 1.4741 - val_accuracy: 0.5000 - 59ms/epoch - 30ms/step
# Epoch 484/500
# 2/2 - 0s - loss: 0.0304 - accuracy: 1.0000 - val_loss: 1.4797 - val_accuracy: 0.5000 - 44ms/epoch - 22ms/step
# Epoch 485/500
# 2/2 - 0s - loss: 0.0395 - accuracy: 1.0000 - val_loss: 1.4847 - val_accuracy: 0.5000 - 44ms/epoch - 22ms/step
# Epoch 486/500
# 2/2 - 0s - loss: 0.0359 - accuracy: 1.0000 - val_loss: 1.4879 - val_accuracy: 0.5000 - 45ms/epoch - 22ms/step
# Epoch 487/500
# 2/2 - 0s - loss: 0.0335 - accuracy: 1.0000 - val_loss: 1.4930 - val_accuracy: 0.5000 - 45ms/epoch - 23ms/step
# Epoch 488/500
# 2/2 - 0s - loss: 0.0384 - accuracy: 1.0000 - val_loss: 1.4920 - val_accuracy: 0.5000 - 62ms/epoch - 31ms/step
# Epoch 489/500
# 2/2 - 0s - loss: 0.0446 - accuracy: 1.0000 - val_loss: 1.4872 - val_accuracy: 0.5000 - 43ms/epoch - 21ms/step
# Epoch 490/500
# 2/2 - 0s - loss: 0.0460 - accuracy: 1.0000 - val_loss: 1.4820 - val_accuracy: 0.5000 - 45ms/epoch - 22ms/step
# Epoch 491/500
# 2/2 - 0s - loss: 0.0393 - accuracy: 1.0000 - val_loss: 1.4811 - val_accuracy: 0.5000 - 64ms/epoch - 32ms/step
# Epoch 492/500
# 2/2 - 0s - loss: 0.0418 - accuracy: 1.0000 - val_loss: 1.4845 - val_accuracy: 0.5000 - 45ms/epoch - 22ms/step
# Epoch 493/500
# 2/2 - 0s - loss: 0.0361 - accuracy: 1.0000 - val_loss: 1.4869 - val_accuracy: 0.5000 - 61ms/epoch - 31ms/step
# Epoch 494/500
# 2/2 - 0s - loss: 0.0401 - accuracy: 1.0000 - val_loss: 1.4986 - val_accuracy: 0.5000 - 59ms/epoch - 30ms/step
# Epoch 495/500
# 2/2 - 0s - loss: 0.0361 - accuracy: 1.0000 - val_loss: 1.5040 - val_accuracy: 0.5000 - 54ms/epoch - 27ms/step
# Epoch 496/500
# 2/2 - 0s - loss: 0.0565 - accuracy: 1.0000 - val_loss: 1.5105 - val_accuracy: 0.5000 - 45ms/epoch - 23ms/step
# Epoch 497/500
# 2/2 - 0s - loss: 0.0370 - accuracy: 1.0000 - val_loss: 1.5124 - val_accuracy: 0.5000 - 47ms/epoch - 23ms/step
# Epoch 498/500
# 2/2 - 0s - loss: 0.0305 - accuracy: 1.0000 - val_loss: 1.5153 - val_accuracy: 0.5000 - 46ms/epoch - 23ms/step
# Epoch 499/500
# 2/2 - 0s - loss: 0.0328 - accuracy: 1.0000 - val_loss: 1.5160 - val_accuracy: 0.5000 - 44ms/epoch - 22ms/step
# Epoch 500/500
# 2/2 - 0s - loss: 0.0440 - accuracy: 1.0000 - val_loss: 1.5213 - val_accuracy: 0.5000 - 58ms/epoch - 29ms/step
# 1/1 [==============================] - 0s 99ms/step
# Shallow Conv Net Accuracy Metrics
# Accuracy: 0.5
# F1 Score: 0.5714285714285714
